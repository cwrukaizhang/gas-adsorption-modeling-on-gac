# %%
import pandas as pd 
import numpy as np
import os

# %% [markdown]
# # comparing combined dataset with separate datasets

# %%
import pandas as pd
import numpy as np

def pred_dataset(file_names):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-02-01-2022.xlsx'),skiprows= 1 )
        
        temp_data = temp_data.dropna(axis=0,how = 'any',subset = ["BET",'Vt','Vmic','Vmeso'])
        temp_data = temp_data[temp_data['Pressure']>0.01]
        #temp_data = temp_data[temp_data['Vmic']<2]
        index = list(set(temp_data['Index'].values))
        print(len(index))
        test_index= np.random.choice(index,int(0.2*len(index)),replace=False)
        train_x = temp_data.loc[~temp_data['Index'].isin( test_index)]
        test_x = temp_data.loc[temp_data['Index'].isin(test_index)]
        
        train_df = pd.concat([train_df,train_x],axis=0)
        test_df = pd.concat([test_df,test_x],axis =0)
    return train_df,test_df

# %%
train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'])
# Out:
# 1535
# 676
# 276
# 31

# %% [markdown]
# # select some groups from the CO2 big dataset
# def small_dataset():
#     source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
#
#     temp_data = pd.read_excel(os.path.join(source_path,'CO2-01-10-2022.xlsx'),skiprows= 1 )
#
#     temp_data = temp_data.dropna(axis=0,how = 'any',subset = ["BET",'Vt',])
#     temp_data = temp_data[temp_data['Pressure']>0.01]
#     #temp_data = temp_data[temp_data['Vmic']<2]
#     index = list(set(temp_data['Index'].values))
#     print(len(index))
#     test_index= np.random.choice(index,394,replace=False)
#     test_x = temp_data.loc[temp_data['Index'].isin(test_index)]
#     test_x.to_excel(os.path.join(source_path,'CO2_small-01-10-2022.xlsx'),startrow =1)

# %% [markdown]
# # List of optmizable parameters for different models

# %%
#SVM
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
  
n_estimators = [50,100,120,150,180,200]

# define different models#('SVR',SVR(max_iter=10000)),
models = [
    #('DT',DecisionTreeRegressor(random_state=42)),\
     #('ADBR',AdaBoostRegressor(random_state=42)), 
    #("GBR",GradientBoostingRegressor(random_state=42)),\
    #('BG',BaggingRegressor(random_state=42,n_jobs=-1)),
    #('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
    #('RF',RandomForestRegressor(n_jobs=-1,random_state=42)),
   # ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
    #('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators = 200, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1)),\
    ('BGETR',BaggingRegressor(ExtraTreesRegressor(n_estimators = 180,random_state=42,n_jobs=6),random_state=42,n_jobs=-1))
    ]

# set search parameters grid for different models
para_grids = { #'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
    'DT':{'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2],'loss':['linear','square','exponential']},\
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'BG':{'n_estimators':[10,50,100]},\
    'ETR':{'n_estimators':n_estimators},\
    'RF':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,50],'learning_rate': [0.05,0.1,0.5,1],
    'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,30,50]},\
    'BGETR':{'n_estimators':[10]}
    }

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,groups,model,para_grid):

    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(model,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list):
    gas_list = ['total','CO2','CFCs','Methane','E&E'] #'total',
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []

    for gas in gas_list:
        
        if gas =='total':

            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index'].values
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            
            for model_name, model in model_list:

                
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])

                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))

            
        else:
            
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
           
            for model_name, model in model_list:

                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
    return result_total

# %%
feature_1 = ['V','S','L','BET','Vt','Temp(K)','Pressure']
feature_2 = ['V','S','L','BET','Vt',"Vmeso",'Temp(K)','Pressure']
feature_3 = ['V','S','L','BET','Vt',"Vmic",'Temp(K)','Pressure']
feature_4 = ['V','S','L','BET','Vt',"Vmic",'Vmeso','Temp(K)','Pressure']
feature_5 = ['V','S','L','BET',"Vmic",'Vmeso','Temp(K)','Pressure']
feature_list = [feature_1,feature_2,feature_3,feature_4,feature_5]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ['Total',"Meso","Micro",'All','Vmic_meso']
for i in range(10):
    train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'])
    #train_df.to_csv(os.path.join('./Splitted_data/',str(i)+'_train_df.csv'))
    #test_df.to_csv(os.path.join('./Splitted_data/',str(i)+'_test_df.csv'))
    for j in range(5):
        results = model_comparison(models,para_grids, feature_list[j])
        files_name = 'BG_ETR_Full_Four_gases_with_pred_Vmic_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./',files_name))  
        #pd.DataFrame(results,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))

# %% [markdown]
# # Testing optmization with smaller sample size for carbon dioxide (CO2)

# %%
#SVM
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
  
n_estimators = [50,100,150,200,250,300]

# define different models#('SVR',SVR(max_iter=10000)),
models = [#('DT',DecisionTreeRegressor(random_state=42)),\
     #('ADBR',AdaBoostRegressor(random_state=42)), ("GBR",GradientBoostingRegressor(random_state=42)),\
        ('BG',BaggingRegressor(random_state=42,n_jobs=-1)), ('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
        ('RF',RandomForestRegressor(n_jobs=-1,random_state=42)), ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
            ('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators=300, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1))]

# set search parameters grid for different models
para_grids = { #'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
   'DT':{'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2],'loss':['linear','square','exponential']},\
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'BG':{'n_estimators':[10,50,100]},\
    'ETR':{'n_estimators':n_estimators},\
    'RF':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,40,50,60],'learning_rate': [0.01,0.05,0.1,0.5,1],
    'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,50,100]}
    }

# %%
# read data and reduce the dataset size
def small(file_name,selected_group):
    temp = pd.read_csv(file_name)
    CO2_data = temp[temp['Label']=='CO2']
    Other_data = temp[temp['Label']!='CO2']
    CO2_index = list(set(CO2_data['Index'].values))
    selec_index = np.random.choice(CO2_index,selected_group,replace = False)
    CO2_select = CO2_data[CO2_data['Index'].isin(selec_index)]
    return pd.concat([Other_data,CO2_select],axis = 0)
# the same dataset except smaller CO2
feature_1 = ['V','S','L','BET','Vt','Temp(K)','Pressure']
feature_2 = ['V','S','L','BET',"Vmeso",'Vt','Temp(K)','Pressure']
feature_3 = ['V','S','L','BET',"Vmic",'Vt','Temp(K)','Pressure']
feature_4 = ['V','S','L','BET',"Vmic",'Vt','Vmeso','Temp(K)','Pressure']
feature_list = [feature_1,feature_2,feature_3,feature_4]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ['Total',"Meso","Micro",'All']
for i in range(5):

    train_df  = small(os.path.join('./Splitted_data/',str(i)+'_train_df.csv'),316)
    test_df = pd.read_csv(os.path.join('./Splitted_data/',str(i)+'_test_df.csv'))
    #train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'])
    train_df.to_csv(os.path.join('./Splitted_data/',str(i)+'_small_train_df.csv'))
    #test_df.to_csv(os.path.join('./Splitted_data/',str(i)+'_test_df.csv'))
    for j in range(1):
        results = model_comparison(models,para_grids, feature_list[j])
        files_name = 'Small_CO2_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./',files_name))  
        #pd.DataFrame(results,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))

# %% [markdown]
# # Using pipeline with scaling

# %%
# Pipeline version
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
  
n_estimators = [50,100,120,150,180,200]

# define different models#('SVR',SVR(max_iter=10000)),
models = [('DT',DecisionTreeRegressor(random_state=42)),
     ('ADBR',AdaBoostRegressor(random_state=42)), ("GBR",GradientBoostingRegressor(random_state=42)),\
        ('BG',BaggingRegressor(random_state=42,n_jobs=-1)), ('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
        ('RF',RandomForestRegressor(n_jobs=-1,random_state=42)), ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42))]

# set search parameters grid for different models
para_grids = { #'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
   'DT':{'DT__criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'ADBR__n_estimators':n_estimators,'ADBR__learning_rate':[0.1,0.5,1,2],'ADBR__loss':['linear','square','exponential']},\
    'GBR':{'GBR__n_estimators':n_estimators,'GBR__learning_rate':[0.1,0.5,1,2]},\
    'BG':{'BG__n_estimators':[10,50,100]},\
    'ETR':{'ETR__n_estimators':n_estimators},\
    'RF':{'RF__n_estimators':n_estimators},\
    'LGBM':{'LGBM__num_leaves':[10,20,30,40,50,60],'LGBM__learning_rate': [0.01,0.05,0.1,0.5,1],
    'LGBM__n_estimators':n_estimators}
    }

# %%
#Pipeline version
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle
#new codes
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler

def para_convert(results,model_name):
    best = results.best_params_
    keys = list(results.best_params_.keys())
    new_keys = {key[len(model_name)+2:]:best[key] for key in keys}
    return new_keys


def model_CV(train_x,train_y,groups,model,model_name,para_grid):
    #new codes
    scaler = StandardScaler()
    pipe = Pipeline(steps = [('scaler',scaler),(model_name,model)])
    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(pipe,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)

    best_params = para_convert(result,model_name)
    
    #model_refit =model.set_params(**result.best_params_)
    model_refit = model.set_params(**best_params)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv], best_params

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list):
    gas_list = ['total','CO2','CFCs','Methane','E&E']
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []

    for gas in gas_list:
        
        if gas =='total':

            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index'].values
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            
            for model_name, model in model_list:

                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,model_name,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:

                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])

                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))

            
        else:
            
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
           
            for model_name, model in model_list:

                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,model_name,para_grids[model_name])
                
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
    return result_total

# %%
feature_1 = ['V','S','L','BET','Vt','Temp(K)','Pressure']
feature_2 = ['V','S','L','BET',"Vmeso",'Vt','Temp(K)','Pressure']
feature_3 = ['V','S','L','BET',"Vmic",'Vt','Temp(K)','Pressure']
feature_4 = ['V','S','L','BET',"Vmic",'Vt','Vmeso','Temp(K)','Pressure']
feature_list = [feature_1,feature_2,feature_3,feature_4]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ['Total',"Meso","Micro",'All'] 
for i in range(10):
    train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'])
    for j in range(4):
        results = model_comparison(models,para_grids, feature_list[j])
        files_name = 'With_scaling_Four gases_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./',files_name))  
        #pd.DataFrame(results,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))
# Out:
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.8735793799313649, Test_error 1.2530892340955515
# Dataset total, Algorithm DT_total, Test_r2 0.7315368017371896, Test_error 2.6555294364733895
# Dataset total, Algorithm DT_total, Test_r2 0.8384345474573228, Test_error 1.6750248602104658
# Dataset total, Algorithm DT_total, Test_r2 0.8250677577186132, Test_error 1.2729875579693222
# Dataset total, Algorithm ADBR_total, Test_r2 0.44240391120032085, Test_error 3.094082533690495
# Dataset total, Algorithm ADBR_total, Test_r2 -0.058839078948979884, Test_error 4.595329248873996
# Dataset total, Algorithm ADBR_total, Test_r2 0.16280779439460968, Test_error 6.406808481220521
# Dataset total, Algorithm ADBR_total, Test_r2 0.01571660608578318, Test_error 3.132020678980291
# Dataset total, Algorithm GBR_total, Test_r2 0.9152535726972966, Test_error 0.8585778585913404
# Dataset total, Algorithm GBR_total, Test_r2 0.930316597271265, Test_error 0.7769138989629911
# Dataset total, Algorithm GBR_total, Test_r2 0.877810614330383, Test_error 1.244001855088135
# Dataset total, Algorithm GBR_total, Test_r2 0.9313505819437484, Test_error 0.520284764837448
# Dataset total, Algorithm BG_total, Test_r2 0.9141679034934846, Test_error 0.8387603664695198
# Dataset total, Algorithm BG_total, Test_r2 0.8307499203695794, Test_error 1.579298811927174
# Dataset total, Algorithm BG_total, Test_r2 0.9035964251823829, Test_error 0.8950229801021543
# Dataset total, Algorithm BG_total, Test_r2 0.8933366536137884, Test_error 0.7722389242844839
# Dataset total, Algorithm ETR_total, Test_r2 0.910759732347007, Test_error 0.8546595742026782
# Dataset total, Algorithm ETR_total, Test_r2 0.8366507917506047, Test_error 1.5077446703836261
# Dataset total, Algorithm ETR_total, Test_r2 0.9010791159710985, Test_error 0.9173959572993019
# Dataset total, Algorithm ETR_total, Test_r2 0.9140902582749262, Test_error 0.609432693523185
# Dataset total, Algorithm RF_total, Test_r2 0.9143081482086106, Test_error 0.8378100827832848
# Dataset total, Algorithm RF_total, Test_r2 0.8355189937091055, Test_error 1.5419654351061476
# Dataset total, Algorithm RF_total, Test_r2 0.9043485806959763, Test_error 0.887623183984786
# Dataset total, Algorithm RF_total, Test_r2 0.8913992031074877, Test_error 0.7899648503730112
# Dataset total, Algorithm LGBM_total, Test_r2 0.9235559993134327, Test_error 0.7846931396429272
# Dataset total, Algorithm LGBM_total, Test_r2 0.972732583238584, Test_error 0.4199882131687451
# Dataset total, Algorithm LGBM_total, Test_r2 0.9023537815673596, Test_error 0.9520116366219159
# Dataset total, Algorithm LGBM_total, Test_r2 0.9457526247957955, Test_error 0.4057868364601916
# Dataset total, Algorithm DT_total, Test_r2 0.8684059152507049, Test_error 1.4192620139354248
# Dataset total, Algorithm DT_total, Test_r2 0.7697007306074366, Test_error 2.3855426562850166
# Dataset total, Algorithm DT_total, Test_r2 0.8586612636519205, Test_error 1.3984203627266367
# Dataset total, Algorithm DT_total, Test_r2 0.8261032655615763, Test_error 1.2712354715423448
# Dataset total, Algorithm ADBR_total, Test_r2 0.39450334359935135, Test_error 3.1829944482411956
# Dataset total, Algorithm ADBR_total, Test_r2 -0.2265251511871973, Test_error 4.890039058205601
# Dataset total, Algorithm ADBR_total, Test_r2 0.16928097870139858, Test_error 6.28353722757148
# Dataset total, Algorithm ADBR_total, Test_r2 0.011854892517456306, Test_error 3.293219758968834
# Dataset total, Algorithm GBR_total, Test_r2 0.9197792177875106, Test_error 0.8081280304110513
# Dataset total, Algorithm GBR_total, Test_r2 0.9144367018041591, Test_error 0.9333629486153078
# Dataset total, Algorithm GBR_total, Test_r2 0.8942197687687369, Test_error 1.0958266507993308
# Dataset total, Algorithm GBR_total, Test_r2 0.9135735357803025, Test_error 0.6181218309322105
# Dataset total, Algorithm BG_total, Test_r2 0.9129440648481683, Test_error 0.8733328223915543
# Dataset total, Algorithm BG_total, Test_r2 0.7770991693067664, Test_error 1.8927751080752506
# Dataset total, Algorithm BG_total, Test_r2 0.9122500872771391, Test_error 0.8038766082283374
# Dataset total, Algorithm BG_total, Test_r2 0.8933855740939364, Test_error 0.7771480174691975
# Dataset total, Algorithm ETR_total, Test_r2 0.9101440936322307, Test_error 0.8536782819008546
# Dataset total, Algorithm ETR_total, Test_r2 0.8690966794895438, Test_error 1.2757652859646147
# Dataset total, Algorithm ETR_total, Test_r2 0.9153093414066636, Test_error 0.7874920096942667
# Dataset total, Algorithm ETR_total, Test_r2 0.9184887270804187, Test_error 0.5787056464318655
# Dataset total, Algorithm RF_total, Test_r2 0.9114369849808275, Test_error 0.8866409805009905
# Dataset total, Algorithm RF_total, Test_r2 0.7901425792177618, Test_error 1.813431851867261
# Dataset total, Algorithm RF_total, Test_r2 0.9138181860464097, Test_error 0.7922262154610712
# Dataset total, Algorithm RF_total, Test_r2 0.891077072833653, Test_error 0.7935221612166001
# Dataset total, Algorithm LGBM_total, Test_r2 0.9204418942815262, Test_error 0.8129233074001582
# Dataset total, Algorithm LGBM_total, Test_r2 0.9394656323456133, Test_error 0.7288553006863067
# Dataset total, Algorithm LGBM_total, Test_r2 0.9095122031533337, Test_error 0.9439910164744262
# Dataset total, Algorithm LGBM_total, Test_r2 0.9391547990971554, Test_error 0.46622679962959224
# Dataset total, Algorithm DT_total, Test_r2 0.8617464616752684, Test_error 1.4467545900291259
# Dataset total, Algorithm DT_total, Test_r2 0.7952259282389247, Test_error 2.083967450885796
# Dataset total, Algorithm DT_total, Test_r2 0.8389633166898238, Test_error 1.7054663726551667
# Dataset total, Algorithm DT_total, Test_r2 0.8509536611879689, Test_error 1.0903567971458124
# Dataset total, Algorithm ADBR_total, Test_r2 0.428643391717092, Test_error 3.134043406732102
# Dataset total, Algorithm ADBR_total, Test_r2 -0.3202546117337359, Test_error 5.060972129761663
# Dataset total, Algorithm ADBR_total, Test_r2 0.20996467715150202, Test_error 6.070683499376292
# Dataset total, Algorithm ADBR_total, Test_r2 0.05953301479408635, Test_error 3.3760069226483695
# Dataset total, Algorithm GBR_total, Test_r2 0.9164172081372666, Test_error 0.8288225779434565
# Dataset total, Algorithm GBR_total, Test_r2 0.9467582677192815, Test_error 0.6297216468070567
# Dataset total, Algorithm GBR_total, Test_r2 0.8818307509994731, Test_error 1.25790372369656
# Dataset total, Algorithm GBR_total, Test_r2 0.9068518254754919, Test_error 0.6869226049997844
# Dataset total, Algorithm BG_total, Test_r2 0.9082464895039145, Test_error 0.9064709459265853
# Dataset total, Algorithm BG_total, Test_r2 0.836355482494692, Test_error 1.4921315507607882
# Dataset total, Algorithm BG_total, Test_r2 0.9182982912301929, Test_error 0.7589759399961176
# Dataset total, Algorithm BG_total, Test_r2 0.9028465144792385, Test_error 0.7042180947211657
# Dataset total, Algorithm ETR_total, Test_r2 0.9124830010091725, Test_error 0.8320409673986577
# Dataset total, Algorithm ETR_total, Test_r2 0.8482403573622499, Test_error 1.395405764312735
# Dataset total, Algorithm ETR_total, Test_r2 0.9226127668041695, Test_error 0.7204933314512559
# Dataset total, Algorithm ETR_total, Test_r2 0.9200274799449377, Test_error 0.5706038002677538
# Dataset total, Algorithm RF_total, Test_r2 0.9080880806950568, Test_error 0.9092585289676066
# Dataset total, Algorithm RF_total, Test_r2 0.83309977919536, Test_error 1.5104249742714275
# Dataset total, Algorithm RF_total, Test_r2 0.9180715868672077, Test_error 0.763549604842779
# Dataset total, Algorithm RF_total, Test_r2 0.9017546422104561, Test_error 0.7131664018888217
# Dataset total, Algorithm LGBM_total, Test_r2 0.92785682160366, Test_error 0.7228681791255032
# Dataset total, Algorithm LGBM_total, Test_r2 0.9636528449442568, Test_error 0.4757509336659958
# Dataset total, Algorithm LGBM_total, Test_r2 0.9115891114194762, Test_error 0.9293847301325572
# Dataset total, Algorithm LGBM_total, Test_r2 0.9385901173851088, Test_error 0.4600950393415277
# Dataset total, Algorithm DT_total, Test_r2 0.8637385223390371, Test_error 1.4959485130927903
# Dataset total, Algorithm DT_total, Test_r2 0.7974303655718963, Test_error 2.072799923123795
# Dataset total, Algorithm DT_total, Test_r2 0.8643821313352306, Test_error 1.4227279890759348
# Dataset total, Algorithm DT_total, Test_r2 0.8361881561991976, Test_error 1.192598751107871
# Dataset total, Algorithm ADBR_total, Test_r2 0.4159804348641537, Test_error 3.1130627767336145
# Dataset total, Algorithm ADBR_total, Test_r2 -0.1776800523974411, Test_error 4.8038105999059635
# Dataset total, Algorithm ADBR_total, Test_r2 0.16683617198815281, Test_error 6.217698066350719
# Dataset total, Algorithm ADBR_total, Test_r2 0.06084530689319945, Test_error 3.1663457960365418
# Dataset total, Algorithm GBR_total, Test_r2 0.9188573098438557, Test_error 0.8263427091405791
# Dataset total, Algorithm GBR_total, Test_r2 0.9020001196275949, Test_error 1.067486462601347
# Dataset total, Algorithm GBR_total, Test_r2 0.8843815039725443, Test_error 1.2155049809795713
# Dataset total, Algorithm GBR_total, Test_r2 0.8979064423289043, Test_error 0.7268152015468595
# Dataset total, Algorithm BG_total, Test_r2 0.9095600990125695, Test_error 0.9061967854232349
# Dataset total, Algorithm BG_total, Test_r2 0.8213638554067468, Test_error 1.584676912404119
# Dataset total, Algorithm BG_total, Test_r2 0.9198087898040442, Test_error 0.7408548996381938
# Dataset total, Algorithm BG_total, Test_r2 0.900130961567122, Test_error 0.7318346696049204
# Dataset total, Algorithm ETR_total, Test_r2 0.9092392989622035, Test_error 0.8600970196577484
# Dataset total, Algorithm ETR_total, Test_r2 0.8640679979620534, Test_error 1.3025426889546987
# Dataset total, Algorithm ETR_total, Test_r2 0.9245733508545595, Test_error 0.6959843350382056
# Dataset total, Algorithm ETR_total, Test_r2 0.9226900219275436, Test_error 0.5483465812291736
# Dataset total, Algorithm RF_total, Test_r2 0.9089127613956814, Test_error 0.9136416803280558
# Dataset total, Algorithm RF_total, Test_r2 0.8004444555491657, Test_error 1.7191459135965432
# Dataset total, Algorithm RF_total, Test_r2 0.9206615055706273, Test_error 0.7335363454794936
# Dataset total, Algorithm RF_total, Test_r2 0.9024572527492287, Test_error 0.7115836715067915
# Dataset total, Algorithm LGBM_total, Test_r2 0.9227411986826457, Test_error 0.7762708304966521
# Dataset total, Algorithm LGBM_total, Test_r2 0.9383014854754856, Test_error 0.7338012664238172
# Dataset total, Algorithm LGBM_total, Test_r2 0.9131597426721808, Test_error 0.9239443802001158
# Dataset total, Algorithm LGBM_total, Test_r2 0.9443763821759981, Test_error 0.4276082740963144
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.9016722607192064, Test_error 1.4321822814130454
# Dataset total, Algorithm DT_total, Test_r2 0.8206905644179961, Test_error 0.7520717436590875
# Dataset total, Algorithm DT_total, Test_r2 0.8283622497023994, Test_error 2.3640689978536367
# Dataset total, Algorithm DT_total, Test_r2 0.891073316808717, Test_error 0.9420184172790858
# Dataset total, Algorithm ADBR_total, Test_r2 0.6650618819305244, Test_error 3.1608729598773277
# Dataset total, Algorithm ADBR_total, Test_r2 0.5679398778934505, Test_error 1.4990370421656671
# Dataset total, Algorithm ADBR_total, Test_r2 0.46844322216152634, Test_error 5.499266842622628
# Dataset total, Algorithm ADBR_total, Test_r2 -0.6933142940520103, Test_error 5.4447730469186455
# Dataset total, Algorithm GBR_total, Test_r2 0.9421031037346447, Test_error 0.8660857132119658
# Dataset total, Algorithm GBR_total, Test_r2 0.9217643390099701, Test_error 0.30727805126751817
# Dataset total, Algorithm GBR_total, Test_r2 0.8681381139593836, Test_error 1.4829985749419112
# Dataset total, Algorithm GBR_total, Test_r2 0.9265897806846305, Test_error 0.6507729348184149
# Dataset total, Algorithm BG_total, Test_r2 0.9342396141644075, Test_error 0.9190046901983023
# Dataset total, Algorithm BG_total, Test_r2 0.9265688867666784, Test_error 0.27527608764311545
# Dataset total, Algorithm BG_total, Test_r2 0.903976777224215, Test_error 1.1464505458125536
# Dataset total, Algorithm BG_total, Test_r2 0.9342295127791687, Test_error 0.5420287075805154
# Dataset total, Algorithm ETR_total, Test_r2 0.9338800140413838, Test_error 0.953828696180821
# Dataset total, Algorithm ETR_total, Test_r2 0.9443044495657926, Test_error 0.19021414707236364
# Dataset total, Algorithm ETR_total, Test_r2 0.9189230148367347, Test_error 0.9621415826691767
# Dataset total, Algorithm ETR_total, Test_r2 0.9472502465801919, Test_error 0.4478792849720262
# Dataset total, Algorithm RF_total, Test_r2 0.9345123515384814, Test_error 0.9164364893531988
# Dataset total, Algorithm RF_total, Test_r2 0.9333940244172226, Test_error 0.25003479520277405
# Dataset total, Algorithm RF_total, Test_r2 0.9040804624041815, Test_error 1.1444660511944875
# Dataset total, Algorithm RF_total, Test_r2 0.9339063263797687, Test_error 0.545195250157348
# Dataset total, Algorithm LGBM_total, Test_r2 0.9507632064401109, Test_error 0.7299606788309995
# Dataset total, Algorithm LGBM_total, Test_r2 0.9177047252802407, Test_error 0.32983078139114985
# Dataset total, Algorithm LGBM_total, Test_r2 0.9074718597485559, Test_error 1.1737822689348245
# Dataset total, Algorithm LGBM_total, Test_r2 0.963644707580895, Test_error 0.3273003378868815
# Dataset total, Algorithm DT_total, Test_r2 0.8987609163637091, Test_error 1.4893507532670456
# Dataset total, Algorithm DT_total, Test_r2 0.8144611675580379, Test_error 0.8105931829799338
# Dataset total, Algorithm DT_total, Test_r2 0.8316414260582672, Test_error 2.2429948187881377
# Dataset total, Algorithm DT_total, Test_r2 0.904173796308406, Test_error 0.8220426310410619
# Dataset total, Algorithm ADBR_total, Test_r2 0.6443132841605941, Test_error 3.2329388899909084
# Dataset total, Algorithm ADBR_total, Test_r2 0.5752353501151943, Test_error 1.4104988197958965
# Dataset total, Algorithm ADBR_total, Test_r2 0.44243300249790696, Test_error 5.173530624075871
# Dataset total, Algorithm ADBR_total, Test_r2 -0.7355161927441951, Test_error 5.5451566749996735
# Dataset total, Algorithm GBR_total, Test_r2 0.9390177917157937, Test_error 0.9024880047639828
# Dataset total, Algorithm GBR_total, Test_r2 0.8962508631468458, Test_error 0.4527728651288891
# Dataset total, Algorithm GBR_total, Test_r2 0.8916124792314583, Test_error 1.2495786210670556
# Dataset total, Algorithm GBR_total, Test_r2 0.9306259033074273, Test_error 0.6152406442066013
# Dataset total, Algorithm BG_total, Test_r2 0.9385328843106727, Test_error 0.8596293462706842
# Dataset total, Algorithm BG_total, Test_r2 0.9203165979058159, Test_error 0.3101341249487872
# Dataset total, Algorithm BG_total, Test_r2 0.9166663456372988, Test_error 0.9884766171863841
# Dataset total, Algorithm BG_total, Test_r2 0.9418208325564188, Test_error 0.47733384468238244
# Dataset total, Algorithm ETR_total, Test_r2 0.9395592879672173, Test_error 0.8639865861101425
# Dataset total, Algorithm ETR_total, Test_r2 0.9457428001544743, Test_error 0.18514075630422266
# Dataset total, Algorithm ETR_total, Test_r2 0.9303357046547664, Test_error 0.8235481092934612
# Dataset total, Algorithm ETR_total, Test_r2 0.9522543654052741, Test_error 0.40663332886583115
# Dataset total, Algorithm RF_total, Test_r2 0.9381561462924498, Test_error 0.8648514660949382
# Dataset total, Algorithm RF_total, Test_r2 0.9276426852991075, Test_error 0.2820290264162817
# Dataset total, Algorithm RF_total, Test_r2 0.918125511093598, Test_error 0.970886786028033
# Dataset total, Algorithm RF_total, Test_r2 0.9420029435186262, Test_error 0.4766488336924096
# Dataset total, Algorithm LGBM_total, Test_r2 0.9546161179028891, Test_error 0.6604036904523043
# Dataset total, Algorithm LGBM_total, Test_r2 0.9518061096729954, Test_error 0.16271915327680533
# Dataset total, Algorithm LGBM_total, Test_r2 0.9148705384335175, Test_error 1.059701612142889
# Dataset total, Algorithm LGBM_total, Test_r2 0.9606797530762605, Test_error 0.3464769001783725
# Dataset total, Algorithm DT_total, Test_r2 0.8949967018571238, Test_error 1.5225232431027602
# Dataset total, Algorithm DT_total, Test_r2 0.8304816917787026, Test_error 0.7073787942466382
# Dataset total, Algorithm DT_total, Test_r2 0.8766482507505415, Test_error 1.5169360876584446
# Dataset total, Algorithm DT_total, Test_r2 0.9244233484293891, Test_error 0.6838869841638534
# Dataset total, Algorithm ADBR_total, Test_r2 0.653469818519197, Test_error 3.1864999743067437
# Dataset total, Algorithm ADBR_total, Test_r2 0.5807089057227776, Test_error 1.4277245640560154
# Dataset total, Algorithm ADBR_total, Test_r2 0.47149984608959494, Test_error 5.564006372770188
# Dataset total, Algorithm ADBR_total, Test_r2 -0.6463178579998117, Test_error 5.4154576330329816
# Dataset total, Algorithm GBR_total, Test_r2 0.9378873273186548, Test_error 0.8778821802518019
# Dataset total, Algorithm GBR_total, Test_r2 0.9569446368085829, Test_error 0.15273972643799857
# Dataset total, Algorithm GBR_total, Test_r2 0.8930838507200467, Test_error 1.3040255295140102
# Dataset total, Algorithm GBR_total, Test_r2 0.9368937484465139, Test_error 0.5576178871310546
# Dataset total, Algorithm BG_total, Test_r2 0.9365175577302027, Test_error 0.8934816760108489
# Dataset total, Algorithm BG_total, Test_r2 0.9123407121020303, Test_error 0.31928351642985625
# Dataset total, Algorithm BG_total, Test_r2 0.9158471551339613, Test_error 0.9876693503754641
# Dataset total, Algorithm BG_total, Test_r2 0.9478558214610208, Test_error 0.43619646513587795
# Dataset total, Algorithm ETR_total, Test_r2 0.9415080705038796, Test_error 0.8435397329607741
# Dataset total, Algorithm ETR_total, Test_r2 0.9312416426221264, Test_error 0.24509343868040512
# Dataset total, Algorithm ETR_total, Test_r2 0.9256603265092667, Test_error 0.8562200950032652
# Dataset total, Algorithm ETR_total, Test_r2 0.9570753615520012, Test_error 0.3636836112324434
# Dataset total, Algorithm RF_total, Test_r2 0.936492276256669, Test_error 0.8936822932586695
# Dataset total, Algorithm RF_total, Test_r2 0.9177426985146484, Test_error 0.29132292823339256
# Dataset total, Algorithm RF_total, Test_r2 0.9145971089242722, Test_error 1.0017758833831498
# Dataset total, Algorithm RF_total, Test_r2 0.9464831900071016, Test_error 0.44784636126887933
# Dataset total, Algorithm LGBM_total, Test_r2 0.9565055907079736, Test_error 0.6334244220925885
# Dataset total, Algorithm LGBM_total, Test_r2 0.7184411946173719, Test_error 1.118799866849876
# Dataset total, Algorithm LGBM_total, Test_r2 0.9191940172278913, Test_error 0.9906004108251054
# Dataset total, Algorithm LGBM_total, Test_r2 0.9674337844250047, Test_error 0.3049695256575814
# Dataset total, Algorithm DT_total, Test_r2 0.894231152798533, Test_error 1.56875617816711
# Dataset total, Algorithm DT_total, Test_r2 0.78915614659013, Test_error 0.9088001844165531
# Dataset total, Algorithm DT_total, Test_r2 0.8732568520752604, Test_error 1.632108196021102
# Dataset total, Algorithm DT_total, Test_r2 0.9186182099411929, Test_error 0.7036761050339958
# Dataset total, Algorithm ADBR_total, Test_r2 0.6680936925855248, Test_error 3.117909240938599
# Dataset total, Algorithm ADBR_total, Test_r2 0.576715174198153, Test_error 1.4143334076512868
# Dataset total, Algorithm ADBR_total, Test_r2 0.45748222207490064, Test_error 5.362952097518871
# Dataset total, Algorithm ADBR_total, Test_r2 -0.6946424441027219, Test_error 5.352370362641091
# Dataset total, Algorithm GBR_total, Test_r2 0.9369483764574428, Test_error 0.891893406614166
# Dataset total, Algorithm GBR_total, Test_r2 0.9485757877477101, Test_error 0.15961168371765036
# Dataset total, Algorithm GBR_total, Test_r2 0.9003239930070099, Test_error 1.2480369050605904
# Dataset total, Algorithm GBR_total, Test_r2 0.9321915791413931, Test_error 0.572475930899498
# Dataset total, Algorithm BG_total, Test_r2 0.9377723556402747, Test_error 0.8737777457717072
# Dataset total, Algorithm BG_total, Test_r2 0.9122502326855165, Test_error 0.3264316462711926
# Dataset total, Algorithm BG_total, Test_r2 0.9192889560867767, Test_error 0.948723502171407
# Dataset total, Algorithm BG_total, Test_r2 0.9471552053564891, Test_error 0.43694835333556475
# Dataset total, Algorithm ETR_total, Test_r2 0.9429762702132102, Test_error 0.8207910130157181
# Dataset total, Algorithm ETR_total, Test_r2 0.9239240621081385, Test_error 0.2868745460542101
# Dataset total, Algorithm ETR_total, Test_r2 0.9313930305785574, Test_error 0.7964414635636657
# Dataset total, Algorithm ETR_total, Test_r2 0.9559034583400927, Test_error 0.371750253544469
# Dataset total, Algorithm RF_total, Test_r2 0.9380597272565927, Test_error 0.870776149195343
# Dataset total, Algorithm RF_total, Test_r2 0.9184881905651345, Test_error 0.29728320091927524
# Dataset total, Algorithm RF_total, Test_r2 0.9206060231382533, Test_error 0.9316573160129736
# Dataset total, Algorithm RF_total, Test_r2 0.9468143015421541, Test_error 0.44182223403106635
# Dataset total, Algorithm LGBM_total, Test_r2 0.963628529169745, Test_error 0.5352558531450472
# Dataset total, Algorithm LGBM_total, Test_r2 0.9272521148807424, Test_error 0.2753241053303423
# Dataset total, Algorithm LGBM_total, Test_r2 0.9274904865523896, Test_error 0.9035823044105477
# Dataset total, Algorithm LGBM_total, Test_r2 0.9622346507481901, Test_error 0.3421138781255985
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.8961941372646232, Test_error 1.9245357709775566
# Dataset total, Algorithm DT_total, Test_r2 0.5338285833476529, Test_error 1.2781243133105447
# Dataset total, Algorithm DT_total, Test_r2 0.8695702044221525, Test_error 1.304748695313648
# Dataset total, Algorithm DT_total, Test_r2 0.8915637549375776, Test_error 0.8114179308013214
# Dataset total, Algorithm ADBR_total, Test_r2 0.6157168890820162, Test_error 4.008498743816196
# Dataset total, Algorithm ADBR_total, Test_r2 0.47124834445044994, Test_error 1.027135975581142
# Dataset total, Algorithm ADBR_total, Test_r2 0.3519508005750962, Test_error 5.960954489872646
# Dataset total, Algorithm ADBR_total, Test_r2 -0.358394525699145, Test_error 3.8816733351664574
# Dataset total, Algorithm GBR_total, Test_r2 0.9372059086275616, Test_error 1.1289937275525919
# Dataset total, Algorithm GBR_total, Test_r2 0.9078351526834383, Test_error 0.4103831034754373
# Dataset total, Algorithm GBR_total, Test_r2 0.8807258670854208, Test_error 1.3311049911263222
# Dataset total, Algorithm GBR_total, Test_r2 0.9349049696492547, Test_error 0.46587192468284694
# Dataset total, Algorithm BG_total, Test_r2 0.9346864364413442, Test_error 1.1898132513580382
# Dataset total, Algorithm BG_total, Test_r2 0.8113939502794368, Test_error 0.4392281072357316
# Dataset total, Algorithm BG_total, Test_r2 0.9140000142265051, Test_error 0.7964345114370401
# Dataset total, Algorithm BG_total, Test_r2 0.9426368502841611, Test_error 0.4128508325748643
# Dataset total, Algorithm ETR_total, Test_r2 0.9411855446852622, Test_error 1.1298248906579007
# Dataset total, Algorithm ETR_total, Test_r2 0.9619527645497926, Test_error 0.10373591339696822
# Dataset total, Algorithm ETR_total, Test_r2 0.9170496389734214, Test_error 0.7761143995774767
# Dataset total, Algorithm ETR_total, Test_r2 0.9526286164733941, Test_error 0.34905270071799543
# Dataset total, Algorithm RF_total, Test_r2 0.9353495884786847, Test_error 1.1796845105031235
# Dataset total, Algorithm RF_total, Test_r2 0.8227611381410572, Test_error 0.4287026759794119
# Dataset total, Algorithm RF_total, Test_r2 0.9137339349442924, Test_error 0.7989470208886069
# Dataset total, Algorithm RF_total, Test_r2 0.9442525903297142, Test_error 0.40294083726738444
# Dataset total, Algorithm LGBM_total, Test_r2 0.94245104450927, Test_error 1.0602907386449005
# Dataset total, Algorithm LGBM_total, Test_r2 0.9086416122117424, Test_error 0.26570103914580784
# Dataset total, Algorithm LGBM_total, Test_r2 0.9267137286805543, Test_error 0.7300732030661176
# Dataset total, Algorithm LGBM_total, Test_r2 0.956917119872738, Test_error 0.32119828612074086
# Dataset total, Algorithm DT_total, Test_r2 0.9118696525380109, Test_error 1.684136420261756
# Dataset total, Algorithm DT_total, Test_r2 0.5585085852959049, Test_error 1.2317603899668863
# Dataset total, Algorithm DT_total, Test_r2 0.8720616648974757, Test_error 1.2446465001258364
# Dataset total, Algorithm DT_total, Test_r2 0.9173844747419883, Test_error 0.64075100152695
# Dataset total, Algorithm ADBR_total, Test_r2 0.6180840625833598, Test_error 4.02149288817583
# Dataset total, Algorithm ADBR_total, Test_r2 0.5310174195677033, Test_error 0.9347064359869737
# Dataset total, Algorithm ADBR_total, Test_r2 0.3781937182935289, Test_error 5.671806372277521
# Dataset total, Algorithm ADBR_total, Test_r2 -0.3541280395067632, Test_error 4.117544946449463
# Dataset total, Algorithm GBR_total, Test_r2 0.9313728639874763, Test_error 1.2205241186674627
# Dataset total, Algorithm GBR_total, Test_r2 0.9261901887116557, Test_error 0.2840969781880884
# Dataset total, Algorithm GBR_total, Test_r2 0.890268377260072, Test_error 1.2572134350456843
# Dataset total, Algorithm GBR_total, Test_r2 0.93934599372647, Test_error 0.44939423951648805
# Dataset total, Algorithm BG_total, Test_r2 0.936827161197294, Test_error 1.158792977710178
# Dataset total, Algorithm BG_total, Test_r2 0.8152923981051772, Test_error 0.4025610238703824
# Dataset total, Algorithm BG_total, Test_r2 0.9200984506572009, Test_error 0.7332112611890939
# Dataset total, Algorithm BG_total, Test_r2 0.9487985950802096, Test_error 0.36679581983614934
# Dataset total, Algorithm ETR_total, Test_r2 0.9444694044359231, Test_error 1.0794860270668103
# Dataset total, Algorithm ETR_total, Test_r2 0.9628618255505584, Test_error 0.09098089618312358
# Dataset total, Algorithm ETR_total, Test_r2 0.9281359939247692, Test_error 0.6754925876626433
# Dataset total, Algorithm ETR_total, Test_r2 0.958281219432687, Test_error 0.30250666461161857
# Dataset total, Algorithm RF_total, Test_r2 0.9379707405565922, Test_error 1.141898244859005
# Dataset total, Algorithm RF_total, Test_r2 0.8270106113476637, Test_error 0.3837281525226197
# Dataset total, Algorithm RF_total, Test_r2 0.9198713538926414, Test_error 0.7377980665569851
# Dataset total, Algorithm RF_total, Test_r2 0.9492132944726988, Test_error 0.36508664336279784
# Dataset total, Algorithm LGBM_total, Test_r2 0.9414306429085998, Test_error 1.086150786611182
# Dataset total, Algorithm LGBM_total, Test_r2 0.9222959101087229, Test_error 0.24556147341252962
# Dataset total, Algorithm LGBM_total, Test_r2 0.9356215911031455, Test_error 0.6400090608321817
# Dataset total, Algorithm LGBM_total, Test_r2 0.9620089022054549, Test_error 0.2964685159742927
# Dataset total, Algorithm DT_total, Test_r2 0.9093096353271173, Test_error 1.8328614975809847
# Dataset total, Algorithm DT_total, Test_r2 0.6065851817550412, Test_error 0.775004144208381
# Dataset total, Algorithm DT_total, Test_r2 0.8410609547830392, Test_error 1.624618588833764
# Dataset total, Algorithm DT_total, Test_r2 0.9095405156745292, Test_error 0.6599260359765584
# Dataset total, Algorithm ADBR_total, Test_r2 0.6090468345334001, Test_error 4.056169857234541
# Dataset total, Algorithm ADBR_total, Test_r2 0.4552690099341291, Test_error 1.0638490480599958
# Dataset total, Algorithm ADBR_total, Test_r2 0.3527653260871718, Test_error 6.02010027506456
# Dataset total, Algorithm ADBR_total, Test_r2 -0.343020557848263, Test_error 3.8386253575876648
# Dataset total, Algorithm GBR_total, Test_r2 0.9343245855298999, Test_error 1.1984225388005887
# Dataset total, Algorithm GBR_total, Test_r2 0.9412079718674823, Test_error 0.20523183183537125
# Dataset total, Algorithm GBR_total, Test_r2 0.8775343265272211, Test_error 1.4056601127728168
# Dataset total, Algorithm GBR_total, Test_r2 0.9358798210614949, Test_error 0.4518408864183649
# Dataset total, Algorithm BG_total, Test_r2 0.9390499738917343, Test_error 1.1207107586562595
# Dataset total, Algorithm BG_total, Test_r2 0.8099423608180975, Test_error 0.4042859634270657
# Dataset total, Algorithm BG_total, Test_r2 0.9220703887051042, Test_error 0.7217921053484453
# Dataset total, Algorithm BG_total, Test_r2 0.9503991855361987, Test_error 0.35324906535434497
# Dataset total, Algorithm ETR_total, Test_r2 0.9472565681163627, Test_error 1.0207627169685136
# Dataset total, Algorithm ETR_total, Test_r2 0.9643833630325362, Test_error 0.08637346706270657
# Dataset total, Algorithm ETR_total, Test_r2 0.9297573809717689, Test_error 0.6598289265837614
# Dataset total, Algorithm ETR_total, Test_r2 0.9577419118399408, Test_error 0.30640054716933646
# Dataset total, Algorithm RF_total, Test_r2 0.9402570712697577, Test_error 1.1054371716085007
# Dataset total, Algorithm RF_total, Test_r2 0.8197210426864825, Test_error 0.3903523556012346
# Dataset total, Algorithm RF_total, Test_r2 0.9212802104358246, Test_error 0.7301711752183943
# Dataset total, Algorithm RF_total, Test_r2 0.9521401504497061, Test_error 0.34199649800821746
# Dataset total, Algorithm LGBM_total, Test_r2 0.9519475119342985, Test_error 0.919983967100133
# Dataset total, Algorithm LGBM_total, Test_r2 0.9162171871168903, Test_error 0.2281700458727158
# Dataset total, Algorithm LGBM_total, Test_r2 0.9322232690504746, Test_error 0.7120491813120358
# Dataset total, Algorithm LGBM_total, Test_r2 0.9697366241620619, Test_error 0.22538574952009596
# Dataset total, Algorithm DT_total, Test_r2 0.9076958977089471, Test_error 1.7905770744691425
# Dataset total, Algorithm DT_total, Test_r2 0.7233654133943326, Test_error 0.4924685879244406
# Dataset total, Algorithm DT_total, Test_r2 0.8325959417606713, Test_error 1.6853377520803638
# Dataset total, Algorithm DT_total, Test_r2 0.9310081096027039, Test_error 0.5256109315554522
# Dataset total, Algorithm ADBR_total, Test_r2 0.6241895377794798, Test_error 3.9725802436436264
# Dataset total, Algorithm ADBR_total, Test_r2 0.5810389632910993, Test_error 0.8746726474910117
# Dataset total, Algorithm ADBR_total, Test_r2 0.38324248185066334, Test_error 5.415554259216425
# Dataset total, Algorithm ADBR_total, Test_r2 -0.3746790128259261, Test_error 4.018085910230535
# Dataset total, Algorithm GBR_total, Test_r2 0.9297817272875636, Test_error 1.2607025075849811
# Dataset total, Algorithm GBR_total, Test_r2 0.9492082744512533, Test_error 0.17218572166355825
# Dataset total, Algorithm GBR_total, Test_r2 0.8813936829569469, Test_error 1.3893479560674018
# Dataset total, Algorithm GBR_total, Test_r2 0.9370573604758283, Test_error 0.46344719104117943
# Dataset total, Algorithm BG_total, Test_r2 0.9386596505476559, Test_error 1.1280481910915348
# Dataset total, Algorithm BG_total, Test_r2 0.822671465024499, Test_error 0.36460156428357776
# Dataset total, Algorithm BG_total, Test_r2 0.9213579615454949, Test_error 0.7261845311976936
# Dataset total, Algorithm BG_total, Test_r2 0.9508905189840475, Test_error 0.34862376658113653
# Dataset total, Algorithm ETR_total, Test_r2 0.9488216155371314, Test_error 0.9882792638629967
# Dataset total, Algorithm ETR_total, Test_r2 0.9553911466450787, Test_error 0.10167035500882253
# Dataset total, Algorithm ETR_total, Test_r2 0.9350100038528438, Test_error 0.6163197234184226
# Dataset total, Algorithm ETR_total, Test_r2 0.9599708422013179, Test_error 0.2904761205283573
# Dataset total, Algorithm RF_total, Test_r2 0.9405446947877434, Test_error 1.0991059138201884
# Dataset total, Algorithm RF_total, Test_r2 0.8280212639608951, Test_error 0.35066292038584346
# Dataset total, Algorithm RF_total, Test_r2 0.9231397764498199, Test_error 0.7129388794271311
# Dataset total, Algorithm RF_total, Test_r2 0.9522871605685345, Test_error 0.339284358537297
# Dataset total, Algorithm LGBM_total, Test_r2 0.954611703144511, Test_error 0.870600504358297
# Dataset total, Algorithm LGBM_total, Test_r2 0.9173808373996345, Test_error 0.24097875335913269
# Dataset total, Algorithm LGBM_total, Test_r2 0.9370512722019647, Test_error 0.6655048828498722
# Dataset total, Algorithm LGBM_total, Test_r2 0.9686690534747587, Test_error 0.23858211775017943
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.8942263699382029, Test_error 1.3487484339147113
# Dataset total, Algorithm DT_total, Test_r2 0.8198053518351125, Test_error 2.476074729997115
# Dataset total, Algorithm DT_total, Test_r2 0.8243713043157437, Test_error 1.7132354947855666
# Dataset total, Algorithm DT_total, Test_r2 0.8004514346584181, Test_error 1.395488123841232
# Dataset total, Algorithm ADBR_total, Test_r2 0.5962631586245393, Test_error 2.9814402753169587
# Dataset total, Algorithm ADBR_total, Test_r2 0.5760307915366532, Test_error 2.712914249617939
# Dataset total, Algorithm ADBR_total, Test_r2 0.4230992713631605, Test_error 5.195818845257103
# Dataset total, Algorithm ADBR_total, Test_r2 -0.0856945857795599, Test_error 4.191363331730066
# Dataset total, Algorithm GBR_total, Test_r2 0.9375149947038549, Test_error 0.7493026399745659
# Dataset total, Algorithm GBR_total, Test_r2 0.9106478787786504, Test_error 1.2148273403118168
# Dataset total, Algorithm GBR_total, Test_r2 0.9013833870498531, Test_error 0.9367846386137594
# Dataset total, Algorithm GBR_total, Test_r2 0.9153375024609716, Test_error 0.6514952338245931
# Dataset total, Algorithm BG_total, Test_r2 0.9367361549309067, Test_error 0.7709799087022009
# Dataset total, Algorithm BG_total, Test_r2 0.9136642342506023, Test_error 1.0600659501138503
# Dataset total, Algorithm BG_total, Test_r2 0.8843099611630582, Test_error 1.0980977621638726
# Dataset total, Algorithm BG_total, Test_r2 0.8823765142014235, Test_error 0.7975287016568172
# Dataset total, Algorithm ETR_total, Test_r2 0.9348210165709254, Test_error 0.7863716784604373
# Dataset total, Algorithm ETR_total, Test_r2 0.9228743641177464, Test_error 0.8910853300670194
# Dataset total, Algorithm ETR_total, Test_r2 0.8710850912306725, Test_error 1.175297186214278
# Dataset total, Algorithm ETR_total, Test_r2 0.8890560269529552, Test_error 0.7303763459290153
# Dataset total, Algorithm RF_total, Test_r2 0.936232584788342, Test_error 0.7780676104049828
# Dataset total, Algorithm RF_total, Test_r2 0.9094034056624358, Test_error 1.1209666093512198
# Dataset total, Algorithm RF_total, Test_r2 0.883852911331856, Test_error 1.108546038834702
# Dataset total, Algorithm RF_total, Test_r2 0.8817204579133431, Test_error 0.8016164352790659
# Dataset total, Algorithm LGBM_total, Test_r2 0.9497294475928847, Test_error 0.6444273959402542
# Dataset total, Algorithm LGBM_total, Test_r2 0.9801354601191252, Test_error 0.16690170021073297
# Dataset total, Algorithm LGBM_total, Test_r2 0.9088797120873109, Test_error 0.8821813470238946
# Dataset total, Algorithm LGBM_total, Test_r2 0.9330663187813522, Test_error 0.4844045154242211
# Dataset total, Algorithm DT_total, Test_r2 0.9059547930626877, Test_error 1.2022343092523329
# Dataset total, Algorithm DT_total, Test_r2 0.8222087348398823, Test_error 2.3969403291159552
# Dataset total, Algorithm DT_total, Test_r2 0.8096348406693769, Test_error 1.8263297813369093
# Dataset total, Algorithm DT_total, Test_r2 0.8108207422828815, Test_error 1.3279208644414304
# Dataset total, Algorithm ADBR_total, Test_r2 0.6051710398930925, Test_error 2.879513200350337
# Dataset total, Algorithm ADBR_total, Test_r2 0.5686099187322089, Test_error 2.7974419707497455
# Dataset total, Algorithm ADBR_total, Test_r2 0.42042391292627224, Test_error 5.144450001242865
# Dataset total, Algorithm ADBR_total, Test_r2 -0.046356591997165575, Test_error 4.040942239492204
# Dataset total, Algorithm GBR_total, Test_r2 0.9375050061723377, Test_error 0.7469657652334979
# Dataset total, Algorithm GBR_total, Test_r2 0.9098427827604333, Test_error 1.1622691495747648
# Dataset total, Algorithm GBR_total, Test_r2 0.9084065142033522, Test_error 0.9054120432507389
# Dataset total, Algorithm GBR_total, Test_r2 0.9256275535341478, Test_error 0.5485475224727158
# Dataset total, Algorithm BG_total, Test_r2 0.9407828663204698, Test_error 0.7195590528691693
# Dataset total, Algorithm BG_total, Test_r2 0.9174514041484881, Test_error 1.0207275433434637
# Dataset total, Algorithm BG_total, Test_r2 0.8844365005807988, Test_error 1.08754321536024
# Dataset total, Algorithm BG_total, Test_r2 0.8922081565630244, Test_error 0.7342049442325935
# Dataset total, Algorithm ETR_total, Test_r2 0.9387886931879691, Test_error 0.7385707008291554
# Dataset total, Algorithm ETR_total, Test_r2 0.9358626590822409, Test_error 0.6921254463249212
# Dataset total, Algorithm ETR_total, Test_r2 0.8836854534338252, Test_error 1.070590460857543
# Dataset total, Algorithm ETR_total, Test_r2 0.8941994698174891, Test_error 0.7048804350547009
# Dataset total, Algorithm RF_total, Test_r2 0.940776661008151, Test_error 0.7185913644374256
# Dataset total, Algorithm RF_total, Test_r2 0.9168600190834473, Test_error 1.0308128435862336
# Dataset total, Algorithm RF_total, Test_r2 0.8848289801626946, Test_error 1.0908246967816926
# Dataset total, Algorithm RF_total, Test_r2 0.8908225375440404, Test_error 0.7423256374150464
# Dataset total, Algorithm LGBM_total, Test_r2 0.9494404353262998, Test_error 0.6250997041643513
# Dataset total, Algorithm LGBM_total, Test_r2 0.8761494047104867, Test_error 1.566271577701119
# Dataset total, Algorithm LGBM_total, Test_r2 0.9044390299280898, Test_error 0.9066311276851483
# Dataset total, Algorithm LGBM_total, Test_r2 0.9439847289813684, Test_error 0.4077957377985401
# Dataset total, Algorithm DT_total, Test_r2 0.8982672937999084, Test_error 1.2916180649734732
# Dataset total, Algorithm DT_total, Test_r2 0.8380932363753887, Test_error 2.6128965225416825
# Dataset total, Algorithm DT_total, Test_r2 0.8408924705152983, Test_error 1.6376052495702498
# Dataset total, Algorithm DT_total, Test_r2 0.8326948617876417, Test_error 1.1543239144714608
# Dataset total, Algorithm ADBR_total, Test_r2 0.609149705636345, Test_error 2.927360388328968
# Dataset total, Algorithm ADBR_total, Test_r2 0.5705535774151295, Test_error 2.7057660770435574
# Dataset total, Algorithm ADBR_total, Test_r2 0.4336501040872408, Test_error 5.243578190604864
# Dataset total, Algorithm ADBR_total, Test_r2 -0.07065462416284318, Test_error 4.057885750532756
# Dataset total, Algorithm GBR_total, Test_r2 0.9334120103141585, Test_error 0.8140633826022042
# Dataset total, Algorithm GBR_total, Test_r2 0.9212489308492559, Test_error 0.9783568790348147
# Dataset total, Algorithm GBR_total, Test_r2 0.913111908545625, Test_error 0.9028950553278007
# Dataset total, Algorithm GBR_total, Test_r2 0.9224637840862068, Test_error 0.5628925650174913
# Dataset total, Algorithm BG_total, Test_r2 0.9395806417047187, Test_error 0.7350994840002419
# Dataset total, Algorithm BG_total, Test_r2 0.9241321898685626, Test_error 0.9292233729726727
# Dataset total, Algorithm BG_total, Test_r2 0.8894702367603545, Test_error 1.065362124695315
# Dataset total, Algorithm BG_total, Test_r2 0.9027102042929808, Test_error 0.6715094103987298
# Dataset total, Algorithm ETR_total, Test_r2 0.941154123021597, Test_error 0.7044970579898453
# Dataset total, Algorithm ETR_total, Test_r2 0.9292258687766074, Test_error 0.8075288022377098
# Dataset total, Algorithm ETR_total, Test_r2 0.8833443467708657, Test_error 1.088559050165935
# Dataset total, Algorithm ETR_total, Test_r2 0.9137638023752841, Test_error 0.5822857469289696
# Dataset total, Algorithm RF_total, Test_r2 0.9396036095409133, Test_error 0.7344522078519291
# Dataset total, Algorithm RF_total, Test_r2 0.9210825931141827, Test_error 0.9874427523177737
# Dataset total, Algorithm RF_total, Test_r2 0.889214413515681, Test_error 1.067919678535301
# Dataset total, Algorithm RF_total, Test_r2 0.9017434631962196, Test_error 0.6780659694239065
# Dataset total, Algorithm LGBM_total, Test_r2 0.9552310863548503, Test_error 0.554900790487321
# Dataset total, Algorithm LGBM_total, Test_r2 0.93261493774124, Test_error 0.7720133226943131
# Dataset total, Algorithm LGBM_total, Test_r2 0.9149462613636378, Test_error 0.8400774206019831
# Dataset total, Algorithm LGBM_total, Test_r2 0.943480406629866, Test_error 0.4104228416393169
# Dataset total, Algorithm DT_total, Test_r2 0.8993764221894133, Test_error 1.2760697003298795
# Dataset total, Algorithm DT_total, Test_r2 0.8662398329570813, Test_error 2.0836093184941693
# Dataset total, Algorithm DT_total, Test_r2 0.8287480250156052, Test_error 1.7412321750272206
# Dataset total, Algorithm DT_total, Test_r2 0.8286364205723955, Test_error 1.1914968036377878
# Dataset total, Algorithm ADBR_total, Test_r2 0.610974400061719, Test_error 2.8837127542804164
# Dataset total, Algorithm ADBR_total, Test_r2 0.5781923211081126, Test_error 2.7707901847679386
# Dataset total, Algorithm ADBR_total, Test_r2 0.40855187657726366, Test_error 5.268195125194526
# Dataset total, Algorithm ADBR_total, Test_r2 -0.07642117201378751, Test_error 4.008749661790961
# Dataset total, Algorithm GBR_total, Test_r2 0.9422938183366044, Test_error 0.6822139253292777
# Dataset total, Algorithm GBR_total, Test_r2 0.9347522178286611, Test_error 0.7249251546337028
# Dataset total, Algorithm GBR_total, Test_r2 0.9101558005249731, Test_error 0.8847919996166093
# Dataset total, Algorithm GBR_total, Test_r2 0.9201201221436799, Test_error 0.6285796143352824
# Dataset total, Algorithm BG_total, Test_r2 0.9420757595521998, Test_error 0.7031391944512679
# Dataset total, Algorithm BG_total, Test_r2 0.9243016109719134, Test_error 0.9259703694083573
# Dataset total, Algorithm BG_total, Test_r2 0.8845912866303242, Test_error 1.101448027578805
# Dataset total, Algorithm BG_total, Test_r2 0.909244453338567, Test_error 0.6280255166415716
# Dataset total, Algorithm ETR_total, Test_r2 0.9410087109423162, Test_error 0.7126950963065143
# Dataset total, Algorithm ETR_total, Test_r2 0.9312086212917061, Test_error 0.764330905061741
# Dataset total, Algorithm ETR_total, Test_r2 0.8875287628632951, Test_error 1.0440558689452908
# Dataset total, Algorithm ETR_total, Test_r2 0.9153105269992481, Test_error 0.5730200633051648
# Dataset total, Algorithm RF_total, Test_r2 0.942377500771001, Test_error 0.6989085286652921
# Dataset total, Algorithm RF_total, Test_r2 0.9228487551180878, Test_error 0.9617325984827441
# Dataset total, Algorithm RF_total, Test_r2 0.8866545080081217, Test_error 1.083960704299457
# Dataset total, Algorithm RF_total, Test_r2 0.9064152263960341, Test_error 0.6461900926438963
# Dataset total, Algorithm LGBM_total, Test_r2 0.9555724742348612, Test_error 0.5456537528845299
# Dataset total, Algorithm LGBM_total, Test_r2 0.9104636739947428, Test_error 1.1013091897363345
# Dataset total, Algorithm LGBM_total, Test_r2 0.9011915965392495, Test_error 0.9567923013775587
# Dataset total, Algorithm LGBM_total, Test_r2 0.9369061932597359, Test_error 0.4637920353756008
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.9157891722861988, Test_error 1.6963307408858657
# Dataset total, Algorithm DT_total, Test_r2 0.7675269535282025, Test_error 2.7537823324275905
# Dataset total, Algorithm DT_total, Test_r2 0.8390259885537604, Test_error 1.7975269392297915
# Dataset total, Algorithm DT_total, Test_r2 0.7864114729543923, Test_error 1.3803327193850838
# Dataset total, Algorithm ADBR_total, Test_r2 0.7102733860153618, Test_error 3.4673182830766707
# Dataset total, Algorithm ADBR_total, Test_r2 -0.24868079598070048, Test_error 6.441109497577412
# Dataset total, Algorithm ADBR_total, Test_r2 0.4296282026328597, Test_error 4.767752846909099
# Dataset total, Algorithm ADBR_total, Test_r2 -0.3108544287589996, Test_error 4.858423729787391
# Dataset total, Algorithm GBR_total, Test_r2 0.9596988991179608, Test_error 0.7751916599751875
# Dataset total, Algorithm GBR_total, Test_r2 0.9470828987863058, Test_error 0.8185691548157805
# Dataset total, Algorithm GBR_total, Test_r2 0.868591171246163, Test_error 1.491383001160339
# Dataset total, Algorithm GBR_total, Test_r2 0.8954493277522034, Test_error 0.6460059139024714
# Dataset total, Algorithm BG_total, Test_r2 0.9527427817756007, Test_error 0.8946265392308943
# Dataset total, Algorithm BG_total, Test_r2 0.8633041372558119, Test_error 1.5602380379776435
# Dataset total, Algorithm BG_total, Test_r2 0.8921449159474074, Test_error 1.0708093487353025
# Dataset total, Algorithm BG_total, Test_r2 0.862056948981103, Test_error 0.8196540188257442
# Dataset total, Algorithm ETR_total, Test_r2 0.9539847409369365, Test_error 0.8522291288238756
# Dataset total, Algorithm ETR_total, Test_r2 0.8826441193488931, Test_error 1.373417754106403
# Dataset total, Algorithm ETR_total, Test_r2 0.8898631659324095, Test_error 1.085305336786059
# Dataset total, Algorithm ETR_total, Test_r2 0.8668782823630944, Test_error 0.8003500986141112
# Dataset total, Algorithm RF_total, Test_r2 0.9530097417977489, Test_error 0.8911366943404743
# Dataset total, Algorithm RF_total, Test_r2 0.8525718016793706, Test_error 1.6715723099692825
# Dataset total, Algorithm RF_total, Test_r2 0.8926619604150399, Test_error 1.0677851051046745
# Dataset total, Algorithm RF_total, Test_r2 0.8599601850795777, Test_error 0.8279405459652522
# Dataset total, Algorithm LGBM_total, Test_r2 0.9593114923171415, Test_error 0.8030306814833698
# Dataset total, Algorithm LGBM_total, Test_r2 0.9457319517302221, Test_error 0.8582205721074495
# Dataset total, Algorithm LGBM_total, Test_r2 0.895267579108066, Test_error 1.0922136812980368
# Dataset total, Algorithm LGBM_total, Test_r2 0.9092236723990405, Test_error 0.5571984238698785
# Dataset total, Algorithm DT_total, Test_r2 0.9156417529117201, Test_error 1.7162701997235013
# Dataset total, Algorithm DT_total, Test_r2 0.765661638767402, Test_error 2.7848845364031987
# Dataset total, Algorithm DT_total, Test_r2 0.8415412355392858, Test_error 1.7421820053382227
# Dataset total, Algorithm DT_total, Test_r2 0.8240747467654821, Test_error 1.129327251359341
# Dataset total, Algorithm ADBR_total, Test_r2 0.7972730894136658, Test_error 2.8466221630173627
# Dataset total, Algorithm ADBR_total, Test_r2 0.45950075371666166, Test_error 4.374077767767432
# Dataset total, Algorithm ADBR_total, Test_r2 0.2830893280917036, Test_error 5.2589876798420745
# Dataset total, Algorithm ADBR_total, Test_r2 -0.09038532428951851, Test_error 5.328850111091913
# Dataset total, Algorithm GBR_total, Test_r2 0.9581527432460795, Test_error 0.812006198728262
# Dataset total, Algorithm GBR_total, Test_r2 0.9358248738826485, Test_error 1.05960717403816
# Dataset total, Algorithm GBR_total, Test_r2 0.8759462275327337, Test_error 1.3843707914822554
# Dataset total, Algorithm GBR_total, Test_r2 0.8940467686607801, Test_error 0.686746526005279
# Dataset total, Algorithm BG_total, Test_r2 0.9529764647738223, Test_error 0.9074929540689711
# Dataset total, Algorithm BG_total, Test_r2 0.8292995016262128, Test_error 1.8469426518324144
# Dataset total, Algorithm BG_total, Test_r2 0.9092285738755648, Test_error 0.8930022882982863
# Dataset total, Algorithm BG_total, Test_r2 0.8753828937182058, Test_error 0.7388165255668878
# Dataset total, Algorithm ETR_total, Test_r2 0.9557684292306659, Test_error 0.8171131823756259
# Dataset total, Algorithm ETR_total, Test_r2 0.8889000576293219, Test_error 1.3052360106896606
# Dataset total, Algorithm ETR_total, Test_r2 0.9094719137733848, Test_error 0.8770023430970167
# Dataset total, Algorithm ETR_total, Test_r2 0.8822310505422994, Test_error 0.6983257519037681
# Dataset total, Algorithm RF_total, Test_r2 0.9532659767562767, Test_error 0.9021660425989894
# Dataset total, Algorithm RF_total, Test_r2 0.8159993947493056, Test_error 1.9661735950397947
# Dataset total, Algorithm RF_total, Test_r2 0.9106326889909662, Test_error 0.882327865294247
# Dataset total, Algorithm RF_total, Test_r2 0.8747469198596796, Test_error 0.7422623826606966
# Dataset total, Algorithm LGBM_total, Test_r2 0.9630774489868656, Test_error 0.7296220788843132
# Dataset total, Algorithm LGBM_total, Test_r2 0.9259677226596618, Test_error 1.084096003288144
# Dataset total, Algorithm LGBM_total, Test_r2 0.9105551433692982, Test_error 0.9386944851655707
# Dataset total, Algorithm LGBM_total, Test_r2 0.9199251764320802, Test_error 0.520329795373223
# Dataset total, Algorithm DT_total, Test_r2 0.924071101879729, Test_error 1.5456137323176775
# Dataset total, Algorithm DT_total, Test_r2 0.7571016338790433, Test_error 2.851426393392783
# Dataset total, Algorithm DT_total, Test_r2 0.8385670236487657, Test_error 1.6984310668060398
# Dataset total, Algorithm DT_total, Test_r2 0.8240724668769621, Test_error 1.1312915795442657
# Dataset total, Algorithm ADBR_total, Test_r2 0.7097953382574017, Test_error 3.504330607769226
# Dataset total, Algorithm ADBR_total, Test_r2 -0.27596091412543355, Test_error 6.524446375985197
# Dataset total, Algorithm ADBR_total, Test_r2 0.4221204796836573, Test_error 4.803680290980156
# ...
# Dataset total, Algorithm LGBM_total, Test_r2 0.9397601692817451, Test_error 0.9692604127977069
# Dataset total, Algorithm LGBM_total, Test_r2 0.9207231704205481, Test_error 0.6044262221625502
# Dataset total, Algorithm DT_total, Test_r2 0.9077706292933608, Test_error 2.019672580123283
# Dataset total, Algorithm DT_total, Test_r2 0.325056576575257, Test_error 7.346337593396252
# Dataset total, Algorithm DT_total, Test_r2 0.8606599433574635, Test_error 2.2224488968465015
# Dataset total, Algorithm DT_total, Test_r2 0.8644486517749427, Test_error 0.9931235254061105
# Dataset total, Algorithm ADBR_total, Test_r2 0.4874321064455851, Test_error 5.546985348976766
# Dataset total, Algorithm ADBR_total, Test_r2 -0.7070369567253414, Test_error 6.540588354269837
# Dataset total, Algorithm ADBR_total, Test_r2 0.3435233663435916, Test_error 6.080694694795203
# Dataset total, Algorithm ADBR_total, Test_r2 -0.3316346891286974, Test_error 4.828185905577442
# Dataset total, Algorithm GBR_total, Test_r2 0.9382654288701531, Test_error 1.250967195890395
# Dataset total, Algorithm GBR_total, Test_r2 0.8594720392278697, Test_error 1.9154220450784096
# Dataset total, Algorithm GBR_total, Test_r2 0.876964518174782, Test_error 2.0513727903076178
# Dataset total, Algorithm GBR_total, Test_r2 0.893123600403538, Test_error 0.7625359920685579
# Dataset total, Algorithm BG_total, Test_r2 0.94143102926181, Test_error 1.2322388986944528
# Dataset total, Algorithm BG_total, Test_r2 0.8111838304834399, Test_error 1.9807531255535014
# Dataset total, Algorithm BG_total, Test_r2 0.9307097421336501, Test_error 1.033943782475373
# Dataset total, Algorithm BG_total, Test_r2 0.9107035771492527, Test_error 0.6225267737800163
# Dataset total, Algorithm ETR_total, Test_r2 0.950363231760271, Test_error 1.055985953144238
# Dataset total, Algorithm ETR_total, Test_r2 0.9054906744946828, Test_error 1.1350966945191172
# Dataset total, Algorithm ETR_total, Test_r2 0.9388079119668657, Test_error 0.8927626489214687
# Dataset total, Algorithm ETR_total, Test_r2 0.9091866251037883, Test_error 0.6344368691093776
# Dataset total, Algorithm RF_total, Test_r2 0.9415330495313928, Test_error 1.230251846638016
# Dataset total, Algorithm RF_total, Test_r2 0.809875345578965, Test_error 1.9870046318425911
# Dataset total, Algorithm RF_total, Test_r2 0.9313412935765102, Test_error 1.0266836127379768
# Dataset total, Algorithm RF_total, Test_r2 0.9089876232061121, Test_error 0.6333944501322013
# Dataset total, Algorithm LGBM_total, Test_r2 0.9553513083500366, Test_error 1.0458731317135963
# Dataset total, Algorithm LGBM_total, Test_r2 0.8581747003836727, Test_error 1.821309553914913
# Dataset total, Algorithm LGBM_total, Test_r2 0.9321035484631744, Test_error 1.0765912084767013
# Dataset total, Algorithm LGBM_total, Test_r2 0.9350661517978661, Test_error 0.5284554257508899
# Dataset total, Algorithm DT_total, Test_r2 0.9066243084650857, Test_error 2.0777836863629364
# Dataset total, Algorithm DT_total, Test_r2 0.33512546324723336, Test_error 7.401439152033127
# Dataset total, Algorithm DT_total, Test_r2 0.8606767697326749, Test_error 2.1895105109934616
# Dataset total, Algorithm DT_total, Test_r2 0.8500174412891333, Test_error 1.1062011444834463
# Dataset total, Algorithm ADBR_total, Test_r2 0.5177930556011712, Test_error 5.363364999065714
# Dataset total, Algorithm ADBR_total, Test_r2 -0.5302281754063205, Test_error 6.270736204064695
# Dataset total, Algorithm ADBR_total, Test_r2 0.39566404167301794, Test_error 5.724280075428286
# Dataset total, Algorithm ADBR_total, Test_r2 -0.29493374581936105, Test_error 4.68080933823494
# Dataset total, Algorithm GBR_total, Test_r2 0.926243086448925, Test_error 1.4565701459908473
# Dataset total, Algorithm GBR_total, Test_r2 0.8095558697646735, Test_error 2.262816706917472
# Dataset total, Algorithm GBR_total, Test_r2 0.8945978411952795, Test_error 1.77671895857308
# Dataset total, Algorithm GBR_total, Test_r2 0.8834948260711926, Test_error 0.7914724928406811
# Dataset total, Algorithm BG_total, Test_r2 0.9397262578465573, Test_error 1.2747679065930484
# Dataset total, Algorithm BG_total, Test_r2 0.8143325915464815, Test_error 1.9346968104717703
# Dataset total, Algorithm BG_total, Test_r2 0.9362467489321616, Test_error 0.9433876771992369
# Dataset total, Algorithm BG_total, Test_r2 0.9070928274462882, Test_error 0.644134088543813
# Dataset total, Algorithm ETR_total, Test_r2 0.9508387103962829, Test_error 1.0298524659330128
# Dataset total, Algorithm ETR_total, Test_r2 0.8970391233354194, Test_error 1.2654496455530644
# Dataset total, Algorithm ETR_total, Test_r2 0.9419033518976709, Test_error 0.8541896692614935
# Dataset total, Algorithm ETR_total, Test_r2 0.9092822425084705, Test_error 0.6263897328911294
# Dataset total, Algorithm RF_total, Test_r2 0.939429953300024, Test_error 1.2818152472642088
# Dataset total, Algorithm RF_total, Test_r2 0.8146161311584326, Test_error 1.935632711644913
# Dataset total, Algorithm RF_total, Test_r2 0.9351354951628286, Test_error 0.9569992238742488
# Dataset total, Algorithm RF_total, Test_r2 0.9050670611303075, Test_error 0.6541571957971185
# Dataset total, Algorithm LGBM_total, Test_r2 0.9572915646116973, Test_error 0.9672746049894614
# Dataset total, Algorithm LGBM_total, Test_r2 0.8979575036414861, Test_error 1.303272026196588
# Dataset total, Algorithm LGBM_total, Test_r2 0.9385789339681908, Test_error 0.9749533255620692
# Dataset total, Algorithm LGBM_total, Test_r2 0.9248467963611111, Test_error 0.592164633703851
# 1535
# 676
# 276
# 31
# Dataset total, Algorithm DT_total, Test_r2 0.8953825235679973, Test_error 1.685591953101072
# Dataset total, Algorithm DT_total, Test_r2 0.8393077447652163, Test_error 1.7521898201536277
# Dataset total, Algorithm DT_total, Test_r2 0.8774286437872015, Test_error 1.5660919584841815
# Dataset total, Algorithm DT_total, Test_r2 0.8740028977169731, Test_error 0.9569450704249701
# Dataset total, Algorithm ADBR_total, Test_r2 0.4538589461757033, Test_error 4.4595445864702725
# Dataset total, Algorithm ADBR_total, Test_r2 0.581659725327637, Test_error 3.8013313779870863
# Dataset total, Algorithm ADBR_total, Test_r2 0.4283653709721955, Test_error 5.104621526535678
# Dataset total, Algorithm ADBR_total, Test_r2 -0.08503655199510196, Test_error 4.98524739770401
# Dataset total, Algorithm GBR_total, Test_r2 0.935071490942916, Test_error 0.9561190755772938
# Dataset total, Algorithm GBR_total, Test_r2 0.9231179906189498, Test_error 1.0829083118809122
# Dataset total, Algorithm GBR_total, Test_r2 0.9040521344685758, Test_error 1.2096196757362323
# Dataset total, Algorithm GBR_total, Test_r2 0.9161771937081715, Test_error 0.5377619362448628
# Dataset total, Algorithm BG_total, Test_r2 0.9380443076073738, Test_error 0.9264959657015516
# Dataset total, Algorithm BG_total, Test_r2 0.9761737416971915, Test_error 0.25663272094001227
# Dataset total, Algorithm BG_total, Test_r2 0.9272377836848972, Test_error 0.860398350745725
# Dataset total, Algorithm BG_total, Test_r2 0.907267021674028, Test_error 0.6450249064275264
# Dataset total, Algorithm ETR_total, Test_r2 0.9379540435851168, Test_error 0.9285201762022948
# Dataset total, Algorithm ETR_total, Test_r2 0.9616818333450136, Test_error 0.43214927943733794
# Dataset total, Algorithm ETR_total, Test_r2 0.9162345515139118, Test_error 0.9729491151229497
# Dataset total, Algorithm ETR_total, Test_r2 0.9133785298686552, Test_error 0.6090863506592068
# Dataset total, Algorithm RF_total, Test_r2 0.9380580343180325, Test_error 0.9261499647146243
# Dataset total, Algorithm RF_total, Test_r2 0.9769020812461214, Test_error 0.2517268799527529
# Dataset total, Algorithm RF_total, Test_r2 0.9268917241449134, Test_error 0.8676536132843325
# Dataset total, Algorithm RF_total, Test_r2 0.907311496598099, Test_error 0.6442775061976546
# Dataset total, Algorithm LGBM_total, Test_r2 0.9430501683754312, Test_error 0.8509080001194523
# Dataset total, Algorithm LGBM_total, Test_r2 0.976687738765877, Test_error 0.23012565281584468
# Dataset total, Algorithm LGBM_total, Test_r2 0.9260946078436159, Test_error 0.898670954803978
# Dataset total, Algorithm LGBM_total, Test_r2 0.9576020518689982, Test_error 0.2851791200293751
# Dataset total, Algorithm DT_total, Test_r2 0.9042115764096136, Test_error 1.557132518119933
# Dataset total, Algorithm DT_total, Test_r2 0.8155723121242702, Test_error 1.8923227455134402
# Dataset total, Algorithm DT_total, Test_r2 0.881932850249236, Test_error 1.5070138506514528
# Dataset total, Algorithm DT_total, Test_r2 0.8862281466738087, Test_error 0.8370629829631093
# Dataset total, Algorithm ADBR_total, Test_r2 0.4993294447025022, Test_error 3.9848983082126286
# Dataset total, Algorithm ADBR_total, Test_r2 0.5719976020264395, Test_error 3.121461480047197
# Dataset total, Algorithm ADBR_total, Test_r2 0.4390959179089706, Test_error 5.701278299230042
# Dataset total, Algorithm ADBR_total, Test_r2 -0.22082184967218477, Test_error 4.841423678154758
# Dataset total, Algorithm GBR_total, Test_r2 0.9372669835371883, Test_error 0.9348056325802622
# Dataset total, Algorithm GBR_total, Test_r2 0.9457074739989737, Test_error 0.691713661931766
# Dataset total, Algorithm GBR_total, Test_r2 0.8934500753152654, Test_error 1.38270536178771
# Dataset total, Algorithm GBR_total, Test_r2 0.9114167052050851, Test_error 0.5639572366161091
# Dataset total, Algorithm BG_total, Test_r2 0.939024665880065, Test_error 0.9082848397680332
# Dataset total, Algorithm BG_total, Test_r2 0.9799952615540586, Test_error 0.20526196060007304
# Dataset total, Algorithm BG_total, Test_r2 0.9282083680276676, Test_error 0.8470497149586985
# Dataset total, Algorithm BG_total, Test_r2 0.9233994639712076, Test_error 0.530979482822662
# Dataset total, Algorithm ETR_total, Test_r2 0.9411187980585947, Test_error 0.8856479750535741
# Dataset total, Algorithm ETR_total, Test_r2 0.971089101906593, Test_error 0.2961390174535952
# Dataset total, Algorithm ETR_total, Test_r2 0.9203236405234011, Test_error 0.9130519626200634
# Dataset total, Algorithm ETR_total, Test_r2 0.9339636625634863, Test_error 0.4675913099757653
# Dataset total, Algorithm RF_total, Test_r2 0.9392467276841351, Test_error 0.9057070418575633
# Dataset total, Algorithm RF_total, Test_r2 0.9799150106583172, Test_error 0.21014527398603922
# Dataset total, Algorithm RF_total, Test_r2 0.9284683302733823, Test_error 0.8440903121909006
# Dataset total, Algorithm RF_total, Test_r2 0.9233358078658075, Test_error 0.5326277754947241
# Dataset total, Algorithm LGBM_total, Test_r2 0.9531432908877112, Test_error 0.73388342067749
# Dataset total, Algorithm LGBM_total, Test_r2 0.9692048966804815, Test_error 0.2772813316331212
# Dataset total, Algorithm LGBM_total, Test_r2 0.9397883072550139, Test_error 0.7459382869545849
# Dataset total, Algorithm LGBM_total, Test_r2 0.9568995905680603, Test_error 0.2906629531411553
# Dataset total, Algorithm DT_total, Test_r2 0.8949560560603406, Test_error 1.6491899416792377
# Dataset total, Algorithm DT_total, Test_r2 0.7958177115299631, Test_error 2.047607679444059
# Dataset total, Algorithm DT_total, Test_r2 0.8788617769207696, Test_error 1.590434809847934
# Dataset total, Algorithm DT_total, Test_r2 0.8968929916324361, Test_error 0.8130373442089398
# Dataset total, Algorithm ADBR_total, Test_r2 0.4972409603048179, Test_error 4.017616745789418
# Dataset total, Algorithm ADBR_total, Test_r2 0.5760252837351691, Test_error 3.1745784750466286
# Dataset total, Algorithm ADBR_total, Test_r2 0.43475237166568004, Test_error 5.562547098022644
# Dataset total, Algorithm ADBR_total, Test_r2 -0.23000507949174898, Test_error 4.883568712705308
# Dataset total, Algorithm GBR_total, Test_r2 0.9371667942250647, Test_error 0.9293206398446938
# Dataset total, Algorithm GBR_total, Test_r2 0.9600647251152616, Test_error 0.4245322398974506
# Dataset total, Algorithm GBR_total, Test_r2 0.9033489009600486, Test_error 1.2600867399528588
# Dataset total, Algorithm GBR_total, Test_r2 0.9329617998407291, Test_error 0.4529730265304624
# Dataset total, Algorithm BG_total, Test_r2 0.9399357434508613, Test_error 0.8893454701764871
# Dataset total, Algorithm BG_total, Test_r2 0.9704011969833286, Test_error 0.33034660891150797
# Dataset total, Algorithm BG_total, Test_r2 0.9273352114513449, Test_error 0.8706044527975974
# Dataset total, Algorithm BG_total, Test_r2 0.9352215821970518, Test_error 0.4647980903809508
# Dataset total, Algorithm ETR_total, Test_r2 0.9434266633573097, Test_error 0.8408633916999732
# Dataset total, Algorithm ETR_total, Test_r2 0.9599512326060592, Test_error 0.4012724885412833
# Dataset total, Algorithm ETR_total, Test_r2 0.9275089031333513, Test_error 0.8511589167019313
# Dataset total, Algorithm ETR_total, Test_r2 0.9359446211755555, Test_error 0.4669660517348881
# Dataset total, Algorithm RF_total, Test_r2 0.9398544600468873, Test_error 0.8913827016505108
# Dataset total, Algorithm RF_total, Test_r2 0.9705879313059185, Test_error 0.331147598290688
# Dataset total, Algorithm RF_total, Test_r2 0.9264159008508114, Test_error 0.8808959021234667
# Dataset total, Algorithm RF_total, Test_r2 0.9348863137549939, Test_error 0.46628432336740855
# Dataset total, Algorithm LGBM_total, Test_r2 0.9501916487207569, Test_error 0.7608363581093386
# Dataset total, Algorithm LGBM_total, Test_r2 0.9512333764635912, Test_error 0.53748061050604
# Dataset total, Algorithm LGBM_total, Test_r2 0.9452585289446355, Test_error 0.6943306687341391
# Dataset total, Algorithm LGBM_total, Test_r2 0.9634002304774093, Test_error 0.25869486277260423
# Dataset total, Algorithm DT_total, Test_r2 0.902560483748804, Test_error 1.5296783332305994
# Dataset total, Algorithm DT_total, Test_r2 0.8161436293723916, Test_error 1.9130137935030669
# Dataset total, Algorithm DT_total, Test_r2 0.8715424608154227, Test_error 1.6572534987241887
# Dataset total, Algorithm DT_total, Test_r2 0.8921522961065287, Test_error 0.8460742718214196
# Dataset total, Algorithm ADBR_total, Test_r2 0.5011891873805561, Test_error 3.9828018552808273
# Dataset total, Algorithm ADBR_total, Test_r2 0.57383058811872, Test_error 3.0806315643639866
# Dataset total, Algorithm ADBR_total, Test_r2 0.43228582866700094, Test_error 5.642346648945659
# Dataset total, Algorithm ADBR_total, Test_r2 -0.2176581755948488, Test_error 4.836540014857658
# Dataset total, Algorithm GBR_total, Test_r2 0.9357835174024239, Test_error 0.9634216166478382
# Dataset total, Algorithm GBR_total, Test_r2 0.9389669807372902, Test_error 0.7283377282172835
# Dataset total, Algorithm GBR_total, Test_r2 0.9074154808429788, Test_error 1.1819488173186123
# Dataset total, Algorithm GBR_total, Test_r2 0.9232036215261779, Test_error 0.4918494509376313
# Dataset total, Algorithm BG_total, Test_r2 0.939459723385126, Test_error 0.896862786703585
# Dataset total, Algorithm BG_total, Test_r2 0.9754355091548075, Test_error 0.26373421891839127
# Dataset total, Algorithm BG_total, Test_r2 0.9278817396781208, Test_error 0.8631965891969651
# Dataset total, Algorithm BG_total, Test_r2 0.9358145361400794, Test_error 0.4599848860302178
# Dataset total, Algorithm ETR_total, Test_r2 0.9422881119288309, Test_error 0.8545949603736583
# Dataset total, Algorithm ETR_total, Test_r2 0.9572147918310313, Test_error 0.4343600661556469
# Dataset total, Algorithm ETR_total, Test_r2 0.929156676561273, Test_error 0.8292482943038049
# Dataset total, Algorithm ETR_total, Test_r2 0.9436280943059895, Test_error 0.4125896413982443
# Dataset total, Algorithm RF_total, Test_r2 0.9390603693646886, Test_error 0.9012914605577471
# Dataset total, Algorithm RF_total, Test_r2 0.9747623655857733, Test_error 0.2749606705160331
# Dataset total, Algorithm RF_total, Test_r2 0.9270591156866568, Test_error 0.8707230440435203
# Dataset total, Algorithm RF_total, Test_r2 0.9353491462394379, Test_error 0.46194693892193206
# Dataset total, Algorithm LGBM_total, Test_r2 0.9513938678236098, Test_error 0.7511437298975773
# Dataset total, Algorithm LGBM_total, Test_r2 0.9392467715757634, Test_error 0.794092421311467
# Dataset total, Algorithm LGBM_total, Test_r2 0.9339875552993192, Test_error 0.8397079528658343
# Dataset total, Algorithm LGBM_total, Test_r2 0.9484975818597429, Test_error 0.3495742996348108

# %%
pd.DataFrame(results,columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_mse_separa_r2','test_mse_separa_model'])
# Out:
#        Gas   Model_name     CV_r2    CV_mse  test_r2_total_model  \
# 0      CO2           RF  0.916850  1.134517              0.92742
# 1     CFCs           RF  0.916850  1.134517              0.92742
# 2  Methane           RF  0.916850  1.134517              0.92742
# 3      E&E           RF  0.916850  1.134517              0.92742
# 4      CO2  RF_separate  0.921323  1.171232             -1.00000
# 5     CFCs  RF_separate  0.817262  1.880100             -1.00000
# 6  Methane  RF_separate  0.912285  1.060407             -1.00000
# 7      E&E  RF_separate  0.887397  0.882538             -1.00000
#
#    test_mse_by_total_model  test_mse_separa_r2  test_mse_separa_model
# 0                 1.029823            0.941160               1.103142
# 1                 1.029823            0.688753               1.993656
# 2                 1.029823            0.899515               0.919708
# 3                 1.029823            0.851791               0.784912
# 4                -1.000000            0.940396               1.118080
# 5                -1.000000            0.714499               1.805199
# 6                -1.000000            0.896908               0.949832
# 7                -1.000000            0.839518               0.870219

# %%
temp1 = train_df.iloc[0:10,:]
temp2 = train_df.iloc[20:30,:]
temp1.shape,temp2.shape
# Out:
# ((10, 26), (10, 26))

# %%
temp3 = pd.concat([temp1.set_index(temp2.index),temp2],axis =1)
temp3.shape
# Out:
# (10, 52)

# %%
input_feature = ['S','V','L','BET',"Vmeso",'Vt','Vmic','Temp(K)','Pressure'] # break Vt
output = ['Adsorp(mmol/g)']
train_x= train_df[input_feature]
test_x = test_df[input_feature]
train_y = train_df[output].values
test_y = test_df[output].values

# %%
from sklearn.preprocessing import StandardScaler
x_scaler = StandardScaler()
train_xs = x_scaler.fit_transform(train_x)
test_xs = x_scaler.transform(test_x)
for model_name, model in model_list:

    model.fit(train_xs,train_y.squeeze())
    test_pre = model.predict(test_xs)
    train_error = mean_squared_error(train_y,model.predict(train_xs))
    test_error = mean_squared_error(test_y,test_pre)
    print('Algorithm {}, Train_error {}, Test_error {}'.format(model_name,train_error,test_error))
    #plt.scatter(test_y,test_pre)

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error

out_cv = GroupKFold(n_splits = 5)
model = ExtraTreesRegressor(n_jobs=-1)
#model = RandomForestRegressor(n_jobs=-1)
groups = train_df['Index']
#estimator = cross_validate(model,train_x,train_y,groups = groups,cv =out_cv)
param = {'n_estimators':[50,100,200,300,400,450,500],}
result = GridSearchCV(model,param,cv= out_cv.get_n_splits(groups =groups),
scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
result.fit(train_x,train_y)

# %%
result.predict(test_x)
#result.cv_results_

# %%
model = ExtraTreesRegressor(500,n_jobs=-1,random_state=42)

#model = RandomForestRegressor(500,random_state=42)
model.fit(train_x,train_y)
test_pre = model.predict(test_x)
train_error = mean_squared_error(train_y,model.predict(train_x))
test_error = mean_squared_error(test_y,test_pre)
print('Algorithm {}, Train_error {}, Test_error {}'.format('ETR',train_error,test_error))
cross_validate(model,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))

# %%
for model_name, model in model_list:

    model.fit(train_x,train_y)
    test_pre = model.predict(test_x)
    train_error = mean_squared_error(train_y,model.predict(train_x))
    test_error = mean_squared_error(test_y,test_pre)
    print('Algorithm {}, Train_error {}, Test_error {}'.format(model_name,train_error,test_error))
    #plt.scatter(test_y,test_pre)

# %%
def model_comparison(model_list,feature_list):
    gas_list = ['total','CO2','CFCs','Methane','E&E']
    result = []
    for gas in gas_list:
        
        # break Vt
        output = ['Adsorp(mmol/g)']
        
        if gas =='total':
            train_df_com = train_df
            test_df_com = test_df
            #input_feature = ['E','V','L','BET',"Vmeso",'Vt','Temp(K)','Pressure'] 
            input_feature = feature_list
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output]
            test_y = test_df_com[output]
            for model_name, model in model_list:

                model.fit(train_x,train_y)
                test_pre = model.predict(test_x)
                train_error = mean_squared_error(train_y,model.predict(train_x))
                test_error = mean_squared_error(test_y,test_pre)
                result.append([gas,model_name,train_error,test_error])
                for gases in gas_list[1:]:
                    
                    test_df_com = test_df[test_df['Label']==gases]
                    test_x = test_df_com[input_feature]
                    test_y = test_df_com[output]
                    test_pre = model.predict(test_x)
                    train_error = mean_squared_error(train_y,model.predict(train_x))
                    test_error = mean_squared_error(test_y,test_pre)
                    result.append([gases,model_name,train_error,test_error])
        
                print('Dataset {}, Algorithm {}, Train_error {}, Test_error {}'.format(gas,model_name,train_error,test_error))
            
        else:
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            if gas in ['E&E','CFCs']:
                #input_feature = ['V','L','BET',"Vmeso",'Vt','Temp(K)','Pressure'] 
                input_feature = feature_list
            else:
                #input_feature = ['BET',"Vmeso",'Vt','Temp(K)','Pressure']
                input_feature = feature_list[-5:]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output]
            test_y = test_df_com[output]
            for model_name, model in model_list:

                model.fit(train_x,train_y)
                test_pre = model.predict(test_x)
                train_error = mean_squared_error(train_y,model.predict(train_x))
                test_error = mean_squared_error(test_y,test_pre)
                print('Dataset {}, Algorithm {}, Train_error {}, Test_error {}'.format(gas,model_name,train_error,test_error))
                #plt.scatter(test_y,test_pre)
                result.append([gas,model_name,train_error,test_error])
    return result

# %%
feature_1 = ['V','S','L','BET','Vt','Temp(K)','Pressure']
feature_2 = ['V','S','L','BET',"Vmeso",'Vt','Temp(K)','Pressure']
feature_3 = ['V','S','L','BET',"Vmic",'Vt','Temp(K)','Pressure']
feature_4 = ['V','S','L','BET',"Vmic",'Vt','Vmeso','Temp(K)','Pressure']
feature_list = [feature_1,feature_2,feature_3,feature_4]
file_name = ['Total',"Meso","Micro",'All']
for i in range(5):
    train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'])
    for j in range(4):
        result = model_comparison(model_list,feature_list[j])
        files_name = 'No-H'+file_name[j]+'result'+str(i)+'.csv'
        pd.DataFrame(result,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))

# %%
gas_list = ['total','CO2','CFCs','Methane','E&E','Hydrogen']
result = []
for gas in gas_list:
    
    # break Vt
    output = ['Adsorp(mmol/g)']
    
    if gas =='total':
        train_df_com = train_df
        test_df_com = test_df
        input_feature = ['E','V','L','BET',"Vmeso",'Vt','Temp(K)','Pressure'] 
        
        
        train_x = train_df_com[input_feature]
        test_x = test_df_com[input_feature]
        train_y = train_df_com[output]
        test_y = test_df_com[output]
        for model_name, model in model_list:

            model.fit(train_x,train_y)
            test_pre = model.predict(test_x)
            train_error = mean_squared_error(train_y,model.predict(train_x))
            test_error = mean_squared_error(test_y,test_pre)
            result.append([gas,model_name,train_error,test_error])
            for gases in gas_list[1:]:
                
                test_df_com = test_df[test_df['Label']==gases]
                test_x = test_df_com[input_feature]
                test_y = test_df_com[output]
                test_pre = model.predict(test_x)
                train_error = mean_squared_error(train_y,model.predict(train_x))
                test_error = mean_squared_error(test_y,test_pre)
                result.append([gases,model_name,train_error,test_error])
    
            print('Dataset {}, Algorithm {}, Train_error {}, Test_error {}'.format(gas,model_name,train_error,test_error))
           
    else:
        train_df_com = train_df[train_df['Label']==gas]
        test_df_com = test_df[test_df['Label']==gas]
        if gas in ['E&E','CFCs']:
            input_feature = ['V','L','BET',"Vmeso",'Vt','Temp(K)','Pressure'] 
        else:
            input_feature = ['BET',"Vmeso",'Vt','Temp(K)','Pressure']
        train_x = train_df_com[input_feature]
        test_x = test_df_com[input_feature]
        train_y = train_df_com[output]
        test_y = test_df_com[output]
        for model_name, model in model_list:

            model.fit(train_x,train_y)
            test_pre = model.predict(test_x)
            train_error = mean_squared_error(train_y,model.predict(train_x))
            test_error = mean_squared_error(test_y,test_pre)
            print('Dataset {}, Algorithm {}, Train_error {}, Test_error {}'.format(gas,model_name,train_error,test_error))
            #plt.scatter(test_y,test_pre)
            result.append([gas,model_name,train_error,test_error])

# %%
pd.DataFrame(result,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv('./result3.csv')

# %% [markdown]
# # Leave-one-group-Out cross validation

# %%
import numpy as np
from sklearn.model_selection import LeavePGroupsOut

# %%
lpgo = LeavePGroupsOut(n_groups=2)
lpgo.get_n_splits(groups=groups)

# %%
input_feature = ['E','V','L','BET',"Vmeso",'Vt','Temp(K)','Pressure']
input_feature[-5:]

# %%
pd.DataFrame(result,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv('./resultnew.csv')

# %%
import matplotlib.pyplot as plt
#model = RandomForestRegressor(n_estimators=30,n_jobs=-1)
#model = BaggingRegressor(base_estimator=RandomForestRegressor(n_estimators=30),n_estimators=30)
model = LGBMRegressor(objective = 'regression',num_leaves = 30,learning_rate =0.5,n_estimators=60)
model.fit(train_x,train_y)
print(r2_score(test_y,model.predict(test_x))), print(mean_squared_error(test_y,model.predict(test_x),squared=True))
plt.subplot(1,2,1)
plt.scatter(test_y,model.predict(test_x))
plt.subplot(1,2,2)
plt.scatter(train_y,model.predict(train_x))

# %%
y = test_y.values.squeeze()
y_pred = model.predict(test_x)
P = test_x['logP'].values

# %%
from sklearn.model_selection import GridSearchCV
estimator = LGBMRegressor()
param_grid = {'num_leaves':[10,20,30,40,50,60],'learning_rate': [0.001,0.01,0.05,0.1,0.5,1],'n_estimators':[20,30,40,50,60,80,100]}
lgbm = GridSearchCV(estimator,param_grid)
lgbm.fit(train_x,train_y)

# %%
lgbm.best_params_

# %% [markdown]
# # Pytorch NN model

# %%
train_df,test_df = pred_dataset(['CO2'])

# %%
from torch.utils.data import DataLoader
from sklearn.preprocessing import StandardScaler
import torch
x_scaler = StandardScaler()
y_scaler = StandardScaler()

train_x = x_scaler.fit_transform(train_df[input_feature])
test_x = x_scaler.transform(test_df[input_feature])
#without y-scaling

train_y = train_df[output].values.reshape(-1,1)


# with y_scaling
#train_y = y_scaler.fit_transform(train_df[output]).reshape(-1,1)
test_y = test_df[output].values.reshape(-1,1)
#print(train_y)

train_x = torch.Tensor(train_x).float()
train_y = torch.Tensor(train_y).float()
test_x = torch.Tensor(test_x).float()
test_y = torch.Tensor(test_y).float()

from torch.utils.data import Dataset
class CustomImageDataset(Dataset):
    def __init__(self, inputs, outputs):
        self.inputs = inputs
        self.outputs = outputs
        
    def __len__(self):
        return len(self.inputs)

    def __getitem__(self,idx):   
        return self.inputs[idx], self.outputs[idx]

# %%
train_dataset = CustomImageDataset(train_x,train_y.reshape(-1,1))
train_loader = DataLoader(train_dataset)
val_dataset = CustomImageDataset(test_x,test_y.reshape(-1,1))
val_loader = DataLoader(val_dataset,batch_size=500)

# %%
import torch.nn as nn
class Net(nn.Module):
    def __init__(self,input_length):
        super().__init__()
        self.input_length = input_length
        self.fc1 = torch.nn.Linear(self.input_length,158)
        self.ac1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(158,158)
        self.drop1 = torch.nn.Dropout(0.14)
        self.ac2 = torch.nn.ReLU()
        self.fc3 = torch.nn.Linear(158,158)
        self.ac3 = torch.nn.ReLU()
        self.out = torch.nn.Linear(158,1)
    def forward(self,x):
        out = self.drop1(self.ac1(self.fc1(x)))
        out = self.ac2(self.fc2(out))
        out = self.ac3(self.fc3(out))
        return self.out(out)

# %%
# change the weight initiation
import torch.nn as nn
def mol_init(model):
    for m in model.modules():
        if isinstance(m,nn.Linear):
            nn.init.xavier_normal_(m.weight)

# %%
import torch.optim as opt
input_length = len(input_feature)
model = Net(input_length)
mol_init(model)
loss_fn = torch.nn.MSELoss()
optimizer = opt.Adam(model.parameters(),lr=0.024)
hist_loss = []
epoches = 200
for epoch in range(1,epoches+1):
    
    losses = []
    for x,y in train_loader:
        y_pred = model(x)
        loss = loss_fn(y,y_pred)
        losses.append(loss)
    lossn = sum(losses)/len(losses)
    hist_loss.append(lossn.item())
    optimizer.zero_grad()
    lossn.backward()
    optimizer.step()

    if epoch%10 ==0:
        
        y_real= torch.Tensor(())
        y_pred = torch.Tensor(())
        with torch.no_grad():
            for val_x,val_y in val_loader:
                val_y_pre = model(val_x) 
                
                y_real=torch.cat((y_real,val_y),0)
                y_pred = torch.cat((y_pred,val_y_pre),0)
    
            #y_pred = torch.Tensor(y_scaler.inverse_transform(y_pred))
            y_pred = torch.Tensor(y_pred)
    
            val_loss = loss_fn(y_real,y_pred)
        print('Epcoh: {}, Train_loss {:.4f}, Val_loss {:.4f}'.format(epoch,hist_loss[-1],val_loss))

# %%
from sklearn.metrics import mean_squared_error,r2_score


from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,\
    GradientBoostingRegressor,ExtraTreesRegressor, BaggingRegressor

    
model_list = [('RF',RandomForestRegressor(n_estimators=50)),('ADB',AdaBoostRegressor(n_estimators=50)),
('GBR',GradientBoostingRegressor(n_estimators=50)),('ETR',ExtraTreesRegressor(n_estimators=50)),
('BGR',BaggingRegressor(ExtraTreesRegressor(n_estimators=50)))]
input_feature = ['E','V','L','BET',"Vmeso",'Vt','Vmic','Temp(K)','Pressure'] # break Vt
output = ['Adsorp(mmol/g)']
train_x= train_df[input_feature].values
test_x = test_df[input_feature].values
train_y = train_df[output].values
test_y = test_df[output].values


for model_name, model in model_list:

    model.fit(train_x,train_y)
    test_pre = model.predict(test_x)
    train_error = mean_squared_error(train_y,model.predict(train_x))
    test_error = mean_squared_error(test_y,test_pre)
    print('Algorithm {}, Train_error {}, Test_error {}'.format(model_name,train_error,test_error))
    #plt.scatter(test_y,test_pre)

# %% [markdown]
# # Leave-one-out looping to remove poor data points

# %%
import pandas as pd 
import os
import numpy as np
file_name = 'Hydrogen'
source_path = '/Users/kai/Documents/Desktop/CO2_adsorption/new_data'

temp_data = pd.read_excel(os.path.join(source_path,file_name+'-01-01-2022.xlsx'),skiprows=1)

# %%
#os.listdir(source_path)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

test_mse = []
temp_data = temp_data.dropna(axis=0,how = 'any',subset = ["BET","Vt",'Vmic'])
for i in list(set(temp_data['Index'].values)):
    
    #if i not in ex_list:
    
        test_data = temp_data[temp_data['Index']==i]
        train_data = temp_data[temp_data['Index']!=i]
        
        input_feature = ['E','V','L','BET','Vt','Vmic','Temp(K)','Pressure']
        output = ['Adsorp(mmol/g)']
        train_x = train_data[input_feature]
        train_y = train_data[output].values.reshape(-1)
        test_x = test_data[input_feature]
        test_y = test_data[output].values.reshape(-1)
        model = RandomForestRegressor(n_estimators=200,n_jobs=-1)
        model.fit(train_x,train_y)
        test_mse.append([i,r2_score(test_y,model.predict(test_x)),mean_squared_error(test_y,model.predict(test_x))])
        if len(test_mse)%20==0:
            print(test_mse[-1])

# %%
pd.DataFrame(test_mse,columns=['group','r2','mse']).to_csv(os.path.join(source_path,'Hydrogen_LOO2_0109_del_del_mic_del_del.csv'))

# %%
ex_list = [132,173,182,191,212,711,739,
825,828,830,833,876,957,1136,1201,
1227,1457,1516,1535,1536,1675,1953,
1985,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2040,2042]

# %%
import numpy as np
def square(x: np.ndarray):
    return np.power(x,2)

# %%
square(np.array([1,3]))

# %%
from typing import List
