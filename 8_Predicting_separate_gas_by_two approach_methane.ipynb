# %% [markdown]
# # 1. predicting adsorption for each adsorption data point using Vt&BET only

# %%
import pandas as pd
import numpy as np
import os 
BET_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/Treated/Methane'

def pred_dataset(file_names):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-02-02-2022.xlsx'),skiprows= 1 )
        #temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        train_df = pd.concat([train_df,temp_data],axis=0)
       
    return train_df

# %%
from scipy import interpolate
import numpy as np
import pandas as pd

def inter_data(x_old,y_old):
    
    f = interpolate.interp1d(x_old, y_old,'slinear')    
    x_new = np.linspace(min(x_old), max(x_old),num=50)
       
    """
        for ele in x_old:
            t = bi_find(x_new,ele)

            x_new[t] = ele
        
        if (len(x_new)>150):
            x_new = x_new[len(x_new)-150:]
         = np.arange(min(x_old), max(x_old), (max(x_old)-min(x_old))/150)
    """
    y_new = f(x_new)
    #X_feature = np.append(x_new.reshape(-1,1),y_new.reshape(-1,1),axis=1).reshape(2,35).tolist()
    #x_mat = np.append(x_mat,X_feature,axis=1)
       
    return x_new, y_new

# %%
data = pred_dataset(["Methane"])
data.head()
# Out:
#    Unnamed: 0 Literature Literature_full  Unnamed: 1       GAC      GAS  E  S  \
# 0           0          1               1          26  Graphene  Methane  0  0
# 1           1          1               1          27  Graphene  Methane  0  0
# 2           2          1               1          28  Graphene  Methane  0  0
# 3           3          1               1          29  Graphene  Methane  0  0
# 4           4          1               1          30  Graphene  Methane  0  0
#
#    A  B  ...  %N  Temp(K)  Pressure  Adsorp(mmol/g)  Index      logP  \
# 0  0  0  ... NaN    278.0  0.053415        0.018737   2751 -2.929665
# 1  0  0  ... NaN    278.0  0.170583        0.061587   2751 -1.768532
# 2  0  0  ... NaN    278.0  0.301536        0.104402   2751 -1.198866
# 3  0  0  ... NaN    278.0  0.404920        0.136500   2751 -0.904066
# 4  0  0  ... NaN    278.0  0.534150        0.171229   2751 -0.627079
#
#        logQ      logD    Label  Vmic_index
# 0 -3.977255 -1.047591  Methane           0
# 1 -2.787307 -1.018775  Methane           0
# 2 -2.259508 -1.060643  Methane           0
# 3 -1.991431 -1.087365  Methane           0
# 4 -1.764751 -1.137672  Methane           0
#
# [5 rows x 28 columns]

# %%
BET_df = pd.DataFrame()
cols = ["E","S","A","B","V","BET","Vt","Vmic","Vmeso","Temp(K)","Pressure","Adsorp(mmol/g)","Index"]
def bet_extraction(temp_df:pd.DataFrame):
    global BET_df
    literature = temp_df["Literature"].values[0]
    gac_name = temp_df["GAC"].values[0]
    print(literature,gac_name)
    
    try:
        if literature!=np.nan:
                bet_data = BET_path+'/'+str(literature)+"/"+gac_name+".csv"
                #print(bet_data)
                bet_curve = pd.read_csv(bet_data,header=None)
                
                x = bet_curve.iloc[:,0].values.tolist()
                y = bet_curve.iloc[:,1].values.tolist()
                _,new_y = inter_data(x,y)
                rows = len(temp_df)
                bet_matrix = [new_y for _ in range(rows)]
                bet_df = pd.DataFrame(bet_matrix,columns = ["BET_"+str(i) for i in range(len(new_y))])
                bet_df = pd.concat([bet_df,temp_df[cols].reset_index()],axis= 1,ignore_index=True)
                print(bet_df.shape)
                BET_df = pd.concat([BET_df,bet_df,],axis= 0,ignore_index=True)    
               

        else:
            print("There is not leterature for this gac: {}".format(gac_name))         
    except:
        print("The BET curve for gac: {} from paper {} is not available.".format(gac_name,literature))
total_index = list(set(data["Index"].values.tolist()))
for index in total_index:
    temp_df =  data[data["Index"]==index]
    bet_extraction(temp_df)
print(i)
# Out:
# 1 Graphene
# (8, 64)
# 1 Graphene
# (8, 64)
# nan Norit R1 Extra
# The BET curve for gac: Norit R1 Extra from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan BPL
# The BET curve for gac: BPL from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan A10
# The BET curve for gac: A10 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MaxSorb
# The BET curve for gac: MaxSorb from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Carbon A
# The BET curve for gac: Carbon A from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CAQF-30
# The BET curve for gac: CAQF-30 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Maxsorb II
# The BET curve for gac: Maxsorb II from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 7 ACB-5
# (9, 64)
# 7 ACB-2
# (11, 64)
# nan MAC
# The BET curve for gac: MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3/MAC
# The BET curve for gac: K2CO3/MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Coal tar pitch
# The BET curve for gac: Coal tar pitch from paper nan is not available.
# nan Petro pitch 1
# The BET curve for gac: Petro pitch 1 from paper nan is not available.
# nan Viscose Rayon
# The BET curve for gac: Viscose Rayon from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# 10 KUA11701
# (9, 64)
# 10 KUA2170-200
# The BET curve for gac: KUA2170-200 from paper 10 is not available.
# 10 KUA21801
# (10, 64)
# 10 KUA21751
# (10, 64)
# 10 KUA41701
# The BET curve for gac: KUA41701 from paper 10 is not available.
# 10 KUA31752
# (10, 64)
# 10 CFC79
# (10, 64)
# 10 Com-AFC
# The BET curve for gac: Com-AFC from paper 10 is not available.
# 10 LFC61
# (9, 64)
# 10 CFC50
# (8, 64)
# 10 CFS54
# (9, 64)
# 10 LFC29
# (8, 64)
# 10 CFS27
# (8, 64)
# 10 CFC11
# (8, 64)
# 11 RP-15
# (13, 64)
# 11 RP-15
# (13, 64)
# 11 RP-15
# (12, 64)
# 11 RP-20
# (14, 64)
# 11 RP-20
# (12, 64)
# 11 RP-20
# (12, 64)
# 12 Maxsorb II
# The BET curve for gac: Maxsorb II from paper 12 is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 13 MaxSorb III
# The BET curve for gac: MaxSorb III from paper 13 is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AFC-20
# The BET curve for gac: AFC-20 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 14 ACF
# (9, 64)
# 14 ACF
# (9, 64)
# 14 ACF
# (9, 64)
# 14 ACS
# (9, 64)
# 14 ACS
# (9, 64)
# 14 ACS
# (9, 64)
# 15 C2
# The BET curve for gac: C2 from paper 15 is not available.
# nan 53-W2-N
# The BET curve for gac: 53-W2-N from paper nan is not available.
# nan 36-W2
# The BET curve for gac: 36-W2 from paper nan is not available.
# nan 53-W1
# The BET curve for gac: 53-W1 from paper nan is not available.
# nan 44-W2
# The BET curve for gac: 44-W2 from paper nan is not available.
# nan 53-W2
# The BET curve for gac: 53-W2 from paper nan is not available.
# nan 29-W1
# The BET curve for gac: 29-W1 from paper nan is not available.
# 16 C1
# The BET curve for gac: C1 from paper 16 is not available.
# nan C2
# The BET curve for gac: C2 from paper nan is not available.
# nan C3
# The BET curve for gac: C3 from paper nan is not available.
# nan C4
# The BET curve for gac: C4 from paper nan is not available.
# nan C5
# The BET curve for gac: C5 from paper nan is not available.
# nan C6
# The BET curve for gac: C6 from paper nan is not available.
# nan C7
# The BET curve for gac: C7 from paper nan is not available.
# nan C10
# The BET curve for gac: C10 from paper nan is not available.
# 17 Glc-C-4
# (13, 64)
# 17 Glc-C-4
# (13, 64)
# 17 Glc-C-4
# (13, 64)
# 18 LMA738
# (8, 64)
# 18 LMA726
# (9, 64)
# 18 LMA405
# (10, 64)
# 18 MaxSorb
# (8, 64)
# 18 RGC30
# (10, 64)
# 18 F400
# (7, 64)
# 19 S-750-30-09
# (7, 64)
# 19 S-800-30-09
# (7, 64)
# 19 S-850-30-09
# (7, 64)
# 19 S-900-30-09
# (6, 64)
# 19 S-800-90-09
# (8, 64)
# 19 S-800-150-09
# (6, 64)
# 19 S-800-90-06
# (5, 64)
# 19 S-800-90-10
# (6, 64)
# 19 S-800-90-12
# (6, 64)
# 20 ACDS2800
# (11, 64)
# 20 ACDS2700
# (12, 64)
# 20 ACDS2600
# (14, 64)
# 20 ACDS4800
# (12, 64)
# 20 ACDS4700
# (12, 64)
# 20 ACDS4600
# (12, 64)
# 21 sOMC
# (10, 64)
# 21 sOMC
# (9, 64)
# 21 sOMC
# (10, 64)
# 22 AC700
# (12, 64)
# 22 AC700
# (11, 64)
# 22 AC700
# (11, 64)
# 22 AC700
# (11, 64)
# 22 AC700
# (11, 64)
# 23 GAC-Egypt
# (17, 64)
# 23 GAC-Egypt
# (13, 64)
# 23 GAC-Egypt
# (13, 64)
# 23 GAC-Egypt
# (13, 64)
# 23 GAC-Egypt
# (13, 64)
# 23 GAC-Egypt
# (15, 64)
# nan 875-CO-8
# The BET curve for gac: 875-CO-8 from paper nan is not available.
# nan 875-CO-4
# The BET curve for gac: 875-CO-4 from paper nan is not available.
# nan 875-CO-2
# The BET curve for gac: 875-CO-2 from paper nan is not available.
# nan 990-CO-2
# The BET curve for gac: 990-CO-2 from paper nan is not available.
# nan 970-CO-2
# The BET curve for gac: 970-CO-2 from paper nan is not available.
# nan 925-CO-2
# The BET curve for gac: 925-CO-2 from paper nan is not available.
# nan 600-600-H2
# The BET curve for gac: 600-600-H2 from paper nan is not available.
# nan 500-600-H2
# The BET curve for gac: 500-600-H2 from paper nan is not available.
# nan 400-600-H2
# The BET curve for gac: 400-600-H2 from paper nan is not available.
# nan 400-600-H-KOH
# The BET curve for gac: 400-600-H-KOH from paper nan is not available.
# nan 500-600-H-KOH
# The BET curve for gac: 500-600-H-KOH from paper nan is not available.
# nan MaxSorb III
# The BET curve for gac: MaxSorb III from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan ACF-20
# The BET curve for gac: ACF-20 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 26 UK-GAC
# (9, 64)
# 26 UK-GAC
# (10, 64)
# 26 UK-GAC
# (9, 64)
# 27 AC1
# (10, 64)
# 27 AC2
# (12, 64)
# 27 AC3
# (12, 64)
# 27 AC4
# (12, 64)
# 27 AC3
# (13, 64)
# 27 AC3
# (12, 64)
# 27 AC3
# (13, 64)
# nan CAGO Com
# The BET curve for gac: CAGO Com from paper nan is not available.
# nan CAGO C
# The BET curve for gac: CAGO C from paper nan is not available.
# nan CA GO P
# The BET curve for gac: CA GO P from paper nan is not available.
# 29 MAXSorB
# (9, 64)
# 29 CMK-3
# (9, 64)
# 29 PACN-CO2-12h
# (9, 64)
# 29 PACN-CO2-9h
# (8, 64)
# 29 PACN-CO2-12h PELLET
# (12, 64)
# 29 PACN-CO2-9h PELLET
# (11, 64)
# 30 AN2.57301
# (12, 64)
# 30 AN37301
# (11, 64)
# 30 AN27301
# (10, 64)
# 30 AN26701
# (13, 64)
# 30 AN26702
# (10, 64)
# 30 AN27302
# (12, 64)
# nan Nprot-AC
# The BET curve for gac: Nprot-AC from paper nan is not available.
# 32 EC250H2
# (8, 64)
# 32 EC250H2
# (8, 64)
# 32 EC250H2
# (9, 64)
# 33 C-4
# (10, 64)
# 33 C-5
# (11, 64)
# 33 C-3
# (9, 64)
# 33 C-2
# (11, 64)
# 33 C-6
# (13, 64)
# 33 C-1
# (10, 64)
# 34 S0
# (7, 64)
# 34 S40
# (7, 64)
# 34 S50
# (7, 64)
# 34 S50
# (7, 64)
# 34 S50
# (6, 64)
# 35 CMS-1
# (10, 64)
# 35 CMS-2
# (12, 64)
# 35 CMS-3
# (12, 64)
# 35 CMS-1
# (11, 64)
# 35 CMS-2
# (12, 64)
# 35 CMS-3
# (12, 64)
# 35 CMS-1
# (12, 64)
# 35 CMS-2
# (12, 64)
# 35 CMS-3
# (12, 64)
# nan MICRO-GAC
# The BET curve for gac: MICRO-GAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 37 GS
# (12, 64)
# 37 GS
# (11, 64)
# 37 GS
# (11, 64)
# 37 AC-01
# (12, 64)
# 37 AC-01
# (11, 64)
# 37 AC-01
# (11, 64)
# 37 Carbon Black
# (13, 64)
# 37 Carbon Black
# (10, 64)
# 37 Carbon Black
# (10, 64)
# 38 KOH0.5TP50
# (11, 64)
# 38 KOH0.5TP50
# (11, 64)
# 38 KOH0.5TP50
# (12, 64)
# nan DO_800
# The BET curve for gac: DO_800 from paper nan is not available.
# nan DO_700
# The BET curve for gac: DO_700 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MSC-30
# The BET curve for gac: MSC-30 from paper nan is not available.
# 40 M1273-150
# (13, 64)
# 40 M1273-150
# (13, 64)
# 40 M1273-150
# (12, 64)
# 40 M1273-150
# (13, 64)
# 40 M1273-150
# (12, 64)
# 41 babassu-AC
# (15, 64)
# 41 babassu-AC
# (16, 64)
# 41 babassu-AC
# (14, 64)
# 42 C60-CC-PNP
# (11, 64)
# 42 C30-CC-PNP
# (11, 64)
# 42 C85-CC-PNP
# (12, 64)
# 42 P-CC-PNP
# (14, 64)
# 43 PRC-850
# (11, 64)
# 43 PRC-800
# (10, 64)
# 43 PRC-900
# (11, 64)
# 43 PRC-850
# (9, 64)
# 43 PRC-850
# (10, 64)
# 44 AC800
# (9, 64)
# 44 AC800
# (10, 64)
# 44 CMS
# (9, 64)
# 44 CMS
# (9, 64)
# 44 CMS
# (7, 64)
# 45 AC-H3PO4
# (7, 64)
# 45 AC-H3PO4
# (7, 64)
# 45 AC-H2O
# (9, 64)
# 45 AC-H2O
# (8, 64)
# 45 AC-CO2
# (7, 64)
# 45 AC-CO2
# (7, 64)
# 46 AC-1
# (8, 64)
# 46 AC-2
# (9, 64)
# 46 AC-4
# (8, 64)
# 46 NAC-1
# (7, 64)
# 46 NAC-2
# (8, 64)
# 46 NAC-4
# (8, 64)
# nan ADPC05
# The BET curve for gac: ADPC05 from paper nan is not available.
# nan ADPC1
# The BET curve for gac: ADPC1 from paper nan is not available.
# nan ADPC3
# The BET curve for gac: ADPC3 from paper nan is not available.
# nan C1050
# The BET curve for gac: C1050 from paper nan is not available.
# nan C1050P
# The BET curve for gac: C1050P from paper nan is not available.
# nan CDC
# The BET curve for gac: CDC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 50 AAC-1
# (9, 64)
# 50 CAC-2
# (13, 64)
# 50 AAC-1
# (17, 64)
# 50 AAC-1
# (15, 64)
# 50 AAC-1
# (18, 64)
# 51 PN18001
# (10, 64)
# 51 AC
# (8, 64)
# 51 IN18001
# (11, 64)
# 51 CN18001
# (11, 64)
# 52 CS-CO2
# (13, 64)
# 52 CS-H2O
# (12, 64)
# 52 CS-CO2
# (12, 64)
# 52 CS-H2O
# (13, 64)
# 52 CS-CO2
# (12, 64)
# 52 CS-H2O
# (11, 64)
# 53 SMC-1
# (11, 64)
# 53 SMC-2
# (8, 64)
# 53 SMC-3
# (9, 64)
# 53 SMC-1
# (9, 64)
# 53 SMC-2
# (9, 64)
# 53 SMC-2
# (8, 64)
# 53 SMC-1
# (8, 64)
# 53 SMC-2
# (8, 64)
# 53 SMC-3
# (8, 64)
# 54 CS0
# (5, 64)
# 54 CS3
# (6, 64)
# 54 CS6
# (6, 64)
# 55 AKFs1
# (8, 64)
# 55 AKFs2
# (8, 64)
# 55 AKFs3
# (6, 64)
# 55 AKFs4
# (10, 64)
# 55 AKFs5
# (9, 64)
# 55 AKFs6
# (7, 64)
# 55 AKFs7
# (8, 64)
# 55 AKFs1
# (8, 64)
# 55 AKFs2
# (8, 64)
# 55 AKFs3
# (6, 64)
# 55 AKFs4
# (8, 64)
# 55 AKFs5
# (9, 64)
# 55 AKFs6
# (8, 64)
# 55 AKFs7
# (8, 64)
# 55 AKFs1
# (7, 64)
# 55 AKFs3
# (6, 64)
# 55 AKFs5
# (9, 64)
# 55 AKFs7
# (6, 64)
# 56 RP-15
# (13, 64)
# 56 RP-15
# (13, 64)
# 56 RP-15
# (12, 64)
# 56 RP-20
# (14, 64)
# 56 RP-20
# (12, 64)
# 56 RP-20
# (12, 64)
# 58 I-AC
# (18, 64)
# 58 I-AC
# (18, 64)
# 58 I-AC
# (18, 64)
# nan AC bead
# The BET curve for gac: AC bead from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 60 Super-AC
# (8, 64)
# 60 AC
# (7, 64)
# 60 OMC
# (8, 64)
# 60 Super-AC
# (7, 64)
# 60 AC
# (7, 64)
# 60 OMC
# (8, 64)
# 60 Super-AC
# (7, 64)
# 60 AC
# (8, 64)
# 60 OMC
# (7, 64)
# 61 C3
# (9, 64)
# 61 C7
# (10, 64)
# 61 C8
# (11, 64)
# 61 C10
# (12, 64)
# 62 AC600CTP
# (12, 64)
# 62 AC500CTP
# (11, 64)
# 62 AC700CTP
# (11, 64)
# 62 AC600CTP
# (13, 64)
# 62 AC600CTP
# (13, 64)
# 63 HS-KOH-1-4
# (7, 64)
# 63 HS-KOH-1-4
# (7, 64)
# 63 HS-KOH-1-4
# (7, 64)
# 64 TPC-1
# (12, 64)
# 65 PHA
# (10, 64)
# 65 NAHA-0.5
# (10, 64)
# 65 NAHA-1
# (11, 64)
# 65 NAHA-2
# (10, 64)
# 65 NAHA-4
# (10, 64)
# 65 NAHA-2
# (9, 64)
# 65 NAHA-2
# (9, 64)
# 65 NAHA-1
# (10, 64)
# 65 NAHA-1
# (10, 64)
# 65 PHA
# (10, 64)
# 65 PHA
# (10, 64)
# 66 AC-PKOH
# (10, 64)
# 66 AC-PKOH
# (10, 64)
# 66 AC-PKOH
# (11, 64)
# 66 AC-RH
# (8, 64)
# 66 AC-RH
# (7, 64)
# 66 AC-RH
# (9, 64)
# 66 AC-PH2O
# (10, 64)
# 66 AC-PH2O
# (10, 64)
# 66 AC-PH2O
# (9, 64)
# 67 Zn2-1 (+10)
# The BET curve for gac: Zn2-1 (+10) from paper 67 is not available.
# 67 Zn1-1 (+10)
# The BET curve for gac: Zn1-1 (+10) from paper 67 is not available.
# 67 Zn0.5-1 (+10)
# The BET curve for gac: Zn0.5-1 (+10) from paper 67 is not available.
# 67 LAAF2
# (10, 64)
# 67 LAAF1
# (11, 64)
# 67 LAFF3
# The BET curve for gac: LAFF3 from paper 67 is not available.
# 68 CZ1023
# (10, 64)
# 68 CZ1073
# (9, 64)
# 68 CZ1123
# (9, 64)
# 68 CZ1073
# (7, 64)
# 68 CZ1073
# (7, 64)
# 69 MR-1-2
# (11, 64)
# 69 MR-1-2
# (10, 64)
# 69 MR-1-2
# (11, 64)
# 69 MR-1-3
# (10, 64)
# 69 MR-1-3
# (11, 64)
# 69 MR-1-3
# (10, 64)
# 69 MR-1-4
# (10, 64)
# 69 MR-1-4
# (11, 64)
# 69 MR-1-4
# (10, 64)
# 70 ACD18-053
# (11, 64)
# 70 ACD18-053
# (9, 64)
# 70 ACD18-053
# (10, 64)
# nan AC-4
# The BET curve for gac: AC-4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC-6
# The BET curve for gac: AC-6 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 72 AMC-700
# (13, 64)
# 72 AMC-800
# (13, 64)
# 72 AMC-900
# (13, 64)
# nan KOH:FPV_850=4
# The BET curve for gac: KOH:FPV_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:FPV_850=1
# The BET curve for gac: K2CO3:FPV_850=1 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan KOH:WG-12_850=4
# The BET curve for gac: KOH:WG-12_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:WG-12_850=1
# The BET curve for gac: K2CO3:WG-12_850=1 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan KOH:CW-22_850=4
# The BET curve for gac: KOH:CW-22_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:CWZ-22_850=4
# The BET curve for gac: K2CO3:CWZ-22_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MPU-007
# The BET curve for gac: MPU-007 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan LCN
# The BET curve for gac: LCN from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 76 C800
# (12, 64)
# 76 C1000
# (16, 64)
# 76 C1200
# (13, 64)
# 76 C1400
# (14, 64)
# 77 C800
# (10, 64)
# 78 CAC-50
# (11, 64)
# 78 CAC-50
# (12, 64)
# 78 CAC-50
# (12, 64)
# 79 C-PVDC-600
# (11, 64)
# 79 C-PVDC-700
# (11, 64)
# 79 C-PVDC-800
# (11, 64)
# 79 C-PVDC-900
# (11, 64)
# 79 C-PVDC-1000
# The BET curve for gac: C-PVDC-1000 from paper 79 is not available.
# 79 C-PVDC-600
# (13, 64)
# 79 C-PVDC-700
# (13, 64)
# 79 C-PVDC-800
# (11, 64)
# 79 C-PVDC-900
# (12, 64)
# 79 C-PVDC-1000
# The BET curve for gac: C-PVDC-1000 from paper 79 is not available.
# 80 UC600
# (9, 64)
# 80 UC700
# (10, 64)
# 80 UC800
# (11, 64)
# 80 UC900
# (11, 64)
# 81 AR-V
# (10, 64)
# 81 AR-V
# (12, 64)
# 81 AR-V
# (12, 64)
# 81 AR-V
# (12, 64)
# 81 AR-V
# (11, 64)
# 81 AR-V
# (10, 64)
# 82 R-AC
# (12, 64)
# 82 1H-AC
# (14, 64)
# 82 15H-AC
# (14, 64)
# 83 GOC-1
# (12, 64)
# 83 GOC-2
# (16, 64)
# 83 GOC-3
# (13, 64)
# 83 GOC-4
# (14, 64)
# 83 GOC-2
# (10, 64)
# 83 GOC-2
# (11, 64)
# 84 SC-1
# (9, 64)
# 84 SC-4
# (11, 64)
# 84 SC-6
# (11, 64)
# 84 SC-6
# (10, 64)
# 84 SC-6
# (10, 64)
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan AC-APS
# The BET curve for gac: AC-APS from paper nan is not available.
# nan AC-HP
# The BET curve for gac: AC-HP from paper nan is not available.
# nan AC-SA-APS
# The BET curve for gac: AC-SA-APS from paper nan is not available.
# 86 AC
# (10, 64)
# 86 AC-U
# (9, 64)
# 86 AC-OX
# (9, 64)
# 86 AC-OX-U1
# (10, 64)
# 86 AC-OX-U2
# (9, 64)
# 87 BEA-ZTC
# (8, 64)
# 87 BEA-ZTC
# (8, 64)
# 87 BEA-ZTC
# (8, 64)
# 87 BEA-ZTC
# (8, 64)
# 87 BEA-ZTC-873K
# (8, 64)
# 87 BEA-ZTC-873K
# (8, 64)
# 87 BEA-ZTC-873K
# (8, 64)
# 87 BEA-ZTC-873K
# (8, 64)
# 87 BEA-ZTC-1073K
# (8, 64)
# 87 BEA-ZTC-1073K
# (8, 64)
# 87 BEA-ZTC-1073K
# (8, 64)
# 87 BEA-ZTC-1073K
# (8, 64)
# 87 FAU-ZTC
# (8, 64)
# 87 FAU-ZTC
# (8, 64)
# 87 FAU-ZTC
# (8, 64)
# 87 FAU-ZTC
# (8, 64)
# 87 FAU-ZTC-873K
# (8, 64)
# 87 FAU-ZTC-873K
# (8, 64)
# 87 FAU-ZTC-873K
# (8, 64)
# 87 FAU-ZTC-873K
# (8, 64)
# 87 FAU-ZTC-1073K
# (8, 64)
# 87 FAU-ZTC-1073K
# (8, 64)
# 87 FAU-ZTC-1073K
# (8, 64)
# 87 FAU-ZTC-1073K
# (8, 64)
# 88 CMS80070-10
# (12, 64)
# 88 CMS80070-20
# (12, 64)
# 88 Pre-AC
# (13, 64)
# nan MAC
# The BET curve for gac: MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 90 CPC-550
# (12, 64)
# 90 CPC-600
# (10, 64)
# 90 CPC-650
# (12, 64)
# 90 CPC-700
# (11, 64)
# 90 CPC-800
# (15, 64)
# 91 CNS-AC
# (13, 64)
# 91 CNS-AC
# (12, 64)
# 91 CNS-AC
# (13, 64)
# 92 AC
# (11, 64)
# 92 PS
# (11, 64)
# 92 ML
# (11, 64)
# 92 GL
# (11, 64)
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan Calgon BP
# The BET curve for gac: Calgon BP from paper nan is not available.
# 94 MA-PC3-PFA-10
# (14, 64)
# 94 MA-PC4-PFA
# (13, 64)
# 94 Norit-R2
# The BET curve for gac: Norit-R2 from paper 94 is not available.
# 94 MA-PC2-PFA
# (10, 64)
# 95 AC-1
# (8, 64)
# 95 AC-2
# (8, 64)
# 95 AC-1
# (8, 64)
# 95 AC-2
# (8, 64)
# 95 AC-1
# (8, 64)
# 95 AC-2
# (8, 64)
# 96 DO
# (11, 64)
# 96 DO-1000
# (11, 64)
# 96 DO-1350
# (12, 64)
# 96 DO-1500
# (13, 64)
# 96 PA
# (8, 64)
# 96 PA-1000
# (10, 64)
# 96 PA-1350
# (10, 64)
# 96 PA-1500
# (11, 64)
# 97 SBL-CO-PP-C-7
# (12, 64)
# 97 SBL-CO-PP-C-20
# (12, 64)
# 97 SBL-CO-PP-20
# (11, 64)
# 97 SBL-CO-PP-7
# (10, 64)
# 97 CO-PP-0
# (12, 64)
# 98 AC
# (10, 64)
# 98 Cl-AC
# (10, 64)
# 98 N-AC
# (9, 64)
# 98 K-AC
# (9, 64)
# 98 KCl-AC
# (9, 64)
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan RX 1.5
# The BET curve for gac: RX 1.5 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CGran
# The BET curve for gac: CGran from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Rox 0.8
# The BET curve for gac: Rox 0.8 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan GAC 1240
# The BET curve for gac: GAC 1240 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 100 SBL-PNP-0.5-2-800
# (12, 64)
# 100 SBL-PNP-1-4-750
# (13, 64)
# 100 SBL-PNP-0.5-4-750
# (11, 64)
# 102 MPP4
# (11, 64)
# 102 MPP3
# (11, 64)
# 102 MPZ8
# (11, 64)
# 102 MPZ7
# (8, 64)
# 102 MPC12
# (7, 64)
# 102 MPK16
# (10, 64)
# 102 MPK15
# (8, 64)
# 103 R-AC
# (8, 64)
# 103 1H-AC
# (9, 64)
# 103 5H-AC
# (10, 64)
# 103 15H-AC
# (10, 64)
# 103 1H-AC
# (8, 64)
# 103 1H-AC
# (9, 64)
# 104 NCSs
# (7, 64)
# 104 ACSs
# (7, 64)
# 104 ACSs-N
# (6, 64)
# 104 ACSs-N
# (8, 64)
# 104 ACSs-N
# (7, 64)
# 105 AC-90S
# (8, 64)
# 105 AC-90S
# (7, 64)
# 105 AC-90S
# (6, 64)
# 105 AC-90S
# (7, 64)
# 105 AC-90L
# (6, 64)
# 105 AC-90L
# (6, 64)
# 105 AC-90L
# (6, 64)
# 105 AC-90L
# (6, 64)
# 105 AC-60L
# (8, 64)
# 105 AC-60L
# (8, 64)
# 105 AC-60L
# (8, 64)
# 105 AC-60L
# (6, 64)
# 106 CNT-AC0
# (6, 64)
# 106 CNT-AC1
# (5, 64)
# 106 CNT-AC2
# (5, 64)
# 106 CNT-AC3
# (5, 64)
# 106 CNT-AC5
# (5, 64)
#   DF-AC
# The BET curve for gac: DF-AC from paper   is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan SM-AC
# The BET curve for gac: SM-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# H46 C-CroPASP
# (8, 64)
# H46 C-PASP
# (9, 64)
# H53 HCPB
# (9, 64)
# H53 CHCPB-K-600
# (10, 64)
# H53 CHCPB-K-700
# (11, 64)
# H53 CHCPB-K-800
# (11, 64)
# CO189 CS
# (6, 64)
# CO189 CSK-1
# (8, 64)
# CO189 CSK-2
# (7, 64)
# CO189 CSK-7
# (7, 64)
# CO189 CSK-5
# (9, 64)
# CO189 CSK-5
# (8, 64)
# CO189 CSK-5
# (9, 64)
# CO189 CSK-5
# (9, 64)
# CO189 CSK-5
# (8, 64)
# nan SPC-5
# The BET curve for gac: SPC-5 from paper nan is not available.
# nan SPC-4
# The BET curve for gac: SPC-4 from paper nan is not available.
# nan SPC-3
# The BET curve for gac: SPC-3 from paper nan is not available.
# nan SPC-2
# The BET curve for gac: SPC-2 from paper nan is not available.
# nan SPC-1
# The BET curve for gac: SPC-1 from paper nan is not available.
# CO184 M-C-KOH-4-800
# (11, 64)
# CO184 M-C-4-800
# (10, 64)
# CO184 M-C-4-700
# (10, 64)
# CO184 M-C-APS-4-800
# (10, 64)
# CO177 CSCN_9_C180
# (8, 64)
# CO177 CSCN_9_C60
# (6, 64)
# CO177 CSCN_6
# (9, 64)
# CO177 CSCN_6_C150
# (8, 64)
# CO177 CSCN_6_C200
# (8, 64)
# CO177 CSCN_9
# (9, 64)
# CO175 PA-P
# (9, 64)
# CO175 PA-P
# (8, 64)
# CO175 PA-P-6C
# (8, 64)
# CO175 PA-P-6C
# (7, 64)
# CO175 PA-P-6A
# (9, 64)
# CO175 PA-P-6A
# (8, 64)
# CO175 PA-P-7C
# (9, 64)
# CO175 PA-P-7C
# (10, 64)
# CO175 PA-P-7A
# (10, 64)
# CO175 PA-P-7A
# (8, 64)
# CO173 NDC
# (7, 64)
# CO173 NDC
# (9, 64)
# CO173 NDC
# (7, 64)
# CO166 SD-600-4
# The BET curve for gac: SD-600-4 from paper CO166 is not available.
# CO166 SD-800-4
# The BET curve for gac: SD-800-4 from paper CO166 is not available.
# CO166 SD-M-800-4
# The BET curve for gac: SD-M-800-4 from paper CO166 is not available.
# CO166 PPY-700-2
# (9, 64)
# CO166 PPY-800-4
# The BET curve for gac: PPY-800-4 from paper CO166 is not available.
# CO166 PTH-600-2
# The BET curve for gac: PTH-600-2 from paper CO166 is not available.
# CO164 PCTP-3
# (8, 64)
# CO164 PCTP-3
# (9, 64)
# CO164 PCTP-3C
# (11, 64)
# CO164 PCTP-3C
# (10, 64)
# CO164 APCTP-3C
# (9, 64)
# CO164 APCTP-3C
# (9, 64)
# CO155 FCDTPA
# (10, 64)
# CO155 FCDTPA-500
# (10, 64)
# CO155 FCDTPA-700
# (9, 64)
# CO155 FCDTPA-900
# (9, 64)
# CO155 FCDTPA-K-500
# (10, 64)
# CO155 FCDTPA-K-700
# (10, 64)
# CO155 FCDTPA-K-900
# (10, 64)
# CO152 NMC
# (7, 64)
# CO152 NMC
# (7, 64)
# CO152 NMC
# (7, 64)
# CO152 MGO-NMC-20
# (7, 64)
# CO152 MGO-NMC-20
# (7, 64)
# CO152 MGO-NMC-20
# (7, 64)
# CO152 MGO-NMC-10
# (6, 64)
# CO152 MGO-NMC-10
# (7, 64)
# CO152 MGO-NMC-10
# (7, 64)
# CO149 OTS-3-750
# (8, 64)
# CO149 OTS-3-750
# (8, 64)
# CO149 OTS-2-650
# (10, 64)
# CO149 OTS-2-650
# (8, 64)
# CO149 OTS-1-550
# (9, 64)
# CO149 OTS-1-550
# (8, 64)
# CO128 OTSS-3-350
# (7, 64)
# CO128 OTSS-2-450
# (7, 64)
# CO128 OTSS-1-550
# (8, 64)
# CO128 OTSS-3-350
# (8, 64)
# CO128 OTSS-2-450
# (9, 64)
# CO128 OTSS-1-550
# (9, 64)
# CO101 SA-2-800
# (9, 64)
# CO101 SA-2-700
# (9, 64)
# CO101 SA-2-600
# (9, 64)
# CO101 SA-2-800
# (9, 64)
# CO101 SA-2-700
# (9, 64)
# CO101 SA-2-600
# (10, 64)
# CO101 SA-2-800
# (8, 64)
# CO101 SA-2-700
# (9, 64)
# CO101 SA-2-600
# (8, 64)
# CO101 SA-1-800
# (8, 64)
# CO101 SA-1-700
# (10, 64)
# CO101 SA-1-600
# (9, 64)
# CO101 SA-1-800
# (8, 64)
# CO101 SA-1-800
# (10, 64)
# CO101 SA-1-700
# (8, 64)
# CO101 SA-1-700
# (9, 64)
# CO101 SA-1-600
# (9, 64)
# CO101 SA-1-600
# (8, 64)
# EE2  PAC
# The BET curve for gac: PAC from paper EE2  is not available.
# EE2 PAC
# (13, 64)
# EE2 PAC
# (11, 64)
# nan PCB
# The BET curve for gac: PCB from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan RX1.5
# The BET curve for gac: RX1.5 from paper nan is not available.
# nan RX0.8
# The BET curve for gac: RX0.8 from paper nan is not available.
# nan CGRAN
# The BET curve for gac: CGRAN from paper nan is not available.
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan GAC-1240
# The BET curve for gac: GAC-1240 from paper nan is not available.
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan RX 1.5
# The BET curve for gac: RX 1.5 from paper nan is not available.
# nan CGRAN
# The BET curve for gac: CGRAN from paper nan is not available.
# nan Rox 0.8
# The BET curve for gac: Rox 0.8 from paper nan is not available.
# nan GAC1240
# The BET curve for gac: GAC1240 from paper nan is not available.
# nan TC
# The BET curve for gac: TC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan pit-GAC
# The BET curve for gac: pit-GAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE10 MHZ-CR
# (8, 64)
# EE10 MHK-CR
# (8, 64)
# EE10 MDZ-CR
# (8, 64)
# EE10 MDK-CR
# (8, 64)
# EE10 AC-CR
# (7, 64)
# EE10 MHZ-CR
# (8, 64)
# EE10 MHZ-CR
# (8, 64)
# nan BDH-AC
# The BET curve for gac: BDH-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE14 HPC800-0.5
# (7, 64)
# EE14 HPC800-1
# (8, 64)
# EE14 HPC800-1.5
# (7, 64)
# EE14 HPC800
# (10, 64)
# EE14 HPC800
# (7, 64)
# EE14 HPC800-0.5
# (7, 64)
# EE14 HPC800-1
# (8, 64)
# nan BDH-activatedcarbon
# The BET curve for gac: BDH-activatedcarbon from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE18 ANPC-1-800
# (10, 64)
# EE18 ANPC-2-700
# (10, 64)
# EE18 ANPC-2-800
# (11, 64)
# EE18 ANPC-1-600
# (11, 64)
# EE18 ANPC-1-700
# (9, 64)
# EE18 ANPC-2-600
# (10, 64)
# EE18 ANPC-1-600
# (11, 64)
# EE18 ANPC-2-600
# (10, 64)
# EE18 ANPC-1-700
# (10, 64)
# EE18 ANPC-2-700
# (8, 64)
# EE18 ANPC-1-800
# (9, 64)
# EE18 ANPC-2-800
# (9, 64)
# EE18 ANPC-1-600
# (9, 64)
# EE18 ANPC-2-600
# (8, 64)
# EE18 ANPC-1-700
# (10, 64)
# EE18 ANPC-2-700
# (8, 64)
# EE18 ANPC-1-800
# (8, 64)
# EE18 ANPC-2-800
# (8, 64)
# EE12 Co-NDPC-500
# (12, 64)
# EE12 Co-NDPC-600
# (11, 64)
# EE12 Co-NDPC-700
# (10, 64)
# EE12 Co-NDPC-800
# (10, 64)
# EE12 Co-NDPC-900
# (8, 64)
# EE12 Co-NDPC-500
# (8, 64)
# EE12 Co-NDPC-600
# (10, 64)
# EE12 Co-NDPC-700
# (10, 64)
# EE12 Co-NDPC-800
# (10, 64)
# EE12 Co-NDPC-900
# (9, 64)
# EE26 A-AC-3
# (9, 64)
# EE26 A-AC-4
# (9, 64)
# EE26 A-AC-5
# (9, 64)
# EE26 A-AC-3
# (8, 64)
# EE26 A-AC-4
# (8, 64)
# EE26 A-AC-5
# (8, 64)
# EE26 A-AC-3
# (8, 64)
# EE26 A-AC-4
# (8, 64)
# EE26 A-AC-5
# (8, 64)
# EE28 NAC-600
# (9, 64)
# EE28 NAC-600
# (11, 64)
# EE28 NAC-700
# (9, 64)
# EE28 NAC-700
# (9, 64)
# EE28 NAC-800
# (10, 64)
# EE28 NAC-800
# (8, 64)
# EE28 NAC-600
# (10, 64)
# EE28 NAC-700
# (9, 64)
# EE28 NAC-800
# (8, 64)
# nan PCB
# The BET curve for gac: PCB from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 49

# %%
BET_df
# Out:
#               0           1           2           3           4           5   \
# 0     101.380981  121.421652  123.031594  126.114134  129.076200  129.006998
# 1     101.380981  121.421652  123.031594  126.114134  129.076200  129.006998
# 2     101.380981  121.421652  123.031594  126.114134  129.076200  129.006998
# 3     101.380981  121.421652  123.031594  126.114134  129.076200  129.006998
# 4     101.380981  121.421652  123.031594  126.114134  129.076200  129.006998
# ...          ...         ...         ...         ...         ...         ...
# 5564  327.041757  399.535749  441.203175  471.788788  497.698318  520.736926
# 5565  327.041757  399.535749  441.203175  471.788788  497.698318  520.736926
# 5566  327.041757  399.535749  441.203175  471.788788  497.698318  520.736926
# 5567  327.041757  399.535749  441.203175  471.788788  497.698318  520.736926
# 5568  327.041757  399.535749  441.203175  471.788788  497.698318  520.736926
#
#               6           7           8           9   ...  54      55      56  \
# 0     128.937796  134.861910  141.008552  146.911738  ...   0  0.2495   514.0
# 1     128.937796  134.861910  141.008552  146.911738  ...   0  0.2495   514.0
# 2     128.937796  134.861910  141.008552  146.911738  ...   0  0.2495   514.0
# 3     128.937796  134.861910  141.008552  146.911738  ...   0  0.2495   514.0
# 4     128.937796  134.861910  141.008552  146.911738  ...   0  0.2495   514.0
# ...          ...         ...         ...         ...  ...  ..     ...     ...
# 5564  534.951482  549.166038  563.890068  579.093969  ...   0  0.2495  1942.8
# 5565  534.951482  549.166038  563.890068  579.093969  ...   0  0.2495  1942.8
# 5566  534.951482  549.166038  563.890068  579.093969  ...   0  0.2495  1942.8
# 5567  534.951482  549.166038  563.890068  579.093969  ...   0  0.2495  1942.8
# 5568  534.951482  549.166038  563.890068  579.093969  ...   0  0.2495  1942.8
#
#         57    58    59     60        61        62    63
# 0     3.00   NaN   NaN  278.0  0.053415  0.018737  2751
# 1     3.00   NaN   NaN  278.0  0.170583  0.061587  2751
# 2     3.00   NaN   NaN  278.0  0.301536  0.104402  2751
# 3     3.00   NaN   NaN  278.0  0.404920  0.136500  2751
# 4     3.00   NaN   NaN  278.0  0.534150  0.171229  2751
# ...    ...   ...   ...    ...       ...       ...   ...
# 5564  1.14  0.73  0.41  323.0  0.469890  0.392164  3599
# 5565  1.14  0.73  0.41  323.0  0.612107  0.421251  3599
# 5566  1.14  0.73  0.41  323.0  0.766028  0.470575  3599
# 5567  1.14  0.73  0.41  323.0  0.937053  0.540081  3599
# 5568  1.14  0.73  0.41  323.0  1.070279  0.650684  3599
#
# [5569 rows x 64 columns]

# %%
BET_df.to_csv('./Methane_Adding_bet_80_new.csv')

# %%
BET_df = pd.read_csv("Methane_Adding_bet_35_new.csv")
BET_df.dropna(axis=0,how="any",subset = ["BET","Vt","Vmic","BET_34"],inplace=True)
#BET_df.dropna(axis=0,how="any",subset = ["BET_34"],inplace=True)

# %%
BET_df.columns
# Out:
# Index(['Unnamed: 0', 'BET_0', 'BET_1', 'BET_2', 'BET_3', 'BET_4', 'BET_5',
#        'BET_6', 'BET_7', 'BET_8', 'BET_9', 'BET_10', 'BET_11', 'BET_12',
#        'BET_13', 'BET_14', 'BET_15', 'BET_16', 'BET_17', 'BET_18', 'BET_19',
#        'BET_20', 'BET_21', 'BET_22', 'BET_23', 'BET_24', 'BET_25', 'BET_26',
#        'BET_27', 'BET_28', 'BET_29', 'BET_30', 'BET_31', 'BET_32', 'BET_33',
#        'BET_34', 'BET_35', 'BET_36', 'BET_37', 'BET_38', 'BET_39', 'BET_40',
#        'BET_41', 'BET_42', 'BET_43', 'BET_44', 'BET_45', 'BET_46', 'BET_47',
#        'BET_48', 'BET_49', 'BET_50', 'BET_51', 'BET_52', 'BET_53', 'BET_54',
#        'BET_55', 'BET_56', 'BET_57', 'BET_58', 'BET_59', 'BET_60', 'BET_61',
#        'BET_62', 'BET_63', 'BET_64', 'BET_65', 'BET_66', 'BET_67', 'BET_68',
#        'BET_69', 'BET_70', 'BET_71', 'BET_72', 'BET_73', 'BET_74', 'BET_75',
#        'BET_76', 'BET_77', 'BET_78', 'BET_79', 'E', 'S', 'A', 'B', 'V', 'BET',
#        'Vt', 'Vmic', 'Vmeso', 'Temp(K)', 'Pressure', 'Adsorp(mmol/g)', 'Index',
#        'Label'],
#       dtype='object')

# %%
# data splitting
#from random import shuffle
from sklearn.model_selection import train_test_split
from numpy import random
def group_split(BET_df:pd.DataFrame,random_state = 42):
    indexs = list(set(BET_df["Index"].values.tolist()))
    #shuffle(indexs)
    _,test_index = train_test_split(indexs,test_size= 0.2,random_state =random_state)

    #test_index = random.choice(indexs,len(indexs)//5,replace=False).tolist()
    train_df = BET_df[~BET_df["Index"].isin(test_index)]
    test_df = BET_df[BET_df["Index"].isin(test_index)]
    return train_df,test_df

# %%
BET_df = BET_df[BET_df.notna()]

# %%
BET_df.describe
# Out:
# <bound method NDFrame.describe of       Unnamed: 0       BET_0       BET_1       BET_2       BET_3       BET_4  \
# 16            16   17.643244  567.318069  603.482236  630.767130  658.843833
# 17            17   17.643244  567.318069  603.482236  630.767130  658.843833
# 18            18   17.643244  567.318069  603.482236  630.767130  658.843833
# 19            19   17.643244  567.318069  603.482236  630.767130  658.843833
# 20            20   17.643244  567.318069  603.482236  630.767130  658.843833
# ...          ...         ...         ...         ...         ...         ...
# 3759        3759  220.194445  242.577496  252.044049  257.873076  261.377191
# 3760        3760  220.194445  242.577496  252.044049  257.873076  261.377191
# 3761        3761  220.194445  242.577496  252.044049  257.873076  261.377191
# 3762        3762  220.194445  242.577496  252.044049  257.873076  261.377191
# 3763        3763  220.194445  242.577496  252.044049  257.873076  261.377191
#
#            BET_5       BET_6       BET_7       BET_8  ...       V     BET  \
# 16    685.510874  708.133113  742.864938  763.226244  ...  0.2495  3537.0
# 17    685.510874  708.133113  742.864938  763.226244  ...  0.2495  3537.0
# 18    685.510874  708.133113  742.864938  763.226244  ...  0.2495  3537.0
# 19    685.510874  708.133113  742.864938  763.226244  ...  0.2495  3537.0
# 20    685.510874  708.133113  742.864938  763.226244  ...  0.2495  3537.0
# ...          ...         ...         ...         ...  ...     ...     ...
# 3759  264.757372  266.062590  267.367807  268.673024  ...  0.2495  1020.0
# 3760  264.757372  266.062590  267.367807  268.673024  ...  0.2495  1020.0
# 3761  264.757372  266.062590  267.367807  268.673024  ...  0.2495  1020.0
# 3762  264.757372  266.062590  267.367807  268.673024  ...  0.2495  1020.0
# 3763  264.757372  266.062590  267.367807  268.673024  ...  0.2495  1020.0
#
#         Vt  Vmic  Vmeso  Temp(K)    Pressure  Adsorp(mmol/g)  Index    Label
# 16    2.56  1.03   1.53    298.0    0.993996        1.163487   2783  Methane
# 17    2.56  1.03   1.53    298.0    2.038097        2.064270   2783  Methane
# 18    2.56  1.03   1.53    298.0    3.954149        3.288360   2783  Methane
# 19    2.56  1.03   1.53    298.0    5.869641        4.640653   2783  Methane
# 20    2.56  1.03   1.53    298.0    8.832454        6.156559   2783  Methane
# ...    ...   ...    ...      ...         ...             ...    ...      ...
# 3759  0.44  0.44   0.00    360.0   13.044182        2.738590   3391  Methane
# 3760  0.44  0.44   0.00    360.0   29.140178        3.932747   3391  Methane
# 3761  0.44  0.44   0.00    360.0   47.891869        4.720687   3391  Methane
# 3762  0.44  0.44   0.00    360.0   71.097494        5.454910   3391  Methane
# 3763  0.44  0.44   0.00    360.0  116.583659        6.164448   3391  Methane
#
# [3651 rows x 95 columns]>

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
  
n_estimators = [50,100,120,150,180,200,300]

# define different models#,
models = [
    #('SVR',SVR(max_iter=100000)),
    #('DT',DecisionTreeRegressor(random_state=42)),\
    # ('ADBR',AdaBoostRegressor(random_state=42)), 
    #("GBR",GradientBoostingRegressor(random_state=42)),\
    #('BG',BaggingRegressor(random_state=42,n_jobs=-1)),
    #('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
    #('RF',RandomForestRegressor(n_jobs=-1,random_state=42)),
    ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
    #('MLPR',MLPRegressor(random_state=42))
    #('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators = 200, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1)),\
    #('BGETR',BaggingRegressor(ExtraTreesRegressor(n_estimators = 180,random_state=42,n_jobs=6),random_state=42,n_jobs=-1))
    ]

# set search parameters grid for different models
para_grids = { 
    'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
    'DT':{'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2],'loss':['linear','square','exponential']},\
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'BG':{'n_estimators':[10,50,100]},\
    'ETR':{'n_estimators':n_estimators},\
    'RF':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,50,],'learning_rate': [0.05,0.1,0.5,1],'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,30,50]},\
    'BGETR':{'n_estimators':[10]},\
    'MLPR':{'hidden_layer_sizes':[(4,100),(5,100),(6,100)],
            "activation":["logistic","relu"],\
            "solver":['sgd', 'adam']}
    }

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,groups,model,para_grid):

    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(model,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []
    for gas in gas_list:
        if gas =='total':
            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index'].values
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])
                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))    
        else:
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
                print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))     
    return result_total

# %%
import os
conditions = ['S','V','Temp(K)','Pressure']
base_feature = ["BET_"+str(i) for i in range(35)]+conditions
feature_list = [base_feature,base_feature+["BET"],base_feature+['Vt'],base_feature+["BET",'Vt'],\
    base_feature+["BET","Vt","Vmic","Vmeso"],["BET","Vt"]+conditions,["BET","Vt","Vmic","Vmeso"]+conditions]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] #['BET_Curve','BET_Plus_Vt',"Vmic_Vmeso"]
gas_list = ['Methane']#,'CFCs','Methane','E&E'

for i in range(50): 
    train_df,test_df = group_split(BET_df,random_state=i)
    for j in range(len(feature_list)):
    
        results = model_comparison(models,para_grids, feature_list[j],gas_list)
        files_name = '35_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./8_using_BET_curve',files_name)) 
    print("The finish of {} th trial".format(i))
# Out:
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9447608429629457, Test_error 0.5892927033619536
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9374708025540808, Test_error 0.6661730790202247
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9432400141170167, Test_error 0.5973685588553374
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9404942978595685, Test_error 0.6358956576399813
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9463210072441994, Test_error 0.5748451631443579
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8870572181769175, Test_error 1.1830155432924234
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9266936180381943, Test_error 0.7552002574422811
# The finish of 0 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9102770287673082, Test_error 0.8630933136509413
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9345064246444277, Test_error 0.5982954890666641
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9320313870258796, Test_error 0.6584886980771499
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9408411921426627, Test_error 0.5477607954338857
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.939077413121619, Test_error 0.5611416506522287
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9166533954140597, Test_error 0.844454467495775
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9270645693751537, Test_error 0.6832164824455154
# The finish of 1 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.898443885291201, Test_error 0.9738386606053303
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9076285797143938, Test_error 0.906492176713964
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9066927839484284, Test_error 0.9169665966008979
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9065654283834252, Test_error 0.9349625999339419
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9013825303414199, Test_error 0.9665074737636554
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8871389388284907, Test_error 1.1130771225028846
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8984415655301378, Test_error 0.9738728629942676
# The finish of 2 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9225752321150841, Test_error 0.7307936149187454
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.925811934279848, Test_error 0.7170404342026611
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9266462492972231, Test_error 0.7010401208761377
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9281629222515363, Test_error 0.7021876674732024
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9221001004737335, Test_error 0.7477894876126413
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8982646577009676, Test_error 1.0783139671756732
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9218967030111299, Test_error 0.7560040337358221
# The finish of 3 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8939567965644963, Test_error 1.0248942549151272
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9159601189707671, Test_error 0.8046886060023083
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9076451684141638, Test_error 0.8800842602698047
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.921612716292664, Test_error 0.7417879083859279
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9203221265136681, Test_error 0.7550823740455247
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9156502495411265, Test_error 0.814675606912138
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.923974680136445, Test_error 0.7088757386764177
# The finish of 4 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9061548581559582, Test_error 0.8609452368610189
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.927839177477831, Test_error 0.6679111627091154
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9173640397603628, Test_error 0.7418421183173689
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9355407349221964, Test_error 0.5967234830797312
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9311938805613877, Test_error 0.6338506741742462
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9280652659609702, Test_error 0.7361248668441632
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9449749600354229, Test_error 0.5221769654257533
# The finish of 5 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8683542515016789, Test_error 1.171067936074133
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8940969862063579, Test_error 0.9224448058718501
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8991944552322897, Test_error 0.8642918496725847
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9083925197538625, Test_error 0.788728143946049
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9169455195389098, Test_error 0.747127124467267
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8989001816234055, Test_error 0.902665233136456
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9195518183366119, Test_error 0.7082047353313754
# The finish of 6 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9483183295468595, Test_error 0.4102087831564384
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9574026208627998, Test_error 0.3399391734431695
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9524043433635412, Test_error 0.3778893100175232
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9616195092219837, Test_error 0.3071627199328058
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9633323998886345, Test_error 0.2939535691845307
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9430581685636397, Test_error 0.451433314650562
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9500062218861713, Test_error 0.4083771074095288
# The finish of 7 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9384207785332037, Test_error 0.549500266173085
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9144370062355177, Test_error 0.7546594906632902
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9553629331554259, Test_error 0.40727884931373143
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9270118503711189, Test_error 0.6421474013003339
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9291894938291723, Test_error 0.6278659540922672
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8999768302984549, Test_error 0.8625615082683336
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9029570083338093, Test_error 0.8650651484461634
# The finish of 8 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9206285959177604, Test_error 0.7778403573057208
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9226290475345289, Test_error 0.7940271138335071
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9243614667627381, Test_error 0.7556377630851173
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.923189931246847, Test_error 0.7835493375118103
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9301357535516448, Test_error 0.6959217500187544
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9142886987600455, Test_error 0.8574242660066651
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9352589998596402, Test_error 0.662777614696838
# The finish of 9 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.942383916955352, Test_error 0.4905256181039451
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9397180220858349, Test_error 0.5097610363489434
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9477162396845266, Test_error 0.444298723313691
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9468912749091696, Test_error 0.44956549659162937
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9511591249448621, Test_error 0.4025441358833814
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.92677895765641, Test_error 0.6085431748749038
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.93452786850421, Test_error 0.5576052403896478
# The finish of 10 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8866122506259391, Test_error 0.9246974448268428
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.894534146436694, Test_error 0.8651803323977347
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9051987362472831, Test_error 0.7893371761944566
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.894507149072305, Test_error 0.8841859503246171
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9088907133908672, Test_error 0.7729914308706575
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8841466500330608, Test_error 1.0493619751358716
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8983447447511571, Test_error 0.881473254083441
# The finish of 11 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9342249953938219, Test_error 0.7282447110313849
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9372122206771155, Test_error 0.7132675900926347
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9346854301193437, Test_error 0.7227666818040327
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9338504742153197, Test_error 0.7272469767430659
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9400339659163168, Test_error 0.6819539477265775
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8979370571874445, Test_error 1.1305995238070057
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9224959862916994, Test_error 0.8553567101509247
# The finish of 12 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9282219827829805, Test_error 0.6585656844862134
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9587248144542663, Test_error 0.3895894301680756
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9499844937697355, Test_error 0.4705832262914821
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.955828036948079, Test_error 0.41650775070004686
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9521448860062544, Test_error 0.4476000787590301
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9336386050970933, Test_error 0.6155348867263689
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9408862112607685, Test_error 0.5431800171371183
# The finish of 13 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9459140934762633, Test_error 0.44103690366133275
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9547562606523723, Test_error 0.3614129509612817
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9521956163825024, Test_error 0.3950016122923056
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9604919157182883, Test_error 0.3190258499504312
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9577057002739215, Test_error 0.3441560873824185
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.923938833641104, Test_error 0.6009278599291572
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9403856369078305, Test_error 0.47463672384269784
# The finish of 14 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9069011125260472, Test_error 0.849118071237014
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9041135657741814, Test_error 0.8892660520031236
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9054904098808663, Test_error 0.8757174260263576
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9085477256143679, Test_error 0.8582055177823914
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.909383381695896, Test_error 0.826946603615981
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8695681925164919, Test_error 1.2818853914287518
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8964084609723192, Test_error 0.9787183537740098
# The finish of 15 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9455944580483732, Test_error 0.5233873980623654
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.952393972163622, Test_error 0.45874569964709777
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9477510743517638, Test_error 0.5151462483764675
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.956378881711377, Test_error 0.4251177368214732
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9524786466901075, Test_error 0.4553083182914708
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9232003621371714, Test_error 0.7492147052176021
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9417788491011121, Test_error 0.5661860211542437
# The finish of 16 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8804896046493212, Test_error 1.0074823323517792
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8902878233929727, Test_error 0.9337743676288718
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8837670491725309, Test_error 0.9816948426683645
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8843882459978859, Test_error 0.9943430879012454
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8828985055755396, Test_error 0.9840006831953426
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8544604712642535, Test_error 1.1747164072547962
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8541481632534824, Test_error 1.167808655072613
# The finish of 17 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.934527011635034, Test_error 0.616943029647582
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9525220390915832, Test_error 0.44614187535918
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9529197010637266, Test_error 0.4390101048626131
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9541871762540992, Test_error 0.43025269981378006
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.959515030753138, Test_error 0.380040068779005
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9411508792301129, Test_error 0.5892328820267044
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9518292690073922, Test_error 0.4538909953109944
# The finish of 18 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9154972616706409, Test_error 0.780291470351412
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9290193714347793, Test_error 0.6549500248083102
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9247794272370985, Test_error 0.6779901367249035
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9323255544543771, Test_error 0.6104886480950582
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9344121650550067, Test_error 0.6126769562495606
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9189421778589776, Test_error 0.772446731528037
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.933295237603026, Test_error 0.6310266645364137
# The finish of 19 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9222892447502382, Test_error 0.7333086255500937
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9426512495214983, Test_error 0.5470304748621598
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.937691210878391, Test_error 0.5972923364063047
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9456644995133588, Test_error 0.5268100630043097
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9445675343836768, Test_error 0.5490457137087876
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9187402746408193, Test_error 0.7940499727321967
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9206323680363477, Test_error 0.8024518634043948
# The finish of 20 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8963956623765047, Test_error 0.8285049424607509
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9069292342241486, Test_error 0.7674420586482417
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9167981694742642, Test_error 0.695708200244877
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9154501485375329, Test_error 0.7192455282679181
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9172226132907731, Test_error 0.7397762141282767
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8811342553524024, Test_error 1.0183544567740215
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9008232388814409, Test_error 0.898259555026762
# The finish of 21 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8851632544433422, Test_error 1.022591156115646
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8908057318823602, Test_error 1.0107553705221703
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8860746587775111, Test_error 1.0295220914000411
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8855578802037831, Test_error 1.0501407209568019
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8963468607877467, Test_error 1.0024195162309433
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8526562571987604, Test_error 1.4238387880690642
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8837757151410056, Test_error 1.1417050236935753
# The finish of 22 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8939320933741484, Test_error 0.9587898129817133
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8821835393142811, Test_error 1.0456269843672397
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8951640065644468, Test_error 0.94899630972569
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.890613438511128, Test_error 0.9856178137218973
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9145876815848717, Test_error 0.7808618893800121
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8683292402196666, Test_error 1.2264223310120235
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9034218950689227, Test_error 0.9091471521756646
# The finish of 23 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9079335859688735, Test_error 0.8201820800358259
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9342533090519213, Test_error 0.5839380171019589
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9247372127975014, Test_error 0.6853585983118139
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9398244768922194, Test_error 0.5427970787077009
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9397232930544253, Test_error 0.5443467353907356
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9189388443762261, Test_error 0.7165121704331634
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9221714223754054, Test_error 0.7197839233771502
# The finish of 24 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9368584887691142, Test_error 0.5960050681333218
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9390375854073999, Test_error 0.5520381036307918
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9428130648234979, Test_error 0.5341903144863286
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9472053296995198, Test_error 0.4936612751360473
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9401393398240502, Test_error 0.5596965155643413
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9217819022970363, Test_error 0.7273761265309492
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9245820393103308, Test_error 0.7094670787274859
# The finish of 25 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9170498357182466, Test_error 0.6314414025945558
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9327792089682032, Test_error 0.5296746711454459
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9227740929917815, Test_error 0.6062558016742375
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9207115255550546, Test_error 0.616851582876894
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9363128947361319, Test_error 0.5182491765530777
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9032736546694371, Test_error 0.7565458584008725
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9189640822806345, Test_error 0.6885714946781609
# The finish of 26 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9201638310779064, Test_error 0.7092287564669737
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9253631584261068, Test_error 0.659956804952175
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9256873830153727, Test_error 0.645833328083285
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9274356754896016, Test_error 0.6382493288747382
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9308968198452874, Test_error 0.601274308851505
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8663697784537002, Test_error 1.2205479743647776
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9110815631121071, Test_error 0.7978582334635682
# The finish of 27 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9125967889028226, Test_error 0.9840073324239937
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9275231481099793, Test_error 0.8208772287466743
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9268906990790706, Test_error 0.8253210969196655
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9315313423795534, Test_error 0.7924896329256055
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9338287322055165, Test_error 0.7475859522416992
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9244551624991635, Test_error 0.8680156120097309
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9224144548755603, Test_error 0.8992311100776896
# The finish of 28 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9413442478634382, Test_error 0.5575141872857441
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9409163823061013, Test_error 0.5708240779703352
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9438290544692461, Test_error 0.5316762899314689
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9442798125613462, Test_error 0.5350033766754254
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.942108850232134, Test_error 0.5703967422419906
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9232485077892688, Test_error 0.7425753112313621
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9343930985038921, Test_error 0.6528312286320614
# The finish of 29 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.893952202304541, Test_error 0.9924768352342406
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9285298488360669, Test_error 0.6725444667589311
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.916189811341553, Test_error 0.798784328262543
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9249496486035235, Test_error 0.7162215517321889
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9292934144883894, Test_error 0.6775921517817711
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8874629318434408, Test_error 1.1002065507202374
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9055753547191718, Test_error 0.9200763308353413
# The finish of 30 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9016528775618289, Test_error 0.9025738596945763
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9022654921629172, Test_error 0.8887999621340648
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8992001961157186, Test_error 0.9205688805764229
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9051381961751608, Test_error 0.8578702529357922
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9175296234293653, Test_error 0.7547221123786751
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8922627742802844, Test_error 1.001005470624634
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9087613947762708, Test_error 0.8664344042675801
# The finish of 31 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9547688504893826, Test_error 0.47642096993170946
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9561648239920464, Test_error 0.45659948160603625
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9560121267391417, Test_error 0.46204811291073233
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9531492102276695, Test_error 0.5006796486023654
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9589608143410449, Test_error 0.43251055717695935
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9408634686948644, Test_error 0.6171645352363184
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9587554697778241, Test_error 0.4377734391630769
# The finish of 32 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9077607926861588, Test_error 0.6533229964115846
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.90732468686256, Test_error 0.6783522571599419
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8892482001072342, Test_error 0.8016857846576986
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9093077873200842, Test_error 0.6570228001510714
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8895860281908522, Test_error 0.818823817060812
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8551627063257805, Test_error 1.0775734659724916
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.851731354749301, Test_error 1.1138222640232167
# The finish of 33 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9026903450817703, Test_error 0.8783769384092088
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9211141330599554, Test_error 0.7087227360623054
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9192735197143177, Test_error 0.7302036812179942
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9187057495192774, Test_error 0.7314148058989483
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9166575595983911, Test_error 0.7688357664962783
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8954501630557903, Test_error 0.966881741768722
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9133352317993255, Test_error 0.8159548933869287
# The finish of 34 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9243475264431467, Test_error 0.666621604912027
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9299930546441149, Test_error 0.6398776257408699
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9308570889001568, Test_error 0.6331827965412935
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9411626598734574, Test_error 0.5453358274419128
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9364699362388336, Test_error 0.5941870537567232
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9207563760623526, Test_error 0.7819980338275909
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9415768078681381, Test_error 0.5540136693011336
# The finish of 35 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9455977828282266, Test_error 0.6011668005964131
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9469516650585047, Test_error 0.5804948385649012
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9408824934851718, Test_error 0.6463787531654104
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9456019903328118, Test_error 0.6120372260248726
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9482650696040622, Test_error 0.5556632177930639
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9205355373312436, Test_error 0.8778448395670979
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9422089017162216, Test_error 0.6237644009134381
# The finish of 36 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9231418713929413, Test_error 0.7098355610753608
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9321479129418003, Test_error 0.6267557190948062
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9277878173920069, Test_error 0.6626630678211372
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9293667022158963, Test_error 0.6489273567189346
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9333952715352037, Test_error 0.5985891007488765
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.916599179573824, Test_error 0.7439302191211221
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9098285913467962, Test_error 0.8043968044293245
# The finish of 37 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.90925978248672, Test_error 0.7942709665498918
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9072758229995234, Test_error 0.833380541213275
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9110074466107329, Test_error 0.7545534635487753
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9064541258297105, Test_error 0.8327382734533563
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9250908709022592, Test_error 0.6356836136312656
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8988882311142647, Test_error 0.8580805489881992
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9139556630882049, Test_error 0.7419186189463207
# The finish of 38 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9212312939245832, Test_error 0.8475539073220415
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9473233550838145, Test_error 0.5617618243147062
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9381480636461982, Test_error 0.6557018467057064
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9466374470130461, Test_error 0.5675914054865467
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.944924442634321, Test_error 0.5901005728767231
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9103858042670404, Test_error 1.0217300861727017
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9296379473276759, Test_error 0.7895954531857232
# The finish of 39 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9124857863623013, Test_error 0.7667999753715147
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.912028059182373, Test_error 0.7950895327886047
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9203436878195453, Test_error 0.7018056942638097
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9102164765969383, Test_error 0.7968578575933465
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8954645454096919, Test_error 0.9100379829187958
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8723643789876873, Test_error 1.1696553553868365
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8952810779269135, Test_error 0.9140588265501792
# The finish of 40 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9111467326864919, Test_error 0.8415462470334499
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9027266463756043, Test_error 0.9293978423106218
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.900624258735977, Test_error 0.9384356769757831
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9055428153908609, Test_error 0.8918107513346297
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9237515827002216, Test_error 0.7158810448310189
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8830910873625952, Test_error 1.1609325621707538
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9212270074907195, Test_error 0.7672658119971814
# The finish of 41 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9265586935235262, Test_error 0.631346172156118
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9311404099368485, Test_error 0.6099622925795823
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.939432221269191, Test_error 0.5309702239037221
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9359351258386631, Test_error 0.5625476298047593
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9389767060526535, Test_error 0.5244218459875705
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8799025021374829, Test_error 1.0298100689984797
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9383851655221902, Test_error 0.5377029760470114
# The finish of 42 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9386920626612685, Test_error 0.6538366753836055
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9427479179264211, Test_error 0.6368142476814698
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9435685106906487, Test_error 0.5995439143644711
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9440578041430742, Test_error 0.6070529303218432
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9469614144392201, Test_error 0.5836828218663754
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9151550393228749, Test_error 0.9457055230364698
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9228381687382778, Test_error 0.8467511720106289
# The finish of 43 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9426506380928245, Test_error 0.5226912806167635
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9508637312977954, Test_error 0.44800752386849874
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9416209048518615, Test_error 0.5414142218701058
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9480161667698523, Test_error 0.4849278581685813
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9548305618138064, Test_error 0.41729755532097196
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.928679491894609, Test_error 0.7030164756992622
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9396221362276641, Test_error 0.6110621390261357
# The finish of 44 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.94476085444554, Test_error 0.5013140521398807
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9475631036145054, Test_error 0.4771853286945129
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.93787661460768, Test_error 0.5743490245778421
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9442471698385144, Test_error 0.5127233350887546
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9489907530487129, Test_error 0.47099166163718204
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9277192805339735, Test_error 0.6850299294781909
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9431916173075376, Test_error 0.5450212695704338
# The finish of 45 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9231961554577748, Test_error 0.6133336601386797
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.930545099917913, Test_error 0.5619625249735163
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9307389862783987, Test_error 0.5451863099055955
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.923232580077904, Test_error 0.6194250693726471
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9382557406593608, Test_error 0.49393174739786333
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.902970566343958, Test_error 0.7830286477799001
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9364870265924796, Test_error 0.5162879911295922
# The finish of 46 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8894397022632266, Test_error 1.0151594673004678
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9161053999972598, Test_error 0.7960751874324256
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9229228687230525, Test_error 0.7276444142067654
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.91602194513358, Test_error 0.8140173905451897
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9358267576372589, Test_error 0.6113252717470128
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8914254063523083, Test_error 1.0819948185119195
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9378360289341234, Test_error 0.5979515730466208
# The finish of 47 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9215529990830313, Test_error 0.731216313908708
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9354130146069325, Test_error 0.5998149458514914
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8984337021320168, Test_error 0.9578277273092959
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.940726487087345, Test_error 0.5636952836088936
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.946714557410975, Test_error 0.5058357968393111
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9225503387369157, Test_error 0.7468893844613145
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9293105800495187, Test_error 0.7078897010846819
# The finish of 48 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9187322194473871, Test_error 0.8839136794391413
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9407866983107128, Test_error 0.642192927947032
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9372251366117521, Test_error 0.6886723914303128
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9445144323486737, Test_error 0.6096407313818507
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9489334471002815, Test_error 0.5663453265714714
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.945281093379413, Test_error 0.6354485146489539
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.948986013550127, Test_error 0.5662751190720777
# The finish of 49 th trial

# %% [markdown]
# # Post result treatments

# %%
import pandas as pd
file_name = ['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] 

cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model"]
for j in range(len(file_name)):
    df_list = []
    for i in range(50):
        files_name = '35_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'
        df_list.append(pd.read_csv(os.path.join('./8_using_BET_curve',files_name))[cal_columns] )
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_mean.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_std.csv'))

# %% [markdown]
# # 2_Predicting adsorption for each data point using the combination Vt, BET, Vmeso, and Vmic
# the dataset for each separate gas will be smaller than previous one.

# %%
import os
base_feature = ['V','S','L','BET',]
condition_feature = ['Temp(K)','Pressure']
combin_1 = ['Vt']
combin_2 = ["Vmeso"]
combin_3 = ['Vmic']
combin_4 = ['Vt',"Vmeso",]
combin_5 = ['Vt',"Vmic",]
combin_6 = ['Vt',"Vmic",'Vmeso',]
combin_7 = ["Vmic",'Vmeso',]

feature_list = [base_feature+condition_feature,base_feature+combin_1+condition_feature, \
    base_feature+combin_3+condition_feature, base_feature+combin_2+condition_feature,\
    base_feature+combin_4+condition_feature, base_feature+combin_5+condition_feature,\
    base_feature+combin_6+condition_feature, base_feature+combin_7+condition_feature, ]

columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']


feature_set = ["BET","Vt","Vmeso","Vmic"]
gas_list = ['CO2','CFCs','Methane','E&E']
file_name = ['BET_only','BET_plut_Vt',"BET_Vmic","BET_Vmeso",'BET_Vt_Vmeso','BET_Vt_Vmic',"BET_Vt_Vmic_meso","BET_Vmic_meso"]


for i in range(10,15):
    train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'],feature_set= feature_set)
    for j in range(len(feature_list)):
        results = model_comparison(models,para_grids, feature_list[j],gas_list)
        files_name = 'Four_gases_with_Vmic_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',files_name))  
        #pd.DataFrame(results,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))

# %% [markdown]
# # Post result treatment

# %%
import pandas as pd
file_name = ['BET_only','BET_plut_Vt',"BET_Vmic","BET_Vmeso",'BET_Vt_Vmeso','BET_Vt_Vmic',"BET_Vt_Vmic_meso","BET_Vmic_meso"]

cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model"]
for j in range(len(file_name)):
    df_list = []
    for i in range(11):
    
        files_name = 'Four_gases_with_Vmic_'+file_name[j]+'_result_'+str(i)+'.csv'
        df_list.append(pd.read_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',files_name))[cal_columns] )
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',file_name[j]+'_mean_new.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',file_name[j]+'_std_new.csv'))

# %% [markdown]
# # Predicting the fitted parameters of adsorption isotherms

# %% [markdown]
# # Using only BET and Vt

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def pred_dataset(file_names, feature_set = feature_set):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-fitting-02-02-2022.xlsx'),skiprows= 1 )
        temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        train_x,test_x = train_test_split(temp_data,test_size = 0.2)
        train_df = pd.concat([train_df,train_x],axis=0)
        test_df = pd.concat([test_df,test_x],axis =0)
    return train_df,test_df

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,model,para_grid):

    
    result = GridSearchCV(model,para_grid,cv= 5,
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,cv =5,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []

    for gas in gas_list:
        
        if gas =='total':

            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            
            train_x, train_y = shuffle(train_x, train_y,random_state=42)
            
            for model_name, model in model_list:

                
                result, best_param = model_CV(train_x,train_y.squeeze(),model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])

                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))

            
        else:
            
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            
            train_x, train_y = shuffle(train_x, train_y, random_state=42)
           
            for model_name, model in model_list:

                result, best_param = model_CV(train_x,train_y.squeeze(),model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
                print(print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))
)
                
    return result_total
