# %% [markdown]
# # 1. predicting adsorption for each adsorption data point using Vt&BET only

# %%
import pandas as pd
import numpy as np
import os 
BET_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/Treated'

def pred_dataset(file_names):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-04-19-2022.xlsx'),skiprows= 1 )
        #temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        train_df = pd.concat([train_df,temp_data],axis=0)
       
    return train_df

# %%
from scipy import interpolate
import numpy as np
import pandas as pd

def inter_data(x_old,y_old):
    
    f = interpolate.interp1d(x_old, y_old,'slinear')    
    x_new = np.linspace(min(x_old), max(x_old),num=80)
       
    """
        for ele in x_old:
            t = bi_find(x_new,ele)

            x_new[t] = ele
        
        if (len(x_new)>150):
            x_new = x_new[len(x_new)-150:]
         = np.arange(min(x_old), max(x_old), (max(x_old)-min(x_old))/150)
    """
    y_new = f(x_new)
    #X_feature = np.append(x_new.reshape(-1,1),y_new.reshape(-1,1),axis=1).reshape(2,35).tolist()
    #x_mat = np.append(x_mat,X_feature,axis=1)
       
    return x_new, y_new

# %%
data = pred_dataset(["CO2"])
data.head()
# Out:
#    Unnamed: 0  Literature  Lines       GAC         GAS  E     S     A    B  \
# 0           0         1.0      0  UC-600-2  CarbonDiox  0  0.28  0.05  0.1
# 1           1         1.0      1  UC-600-2  CarbonDiox  0  0.28  0.05  0.1
# 2           2         1.0      2  UC-600-2  CarbonDiox  0  0.28  0.05  0.1
# 3           3         1.0      3  UC-600-2  CarbonDiox  0  0.28  0.05  0.1
# 4           4         1.0      4  UC-600-2  CarbonDiox  0  0.28  0.05  0.1
#
#         V  ...    %N  Temp(K)  Pressure  Adsorp(mmol/g)  Index      logP  \
# 0  0.2809  ...  1.98    298.0  0.048715        0.547018      0 -3.021763
# 1  0.2809  ...  1.98    298.0  0.104147        0.935902      0 -2.261948
# 2  0.2809  ...  1.98    298.0  0.137430        1.095365      0 -1.984640
# 3  0.2809  ...  1.98    298.0  0.208412        1.502384      0 -1.568239
# 4  0.2809  ...  1.98    298.0  0.266122        1.715469      0 -1.323800
#
#        logQ      logD  Label  Vmic_index
# 0 -0.603274  2.418489    CO2           0
# 1 -0.066244  2.195704    CO2           0
# 2  0.091087  2.075727    CO2           0
# 3  0.407053  1.975292    CO2           0
# 4  0.539687  1.863487    CO2           0
#
# [5 rows x 27 columns]

# %%
BET_df = pd.DataFrame()
cols = ["E","S","A","B","V","BET","Vt","Vmic","Vmeso","Temp(K)","Pressure","Adsorp(mmol/g)","Index"]
def bet_extraction(temp_df:pd.DataFrame):
    global BET_df
    literature = temp_df["Literature"].values[0]
    gac_name = temp_df["GAC"].values[0]
    print(literature,gac_name)
    try:
        if literature!=np.nan:
                bet_data = BET_path+'/'+str(int(literature))+"/"+gac_name+".csv"
                #print(bet_data)
                bet_curve = pd.read_csv(bet_data,header=None)
                
                x = bet_curve.iloc[:,0].values.tolist()
                y = bet_curve.iloc[:,1].values.tolist()
                _,new_y = inter_data(x,y)
                rows = len(temp_df)
                bet_matrix = [new_y for _ in range(rows)]
                bet_df = pd.DataFrame(bet_matrix,columns = ["BET_"+str(i) for i in range(len(new_y))])
                bet_df = pd.concat([bet_df,temp_df[cols].reset_index()],axis= 1,ignore_index=True)
                print(bet_df.shape)
                BET_df = pd.concat([BET_df,bet_df,],axis= 0,ignore_index=True)    

        else:
            print("There is not leterature for this gac: {}".format(gac_name))         
    except:
        print("The BET curve for gac: {} from paper {} is not available.".format(gac_name,literature))
total_index = list(set(data["Index"].values.tolist()))
for index in total_index:
    temp_df =  data[data["Index"]==index]
    bet_extraction(temp_df)
# Out:
# 1.0 UC-600-2
# (16, 94)
# 1.0 UC-600-3
# (17, 94)
# 1.0 UC-600-4
# (21, 94)
# 1.0 UC-600-2
# (21, 94)
# 1.0 UC-600-3
# (19, 94)
# 1.0 UC-600-4
# (22, 94)
# 1.0 UC-650-2
# (21, 94)
# 1.0 UC-650-3
# (17, 94)
# 1.0 UC-650-4
# (18, 94)
# 1.0 UC-650-2
# (16, 94)
# 1.0 UC-650-3
# (18, 94)
# 1.0 UC-650-4
# (17, 94)
# 1.0 UC-700-2
# (15, 94)
# 1.0 UC-700-3
# (17, 94)
# 1.0 UC-700-4
# (16, 94)
# 1.0 UC-700-2
# (14, 94)
# 1.0 UC-700-3
# (20, 94)
# 1.0 UC-700-4
# (19, 94)
# 2.0 CN-600-3
# (22, 94)
# 2.0 CN-600-2
# (16, 94)
# 2.0 CN-600-4
# (21, 94)
# 2.0 CN-700-2
# (20, 94)
# 2.0 CN-700-3
# (20, 94)
# 2.0 CN-800-2
# (21, 94)
# 2.0 CN-800-3
# (21, 94)
# 2.0 CN-600-2
# (14, 94)
# 2.0 CN-600-3
# (12, 94)
# 2.0 CN-600-4
# (12, 94)
# 2.0 CN-700-2
# (16, 94)
# 2.0 CN-700-3
# (11, 94)
# 2.0 CN-800-3
# (15, 94)
# 3.0 PC-2
# (12, 94)
# 3.0 PC-1_4
# (11, 94)
# 3.0 PC-1_5
# (10, 94)
# 4.0 c-CBAP-1N
# (16, 94)
# 4.0 c-CBAP-1N
# (13, 94)
# 4.0 c-CBAP-1N
# (13, 94)
# 4.0 c-CBAP-1N
# (11, 94)
# 5.0 AC
# (7, 94)
# 5.0 AC
# (7, 94)
# 5.0 AC
# (7, 94)
# 6.0 O-3-650-110
# The BET curve for gac: O-3-650-110 from paper 6.0 is not available.
# 6.0 O-3-650-110
# The BET curve for gac: O-3-650-110 from paper 6.0 is not available.
# 6.0 O-3-650-110
# The BET curve for gac: O-3-650-110 from paper 6.0 is not available.
# 6.0 A-3-650-83
# The BET curve for gac: A-3-650-83 from paper 6.0 is not available.
# 6.0 A-3-650-83
# The BET curve for gac: A-3-650-83 from paper 6.0 is not available.
# 6.0 A-3-650-83
# The BET curve for gac: A-3-650-83 from paper 6.0 is not available.
# 7.0 VR5-1_1
# (10, 94)
# 7.0 VR5-2.5_1
# (10, 94)
# 7.0 VR5-2_1
# (10, 94)
# 7.0 VR5-3_1
# (10, 94)
# 7.0 VR5-4_1
# (10, 94)
# 8.0 AC-600-0.5
# (13, 94)
# 8.0 AC-600-0.5
# (13, 94)
# 8.0 AC-600-0.5
# (11, 94)
# 8.0 AC-700-1
# (12, 94)
# 8.0 AC-700-1
# (12, 94)
# 8.0 AC-700-1
# (11, 94)
# 8.0 AC-750-0.5
# (12, 94)
# 8.0 AC-750-0.5
# (12, 94)
# 8.0 AC-750-0.5
# (11, 94)
# 8.0 AC-800-1
# (11, 94)
# 8.0 AC-800-1
# (12, 94)
# 8.0 AC-800-1
# (11, 94)
# 9.0 NOMC-800
# (14, 94)
# 9.0 NOMC-700
# The BET curve for gac: NOMC-700 from paper 9.0 is not available.
# 9.0 NOMC-550
# (11, 94)
# 9.0 NOMC-800
# (12, 94)
# 9.0 NOMC-K
# (12, 94)
# 9.0 NOMC-K
# (12, 94)
# 10.0 NDC
# (12, 94)
# 10.0 NDC-4
# (13, 94)
# 10.0 NDC-5
# (13, 94)
# 10.0 NDC-6
# (12, 94)
# 10.0 NDC-7
# (11, 94)
# 11.0 3C-60
# (15, 94)
# 11.0 3C-650N
# (9, 94)
# 11.0 3C-800N
# (12, 94)
# 11.0 3C-900N
# (11, 94)
# 11.0 3C-1000N
# (10, 94)
# 11.0 H-600
# (10, 94)
# 12.0 RFL-400
# (8, 94)
# 12.0 RFL-500
# (8, 94)
# 12.0 RFL-600
# (8, 94)
# 13.0 NPC-750
# (9, 94)
# 13.0 NPC-700
# (9, 94)
# 13.0 NPC-650
# (10, 94)
# 13.0 NPC-600
# (10, 94)
# 13.0 NPC-750
# (10, 94)
# 13.0 NPC-700
# (10, 94)
# 13.0 NPC-650
# (10, 94)
# 13.0 NPC-600
# (9, 94)
# 14.0 COP-M
# (11, 94)
# 14.0 COP-M-600
# (13, 94)
# 14.0 COP-M-700
# (13, 94)
# 14.0 KCOP-M-600
# The BET curve for gac: KCOP-M-600 from paper 14.0 is not available.
# 14.0 KCOP-M-700
# The BET curve for gac: KCOP-M-700 from paper 14.0 is not available.
# 14.0 KCOP-M-600
# The BET curve for gac: KCOP-M-600 from paper 14.0 is not available.
# 14.0 KCOP-M-700
# The BET curve for gac: KCOP-M-700 from paper 14.0 is not available.
# 15.0 CS-6
# (13, 94)
# 15.0 CS-P-A
# (13, 94)
# 15.0 CS-3-A
# (11, 94)
# 15.0 CS-6-A
# (11, 94)
# 15.0 CSstar-6
# (12, 94)
# 15.0 CSstar-P-A
# (11, 94)
# 15.0 CSstar-3-A
# (12, 94)
# 15.0 CS-P-A
# (13, 94)
# 15.0 CSstar-P-A
# (11, 94)
# 15.0 CSstar-3-A
# (16, 94)
# 16.0 NC-600-2
# (15, 94)
# 16.0 NC-600-3
# (13, 94)
# 16.0 NC-600-4
# (12, 94)
# 16.0 NC-600-3
# (12, 94)
# 16.0 NC-600-4
# (11, 94)
# 16.0 NC-650-2
# (11, 94)
# 16.0 NC-650-3
# (12, 94)
# 16.0 NC-650-4
# (12, 94)
# 16.0 NC-650-2
# (11, 94)
# 16.0 NC-650-3
# (12, 94)
# 16.0 NC-650-4
# (12, 94)
# 16.0 NC-700-4
# (12, 94)
# 16.0 NC-700-2
# (11, 94)
# 16.0 NC-700-3
# (12, 94)
# 16.0 NC-700-2
# (12, 94)
# 16.0 NC-700-3
# (11, 94)
# 16.0 NC-700-4
# (10, 94)
# 17.0 VR-5
# (10, 94)
# 17.0 VR-93
# (10, 94)
# 18.0 PC
# (12, 94)
# 18.0 AC2-PC
# (10, 94)
# 18.0 AC4-PC
# (12, 94)
# 19.0 unmodified AC
# (8, 94)
# 19.0 AC-NH-800
# (8, 94)
# 19.0 unmodified AC
# (8, 94)
# 19.0 unmodified AC
# (8, 94)
# 19.0 unmodified AC
# (8, 94)
# 19.0 AC-NH-800
# (8, 94)
# 19.0 AC-NH-800
# (8, 94)
# 19.0 AC-NH-800
# (8, 94)
# 20.0 CF-700
# (14, 94)
# 20.0 CF-800
# (11, 94)
# 20.0 CF-850
# (11, 94)
# 20.0 CF-700-ACT
# (14, 94)
# 20.0 CF-750-ACT
# (12, 94)
# 20.0 CF-800-ACT
# (12, 94)
# 20.0 CF-850-ACT
# (12, 94)
# 21.0 a-SG-4
# (13, 94)
# 21.0 a-SG-5
# (13, 94)
# 21.0 a-SG-6
# (13, 94)
# 21.0 a-SG-7
# (12, 94)
# 22.0 micro-TiC-CDCs-200
# The BET curve for gac: micro-TiC-CDCs-200 from paper 22.0 is not available.
# 22.0 micro-TiC-CDCs-400
# The BET curve for gac: micro-TiC-CDCs-400 from paper 22.0 is not available.
# 22.0 micro-TiC-CDCs-600
# The BET curve for gac: micro-TiC-CDCs-600 from paper 22.0 is not available.
# 22.0 micro-TiC-CDCs-700
# The BET curve for gac: micro-TiC-CDCs-700 from paper 22.0 is not available.
# 22.0 micro-TiC-CDCs-1000
# The BET curve for gac: micro-TiC-CDCs-1000 from paper 22.0 is not available.
# 22.0 nano-TiC-CDCs-200
# The BET curve for gac: nano-TiC-CDCs-200 from paper 22.0 is not available.
# 22.0 nano-TiC-CDCs-400
# The BET curve for gac: nano-TiC-CDCs-400 from paper 22.0 is not available.
# 22.0 nano-TiC-CDCs-600
# The BET curve for gac: nano-TiC-CDCs-600 from paper 22.0 is not available.
# 22.0 nano-TiC-CDCs-800
# The BET curve for gac: nano-TiC-CDCs-800 from paper 22.0 is not available.
# 22.0 nano-TiC-CDCs-1000
# The BET curve for gac: nano-TiC-CDCs-1000 from paper 22.0 is not available.
# 23.0 PTCT-C
# (12, 94)
# 23.0 PTCA-C
# (12, 94)
# 23.0 PBCP-C
# (13, 94)
# 23.0 PTCT-C
# (12, 94)
# 23.0 PTCA-C
# (11, 94)
# 23.0 PBCP-C
# (11, 94)
# 24.0 Z 0.75
# (8, 94)
# 24.0 Z 1.5
# (8, 94)
# 24.0 Z 2.5
# (7, 94)
# 24.0 HK
# (8, 94)
# 24.0 H 1.5
# (8, 94)
# 24.0 H 2
# (8, 94)
# 24.0 H 2
# (8, 94)
# 24.0 H 2
# (8, 94)
# 24.0 H 2
# (8, 94)
# 24.0 Z 0.75
# (8, 94)
# 24.0 Z 0.75
# (8, 94)
# 24.0 Z 0.75
# (8, 94)
# 25.0 CP-2-600
# (12, 94)
# 25.0 CP-2-600
# (11, 94)
# 25.0 CP-2-600
# (11, 94)
# 25.0 CP-2-650
# (10, 94)
# 25.0 CP-2-650
# (11, 94)
# 25.0 CP-2-650
# (10, 94)
# 25.0 CP-2-700
# (11, 94)
# 25.0 CP-2-700
# (11, 94)
# 25.0 CP-2-700
# (11, 94)
# 25.0 CP-2-800
# (11, 94)
# 25.0 CP-2-800
# (10, 94)
# 25.0 CP-2-800
# (10, 94)
# 26.0 1C
# (7, 94)
# 26.0 9C
# (7, 94)
# 26.0 1C
# (7, 94)
# 26.0 9C
# (7, 94)
# 26.0 1C
# (7, 94)
# 26.0 9C
# (7, 94)
# 26.0 1C
# (7, 94)
# 26.0 9C
# (7, 94)
# 27.0 NHC-600-1
# (13, 94)
# 27.0 NHC-600-2
# (12, 94)
# 27.0 NHC-600-3
# (13, 94)
# 27.0 NHC-600-4
# (13, 94)
# 27.0 NHC-600-1
# (11, 94)
# 27.0 NHC-600-3
# (11, 94)
# 27.0 NHC-600-4
# (8, 94)
# 27.0 NHC-650-1
# (11, 94)
# 27.0 NHC-650-2
# (13, 94)
# 27.0 NHC-650-3
# (13, 94)
# 27.0 NHC-650-4
# (10, 94)
# 27.0 NHC-650-1
# (13, 94)
# 27.0 NHC-650-2
# (12, 94)
# 27.0 NHC-650-3
# (11, 94)
# 27.0 NHC-650-4
# (13, 94)
# 27.0 NHC-700-2
# (12, 94)
# 27.0 NHC-700-3
# (12, 94)
# 27.0 NHC-700-4
# (10, 94)
# 27.0 NHC-700-1
# (10, 94)
# 27.0 NHC-700-2
# (11, 94)
# 27.0 NHC-700-3
# (12, 94)
# 27.0 NHC-700-4
# (11, 94)
# 28.0 MAC
# The BET curve for gac: MAC from paper 28.0 is not available.
# 28.0 MAC
# The BET curve for gac: MAC from paper 28.0 is not available.
# 28.0 MAC
# The BET curve for gac: MAC from paper 28.0 is not available.
# 29.0 PCNS
# (10, 94)
# 30.0 CN500
# (14, 94)
# 30.0 CN500
# (14, 94)
# 31.0 ATS-2-650
# The BET curve for gac: ATS-2-650 from paper 31.0 is not available.
# nan ATS-2-650
# The BET curve for gac: ATS-2-650 from paper nan is not available.
# nan ATS-2-650
# The BET curve for gac: ATS-2-650 from paper nan is not available.
# nan ATS-2-700
# The BET curve for gac: ATS-2-700 from paper nan is not available.
# nan ATS-2-700
# The BET curve for gac: ATS-2-700 from paper nan is not available.
# nan ATS-2-700
# The BET curve for gac: ATS-2-700 from paper nan is not available.
# nan ATS-2-800
# The BET curve for gac: ATS-2-800 from paper nan is not available.
# nan ATS-2-800
# The BET curve for gac: ATS-2-800 from paper nan is not available.
# nan ATS-2-800
# The BET curve for gac: ATS-2-800 from paper nan is not available.
# nan ATS-4-700
# The BET curve for gac: ATS-4-700 from paper nan is not available.
# nan ATS-4-700
# The BET curve for gac: ATS-4-700 from paper nan is not available.
# nan ATS-4-700
# The BET curve for gac: ATS-4-700 from paper nan is not available.
# nan ATS-4-800
# The BET curve for gac: ATS-4-800 from paper nan is not available.
# nan ATS-4-800
# The BET curve for gac: ATS-4-800 from paper nan is not available.
# nan ATS-4-800
# The BET curve for gac: ATS-4-800 from paper nan is not available.
# 32.0 C600K5
# The BET curve for gac: C600K5 from paper 32.0 is not available.
# nan C700K3
# The BET curve for gac: C700K3 from paper nan is not available.
# nan C600K3
# The BET curve for gac: C600K3 from paper nan is not available.
# nan C600K1
# The BET curve for gac: C600K1 from paper nan is not available.
# nan C600K0
# The BET curve for gac: C600K0 from paper nan is not available.
# nan C600-K5
# The BET curve for gac: C600-K5 from paper nan is not available.
# nan C700-K3
# The BET curve for gac: C700-K3 from paper nan is not available.
# nan C600-K3
# The BET curve for gac: C600-K3 from paper nan is not available.
# nan C600-K1
# The BET curve for gac: C600-K1 from paper nan is not available.
# nan C600-K0
# The BET curve for gac: C600-K0 from paper nan is not available.
# 33.0 TF1
# The BET curve for gac: TF1 from paper 33.0 is not available.
# nan TF2
# The BET curve for gac: TF2 from paper nan is not available.
# nan CP
# The BET curve for gac: CP from paper nan is not available.
# nan ML
# The BET curve for gac: ML from paper nan is not available.
# nan MB
# The BET curve for gac: MB from paper nan is not available.
# nan SP
# The BET curve for gac: SP from paper nan is not available.
# nan PP
# The BET curve for gac: PP from paper nan is not available.
# nan FL
# The BET curve for gac: FL from paper nan is not available.
# nan TF1
# The BET curve for gac: TF1 from paper nan is not available.
# nan TF2
# The BET curve for gac: TF2 from paper nan is not available.
# nan CP
# The BET curve for gac: CP from paper nan is not available.
# nan ML
# The BET curve for gac: ML from paper nan is not available.
# nan MB
# The BET curve for gac: MB from paper nan is not available.
# nan KP
# The BET curve for gac: KP from paper nan is not available.
# nan SP
# The BET curve for gac: SP from paper nan is not available.
# nan PP
# The BET curve for gac: PP from paper nan is not available.
# nan FL
# The BET curve for gac: FL from paper nan is not available.
# 34.0 A-NMC
# The BET curve for gac: A-NMC from paper 34.0 is not available.
# nan A-NMC
# The BET curve for gac: A-NMC from paper nan is not available.
# nan A-NMC
# The BET curve for gac: A-NMC from paper nan is not available.
# 35.0 ACGR2600
# The BET curve for gac: ACGR2600 from paper 35.0 is not available.
# nan ACGR2700
# The BET curve for gac: ACGR2700 from paper nan is not available.
# nan ACGR2800
# The BET curve for gac: ACGR2800 from paper nan is not available.
# nan ACCA2600
# The BET curve for gac: ACCA2600 from paper nan is not available.
# nan ACCA2700
# The BET curve for gac: ACCA2700 from paper nan is not available.
# nan ACCA2800
# The BET curve for gac: ACCA2800 from paper nan is not available.
# nan ACGR4600
# The BET curve for gac: ACGR4600 from paper nan is not available.
# nan ACGR4700
# The BET curve for gac: ACGR4700 from paper nan is not available.
# nan ACGR4800
# The BET curve for gac: ACGR4800 from paper nan is not available.
# nan ACCA4600
# The BET curve for gac: ACCA4600 from paper nan is not available.
# nan ACCA4700
# The BET curve for gac: ACCA4700 from paper nan is not available.
# nan ACCA4800
# The BET curve for gac: ACCA4800 from paper nan is not available.
# 36.0 chitosan calcined at 8008C with KOH
# The BET curve for gac: chitosan calcined at 8008C with KOH from paper 36.0 is not available.
# nan alginate calcined at 8008C with KOH
# The BET curve for gac: alginate calcined at 8008C with KOH from paper nan is not available.
# nan chitosan calcined at 800
# The BET curve for gac: chitosan calcined at 800 from paper nan is not available.
# nan alginate calcined at 8008C with KOH
# The BET curve for gac: alginate calcined at 8008C with KOH from paper nan is not available.
# 37.0 native AC
# The BET curve for gac: native AC from paper 37.0 is not available.
# nan native AC
# The BET curve for gac: native AC from paper nan is not available.
# nan native AC
# The BET curve for gac: native AC from paper nan is not available.
# nan native AC
# The BET curve for gac: native AC from paper nan is not available.
# nan AC-MEA
# The BET curve for gac: AC-MEA from paper nan is not available.
# nan AC-MEA
# The BET curve for gac: AC-MEA from paper nan is not available.
# nan AC-MEA
# The BET curve for gac: AC-MEA from paper nan is not available.
# nan AC-MEA
# The BET curve for gac: AC-MEA from paper nan is not available.
# nan AC-DEA
# The BET curve for gac: AC-DEA from paper nan is not available.
# nan AC-DEA
# The BET curve for gac: AC-DEA from paper nan is not available.
# nan AC-DEA
# The BET curve for gac: AC-DEA from paper nan is not available.
# nan AC-DEA
# The BET curve for gac: AC-DEA from paper nan is not available.
# 38.0 AS-2-600
# The BET curve for gac: AS-2-600 from paper 38.0 is not available.
# nan AS-2-600
# The BET curve for gac: AS-2-600 from paper nan is not available.
# nan AS-2-600
# The BET curve for gac: AS-2-600 from paper nan is not available.
# nan AS-2-650
# The BET curve for gac: AS-2-650 from paper nan is not available.
# nan AS-2-650
# The BET curve for gac: AS-2-650 from paper nan is not available.
# nan AS-2-650
# The BET curve for gac: AS-2-650 from paper nan is not available.
# nan AS-2-700
# The BET curve for gac: AS-2-700 from paper nan is not available.
# nan AS-2-700
# The BET curve for gac: AS-2-700 from paper nan is not available.
# nan AS-2-700
# The BET curve for gac: AS-2-700 from paper nan is not available.
# nan AS-2-800
# The BET curve for gac: AS-2-800 from paper nan is not available.
# nan AS-2-800
# The BET curve for gac: AS-2-800 from paper nan is not available.
# nan AS-2-800
# The BET curve for gac: AS-2-800 from paper nan is not available.
# 39.0 WSC-400-1
# The BET curve for gac: WSC-400-1 from paper 39.0 is not available.
# nan WSC-400-2
# The BET curve for gac: WSC-400-2 from paper nan is not available.
# nan WSC-400-3
# The BET curve for gac: WSC-400-3 from paper nan is not available.
# nan WSC-400-1
# The BET curve for gac: WSC-400-1 from paper nan is not available.
# nan WSC-400-2
# The BET curve for gac: WSC-400-2 from paper nan is not available.
# nan WSC-400-3
# The BET curve for gac: WSC-400-3 from paper nan is not available.
# nan WSC-450-1
# The BET curve for gac: WSC-450-1 from paper nan is not available.
# nan WESC-450-2
# The BET curve for gac: WESC-450-2 from paper nan is not available.
# nan WSC-450-3
# The BET curve for gac: WSC-450-3 from paper nan is not available.
# nan WSC-450-1
# The BET curve for gac: WSC-450-1 from paper nan is not available.
# nan WSC-450-2
# The BET curve for gac: WSC-450-2 from paper nan is not available.
# nan WSC-450-3
# The BET curve for gac: WSC-450-3 from paper nan is not available.
# nan WSC-500-1
# The BET curve for gac: WSC-500-1 from paper nan is not available.
# nan WSC-500-2
# The BET curve for gac: WSC-500-2 from paper nan is not available.
# nan WSC-500-3
# The BET curve for gac: WSC-500-3 from paper nan is not available.
# nan WSC-500-1
# The BET curve for gac: WSC-500-1 from paper nan is not available.
# nan WSC-500-2
# The BET curve for gac: WSC-500-2 from paper nan is not available.
# nan WSC-500-3
# The BET curve for gac: WSC-500-3 from paper nan is not available.
# 40.0 NHC-600-1
# The BET curve for gac: NHC-600-1 from paper 40.0 is not available.
# nan NHC-600-2
# The BET curve for gac: NHC-600-2 from paper nan is not available.
# nan NHC-600-3
# The BET curve for gac: NHC-600-3 from paper nan is not available.
# nan NHC-600-4
# The BET curve for gac: NHC-600-4 from paper nan is not available.
# nan NHC-600-1
# The BET curve for gac: NHC-600-1 from paper nan is not available.
# nan NHC-600-2
# The BET curve for gac: NHC-600-2 from paper nan is not available.
# nan NHC-600-3
# The BET curve for gac: NHC-600-3 from paper nan is not available.
# nan NHC-600-4
# The BET curve for gac: NHC-600-4 from paper nan is not available.
# nan NHC-650-1
# The BET curve for gac: NHC-650-1 from paper nan is not available.
# nan NHC-650-2
# The BET curve for gac: NHC-650-2 from paper nan is not available.
# nan NHC-650-3
# The BET curve for gac: NHC-650-3 from paper nan is not available.
# nan NHC-650-4
# The BET curve for gac: NHC-650-4 from paper nan is not available.
# nan NHC-650-1
# The BET curve for gac: NHC-650-1 from paper nan is not available.
# nan NHC-650-2
# The BET curve for gac: NHC-650-2 from paper nan is not available.
# nan NHC-650-3
# The BET curve for gac: NHC-650-3 from paper nan is not available.
# nan NHC-650-4
# The BET curve for gac: NHC-650-4 from paper nan is not available.
# nan NHC-700-1
# The BET curve for gac: NHC-700-1 from paper nan is not available.
# nan NHC-700-2
# The BET curve for gac: NHC-700-2 from paper nan is not available.
# nan NHC-700-3
# The BET curve for gac: NHC-700-3 from paper nan is not available.
# nan NHC-700-4
# The BET curve for gac: NHC-700-4 from paper nan is not available.
# nan NHC-700-1
# The BET curve for gac: NHC-700-1 from paper nan is not available.
# nan NHC-700-2
# The BET curve for gac: NHC-700-2 from paper nan is not available.
# nan NHC-700-3
# The BET curve for gac: NHC-700-3 from paper nan is not available.
# nan NHC-700-4
# The BET curve for gac: NHC-700-4 from paper nan is not available.
# 41.0 ACFK-0
# The BET curve for gac: ACFK-0 from paper 41.0 is not available.
# nan ACFK-1
# The BET curve for gac: ACFK-1 from paper nan is not available.
# nan ACFK-2
# The BET curve for gac: ACFK-2 from paper nan is not available.
# nan ACFK-3
# The BET curve for gac: ACFK-3 from paper nan is not available.
# 42.0 NUT-2-500
# The BET curve for gac: NUT-2-500 from paper 42.0 is not available.
# nan NUT-2-500
# The BET curve for gac: NUT-2-500 from paper nan is not available.
# nan NUT-2-600
# The BET curve for gac: NUT-2-600 from paper nan is not available.
# nan NUT-2-600
# The BET curve for gac: NUT-2-600 from paper nan is not available.
# nan NPC-2-600R
# The BET curve for gac: NPC-2-600R from paper nan is not available.
# nan NPC-2-600R
# The BET curve for gac: NPC-2-600R from paper nan is not available.
# nan NPC-2-700
# The BET curve for gac: NPC-2-700 from paper nan is not available.
# nan NPC-2-700
# The BET curve for gac: NPC-2-700 from paper nan is not available.
# nan NPC-2-800
# The BET curve for gac: NPC-2-800 from paper nan is not available.
# nan NPC-2-800
# The BET curve for gac: NPC-2-800 from paper nan is not available.
# 43.0 GSK0.5-700
# The BET curve for gac: GSK0.5-700 from paper 43.0 is not available.
# nan GSK1-700
# The BET curve for gac: GSK1-700 from paper nan is not available.
# nan GSK2-700
# The BET curve for gac: GSK2-700 from paper nan is not available.
# nan GK-700
# The BET curve for gac: GK-700 from paper nan is not available.
# nan SK-700
# The BET curve for gac: SK-700 from paper nan is not available.
# nan GSK0.5-700
# The BET curve for gac: GSK0.5-700 from paper nan is not available.
# nan GSK1-700
# The BET curve for gac: GSK1-700 from paper nan is not available.
# nan GSK2-700
# The BET curve for gac: GSK2-700 from paper nan is not available.
# nan GK-700
# The BET curve for gac: GK-700 from paper nan is not available.
# nan SK-700
# The BET curve for gac: SK-700 from paper nan is not available.
# 44.0 Zeocarbon
# The BET curve for gac: Zeocarbon from paper 44.0 is not available.
# nan Zeocarbon
# The BET curve for gac: Zeocarbon from paper nan is not available.
# nan Zeocarbon
# The BET curve for gac: Zeocarbon from paper nan is not available.
# nan Zeocarbon
# The BET curve for gac: Zeocarbon from paper nan is not available.
# nan Zeocarbon
# The BET curve for gac: Zeocarbon from paper nan is not available.
# 45.0 k43-BG
# The BET curve for gac: k43-BG from paper 45.0 is not available.
# nan K43-Na
# The BET curve for gac: K43-Na from paper nan is not available.
# nan K43-Fe
# The BET curve for gac: K43-Fe from paper nan is not available.
# 46.0 NGC-600-2
# The BET curve for gac: NGC-600-2 from paper 46.0 is not available.
# nan NGC-650-2
# The BET curve for gac: NGC-650-2 from paper nan is not available.
# nan NGC-700-2
# The BET curve for gac: NGC-700-2 from paper nan is not available.
# nan NGC-600-2
# The BET curve for gac: NGC-600-2 from paper nan is not available.
# nan NGC-650-2
# The BET curve for gac: NGC-650-2 from paper nan is not available.
# nan NGC-700-2
# The BET curve for gac: NGC-700-2 from paper nan is not available.
# nan NGC-600-3
# The BET curve for gac: NGC-600-3 from paper nan is not available.
# nan NGC-650-3
# The BET curve for gac: NGC-650-3 from paper nan is not available.
# nan NGC-700-3
# The BET curve for gac: NGC-700-3 from paper nan is not available.
# nan NGC-600-3
# The BET curve for gac: NGC-600-3 from paper nan is not available.
# nan NGC-650-3
# The BET curve for gac: NGC-650-3 from paper nan is not available.
# nan NGC-700-3
# The BET curve for gac: NGC-700-3 from paper nan is not available.
# nan NGC-600-4
# The BET curve for gac: NGC-600-4 from paper nan is not available.
# nan NGC-650-4
# The BET curve for gac: NGC-650-4 from paper nan is not available.
# nan NGC-700-4
# The BET curve for gac: NGC-700-4 from paper nan is not available.
# nan NGC-600-4
# The BET curve for gac: NGC-600-4 from paper nan is not available.
# nan NGC-650-4
# The BET curve for gac: NGC-650-4 from paper nan is not available.
# nan NGC-700-4
# The BET curve for gac: NGC-700-4 from paper nan is not available.
# 47.0 N1N40X50
# The BET curve for gac: N1N40X50 from paper 47.0 is not available.
# nan N1N40X50
# The BET curve for gac: N1N40X50 from paper nan is not available.
# nan N2.38N360F30
# The BET curve for gac: N2.38N360F30 from paper nan is not available.
# nan N2.38N360F30
# The BET curve for gac: N2.38N360F30 from paper nan is not available.
# nan N0.8A80F50
# The BET curve for gac: N0.8A80F50 from paper nan is not available.
# nan N0.8A80F50
# The BET curve for gac: N0.8A80F50 from paper nan is not available.
# nan N2.38A360F30
# The BET curve for gac: N2.38A360F30 from paper nan is not available.
# nan N2.38A360F30
# The BET curve for gac: N2.38A360F30 from paper nan is not available.
# 48.0 EFB-800
# The BET curve for gac: EFB-800 from paper 48.0 is not available.
# nan EFB-800
# The BET curve for gac: EFB-800 from paper nan is not available.
# nan EFB-800
# The BET curve for gac: EFB-800 from paper nan is not available.
# nan HT150-800
# The BET curve for gac: HT150-800 from paper nan is not available.
# nan HT150-800
# The BET curve for gac: HT150-800 from paper nan is not available.
# nan HT150-800
# The BET curve for gac: HT150-800 from paper nan is not available.
# nan HT250-800
# The BET curve for gac: HT250-800 from paper nan is not available.
# nan HT250-800
# The BET curve for gac: HT250-800 from paper nan is not available.
# nan HT250-800
# The BET curve for gac: HT250-800 from paper nan is not available.
# nan HT350-800
# The BET curve for gac: HT350-800 from paper nan is not available.
# nan HT350-800
# The BET curve for gac: HT350-800 from paper nan is not available.
# nan HT350-800
# The BET curve for gac: HT350-800 from paper nan is not available.
# 49.0 SU-AC-400
# The BET curve for gac: SU-AC-400 from paper 49.0 is not available.
# nan SU-AC-500
# The BET curve for gac: SU-AC-500 from paper nan is not available.
# nan SU-AC-600
# The BET curve for gac: SU-AC-600 from paper nan is not available.
# nan SU-AC-700
# The BET curve for gac: SU-AC-700 from paper nan is not available.
# nan SU-AC-800
# The BET curve for gac: SU-AC-800 from paper nan is not available.
# 50.0 HCM-ZC-0
# The BET curve for gac: HCM-ZC-0 from paper 50.0 is not available.
# nan HCM-ZC-1
# The BET curve for gac: HCM-ZC-1 from paper nan is not available.
# nan HCM-ZnO
# The BET curve for gac: HCM-ZnO from paper nan is not available.
# nan HCM-ZC-0
# The BET curve for gac: HCM-ZC-0 from paper nan is not available.
# nan HCM-ZC-1
# The BET curve for gac: HCM-ZC-1 from paper nan is not available.
# nan HCM-ZnO
# The BET curve for gac: HCM-ZnO from paper nan is not available.
# 51.0 HTC-673
# The BET curve for gac: HTC-673 from paper 51.0 is not available.
# nan HTC-773
# The BET curve for gac: HTC-773 from paper nan is not available.
# nan HTC-873
# The BET curve for gac: HTC-873 from paper nan is not available.
# nan HTC-973
# The BET curve for gac: HTC-973 from paper nan is not available.
# 52.0 nZDCs-1000
# The BET curve for gac: nZDCs-1000 from paper 52.0 is not available.
# nan nZDCs-900
# The BET curve for gac: nZDCs-900 from paper nan is not available.
# nan nZDCS-800
# The BET curve for gac: nZDCS-800 from paper nan is not available.
# nan Nzdcs-700
# The BET curve for gac: Nzdcs-700 from paper nan is not available.
# nan Nzdcs-600
# The BET curve for gac: Nzdcs-600 from paper nan is not available.
# nan Nzdcs-1000C
# The BET curve for gac: Nzdcs-1000C from paper nan is not available.
# nan Nzdcs-900C
# The BET curve for gac: Nzdcs-900C from paper nan is not available.
# nan Nzdcs-800C
# The BET curve for gac: Nzdcs-800C from paper nan is not available.
# nan Nzdcs-700C
# The BET curve for gac: Nzdcs-700C from paper nan is not available.
# nan Nzdcs-600C
# The BET curve for gac: Nzdcs-600C from paper nan is not available.
# 53.0 Norit® SX2
# The BET curve for gac: Norit® SX2 from paper 53.0 is not available.
# nan Norit® SX2
# The BET curve for gac: Norit® SX2 from paper nan is not available.
# nan Norit® SX2
# The BET curve for gac: Norit® SX2 from paper nan is not available.
# 54.0 NC-0.5-600
# The BET curve for gac: NC-0.5-600 from paper 54.0 is not available.
# nan NC-1-600
# The BET curve for gac: NC-1-600 from paper nan is not available.
# nan NC-2-600
# The BET curve for gac: NC-2-600 from paper nan is not available.
# nan NC-1-500
# The BET curve for gac: NC-1-500 from paper nan is not available.
# nan NC-1-700
# The BET curve for gac: NC-1-700 from paper nan is not available.
# nan NC-0.5-600
# The BET curve for gac: NC-0.5-600 from paper nan is not available.
# nan NC-1-600
# The BET curve for gac: NC-1-600 from paper nan is not available.
# nan NC-2-600
# The BET curve for gac: NC-2-600 from paper nan is not available.
# nan NC-1-500
# The BET curve for gac: NC-1-500 from paper nan is not available.
# nan NC-1-700
# The BET curve for gac: NC-1-700 from paper nan is not available.
# 55.0 NPC-600-KOH
# (13, 94)
# 55.0 NPC-700-KOH
# (13, 94)
# 55.0 NPC-800-KOH
# (13, 94)
# 55.0 NPC-700-ZnCl2
# (14, 94)
# 55.0 NPC-700-FeCl3
# (12, 94)
# 56.0 AC2
# (12, 94)
# 56.0 AC2
# (12, 94)
# 56.0 AC2
# (12, 94)
# 57.0 NaAC
# (11, 94)
# 57.0 KAC
# (11, 94)
# 57.0 RbAC
# (11, 94)
# 57.0 CsAC
# (11, 94)
# 57.0 NaAC
# (11, 94)
# 57.0 KAC
# (11, 94)
# 57.0 RbAC
# (11, 94)
# 57.0 CsAC
# (11, 94)
# 57.0 NaAC
# (11, 94)
# 57.0 KAC
# (10, 94)
# 57.0 RbAC
# (10, 94)
# 57.0 CsAC
# (10, 94)
# 58.0 HMT-60-600
# (13, 94)
# 58.0 HMT-100-600
# (13, 94)
# 58.0 HMT-130-600
# (13, 94)
# 58.0 HMT-60-600
# (14, 94)
# 58.0 HMT-100-600
# (13, 94)
# 58.0 HMT-130-600
# (13, 94)
# 58.0 HMT-80-600
# (13, 94)
# 58.0 HMT-80-700
# (12, 94)
# 58.0 HMT-80-800
# (13, 94)
# 58.0 HMT-80-900
# (12, 94)
# 58.0 HMT-80-1000
# (13, 94)
# 58.0 HMT-80-600
# (12, 94)
# 58.0 HMT-80-700
# (11, 94)
# 58.0 HMT-80-800
# (12, 94)
# 58.0 HMT-80-1000
# (12, 94)
# 59.0 SU-MAC-500
# (13, 94)
# 59.0 SU-MAC-500
# (13, 94)
# 59.0 SU-MAC-500
# (12, 94)
# 59.0 SU-MAC-600
# (12, 94)
# 59.0 SU-MAC-800
# (12, 94)
# 59.0 SU-MAC-600
# (12, 94)
# 59.0 SU-MAC-600
# (11, 94)
# 59.0 SU-MAC-800
# (12, 94)
# 59.0 SU-MAC-800
# (10, 94)
# 60.0 C-0
# (14, 94)
# 60.0 C-0
# (12, 94)
# 60.0 C-0
# (12, 94)
# 60.0 CN-0
# (11, 94)
# 60.0 CN-0
# (12, 94)
# 60.0 CN-0
# (12, 94)
# 60.0 C-4
# (8, 94)
# 60.0 C-4
# (8, 94)
# 60.0 C-4
# (8, 94)
# 60.0 CN-4
# (8, 94)
# 60.0 CN-4
# (9, 94)
# 60.0 CN-4
# (9, 94)
# 61.0 LAC2600
# (12, 94)
# 61.0 LAC2600
# (13, 94)
# 61.0 LAC2600
# (12, 94)
# 61.0 LAC2700
# (12, 94)
# 61.0 LAC2700
# (12, 94)
# 61.0 LAC2700
# (11, 94)
# 61.0 LAC2800
# (13, 94)
# 61.0 LAC2800
# (13, 94)
# 61.0 LAC2800
# (11, 94)
# 61.0 LAC2800
# (10, 94)
# 62.0 NPC-1-800
# (13, 94)
# 62.0 NPC-1-700
# (10, 94)
# 62.0 NPC-1-600
# (13, 94)
# 62.0 NPC-1-500
# (12, 94)
# 62.0 NPC-1-600R
# (12, 94)
# 62.0 NPC-1-500
# (11, 94)
# 62.0 NPC-1-600
# (10, 94)
# 62.0 NPC-1-600R
# (11, 94)
# 62.0 NPC-1-700
# (12, 94)
# 62.0 NPC-1-800
# (12, 94)
# 63.0 A-rNPC
# (12, 94)
# 63.0 A-NPC
# (10, 94)
# 63.0 A-PC
# (10, 94)
# 63.0 SPC
# The BET curve for gac: SPC from paper 63.0 is not available.
# 63.0 NPC
# The BET curve for gac: NPC from paper 63.0 is not available.
# 63.0 A-rNPC
# (12, 94)
# 63.0 A-rNPC
# (10, 94)
# 63.0 A-rNPC
# (11, 94)
# 63.0 A-rNPC
# (12, 94)
# 64.0 AG-2-700
# The BET curve for gac: AG-2-700 from paper 64.0 is not available.
# 65.0 A-CS800-2
# (10, 94)
# 65.0 A-CS800-3
# (12, 94)
# 65.0 A-CS800-4
# (14, 94)
# 66.0 SA-2N-P
# (12, 94)
# 66.0 SA-2N-P
# (12, 94)
# 66.0 SA-N-2P
# (19, 94)
# 66.0 SA-N-2P
# (15, 94)
# 66.0 SA-N-2P
# (21, 94)
# 66.0 SA-3N
# (20, 94)
# 66.0 SA-3N
# (19, 94)
# 66.0 SA-3N
# (20, 94)
# 67.0 MCN
# (16, 94)
# 67.0 MCN
# (15, 94)
# 67.0 MCN-C
# (19, 94)
# 67.0 MCN-C
# (18, 94)
# 68.0 RN-400-1
# (15, 94)
# 68.0 RN-450-1
# (15, 94)
# 68.0 RN-500-1
# (17, 94)
# 68.0 RN-400-2
# (13, 94)
# 68.0 RN-450-2
# (14, 94)
# 68.0 RN-500-2
# (13, 94)
# 68.0 RN-400-3
# (13, 94)
# 68.0 RN-450-3
# (13, 94)
# 68.0 RN-500-3
# (15, 94)
# 68.0 RN-400-4
# (13, 94)
# 68.0 RN-450-4
# (15, 94)
# 68.0 RN-500-4
# (15, 94)
# 68.0 RN-400-1
# (15, 94)
# 68.0 RN-450-1
# (15, 94)
# 68.0 RN-500-1
# (14, 94)
# 68.0 RN-400-2
# (13, 94)
# 68.0 RN-450-2
# (12, 94)
# 68.0 RN-500-2
# (15, 94)
# 68.0 RN-400-3
# (16, 94)
# 68.0 RN-450-3
# (14, 94)
# 68.0 RN-500-3
# (15, 94)
# 68.0 RN-400-4
# (14, 94)
# 68.0 RN-450-4
# (15, 94)
# 68.0 RN-500-4
# (15, 94)
# 69.0 grass cuttings
# The BET curve for gac: grass cuttings from paper 69.0 is not available.
# 69.0 horse manure
# The BET curve for gac: horse manure from paper 69.0 is not available.
# 69.0 beer waste
# The BET curve for gac: beer waste from paper 69.0 is not available.
# 69.0 biosludge
# The BET curve for gac: biosludge from paper 69.0 is not available.
# 69.0 C beer waste
# The BET curve for gac: C beer waste from paper 69.0 is not available.
# 69.0 grass cuttings
# The BET curve for gac: grass cuttings from paper 69.0 is not available.
# 69.0 grass cuttings
# The BET curve for gac: grass cuttings from paper 69.0 is not available.
# 69.0 grass cuttings
# The BET curve for gac: grass cuttings from paper 69.0 is not available.
# 70.0 S-973-1.25
# The BET curve for gac: S-973-1.25 from paper 70.0 is not available.
# nan S-973-1.25
# The BET curve for gac: S-973-1.25 from paper nan is not available.
# nan P-973-1
# The BET curve for gac: P-973-1 from paper nan is not available.
# nan P-973-1
# The BET curve for gac: P-973-1 from paper nan is not available.
# 71.0 BICD-0.5-700
# (14, 94)
# 71.0 BICD-1-700
# (14, 94)
# 71.0 BICD-2-700
# (12, 94)
# 71.0 BICD-3-700
# (12, 94)
# 71.0 BICD-0.5-700
# (13, 94)
# 71.0 BICD-1-700
# (14, 94)
# 71.0 BICD-2-700
# (12, 94)
# 71.0 BICD-3-700
# (14, 94)
# 71.0 BICD-0.5-700
# (17, 94)
# 71.0 BICD-1-700
# (17, 94)
# 71.0 BICD-2-700
# (12, 94)
# 71.0 BICD-3-700
# (12, 94)
# 72.0 AC-1-600
# (13, 94)
# 72.0 AC-1-635
# (12, 94)
# 72.0 AC-1-700
# (11, 94)
# 72.0 AC-1-800
# (12, 94)
# 72.0 AC-2-600
# (12, 94)
# 72.0 AC-2-635
# (14, 94)
# 72.0 AC-2-700
# (11, 94)
# 72.0 AC-2-800
# (10, 94)
# 72.0 AC-2-635
# (11, 94)
# 72.0 AC-2-635
# (10, 94)
# 73.0 C600
# (13, 94)
# 73.0 C700
# (12, 94)
# 73.0 C800
# (14, 94)
# 73.0 C900
# (15, 94)
# 73.0 C1000
# (12, 94)
# 73.0 C600W
# (9, 94)
# 73.0 C700W
# (13, 94)
# 73.0 C800W
# (10, 94)
# 73.0 C900W
# (11, 94)
# 73.0 C1000A
# (10, 94)
# 74.0 CKHP700-1
# (12, 94)
# 74.0 SD2600
# (13, 94)
# 74.0 Py2600
# (13, 94)
# 74.0 nCN2600
# (10, 94)
# 75.0 G-800
# (11, 94)
# 75.0 G-900
# (10, 94)
# 75.0 G-1000
# (13, 94)
# 76.0 Bamboo-3-873
# The BET curve for gac: Bamboo-3-873 from paper 76.0 is not available.
# 76.0 Bamboo-3-873
# The BET curve for gac: Bamboo-3-873 from paper 76.0 is not available.
# 76.0 Bamboo-1-973
# The BET curve for gac: Bamboo-1-973 from paper 76.0 is not available.
# 76.0 Bamboo-1-973
# The BET curve for gac: Bamboo-1-973 from paper 76.0 is not available.
# 77.0 4.5H
# (10, 94)
# 77.0 3.5H
# (10, 94)
# 77.0 2H
# The BET curve for gac: 2H from paper 77.0 is not available.
# 77.0 1H
# (11, 94)
# 77.0 1HN2
# (9, 94)
# 77.0 4.5H
# (11, 94)
# 77.0 3.5H
# (11, 94)
# 77.0 2H
# The BET curve for gac: 2H from paper 77.0 is not available.
# 77.0 1H
# (12, 94)
# 77.0 1HN2
# (10, 94)
# 78.0 AC
# (14, 94)
# 78.0 AC-KOH
# (12, 94)
# 78.0 AC-KOH-N
# (13, 94)
# 78.0 AC
# (11, 94)
# 78.0 AC-KOH
# (11, 94)
# 78.0 AC-KOH-N
# (10, 94)
# 78.0 AC-KOH
# (11, 94)
# 78.0 AC-KOH-N
# (10, 94)
# 79.0 N-AC
# (18, 94)
# 79.0 DG-60
# The BET curve for gac: DG-60 from paper 79.0 is not available.
# 79.0 N-AC
# (16, 94)
# 80.0 T-GU-700-6
# (12, 94)
# 80.0 T-GU-750-6
# (13, 94)
# 80.0 T-GU-700-8
# (13, 94)
# 80.0 T-GU-700-6
# (14, 94)
# 80.0 T-GU-750-6
# (13, 94)
# 80.0 T-G-700-6
# (12, 94)
# 80.0 GU-700-6
# (12, 94)
# 80.0 T-G-700-6
# (11, 94)
# 81.0 HPC5b2-1100
# (19, 94)
# 81.0 HPC5b2-1000
# (13, 94)
# 81.0 HPC5b2-900
# (14, 94)
# 81.0 HPC5b1-900
# (16, 94)
# 81.0 HPC74-1000
# (10, 94)
# 81.0 HPC74-900
# (11, 94)
# 81.0 HPC74-800
# (12, 94)
# 81.0 HPC74-600
# (13, 94)
# 81.0 HPC53-1000
# (10, 94)
# 82.0 CNFWs-550-2
# (13, 94)
# 82.0 CNFWs-550-2
# (14, 94)
# 82.0 CNFWs-550-2
# (13, 94)
# 82.0 CNFWs-600-2
# (14, 94)
# 82.0 CNFWs-600-2
# (14, 94)
# 82.0 CNFWs-600-2
# (15, 94)
# 82.0 CNFWs-650-2
# (14, 94)
# 82.0 CNFWs-650-2
# (14, 94)
# 82.0 CNFWs-650-2
# (13, 94)
# 83.0 PC1-700
# (15, 94)
# 83.0 PC2-700
# (16, 94)
# 83.0 PC2-700H
# (13, 94)
# 83.0 PC3-700
# (10, 94)
# 83.0 PC2-600
# (13, 94)
# 83.0 PC2-800
# (11, 94)
# 83.0 PC1-700
# (12, 94)
# 83.0 PC2-700
# (12, 94)
# 83.0 PC2-700H
# (12, 94)
# 83.0 PC3-700
# (11, 94)
# 83.0 PC2-600
# (12, 94)
# 83.0 PC2-800
# (12, 94)
# 84.0 OS
# (12, 94)
# 84.0 OS
# (12, 94)
# 84.0 OS
# (12, 94)
# 84.0 AS
# (13, 94)
# 84.0 AS
# (11, 94)
# 84.0 AS
# (11, 94)
# 85.0 NC-800
# (10, 94)
# 85.0 NC-700
# (10, 94)
# 85.0 NC-600
# (10, 94)
# 85.0 NC-800
# (8, 94)
# 85.0 NC-700
# (7, 94)
# 85.0 NC-600
# (11, 94)
# 86.0 C_N-650
# (11, 94)
# 86.0 C_N-750
# (10, 94)
# 86.0 C_N-850
# (11, 94)
# 86.0 C_N-950
# (11, 94)
# 86.0 C_N-1100
# (10, 94)
# 87.0 KLB3
# (12, 94)
# 88.0 STC-P-A
# (11, 94)
# 88.0 STC-P-600-A
# (11, 94)
# 88.0 STC-P-500-A
# (12, 94)
# 88.0 STC-P-600
# (12, 94)
# 88.0 STC-P-500
# (11, 94)
# 88.0 STC-R-A
# (12, 94)
# 88.0 STC-R-600-A
# (12, 94)
# 88.0 STC-R-500-A
# (11, 94)
# 88.0 STC-R-600
# (11, 94)
# 88.0 STC-R-500
# (11, 94)
# 89.0 CS-4
# (11, 94)
# 89.0 CS-6
# (11, 94)
# 89.0 CS-8
# (12, 94)
# 89.0 CS-4-CD-4
# (10, 94)
# 89.0 CS-6-CD-4
# (11, 94)
# 89.0 CS-8-CD-4
# (11, 94)
# 89.0 CS-4-CD-4
# (13, 94)
# 89.0 CS-6-CD-4
# (12, 94)
# 89.0 CS-8-CD-4
# (17, 94)
# 89.0 CS-6-CD-2
# (11, 94)
# 89.0 CS-6-CD-8
# (10, 94)
# 89.0 CS-6-CD-2
# (11, 94)
# 89.0 CS-6-CD-4
# (11, 94)
# 89.0 CS-6-CD-8
# (12, 94)
# 90.0 PAN-PK
# (12, 94)
# 90.0 PAN-OK
# (11, 94)
# 91.0 C-KOH
# (11, 94)
# 91.0 C-CO2
# (11, 94)
# 91.0 C-NH3
# (10, 94)
# 91.0 C-H2O
# (11, 94)
# 91.0 C-ZnCl2
# (11, 94)
# 91.0 C
# (11, 94)
# 91.0 C-KOH
# (11, 94)
# 91.0 C-CO2
# (11, 94)
# 91.0 C-NH3
# (10, 94)
# 91.0 C-H2O
# (11, 94)
# 91.0 C-ZnCl2
# (10, 94)
# 91.0 C
# (11, 94)
# 92.0 NS-1
# (13, 94)
# 92.0 NS-2
# (14, 94)
# 92.0 NS-3
# (13, 94)
# 92.0 NS2
# The BET curve for gac: NS2 from paper 92.0 is not available.
# 92.0 NS2
# The BET curve for gac: NS2 from paper 92.0 is not available.
# 92.0 SNS2-10
# (15, 94)
# 92.0 SNS2-10
# (15, 94)
# 92.0 SNS2-10
# (16, 94)
# 92.0 SNS2-20
# (15, 94)
# 92.0 SNS2-20
# (14, 94)
# 92.0 SNS2-20
# (14, 94)
# 92.0 NS-1
# (17, 94)
# 92.0 NS-1
# (14, 94)
# 92.0 NS-2
# (15, 94)
# 92.0 NS-2
# (14, 94)
# 92.0 NS-3
# (15, 94)
# 92.0 NS-3
# (15, 94)
# 92.0 SNS1-10
# (18, 94)
# 92.0 SNS1-10
# (15, 94)
# 92.0 SNS1-10
# (16, 94)
# 92.0 SNS1-20
# (18, 94)
# 92.0 SNS1-20
# (17, 94)
# 92.0 SNS1-20
# (16, 94)
# 92.0 SNS3-10
# (17, 94)
# 92.0 SNS3-10
# (16, 94)
# 92.0 SNS3-10
# (15, 94)
# 92.0 SNS3-20
# (16, 94)
# 92.0 SNS3-20
# (15, 94)
# 92.0 SNS3-20
# (16, 94)
# 93.0 IBN9-NC
# (12, 94)
# 93.0 IBN9-NC-A
# (14, 94)
# 93.0 IBN9-NC1
# (15, 94)
# 93.0 IBN9-NC1-A
# (20, 94)
# 93.0 IBN9-NC1
# (15, 94)
# 93.0 IBN9-NC1
# (17, 94)
# 93.0 IBN9-NC1-A
# (16, 94)
# 93.0 IBN9-NC1-A
# (14, 94)
# 94.0 AC-6
# The BET curve for gac: AC-6 from paper 94.0 is not available.
# nan AC-3
# The BET curve for gac: AC-3 from paper nan is not available.
# nan AC-4
# The BET curve for gac: AC-4 from paper nan is not available.
# nan AC-2
# The BET curve for gac: AC-2 from paper nan is not available.
# nan AC-5
# The BET curve for gac: AC-5 from paper nan is not available.
# nan AC-1
# The BET curve for gac: AC-1 from paper nan is not available.
# 95.0 G-800
# (11, 94)
# 95.0 G-850
# (10, 94)
# 95.0 G-850-5
# (10, 94)
# 95.0 G-2.3-2
# (10, 94)
# 95.0 G-2.7-2
# (11, 94)
# 95.0 G-3.6-2
# (10, 94)
# 95.0 G-3.6-1
# (12, 94)
# 96.0 MPC-3
# The BET curve for gac: MPC-3 from paper 96.0 is not available.
# 96.0 MPC-3
# The BET curve for gac: MPC-3 from paper 96.0 is not available.
# 96.0 MPC-3
# The BET curve for gac: MPC-3 from paper 96.0 is not available.
# 96.0 MCP-1
# (11, 94)
# 96.0 MCP-2
# (12, 94)
# 96.0 MCP-4
# (13, 94)
# 97.0 DKC-600-2
# (9, 94)
# 97.0 BKC-600-2
# (10, 94)
# 97.0 HKC-600-2
# (11, 94)
# 97.0 BKC-600-2
# (9, 94)
# 97.0 HKC-600-2
# (10, 94)
# 97.0 HKC-600-2
# (9, 94)
# 97.0 HKC-700-2
# (9, 94)
# 97.0 HKC-800-2
# (10, 94)
# 97.0 HKC-800-1
# (9, 94)
# 97.0 HKC-600-2
# (9, 94)
# 97.0 HKC-700-2
# (9, 94)
# 97.0 HKC-800-2
# (9, 94)
# 97.0 HKC-800-1
# (10, 94)
# 98.0 DC-SI
# (10, 94)
# 98.0 DAC-KHCO3
# (10, 94)
# 98.0 DC
# (9, 94)
# 98.0 PAC-KHCO3
# (12, 94)
# 98.0 DAC-KHCO3-SI
# (10, 94)
# 98.0 PAC-KOH
# (10, 94)
# 98.0 DC-SI
# (9, 94)
# 98.0 DAC-KHCO3
# (10, 94)
# 98.0 DC
# (9, 94)
# 98.0 PAC-KHCO3
# (10, 94)
# 98.0 DAC-KHCO3-SI
# (8, 94)
# 99.0 NSDC1
# (8, 94)
# 99.0 NSDC3
# (8, 94)
# 99.0 NSDC5
# (8, 94)
# 99.0 SDC0
# (10, 94)
# 99.0 SDC3
# (9, 94)
# 99.0 NSDC1
# (7, 94)
# 99.0 NSDC3
# (8, 94)
# 99.0 NSDC5
# (8, 94)
# 99.0 SDC0
# (8, 94)
# 99.0 SDC3
# (9, 94)
# 99.0 NSDC1
# (7, 94)
# 99.0 NSDC3
# (8, 94)
# 99.0 NSDC5
# (8, 94)
# 99.0 SDC0
# (9, 94)
# 99.0 SDC3
# (10, 94)
# 100.0 LSB1-800
# (10, 94)
# 100.0 LSB2-800
# (11, 94)
# 100.0 LSB3-800
# (11, 94)
# 100.0 LSB4-800
# (12, 94)
# 100.0 LSB3-800
# (10, 94)
# 100.0 LSB3-800
# (12, 94)
# 101.0 SA-1-600
# (9, 94)
# 101.0 SA-1-600
# (10, 94)
# 101.0 SA-1-700
# (10, 94)
# 101.0 SA-1-700
# (9, 94)
# 101.0 SA-1-800
# (10, 94)
# 101.0 SA-1-800
# (8, 94)
# 101.0 SA-1-600
# (10, 94)
# 101.0 SA-1-700
# (10, 94)
# 101.0 SA-1-800
# (9, 94)
# 101.0 SA-2-600
# (10, 94)
# 101.0 SA-2-700
# (10, 94)
# 101.0 SA-2-800
# (9, 94)
# 101.0 SA-2-600
# (10, 94)
# 101.0 SA-2-700
# (9, 94)
# 101.0 SA-2-800
# (10, 94)
# 101.0 SA-2-600
# (10, 94)
# 101.0 SA-2-700
# (9, 94)
# 101.0 SA-2-800
# (9, 94)
# 102.0 CMK-3
# (11, 94)
# 102.0 CMK-3
# (11, 94)
# 102.0 CMK-3
# (11, 94)
# 102.0 CMK-3
# (11, 94)
# 102.0 CMK-3
# (10, 94)
# 102.0 CMK-3
# (11, 94)
# 102.0 CMK-3
# (10, 94)
# 103.0 OM-CNS
# (11, 94)
# 103.0 RS-HCS
# (10, 94)
# 103.0 SS-HCS
# (11, 94)
# 103.0 DS-HCS
# (13, 94)
# 104.0 MU600
# The BET curve for gac: MU600 from paper 104.0 is not available.
# 104.0 MUC700
# (8, 94)
# 104.0 MUC800
# (9, 94)
# 104.0 MUC900
# (10, 94)
# 104.0 MUC600
# (8, 94)
# 104.0 MUC700
# (9, 94)
# 104.0 MUC800
# (9, 94)
# 104.0 MUC900
# (8, 94)
# 105.0 APCN-S
# (9, 94)
# 105.0 APCB-T
# The BET curve for gac: APCB-T from paper 105.0 is not available.
# 105.0 APCN-A
# (9, 94)
# 105.0 APCN-S
# (8, 94)
# 105.0 APCN-T
# (8, 94)
# 105.0 APCN-A
# (7, 94)
# 106.0 600_1
# (9, 94)
# 106.0 650_1
# (10, 94)
# 106.0 700_1
# (12, 94)
# 106.0 750_1
# (12, 94)
# 106.0 800_1
# (11, 94)
# 106.0 850_1
# (13, 94)
# 106.0 900_1
# (11, 94)
# 106.0 800_3
# (10, 94)
# 106.0 800_2
# (9, 94)
# 106.0 800_1.5
# (10, 94)
# 106.0 800_0.5
# (10, 94)
# 106.0 850_3
# (9, 94)
# 106.0 850_2
# (12, 94)
# 106.0 850_1.5
# (12, 94)
# 106.0 850_0.5
# (12, 94)
# 106.0 600_1
# (10, 94)
# 106.0 650_1
# (11, 94)
# 106.0 700_1
# (11, 94)
# 106.0 750_1
# (11, 94)
# 106.0 800_1
# (11, 94)
# 106.0 850_1
# (12, 94)
# 106.0 900_1
# (10, 94)
# 106.0 800_3
# (10, 94)
# 106.0 800_2
# (10, 94)
# 106.0 800_1.5
# (10, 94)
# 106.0 800_0.5
# (11, 94)
# 106.0 850_3
# (10, 94)
# 106.0 850_2
# (12, 94)
# 106.0 850_1.5
# (12, 94)
# 106.0 850_0.5
# (12, 94)
# 107.0 gc-17
# (9, 94)
# 107.0 gc-27
# (9, 94)
# 107.0 gc-46
# (8, 94)
# 107.0 gc-47
# (11, 94)
# 107.0 gc-48
# (11, 94)
# 107.0 gc-17
# (10, 94)
# 107.0 gc-27
# (11, 94)
# 107.0 gc-46
# (10, 94)
# 107.0 gc-47
# (11, 94)
# 107.0 gc-48
# (11, 94)
# 108.0 PAB1
# (11, 94)
# 108.0 PAB2
# (11, 94)
# 108.0 PAB3
# (13, 94)
# 108.0 PAB4
# (12, 94)
# 108.0 PAB3
# (12, 94)
# 108.0 PAB3
# (11, 94)
# 108.0 PAB1
# (11, 94)
# 108.0 PAB1
# (11, 94)
# 108.0 PAB2
# (11, 94)
# 108.0 PAB2
# (9, 94)
# 108.0 PAB4
# (10, 94)
# 108.0 PAB4
# (11, 94)
# 109.0 AC100
# (9, 94)
# 109.0 AC450
# (9, 94)
# 109.0 AC800
# (10, 94)
# 109.0 AC1040
# (10, 94)
# 109.0 AC100
# (11, 94)
# 109.0 AC450
# (11, 94)
# 109.0 AC800
# (13, 94)
# 109.0 AC1040
# (12, 94)
# 110.0 NAC-1.5-600
# (11, 94)
# 110.0 NAC-1.5-700
# (8, 94)
# 110.0 NAC-1.5-650
# (10, 94)
# 110.0 NAC-1.5-600
# (11, 94)
# 110.0 NAC-1.5-550
# (12, 94)
# 110.0 NAC-1.5-700
# (9, 94)
# 110.0 NAC-1.5-650
# (11, 94)
# 110.0 NAC-1.5-600
# (13, 94)
# 110.0 NAC-1.5-550
# (12, 94)
# 110.0 NAC-2-600
# (12, 94)
# 110.0 NAC-1.75-600
# (12, 94)
# 110.0 NAC-1.25-600
# (12, 94)
# 110.0 NAC-1-600
# (12, 94)
# 111.0 CA-G300
# (9, 94)
# 111.0 CA-HC
# (11, 94)
# 111.0 CA-HC300
# (11, 94)
# 111.0 CA-G300
# (9, 94)
# 111.0 CA-HC
# (8, 94)
# 111.0 CA-HC300
# (10, 94)
# 111.0 CA-HC200
# (11, 94)
# 111.0 CA-HC250
# (11, 94)
# 111.0 CA-HC350
# (13, 94)
# 111.0 CA-HC200
# (10, 94)
# 111.0 CA-HC250
# (11, 94)
# 111.0 CA-HC-350
# The BET curve for gac: CA-HC-350 from paper 111.0 is not available.
# 112.0 A-NCF-4
# (9, 94)
# 112.0 A-NCF-2
# (11, 94)
# 112.0 A-NCF-6
# (10, 94)
# 112.0 NCF
# (10, 94)
# 112.0 A-NCF-4
# (9, 94)
# 112.0 A-NCF-2
# (11, 94)
# 112.0 A-NCF-6
# (10, 94)
# 112.0 NCF
# (11, 94)
# 112.0 A-NCF-4
# (10, 94)
# 112.0 A-NCF-2
# (9, 94)
# 112.0 A-NCF-6
# (10, 94)
# 112.0 NCF
# (10, 94)
# 113.0 COAL-K-PM
# (10, 94)
# 113.0 COAL-K-LM
# (12, 94)
# 113.0 COAL-NA-PM
# (11, 94)
# 113.0 COAL-NA-LM
# (13, 94)
# 114.0 AC_HTC_CO2-850_3
# The BET curve for gac: AC_HTC_CO2-850_3 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_5_600
# The BET curve for gac: AC_HTC_KOH_5_600 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_5_700
# The BET curve for gac: AC_HTC_KOH_5_700 from paper 114.0 is not available.
# 114.0 AC_HCT_ZN_700_CO2_1
# The BET curve for gac: AC_HCT_ZN_700_CO2_1 from paper 114.0 is not available.
# 114.0 AC_HCT_ZN_700_CO2_3
# The BET curve for gac: AC_HCT_ZN_700_CO2_3 from paper 114.0 is not available.
# 114.0 AC_HCT_ZN_700_N2
# The BET curve for gac: AC_HCT_ZN_700_N2 from paper 114.0 is not available.
# 114.0 AC_HTC_CO2_850_3
# The BET curve for gac: AC_HTC_CO2_850_3 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_2_700
# The BET curve for gac: AC_HTC_KOH_2_700 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_5_600
# The BET curve for gac: AC_HTC_KOH_5_600 from paper 114.0 is not available.
# 114.0 AC_HTC_ZN_700_CO2_3
# The BET curve for gac: AC_HTC_ZN_700_CO2_3 from paper 114.0 is not available.
# 114.0 AC_HTC_CO2_850_3
# The BET curve for gac: AC_HTC_CO2_850_3 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_2_700
# The BET curve for gac: AC_HTC_KOH_2_700 from paper 114.0 is not available.
# 114.0 AC_HTC_KOH_5_600
# The BET curve for gac: AC_HTC_KOH_5_600 from paper 114.0 is not available.
# 115.0 FC1
# (13, 94)
# 115.0 FC2
# (13, 94)
# 115.0 FC3
# (13, 94)
# 115.0 FC4
# (13, 94)
# 116.0 IBAP-500-1.5
# The BET curve for gac: IBAP-500-1.5 from paper 116.0 is not available.
# 116.0 IBAP-700-1.5
# The BET curve for gac: IBAP-700-1.5 from paper 116.0 is not available.
# 116.0 IBAP-900-1.5
# The BET curve for gac: IBAP-900-1.5 from paper 116.0 is not available.
# 116.0 IBAP-700-1.5
# The BET curve for gac: IBAP-700-1.5 from paper 116.0 is not available.
# 116.0 IBAP-700-1.5
# The BET curve for gac: IBAP-700-1.5 from paper 116.0 is not available.
# 117.0 300-3-KOH
# (9, 94)
# 117.0 300-4-KOH
# (11, 94)
# 117.0 300-5-KOH
# (11, 94)
# 117.0 300-6-KOH
# (12, 94)
# 117.0 400-2-KOH
# (12, 94)
# 117.0 400-3-KOH
# (14, 94)
# 117.0 400-4-KOH
# (13, 94)
# 117.0 300-3-KOH
# (9, 94)
# 117.0 300-4-KOH
# (11, 94)
# 117.0 300-5-KOH
# (11, 94)
# 117.0 300-6-KOH
# (13, 94)
# 117.0 400-2-KOH
# (11, 94)
# 117.0 400-3-KOH
# (12, 94)
# 117.0 400-4-KOH
# (12, 94)
# 117.0 300-3-K2CO3
# (10, 94)
# 117.0 300-4-K2CO3
# (10, 94)
# 117.0 300-5-K2CO3
# (10, 94)
# 117.0 300-6-K2CO3
# (12, 94)
# 117.0 400-2-K2CO3
# (11, 94)
# 117.0 400-3-K2CO3
# (12, 94)
# 117.0 400-4-K2CO3
# (12, 94)
# 117.0 300-3-K2CO3
# (8, 94)
# 117.0 300-4-K2CO3
# (10, 94)
# 117.0 300-5-K2CO3
# (10, 94)
# 117.0 300-6-K2CO3
# (11, 94)
# 117.0 400-2-K2CO3
# (11, 94)
# 117.0 400-3-K2CO3
# (11, 94)
# 117.0 400-4-K2CO3
# (10, 94)
# 118.0 NC-AC
# (10, 94)
# 118.0 PNC-0.5
# (9, 94)
# 118.0 PNC-1
# (10, 94)
# 118.0 PNC-2
# (10, 94)
# 118.0 NC-AC
# (8, 94)
# 118.0 PNC-1
# (9, 94)
# 119.0 CG800-5
# (10, 94)
# 119.0 CG800-1
# (11, 94)
# 119.0 CG700-5
# (11, 94)
# 119.0 CG700-1
# (11, 94)
# 119.0 CG600-5
# (11, 94)
# 119.0 CG600-1
# (11, 94)
# 119.0 CG800-5
# (10, 94)
# 119.0 CG800-1
# (11, 94)
# 119.0 CG700-5
# (12, 94)
# 119.0 CG700-1
# (11, 94)
# 119.0 CG600-5
# (11, 94)
# 119.0 CG600-1
# (11, 94)
# 119.0 CG800-5
# (10, 94)
# 119.0 CG800-1
# (10, 94)
# 119.0 CG700-5
# (11, 94)
# 119.0 CG700-1
# (11, 94)
# 119.0 CG600-5
# (10, 94)
# 119.0 CG600-1
# (10, 94)
# 120.0 ACDS-500-2
# (10, 94)
# 120.0 ACDS-500-4
# (9, 94)
# 120.0 ACDS-500-6
# (9, 94)
# 120.0 ACDS-800-2
# (10, 94)
# 120.0 ACDS-800-4
# (11, 94)
# 120.0 ACDS-800-6
# (10, 94)
# 120.0 ACDS-500-2
# (10, 94)
# 120.0 ACDS-500-4
# (10, 94)
# 120.0 ACDS-500-6
# (9, 94)
# 120.0 ACDS-800-2
# (11, 94)
# 120.0 ACDS-800-4
# (11, 94)
# 120.0 ACDS-800-6
# (10, 94)
# 121.0 NDPC-71-F-700
# (7, 94)
# 121.0 NDPC-71-F-600
# (8, 94)
# 121.0 NDPC-71-F-500
# (8, 94)
# 121.0 NDPC-71-F-800
# (7, 94)
# 121.0 NDPC-71-S-600
# (8, 94)
# 121.0 NDPC-71-S-500
# (9, 94)
# 121.0 NDPC-71-S-700
# (8, 94)
# 121.0 NDPC-71-F-500
# (7, 94)
# 121.0 NDPC-71-F-600
# (7, 94)
# 121.0 NDPC-71-F-700
# (7, 94)
# 121.0 NDPC-71-F-800
# (7, 94)
# 121.0 NDPC-71-S-500
# (10, 94)
# 121.0 NDPC-71-S-600
# (9, 94)
# 121.0 NDPC-71-S-700
# (9, 94)
# 122.0 AC-CO2-1
# (11, 94)
# 122.0 AC-CO2-3
# (12, 94)
# 122.0 AC-KOH-D-2-600
# (9, 94)
# 122.0 AC-KOH-D-2-700
# (10, 94)
# 122.0 AC-KOH-D-5-600
# (9, 94)
# 122.0 AC-KOH-D-5-700
# (14, 94)
# 122.0 AC-KOH-W-1-600
# (10, 94)
# 122.0 AC-KOH-W-1-700
# (10, 94)
# 122.0 AC-KOH-W-2-600
# (11, 94)
# 122.0 AC-KOH-W-2-700
# (11, 94)
# 122.0 AC-CO2-1
# (11, 94)
# 122.0 AC-CO2-3
# (14, 94)
# 122.0 AC-KOH-D-5-700
# (12, 94)
# 122.0 AC-CO2-1
# (8, 94)
# 122.0 AC-CO2-3
# (9, 94)
# 122.0 AC-KOH-D-5-700
# (10, 94)
# 122.0 AC-KOH-W-1-600
# (10, 94)
# 122.0 AC-KOH-W-1-700
# (12, 94)
# 122.0 AC-KOH-W-2-600
# (12, 94)
# 122.0 AC-KOH-W-2-700
# (12, 94)
# 122.0 AC-KOH-W-1-600
# (10, 94)
# 122.0 AC-KOH-W-1-700
# (10, 94)
# 122.0 AC-KOH-W-2-600
# (9, 94)
# 122.0 AC-KOH-W-2-700
# (10, 94)
# 123.0 NPC-600
# (7, 94)
# 123.0 NPC-600
# (7, 94)
# 123.0 NPC-700
# (7, 94)
# 123.0 NPC-700
# (7, 94)
# 123.0 NPC-800
# (7, 94)
# 123.0 NPC-800
# (7, 94)
# 123.0 RPC-600
# (7, 94)
# 123.0 RPC-600
# (6, 94)
# 123.0 RPC-700
# (7, 94)
# 123.0 RPC-700
# (7, 94)
# 123.0 RPC-800
# (7, 94)
# 123.0 RPC-800
# (6, 94)
# 124.0 GN-600-1
# (8, 94)
# 124.0 GN-650-1
# (9, 94)
# 124.0 GN-700-1
# (10, 94)
# 124.0 GN-600-1
# (9, 94)
# 124.0 GN-650-1
# (9, 94)
# 124.0 GN-700-1
# (9, 94)
# 124.0 GN-600-2
# (8, 94)
# 124.0 GN-650-2
# (8, 94)
# 124.0 GN-700-2
# (8, 94)
# 124.0 GN-600-2
# (8, 94)
# 124.0 GN-650-2
# (8, 94)
# 124.0 GN-700-2
# (8, 94)
# 124.0 GN-600-3
# (9, 94)
# 124.0 GN-650-3
# (9, 94)
# 124.0 GN-700-3
# (9, 94)
# 124.0 GN-600-3
# (8, 94)
# 124.0 GN-650-3
# (8, 94)
# 124.0 GN-700-3
# (7, 94)
# 124.0 GN-600-4
# (8, 94)
# 124.0 GN-650-4
# (8, 94)
# 124.0 GN-700-4
# (9, 94)
# 124.0 GN-600-4
# (8, 94)
# 124.0 GN-650-4
# (8, 94)
# 124.0 GN-700-4
# (9, 94)
# 125.0 HCP2A-K500
# (9, 94)
# 125.0 HCP2A-K600
# (10, 94)
# 125.0 HCP2A-K700
# (11, 94)
# 125.0 HCP2A-K500
# (8, 94)
# 125.0 HCP2A-K600
# (9, 94)
# 125.0 HCP2A-K700
# (10, 94)
# 126.0 PDA0.1-MA0.9-2
# (10, 94)
# 126.0 PDA0.3-MA0.7-2
# (13, 94)
# 126.0 PDA0.5-MA0.5-2
# (11, 94)
# 126.0 PY0.5-MA0.5-2
# (12, 94)
# 126.0 PDA0.1-MA0.9-2
# (12, 94)
# 126.0 PDA0.3-MA0.7-2
# (10, 94)
# 126.0 PDA0.5-MA0.5-2
# (12, 94)
# 126.0 PY0.5-MA0.5-2
# (11, 94)
# 127.0 PC-1-1
# (8, 94)
# 127.0 PC-1-2
# (9, 94)
# 127.0 PC-1-3
# (9, 94)
# 127.0 PC-2-2
# (9, 94)
# 127.0 PC-2-3
# (9, 94)
# 127.0 PC-2-4
# (9, 94)
# 127.0 PC-1-1
# (8, 94)
# 127.0 PC-1-2
# (8, 94)
# 127.0 PC-1-3
# (9, 94)
# 127.0 PC-2-2
# (10, 94)
# 127.0 PC-2-3
# (10, 94)
# 127.0 PC-2-4
# (10, 94)
# 127.0 PC-1-1
# (9, 94)
# 127.0 PC-1-2
# (11, 94)
# 127.0 PC-1-3
# (10, 94)
# 127.0 PC-2-2
# (10, 94)
# 127.0 PC-2-3
# (11, 94)
# 127.0 PC-2-4
# (10, 94)
# 128.0 OTSS-3-350
# (9, 94)
# 128.0 OTSS-2-450
# (10, 94)
# 128.0 OTSS-1-550
# (10, 94)
# 128.0 OTSS-3-350
# (9, 94)
# 128.0 OTSS-2-450
# (9, 94)
# 128.0 OTSS-1-550
# (9, 94)
# 129.0 NEPB-3UK
# (10, 94)
# 129.0 NEPB-3UZ
# (9, 94)
# 129.0 NEPB-3UK
# (7, 94)
# 129.0 NEPB-3UZ
# (9, 94)
# 130.0 Z4700
# (8, 94)
# 130.0 Z6800
# (8, 94)
# 130.0 Z0800
# (8, 94)
# 130.0 Z4900
# (9, 94)
# 130.0 Z2800
# (8, 94)
# 130.0 Z4950
# (8, 94)
# 130.0 Z4800
# (9, 94)
# 130.0 Z4700
# (7, 94)
# 130.0 Z6800
# (8, 94)
# 130.0 Z0800
# (8, 94)
# 130.0 Z4900
# (8, 94)
# 130.0 Z2800
# (7, 94)
# 130.0 Z4950
# (8, 94)
# 130.0 Z4800
# (8, 94)
# 131.0 TAC-0.5-600
# (8, 94)
# 131.0 TAC-0.5-700
# (9, 94)
# 131.0 TAC-0.5-800
# (10, 94)
# 131.0 TAC-0.5-900
# (9, 94)
# 131.0 TAC-0.25-700
# (10, 94)
# 131.0 TAC-1-700
# (10, 94)
# 131.0 TAC-2-700
# (10, 94)
# 131.0 TAC-0.5-600
# (8, 94)
# 131.0 TAC-0.5-700
# (9, 94)
# 131.0 TAC-0.5-800
# (9, 94)
# 131.0 TAC-0.5-900
# (9, 94)
# 131.0 TAC-0.25-700
# (9, 94)
# 131.0 TAC-1-700
# (9, 94)
# 131.0 TAC-2-700
# (9, 94)
# 132.0 RC-600-0.5
# (12, 94)
# 132.0 RC-650-0.5
# (11, 94)
# 132.0 RC-700-0.5
# (14, 94)
# 132.0 RC-600-0.5
# (13, 94)
# 132.0 RC-650-0.5
# (11, 94)
# 132.0 RC-700-0.5
# (11, 94)
# 132.0 RC-600-1
# (10, 94)
# 132.0 RC-650-1
# (10, 94)
# 132.0 RC-700-1
# (12, 94)
# 132.0 RC-600-1
# (11, 94)
# 132.0 RC-650-1
# (12, 94)
# 132.0 RC-700-1
# (12, 94)
# 132.0 RC-600-1.5
# (9, 94)
# 132.0 RC-650-1.5
# (10, 94)
# 132.0 RC-700-1.5
# (10, 94)
# 132.0 RC-600-1.5
# (13, 94)
# 132.0 RC-650-1.5
# (13, 94)
# 132.0 RC-700-1.5
# (12, 94)
# 133.0 LC-450-1
# (10, 94)
# 133.0 LC-450-2
# (11, 94)
# 133.0 LC-450-3
# (10, 94)
# 133.0 LC-450-1
# (11, 94)
# 133.0 LC-450-2
# (10, 94)
# 133.0 LC-450-3
# (10, 94)
# 133.0 LC-500-1
# (11, 94)
# 133.0 LC-500-2
# (11, 94)
# 133.0 LC-500-3
# (11, 94)
# 133.0 LC-500-1
# (10, 94)
# 133.0 LC-500-2
# (10, 94)
# 133.0 LC-500-3
# (10, 94)
# 133.0 LC-550-1
# (10, 94)
# 133.0 LC-550-2
# (10, 94)
# 133.0 LC-550-3
# (10, 94)
# 133.0 LC-550-1
# (11, 94)
# 133.0 LC-550-2
# (9, 94)
# 133.0 LC-550-3
# (9, 94)
# 134.0 HSM-550-1
# (12, 94)
# 134.0 HSM-600-1
# (12, 94)
# 134.0 HSM-650-1
# (12, 94)
# 134.0 HSM-550-1
# (11, 94)
# 134.0 HSM-600-1
# (12, 94)
# 134.0 HSM-650-1
# (12, 94)
# 134.0 HSM-550-2
# (12, 94)
# 134.0 HSM-600-2
# (12, 94)
# 134.0 HSM-650-2
# (11, 94)
# 134.0 HSM-550-2
# (10, 94)
# 134.0 HSM-600-2
# (11, 94)
# 134.0 HSM-650-2
# (10, 94)
# 134.0 HSM-550-3
# (11, 94)
# 134.0 HSM-600-3
# (11, 94)
# 134.0 HSM-650-3
# (11, 94)
# 134.0 HSM-550-3
# (11, 94)
# 134.0 HSM-600-3
# (10, 94)
# 134.0 HSM-650-3
# (9, 94)
# 135.0 PS-400-2
# (11, 94)
# 135.0 PS-400-3
# (11, 94)
# 135.0 PS-400-4
# (12, 94)
# 135.0 PS-400-2
# (10, 94)
# 135.0 PS-400-3
# (10, 94)
# 135.0 PS-400-4
# (10, 94)
# 135.0 PS-450-2
# (11, 94)
# 135.0 PS-450-3
# (11, 94)
# 135.0 PS-450-4
# (10, 94)
# 135.0 PS-450-2
# (9, 94)
# 135.0 PS-450-3
# (10, 94)
# 135.0 PS-450-3
# (9, 94)
# 135.0 PS-500-2
# (10, 94)
# 135.0 PS-500-3
# (9, 94)
# 135.0 PS-500-4
# (10, 94)
# 135.0 PS-500-2
# (10, 94)
# 135.0 PS-500-3
# (9, 94)
# 135.0 PS-500-4
# (9, 94)
# 136.0 MNPC-750-2
# (9, 94)
# 136.0 MNPC-700-2
# (8, 94)
# 136.0 MNPC-800-2
# (9, 94)
# 136.0 MNPC-800-2
# (8, 94)
# 136.0 MNPC-750-2
# (11, 94)
# 136.0 MNPC-700-2
# (9, 94)
# 136.0 MNPC-750-3
# (8, 94)
# 136.0 MNPC-750-1
# (9, 94)
# 136.0 MNPC-750-3
# (9, 94)
# 136.0 MNPC-750-1
# (10, 94)
# ...
# nan SBL-PNP-1-4-750
# The BET curve for gac: SBL-PNP-1-4-750 from paper nan is not available.
# nan SBL-PNP-0.5-4-750
# The BET curve for gac: SBL-PNP-0.5-4-750 from paper nan is not available.
# nan SBL-PNP-0.25-4-750
# The BET curve for gac: SBL-PNP-0.25-4-750 from paper nan is not available.
# nan Rox 0.8
# The BET curve for gac: Rox 0.8 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CGran
# The BET curve for gac: CGran from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan RX 1.5
# The BET curve for gac: RX 1.5 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC-2
# The BET curve for gac: AC-2 from paper nan is not available.
# nan AC-1
# The BET curve for gac: AC-1 from paper nan is not available.
# nan AC-2
# The BET curve for gac: AC-2 from paper nan is not available.
# nan AC-1
# The BET curve for gac: AC-1 from paper nan is not available.
# nan AC-2
# The BET curve for gac: AC-2 from paper nan is not available.
# nan AC-1
# The BET curve for gac: AC-1 from paper nan is not available.
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan Calgon BPL
# The BET curve for gac: Calgon BPL from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan GF
# The BET curve for gac: GF from paper nan is not available.
# nan ML
# The BET curve for gac: ML from paper nan is not available.
# nan PS
# The BET curve for gac: PS from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan CNS-AC
# The BET curve for gac: CNS-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CPC-550
# The BET curve for gac: CPC-550 from paper nan is not available.
# nan CPC-600
# The BET curve for gac: CPC-600 from paper nan is not available.
# nan CPC-650
# The BET curve for gac: CPC-650 from paper nan is not available.
# nan CPCP-700
# The BET curve for gac: CPCP-700 from paper nan is not available.
# nan CPC-800
# The BET curve for gac: CPC-800 from paper nan is not available.
# nan Pre-AC
# The BET curve for gac: Pre-AC from paper nan is not available.
# nan CMS70060-20
# The BET curve for gac: CMS70060-20 from paper nan is not available.
# nan CMS80020-20
# The BET curve for gac: CMS80020-20 from paper nan is not available.
# nan CMS80040-20
# The BET curve for gac: CMS80040-20 from paper nan is not available.
# nan CMS80050-20
# The BET curve for gac: CMS80050-20 from paper nan is not available.
# nan CMS80060-20
# The BET curve for gac: CMS80060-20 from paper nan is not available.
# nan CMS80070-20
# The BET curve for gac: CMS80070-20 from paper nan is not available.
# nan CMS800120-20
# The BET curve for gac: CMS800120-20 from paper nan is not available.
# nan CMS80070-10
# The BET curve for gac: CMS80070-10 from paper nan is not available.
# nan CMS80070-30
# The BET curve for gac: CMS80070-30 from paper nan is not available.
# nan R-AC
# The BET curve for gac: R-AC from paper nan is not available.
# nan 1H-AC
# The BET curve for gac: 1H-AC from paper nan is not available.
# nan 15H-AC
# The BET curve for gac: 15H-AC from paper nan is not available.
# nan CAC-50
# The BET curve for gac: CAC-50 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan C800
# The BET curve for gac: C800 from paper nan is not available.
# nan C1000
# The BET curve for gac: C1000 from paper nan is not available.
# nan C1200
# The BET curve for gac: C1200 from paper nan is not available.
# nan C1400
# The BET curve for gac: C1400 from paper nan is not available.
# nan C800
# The BET curve for gac: C800 from paper nan is not available.
# nan ACD12-150250
# The BET curve for gac: ACD12-150250 from paper nan is not available.
# nan ACD18-053
# The BET curve for gac: ACD18-053 from paper nan is not available.
# nan ACD18-150250
# The BET curve for gac: ACD18-150250 from paper nan is not available.
# nan ACD18-350550
# The BET curve for gac: ACD18-350550 from paper nan is not available.
# nan ACD24-150250
# The BET curve for gac: ACD24-150250 from paper nan is not available.
# nan ACD18-053
# The BET curve for gac: ACD18-053 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan PHA
# The BET curve for gac: PHA from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan NAHA-1
# The BET curve for gac: NAHA-1 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan NAHA-2
# The BET curve for gac: NAHA-2 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan PHA
# The BET curve for gac: PHA from paper nan is not available.
# nan NAHA-0.5
# The BET curve for gac: NAHA-0.5 from paper nan is not available.
# nan NAHA-1
# The BET curve for gac: NAHA-1 from paper nan is not available.
# nan NAHA-2
# The BET curve for gac: NAHA-2 from paper nan is not available.
# nan NAHA-4
# The BET curve for gac: NAHA-4 from paper nan is not available.
# nan TPC-1
# The BET curve for gac: TPC-1 from paper nan is not available.
# nan Super-AC
# The BET curve for gac: Super-AC from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan OMC
# The BET curve for gac: OMC from paper nan is not available.
# nan Super-AC
# The BET curve for gac: Super-AC from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan OMC
# The BET curve for gac: OMC from paper nan is not available.
# nan Super-AC
# The BET curve for gac: Super-AC from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan AC bead
# The BET curve for gac: AC bead from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan I-AC
# The BET curve for gac: I-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AKFs1
# The BET curve for gac: AKFs1 from paper nan is not available.
# nan AKFs3
# The BET curve for gac: AKFs3 from paper nan is not available.
# nan AKFs5
# The BET curve for gac: AKFs5 from paper nan is not available.
# nan AKFs7
# The BET curve for gac: AKFs7 from paper nan is not available.
# nan AKFs1
# The BET curve for gac: AKFs1 from paper nan is not available.
# nan AKFs3
# The BET curve for gac: AKFs3 from paper nan is not available.
# nan AKFs5
# The BET curve for gac: AKFs5 from paper nan is not available.
# nan AKFs7
# The BET curve for gac: AKFs7 from paper nan is not available.
# nan AKFs1
# The BET curve for gac: AKFs1 from paper nan is not available.
# nan AKFs3
# The BET curve for gac: AKFs3 from paper nan is not available.
# nan AKFs7
# The BET curve for gac: AKFs7 from paper nan is not available.
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan PN1801
# The BET curve for gac: PN1801 from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan IN18001
# The BET curve for gac: IN18001 from paper nan is not available.
# nan CN18001
# The BET curve for gac: CN18001 from paper nan is not available.
# nan AC-1
# The BET curve for gac: AC-1 from paper nan is not available.
# nan AC-2
# The BET curve for gac: AC-2 from paper nan is not available.
# nan AC-4
# The BET curve for gac: AC-4 from paper nan is not available.
# nan NAC-1
# The BET curve for gac: NAC-1 from paper nan is not available.
# nan NAC-2
# The BET curve for gac: NAC-2 from paper nan is not available.
# nan NAC-4
# The BET curve for gac: NAC-4 from paper nan is not available.
# nan AC-H3PO4
# The BET curve for gac: AC-H3PO4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC-H2O
# The BET curve for gac: AC-H2O from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC-CO2
# The BET curve for gac: AC-CO2 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CMS
# The BET curve for gac: CMS from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC800
# The BET curve for gac: AC800 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan C60-CC-PNP
# The BET curve for gac: C60-CC-PNP from paper nan is not available.
# nan C30-CC-PNP
# The BET curve for gac: C30-CC-PNP from paper nan is not available.
# nan C85-CC-PNP
# The BET curve for gac: C85-CC-PNP from paper nan is not available.
# nan P-CC-PNP
# The BET curve for gac: P-CC-PNP from paper nan is not available.
# nan babassu-AC
# The BET curve for gac: babassu-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan KOH0.5TP50
# The BET curve for gac: KOH0.5TP50 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MICRO-GAC
# The BET curve for gac: MICRO-GAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CMS-3
# The BET curve for gac: CMS-3 from paper nan is not available.
# nan CMS-2
# The BET curve for gac: CMS-2 from paper nan is not available.
# nan CMS-1
# The BET curve for gac: CMS-1 from paper nan is not available.
# nan CMS-3
# The BET curve for gac: CMS-3 from paper nan is not available.
# nan CMS-2
# The BET curve for gac: CMS-2 from paper nan is not available.
# nan CMS-1
# The BET curve for gac: CMS-1 from paper nan is not available.
# nan CMS-3
# The BET curve for gac: CMS-3 from paper nan is not available.
# nan CMS-2
# The BET curve for gac: CMS-2 from paper nan is not available.
# nan CMS-1
# The BET curve for gac: CMS-1 from paper nan is not available.
# nan sOMC
# The BET curve for gac: sOMC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Glc-C-4
# The BET curve for gac: Glc-C-4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Glc-C-2
# The BET curve for gac: Glc-C-2 from paper nan is not available.
# nan Glc-C-3
# The BET curve for gac: Glc-C-3 from paper nan is not available.
# nan Glc-C-4
# The BET curve for gac: Glc-C-4 from paper nan is not available.
# nan Glc-C-5
# The BET curve for gac: Glc-C-5 from paper nan is not available.
# nan K2CO3/MAC
# The BET curve for gac: K2CO3/MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MAC
# The BET curve for gac: MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan NAC
# The BET curve for gac: NAC from paper nan is not available.
# nan HAC
# The BET curve for gac: HAC from paper nan is not available.
# nan AAC
# The BET curve for gac: AAC from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan NAC
# The BET curve for gac: NAC from paper nan is not available.
# nan HAC
# The BET curve for gac: HAC from paper nan is not available.
# nan AAC
# The BET curve for gac: AAC from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan ACB-2
# The BET curve for gac: ACB-2 from paper nan is not available.
# nan ACB-2
# The BET curve for gac: ACB-2 from paper nan is not available.
# nan ACB-5
# The BET curve for gac: ACB-5 from paper nan is not available.
# nan ACB-5
# The BET curve for gac: ACB-5 from paper nan is not available.
# nan Carbon A
# The BET curve for gac: Carbon A from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MaxSorb
# The BET curve for gac: MaxSorb from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan A10
# The BET curve for gac: A10 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Norit R1 Extra
# The BET curve for gac: Norit R1 Extra from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan BPL
# The BET curve for gac: BPL from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Palm-AC
# The BET curve for gac: Palm-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Norit-AC
# The BET curve for gac: Norit-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MMN
# The BET curve for gac: MMN from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Co-NDPC-500
# The BET curve for gac: Co-NDPC-500 from paper nan is not available.
# nan Co-NDPC-600
# The BET curve for gac: Co-NDPC-600 from paper nan is not available.
# nan Co-NDPC-700
# The BET curve for gac: Co-NDPC-700 from paper nan is not available.
# nan Co-NDPC-800
# The BET curve for gac: Co-NDPC-800 from paper nan is not available.
# nan Co-NDPC-900
# The BET curve for gac: Co-NDPC-900 from paper nan is not available.
# nan Co-NDPC-500
# The BET curve for gac: Co-NDPC-500 from paper nan is not available.
# nan Co-NDPC-600
# The BET curve for gac: Co-NDPC-600 from paper nan is not available.
# nan Co-NDPC-700
# The BET curve for gac: Co-NDPC-700 from paper nan is not available.
# nan Co-NDPC-800
# The BET curve for gac: Co-NDPC-800 from paper nan is not available.
# nan Co-NDPC-900
# The BET curve for gac: Co-NDPC-900 from paper nan is not available.
# nan R-AC
# The BET curve for gac: R-AC from paper nan is not available.
# nan 1H-AC
# The BET curve for gac: 1H-AC from paper nan is not available.
# nan 5H-AC
# The BET curve for gac: 5H-AC from paper nan is not available.
# nan 15H-AC
# The BET curve for gac: 15H-AC from paper nan is not available.

# %%
BET_df.to_csv('./Adding_bet_50.csv')

# %%
BET_df = pd.read_csv("Adding_bet_80.csv")
BET_df.dropna(axis=0,how="any",subset = ["BET","Vt","Vmic","BET_79"],inplace=True)
#BET_df.dropna(axis=0,how="any",subset = ["BET_34"],inplace=True)

# %%
BET_df.columns
# Out:
# Index(['Unnamed: 0', 'BET_0', 'BET_1', 'BET_2', 'BET_3', 'BET_4', 'BET_5',
#        'BET_6', 'BET_7', 'BET_8', 'BET_9', 'BET_10', 'BET_11', 'BET_12',
#        'BET_13', 'BET_14', 'BET_15', 'BET_16', 'BET_17', 'BET_18', 'BET_19',
#        'BET_20', 'BET_21', 'BET_22', 'BET_23', 'BET_24', 'BET_25', 'BET_26',
#        'BET_27', 'BET_28', 'BET_29', 'BET_30', 'BET_31', 'BET_32', 'BET_33',
#        'BET_34', 'BET_35', 'BET_36', 'BET_37', 'BET_38', 'BET_39', 'BET_40',
#        'BET_41', 'BET_42', 'BET_43', 'BET_44', 'BET_45', 'BET_46', 'BET_47',
#        'BET_48', 'BET_49', 'BET_50', 'BET_51', 'BET_52', 'BET_53', 'BET_54',
#        'BET_55', 'BET_56', 'BET_57', 'BET_58', 'BET_59', 'BET_60', 'BET_61',
#        'BET_62', 'BET_63', 'BET_64', 'BET_65', 'BET_66', 'BET_67', 'BET_68',
#        'BET_69', 'BET_70', 'BET_71', 'BET_72', 'BET_73', 'BET_74', 'BET_75',
#        'BET_76', 'BET_77', 'BET_78', 'BET_79', 'E', 'S', 'A', 'B', 'V', 'BET',
#        'Vt', 'Vmic', 'Vmeso', 'Temp(K)', 'Pressure', 'Adsorp(mmol/g)', 'Index',
#        'Label'],
#       dtype='object')

# %%
# data splitting
#from random import shuffle
from sklearn.model_selection import train_test_split
from numpy import random
def group_split(BET_df:pd.DataFrame,random_state = 42):
    indexs = list(set(BET_df["Index"].values.tolist()))
    #shuffle(indexs)
    _,test_index = train_test_split(indexs,test_size= 0.2,random_state =random_state)

    #test_index = random.choice(indexs,len(indexs)//5,replace=False).tolist()
    train_df = BET_df[~BET_df["Index"].isin(test_index)]
    test_df = BET_df[BET_df["Index"].isin(test_index)]
    return train_df,test_df

# %%
BET_df = BET_df[BET_df.notna()]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
  
n_estimators = [50,100,120,150,180,200,300]

# define different models#,
models = [
    #('SVR',SVR(max_iter=100000)),
    #('DT',DecisionTreeRegressor(random_state=42)),\
    # ('ADBR',AdaBoostRegressor(random_state=42)), 
    #("GBR",GradientBoostingRegressor(random_state=42)),\
    #('BG',BaggingRegressor(random_state=42,n_jobs=-1)),
    #('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
    #('RF',RandomForestRegressor(n_jobs=-1,random_state=42)),
    ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
    #('MLPR',MLPRegressor(random_state=42))
    #('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators = 200, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1)),\
    #('BGETR',BaggingRegressor(ExtraTreesRegressor(n_estimators = 180,random_state=42,n_jobs=6),random_state=42,n_jobs=-1))
    ]

# set search parameters grid for different models
para_grids = { 
    'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
    'DT':{'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2],'loss':['linear','square','exponential']},\
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'BG':{'n_estimators':[10,50,100]},\
    'ETR':{'n_estimators':n_estimators},\
    'RF':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,50,],'learning_rate': [0.05,0.1,0.5,1],'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,30,50]},\
    'BGETR':{'n_estimators':[10]},\
    'MLPR':{'hidden_layer_sizes':[(4,100),(5,100),(6,100)],
            "activation":["logistic","relu"],\
            "solver":['sgd', 'adam']}
    }

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,groups,model,para_grid):

    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(model,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []
    for gas in gas_list:
        if gas =='total':
            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index'].values
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])
                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))    
        else:
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
                print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))     
    return result_total

# %%
import os
conditions = ['S','V','Temp(K)','Pressure']
base_feature = ["BET_"+str(i) for i in range(80)]+conditions
feature_list = [base_feature,base_feature+["BET"],base_feature+['Vt'],base_feature+["BET",'Vt'],\
    base_feature+["BET","Vt","Vmic","Vmeso"],["BET","Vt"]+conditions,["BET","Vt","Vmic","Vmeso"]+conditions]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] #['BET_Curve','BET_Plus_Vt',"Vmic_Vmeso"]
gas_list = ['CO2']#,'CFCs','Methane','E&E'

for i in range(50):
    train_df,test_df = group_split(BET_df,random_state=i)
    for j in range(len(feature_list)):
    
        results = model_comparison(models,para_grids, feature_list[j],gas_list)
        files_name = '80_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./8_using_BET_curve',files_name)) 
    print("The finish of {} th trial".format(i))
# Out:
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9503381893859753, Test_error 0.7064639785333745
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9568528997052239, Test_error 0.6408836616853693
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9497992970316266, Test_error 0.7043464106841902
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9553254803768602, Test_error 0.6622526560471209
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9567200231383386, Test_error 0.6420687468104153
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9352763639631402, Test_error 0.9463311741639848
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9529812225397234, Test_error 0.6773791720286184
# The finish of 0 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.93643083597247, Test_error 0.8259071691149471
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9420367426812619, Test_error 0.7187436211655086
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9415267613476883, Test_error 0.7114700119039478
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.937202368378246, Test_error 0.7466798852368166
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9527325406937244, Test_error 0.5841467915625922
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9338446473187529, Test_error 0.8447695390804831
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9496699859327409, Test_error 0.653470174230053
# The finish of 1 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.905679165549954, Test_error 0.7503458790518456
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9638089694886657, Test_error 0.31062069783909063
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9139578293762111, Test_error 0.681252049348073
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.963192736612844, Test_error 0.32104378451186494
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.96378610208032, Test_error 0.3092720109056821
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9469414121829715, Test_error 0.46058617712468086
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.954217990858404, Test_error 0.3899841444235004
# The finish of 2 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9332943824456734, Test_error 0.8917028216185791
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9444372995834678, Test_error 0.7487971190593566
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9407206845705182, Test_error 0.7820704310860961
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9452836685864341, Test_error 0.7361480784691555
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9483535445725677, Test_error 0.7010280228816418
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9342344023803528, Test_error 0.9571359330695378
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.949975389134455, Test_error 0.6919618683152754
# The finish of 3 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9472263456815436, Test_error 0.6948345196094201
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9560434487766452, Test_error 0.5979519306846168
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9477343301831251, Test_error 0.6894215663323886
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9585619086230762, Test_error 0.5690372477118304
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9611200742487213, Test_error 0.5402261356748344
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9571180908089034, Test_error 0.6156444017356995
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9594558267159052, Test_error 0.5659649574974048
# The finish of 4 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9351540771091277, Test_error 0.710286013292137
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9557379104653461, Test_error 0.4677584040985954
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9482928844551988, Test_error 0.5571730247795871
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9550055705743637, Test_error 0.48339450260132194
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9587001851914292, Test_error 0.44024074340876523
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9370836825570144, Test_error 0.6954616978087254
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9553634690592834, Test_error 0.4965107849954335
# The finish of 5 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9211749519227508, Test_error 0.9983261096162706
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9677843443667989, Test_error 0.4302652634996994
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9356995513523583, Test_error 0.8144480397484104
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9664374276644121, Test_error 0.44581565958149805
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9688477917443117, Test_error 0.41937874494614374
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.958726750708626, Test_error 0.5648040778704596
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9622675240295594, Test_error 0.501660054262956
# The finish of 6 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9526893204493059, Test_error 0.600187675918211
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9595163622173589, Test_error 0.5276449422595384
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9581638498053828, Test_error 0.5288118760020135
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9609399403760626, Test_error 0.5107770854702766
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9630754675481992, Test_error 0.4881690196167085
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9530671092710084, Test_error 0.6525803797066714
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9600346110662725, Test_error 0.5330820556886213
# The finish of 7 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9334622664587826, Test_error 0.599965491958571
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9584329117590865, Test_error 0.385198975741618
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9335466661354364, Test_error 0.6096150781009834
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9588445861218735, Test_error 0.3840756949896017
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.95775177835441, Test_error 0.3950705277891488
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9228969862384164, Test_error 0.681416316878778
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9440878879879018, Test_error 0.5213831172693254
# The finish of 8 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9493364242648821, Test_error 0.6688100482574182
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9648734515513486, Test_error 0.42953950228714766
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9530071047623672, Test_error 0.61572066103534
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9671567150785408, Test_error 0.4096490143330957
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9657538075210542, Test_error 0.4159826463372045
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9475080494448906, Test_error 0.6439456508839404
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9475900442291301, Test_error 0.6373527212803191
# The finish of 9 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9520707767111217, Test_error 0.5100838107182842
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9640159214599306, Test_error 0.39788448318283615
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9539120496758193, Test_error 0.5055957070654018
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9625927325046599, Test_error 0.42149894856296183
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9631714924030561, Test_error 0.4108623264050856
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9402966715617546, Test_error 0.6399280449905331
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9545029287745347, Test_error 0.4918397274836246
# The finish of 10 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9614009023477733, Test_error 0.40254565927962754
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9693006677047075, Test_error 0.3194410665989112
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9591475418962896, Test_error 0.4249308269324987
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9694890201513877, Test_error 0.3224066894471656
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9702225555740234, Test_error 0.3137855473769951
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9546761597304286, Test_error 0.47993632396863695
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.960165221662079, Test_error 0.4236355411276246
# The finish of 11 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9550783787400017, Test_error 0.5809474867718576
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9572205255976587, Test_error 0.5567831809061169
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9515569908511352, Test_error 0.6336167229671043
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9554541402042434, Test_error 0.5783813355090489
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9548160913477188, Test_error 0.5765020094842089
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9467318467283354, Test_error 0.691660304889022
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.946441885539507, Test_error 0.6672797438839427
# The finish of 12 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9455747714259883, Test_error 0.5929397363667042
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9569261894029822, Test_error 0.4815378730361818
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.944047991696764, Test_error 0.6200012024567166
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9574619734035797, Test_error 0.47332454434393095
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9559671640341482, Test_error 0.4817659517779376
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9342424454244345, Test_error 0.7476856296659502
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9451967374107161, Test_error 0.6069603123857626
# The finish of 13 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9473969385080427, Test_error 0.58190224370573
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9667775031028043, Test_error 0.3356629215740737
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9511739963580049, Test_error 0.5488983805324503
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9655835956980819, Test_error 0.34965659400819427
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.969475575839988, Test_error 0.30785495209684755
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.955419190379674, Test_error 0.4673653371100273
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9619601782075753, Test_error 0.3895372318693227
# The finish of 14 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9023371336560246, Test_error 0.9489416050512562
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9518884121885477, Test_error 0.4748108460633134
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9110003693568504, Test_error 0.8703959601411704
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9551391642110856, Test_error 0.4448177056783936
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9560080538606218, Test_error 0.43797604419137937
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9391694257625322, Test_error 0.616350793313704
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.937847282102001, Test_error 0.6215752777615051
# The finish of 15 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9350483234116148, Test_error 0.7018153899097945
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9656804849432047, Test_error 0.36588119793195995
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9402639639229476, Test_error 0.6527709589826792
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9637613359547785, Test_error 0.3844779904796003
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9642603181461047, Test_error 0.3767456711209793
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9549151569869364, Test_error 0.48256595740006253
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.95509602210128, Test_error 0.47326749048505257
# The finish of 16 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9322194353276635, Test_error 0.8037148493013889
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.946935430140192, Test_error 0.6341311224898772
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9335799722259879, Test_error 0.8058128358822304
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9441078600979681, Test_error 0.6808898583334494
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9504507189045174, Test_error 0.5865706782012897
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9439113306937225, Test_error 0.678921748356974
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9457489273209907, Test_error 0.6488802262669711
# The finish of 17 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9611622446339263, Test_error 0.5702978439089385
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9678955272084311, Test_error 0.484870883237621
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9660805452116531, Test_error 0.49845007845142864
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9664032778858507, Test_error 0.5040183734233274
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9684981905881317, Test_error 0.46991303956221137
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9483901965736548, Test_error 0.7608845209643813
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9572421598232111, Test_error 0.6559194530281024
# The finish of 18 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.8814120204119542, Test_error 1.3573399806772029
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9450102704373556, Test_error 0.6838047525254012
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.8956060059535069, Test_error 1.1861742616199842
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9466225050002869, Test_error 0.6630813104339046
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9544032417626253, Test_error 0.5816281665155857
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.94327822334542, Test_error 0.7303980629611676
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9562021434881663, Test_error 0.5888225432451798
# The finish of 19 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9582055743403277, Test_error 0.4960518428336696
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9676137558970143, Test_error 0.39595653063002334
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9549953113276082, Test_error 0.5420793685956613
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9654090944311128, Test_error 0.41944222394919817
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9674460768921451, Test_error 0.39110778425064224
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9515824460850182, Test_error 0.573869746539164
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9578996676857182, Test_error 0.48331128871094403
# The finish of 20 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9567950972056714, Test_error 0.44595015568169855
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9601671943225263, Test_error 0.3973323044911049
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.957878935691752, Test_error 0.41735221605029493
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9558968790994711, Test_error 0.4403236369015372
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9611946595750721, Test_error 0.39500406540919786
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9435182257153528, Test_error 0.584309617260233
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9555792845985538, Test_error 0.4658455718128536
# The finish of 21 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9466883019378969, Test_error 0.5474560700513175
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9608140363709724, Test_error 0.45362518192258794
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9526986480308801, Test_error 0.4997071022743839
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.963576103951061, Test_error 0.41624309345931926
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9631779580309299, Test_error 0.42222960926491243
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9534918627931773, Test_error 0.4932722866250002
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9588256425537759, Test_error 0.44594295253493804
# The finish of 22 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9568339935616069, Test_error 0.4950831501828953
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9589010511388901, Test_error 0.48578276512723656
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9462862980912216, Test_error 0.6200433597282282
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9580892019943921, Test_error 0.4957972886114294
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9569958614130859, Test_error 0.5031675524020941
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9397696369336384, Test_error 0.7227709487066243
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9448705462674186, Test_error 0.630110794090776
# The finish of 23 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9242502154327318, Test_error 0.8507980132601514
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9564397700914055, Test_error 0.5173567420492089
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9380367533569921, Test_error 0.7116558844662214
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9573998510089019, Test_error 0.5090145162842143
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9627259519172151, Test_error 0.4568591393325575
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9415613265990878, Test_error 0.6915628784474099
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9495469160938349, Test_error 0.6372186505425143
# The finish of 24 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9030158508393997, Test_error 0.9777860399869792
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.950806155131052, Test_error 0.5173063239440847
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9065381718327657, Test_error 0.9329513491010216
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9518286744638412, Test_error 0.5076257541928885
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9589273740897044, Test_error 0.44155375936581426
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9418539819809626, Test_error 0.6590820574466736
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9467417203191313, Test_error 0.6060779548847343
# The finish of 25 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9016790052480353, Test_error 0.9382124692197978
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9493643231797092, Test_error 0.5544722587983226
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9110441595732925, Test_error 0.8599657558842779
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.949319182942463, Test_error 0.5516678518234458
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9534292720261861, Test_error 0.5187231448739951
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9402770919494691, Test_error 0.6446370818275631
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9442722826035628, Test_error 0.6238843407485386
# The finish of 26 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9408332724467016, Test_error 0.6131128909863782
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9624312326796048, Test_error 0.39981279743433035
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9451761215007253, Test_error 0.5946356528513167
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9618769197574452, Test_error 0.40612237326402817
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9672428451797015, Test_error 0.3520044762960462
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9321423958026415, Test_error 0.6848917596113491
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9529663268570346, Test_error 0.5336890114260654
# The finish of 27 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9616671843255383, Test_error 0.5053822005203147
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9671042731124586, Test_error 0.4415260859206648
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9703905984433611, Test_error 0.3859198799655248
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9704193119852835, Test_error 0.40023949290747435
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9706000287254997, Test_error 0.3918610559565406
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9646287617719808, Test_error 0.48629479138763926
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.963816301251823, Test_error 0.5063689058315585
# The finish of 28 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9465507099469761, Test_error 0.6012728417846946
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9615322770831252, Test_error 0.4339053649519255
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9432453057288129, Test_error 0.6319607690337662
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9571925386751385, Test_error 0.48733356935032546
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9579060339222222, Test_error 0.4716856775653716
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9546619715102385, Test_error 0.5175491514359849
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9596669147353886, Test_error 0.44791285925717916
# The finish of 29 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9534853418148714, Test_error 0.4393618265288269
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9553193511375705, Test_error 0.430338328219315
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9524921148677705, Test_error 0.4530900430588118
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9560783714518405, Test_error 0.42458253521277906
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9571169935804756, Test_error 0.422789368016629
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9366509501976713, Test_error 0.641716734586936
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9429174852155312, Test_error 0.5617666478884855
# The finish of 30 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9444801654054601, Test_error 0.7610927933439234
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.962208534046911, Test_error 0.45252230799731524
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9583795781660338, Test_error 0.521179363014924
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9616789259074381, Test_error 0.487513814294914
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9686278157214039, Test_error 0.38680816408455004
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9491909500179813, Test_error 0.6370712016529326
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9533475526250692, Test_error 0.5749645401566303
# The finish of 31 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9433424002935926, Test_error 0.7392618578292192
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9551937888658563, Test_error 0.603977660350777
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9474016689051891, Test_error 0.722154292466195
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9533476828039047, Test_error 0.6224748995492377
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9548366816366787, Test_error 0.6071171796271313
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9545200300889328, Test_error 0.6285663529009482
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9522114187258702, Test_error 0.6445104027391644
# The finish of 32 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9564793663327538, Test_error 0.5175142567097443
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9665444345170043, Test_error 0.3780166731976482
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9520838811286659, Test_error 0.5496947778967483
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9642175510562775, Test_error 0.4064742633690142
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.965196031244836, Test_error 0.3906777597060796
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9553507710471588, Test_error 0.49466326378642217
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9348401132941008, Test_error 0.6934660643428423
# The finish of 33 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.893572895584072, Test_error 0.8808015641011736
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.95453685222589, Test_error 0.4220949249109645
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.8997662112313932, Test_error 0.8420338917057513
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9564896198951002, Test_error 0.3974850748306294
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9531473913524462, Test_error 0.42469934239637325
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9350290388346488, Test_error 0.6298488862795963
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9419134171306415, Test_error 0.5515764795437917
# The finish of 34 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9600241122155028, Test_error 0.43410270556179426
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9610852023116297, Test_error 0.4142403725099605
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9641989319262575, Test_error 0.38577012235897346
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9626859772880351, Test_error 0.404670010805374
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9697908955173495, Test_error 0.3259222832763591
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9541861599095007, Test_error 0.48933600846965386
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9529215176443653, Test_error 0.4801313794737258
# The finish of 35 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.8293588355958631, Test_error 1.2794422497805922
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.935045808802398, Test_error 0.4781494386290677
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.867071615975779, Test_error 0.990491618324736
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9279478765646827, Test_error 0.5261953735516622
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9399218954907685, Test_error 0.4473996048110325
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9333675699701973, Test_error 0.5363565283075439
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.940698411952923, Test_error 0.5008959500175655
# The finish of 36 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9617919935834843, Test_error 0.3703710196486551
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9627754091284776, Test_error 0.35497778363487564
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9658917720368407, Test_error 0.3260009805314592
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9603718217088711, Test_error 0.3730759220094766
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9600424356882806, Test_error 0.3768432326598797
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9405035786737148, Test_error 0.573517687842449
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9481975996571732, Test_error 0.5183714759084299
# The finish of 37 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9305177864888522, Test_error 0.9621154454809957
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9534701276519608, Test_error 0.6105721831013368
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9358112595874845, Test_error 0.8787290810637115
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9549373872478671, Test_error 0.5932104376874251
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.956859590063425, Test_error 0.5741736266146359
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9387157485801658, Test_error 0.8066822260366864
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9462574052705779, Test_error 0.7142075242590127
# The finish of 38 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9429209908105747, Test_error 0.5390698625463906
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9576470002619689, Test_error 0.41204903378912194
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9486390034491161, Test_error 0.4965130751349339
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9552351604605267, Test_error 0.43518031145040903
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9554327760103306, Test_error 0.4349029584974463
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9328798800051921, Test_error 0.6449833541245006
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9391322137838545, Test_error 0.5965347498115482
# The finish of 39 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9486940437159865, Test_error 0.5992968541993022
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9642925027200979, Test_error 0.42286758275943603
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.951215381265129, Test_error 0.5673137853383008
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.963736475963128, Test_error 0.43176405886206703
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9654732425341015, Test_error 0.4114450102184786
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9447167733447664, Test_error 0.6395436253894465
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9574359010895007, Test_error 0.5044658903908864
# The finish of 40 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9524098712951596, Test_error 0.41846575876924796
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9634870339306815, Test_error 0.3331950698072313
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9603226557501574, Test_error 0.3536814113269769
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9658089831570493, Test_error 0.31032070703292713
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9680711641919769, Test_error 0.2841868829531253
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.943365078314375, Test_error 0.4821748258934989
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9508980477275899, Test_error 0.42768044674349726
# The finish of 41 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9520897433655788, Test_error 0.4201382047276174
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.959064137940379, Test_error 0.3793930113241118
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9548769269278041, Test_error 0.40601061963939133
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9616367169689727, Test_error 0.3590429227398126
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9619591191116519, Test_error 0.3558946739757814
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9304183863152408, Test_error 0.6280449579226173
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9548611998149552, Test_error 0.4214590119141557
# The finish of 42 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9307672075091045, Test_error 0.7687109219188804
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.957351042894528, Test_error 0.47864213576975
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9268146206747105, Test_error 0.8123214561228035
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9583834156139563, Test_error 0.47425442377882715
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9573657672530851, Test_error 0.4677145917129742
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9544698049939385, Test_error 0.5167186659810001
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9588792578132911, Test_error 0.4640764074325399
# The finish of 43 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9260733037433313, Test_error 0.6366149623256635
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9502564561854839, Test_error 0.4128339636759349
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9312322448889592, Test_error 0.5818905522238762
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9502742070806904, Test_error 0.4144243821826538
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9507303240606901, Test_error 0.4083887598060908
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9177722024576227, Test_error 0.6941531139021259
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9360087337995485, Test_error 0.535683577709949
# The finish of 44 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9560639318289665, Test_error 0.5910227564183509
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9595417155212189, Test_error 0.5515438790441181
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.958020114305505, Test_error 0.5587852289534792
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9622321254026414, Test_error 0.5272863327855254
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9643941803944217, Test_error 0.4954834448529114
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9557829627327377, Test_error 0.6151323697559624
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9621280979598082, Test_error 0.5318037626129635
# The finish of 45 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9348821585976642, Test_error 0.7953655125636143
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9550370438306064, Test_error 0.6061587002179699
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9455227334143196, Test_error 0.7059077635082986
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9556109994570339, Test_error 0.6014992263022514
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9569382833404181, Test_error 0.5745688564006294
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9414437276385116, Test_error 0.8299846020799118
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.946803508487224, Test_error 0.728456076151848
# The finish of 46 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9525603246647354, Test_error 0.47562929971855356
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9573183332591889, Test_error 0.4192798552253344
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9571905699088138, Test_error 0.41912828938920776
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.957395514597499, Test_error 0.4148750255728652
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9567652851305861, Test_error 0.4250996488677033
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9386356932498826, Test_error 0.592959515555645
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9490497180046942, Test_error 0.46951569752695627
# The finish of 47 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9335488439077673, Test_error 0.6521680434015047
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9395404429154762, Test_error 0.5862748766715964
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.936393842370776, Test_error 0.6185568164741259
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9485415575906174, Test_error 0.5103822183761072
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9510441580158944, Test_error 0.4862614212492345
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9351746845649058, Test_error 0.6514187653665328
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9421007593209297, Test_error 0.6039438323056018
# The finish of 48 th trial
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9205064340075043, Test_error 1.0704904512637587
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9525958615818715, Test_error 0.6204159955116191
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9431938883134376, Test_error 0.7418617707590294
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9552360843065377, Test_error 0.587429727346646
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9543856948950278, Test_error 0.6147842827869434
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9503895227319944, Test_error 0.677215831409197
# Dataset CO2, Algorithm LGBM_total, Test_r2 0.9519663051119169, Test_error 0.6859064231318435
# The finish of 49 th trial

# %% [markdown]
# # Post result treatments

# %%
import pandas as pd
file_name = ['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] 

cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model"]
for j in range(len(file_name)):
    df_list = []
    for i in range(50):
        files_name = '80_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'
        df_list.append(pd.read_csv(os.path.join('./8_using_BET_curve',files_name))[cal_columns] )
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_mean.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_std.csv'))

# %% [markdown]
# # 2_Predicting adsorption for each data point using the combination Vt, BET, Vmeso, and Vmic
# the dataset for each separate gas will be smaller than previous one.

# %%
import os
base_feature = ['V','S','L','BET',]
condition_feature = ['Temp(K)','Pressure']
combin_1 = ['Vt']
combin_2 = ["Vmeso"]
combin_3 = ['Vmic']
combin_4 = ['Vt',"Vmeso",]
combin_5 = ['Vt',"Vmic",]
combin_6 = ['Vt',"Vmic",'Vmeso',]
combin_7 = ["Vmic",'Vmeso',]

feature_list = [base_feature+condition_feature,base_feature+combin_1+condition_feature, \
    base_feature+combin_3+condition_feature, base_feature+combin_2+condition_feature,\
    base_feature+combin_4+condition_feature, base_feature+combin_5+condition_feature,\
    base_feature+combin_6+condition_feature, base_feature+combin_7+condition_feature, ]

columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']


feature_set = ["BET","Vt","Vmeso","Vmic"]
gas_list = ['CO2','CFCs','Methane','E&E']
file_name = ['BET_only','BET_plut_Vt',"BET_Vmic","BET_Vmeso",'BET_Vt_Vmeso','BET_Vt_Vmic',"BET_Vt_Vmic_meso","BET_Vmic_meso"]


for i in range(10,15):
    train_df,test_df = pred_dataset(['CO2','Methane','Ethane&Ethylene','CFCs'],feature_set= feature_set)
    for j in range(len(feature_list)):
        results = model_comparison(models,para_grids, feature_list[j],gas_list)
        files_name = 'Four_gases_with_Vmic_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns).to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',files_name))  
        #pd.DataFrame(results,columns = ['Gas','Algo','Train_erro','Test_error']).to_csv(os.path.join('./',files_name))

# %% [markdown]
# # Post result treatment

# %%
import pandas as pd
file_name = ['BET_only','BET_plut_Vt',"BET_Vmic","BET_Vmeso",'BET_Vt_Vmeso','BET_Vt_Vmic',"BET_Vt_Vmic_meso","BET_Vmic_meso"]

cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model"]
for j in range(len(file_name)):
    df_list = []
    for i in range(11):
    
        files_name = 'Four_gases_with_Vmic_'+file_name[j]+'_result_'+str(i)+'.csv'
        df_list.append(pd.read_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',files_name))[cal_columns] )
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',file_name[j]+'_mean_new.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./2_Predicting_separate_gas_BET_Vt_Vmeso_Vmic',file_name[j]+'_std_new.csv'))

# %% [markdown]
# # Predicting the fitted parameters of adsorption isotherms

# %% [markdown]
# # Using only BET and Vt

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

def pred_dataset(file_names, feature_set = feature_set):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-fitting-02-02-2022.xlsx'),skiprows= 1 )
        temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        train_x,test_x = train_test_split(temp_data,test_size = 0.2)
        train_df = pd.concat([train_df,train_x],axis=0)
        test_df = pd.concat([test_df,test_x],axis =0)
    return train_df,test_df

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,model,para_grid):

    
    result = GridSearchCV(model,para_grid,cv= 5,
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,cv =5,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []

    for gas in gas_list:
        
        if gas =='total':

            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            
            train_x, train_y = shuffle(train_x, train_y,random_state=42)
            
            for model_name, model in model_list:

                
                result, best_param = model_CV(train_x,train_y.squeeze(),model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])

                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))

            
        else:
            
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            
            train_x, train_y = shuffle(train_x, train_y, random_state=42)
           
            for model_name, model in model_list:

                result, best_param = model_CV(train_x,train_y.squeeze(),model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
                print(print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))
)
                
    return result_total
