# %% [markdown]
# # 1. predicting adsorption for each adsorption data point using Vt&BET only

# %%
import pandas as pd
import numpy as np
import os 
BET_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/Treated/Methane'

def pred_dataset(file_names):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-02-02-2022.xlsx'),skiprows= 1 )
        #temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        train_df = pd.concat([train_df,temp_data],axis=0)
       
    return train_df

# %%
from scipy import interpolate
import numpy as np
import pandas as pd

def inter_data(x_old,y_old):
    
    f = interpolate.interp1d(x_old, y_old,'slinear') 

    """ seg1 = np.linspace(min(x_old),min(x_old)+0.2,num=20)
    seg2 = np.linspace(min(x_old)+0.2,max(x_old)-0.2,num=12)
    seg3 = np.linspace(max(x_old)-0.2, max(x_old),num=20)
    x_new = np.append(seg1,seg2[1:-1])
    x_new = np.append(x_new,seg3)   """
    x_new = np.linspace(0.05,0.95,num=35)
       
    """
        for ele in x_old:
            t = bi_find(x_new,ele)

            x_new[t] = ele
        
        if (len(x_new)>150):
            x_new = x_new[len(x_new)-150:]
         = np.arange(min(x_old), max(x_old), (max(x_old)-min(x_old))/150)
    """
    y_new = f(x_new)
    #X_feature = np.append(x_new.reshape(-1,1),y_new.reshape(-1,1),axis=1).reshape(2,35).tolist()
    #x_mat = np.append(x_mat,X_feature,axis=1)
       
    return x_new, y_new

# %%
data = pred_dataset(["Methane"])
data
# Out:
#       Unnamed: 0 Literature Literature_full  Unnamed: 1       GAC      GAS  E  \
# 0              0          1               1          26  Graphene  Methane  0
# 1              1          1               1          27  Graphene  Methane  0
# 2              2          1               1          28  Graphene  Methane  0
# 3              3          1               1          29  Graphene  Methane  0
# 4              4          1               1          30  Graphene  Methane  0
# ...          ...        ...             ...         ...       ...      ... ..
# 8359        8473        NaN             NaN         102       NaN  Methane  0
# 8360        8474        NaN             NaN         103       NaN  Methane  0
# 8361        8475        NaN             NaN         104       NaN  Methane  0
# 8362        8476        NaN             NaN         105       NaN  Methane  0
# 8363        8477        NaN             NaN         106       NaN  Methane  0
#
#       S  A  B  ...  %N  Temp(K)   Pressure  Adsorp(mmol/g)  Index      logP  \
# 0     0  0  0  ... NaN    278.0   0.053415        0.018737   2751 -2.929665
# 1     0  0  0  ... NaN    278.0   0.170583        0.061587   2751 -1.768532
# 2     0  0  0  ... NaN    278.0   0.301536        0.104402   2751 -1.198866
# 3     0  0  0  ... NaN    278.0   0.404920        0.136500   2751 -0.904066
# 4     0  0  0  ... NaN    278.0   0.534150        0.171229   2751 -0.627079
# ...  .. .. ..  ...  ..      ...        ...             ...    ...       ...
# 8359  0  0  0  ... NaN    313.0   7.845800        2.712000   3602  2.059978
# 8360  0  0  0  ... NaN    313.0   9.718930        2.996000   3602  2.274076
# 8361  0  0  0  ... NaN    313.0  11.716050        3.253000   3602  2.460960
# 8362  0  0  0  ... NaN    313.0  13.799350        3.464000   3602  2.624621
# 8363  0  0  0  ... NaN    313.0  15.603030        3.611000   3602  2.747465
#
#           logQ      logD    Label  Vmic_index
# 0    -3.977255 -1.047591  Methane           0
# 1    -2.787307 -1.018775  Methane           0
# 2    -2.259508 -1.060643  Methane           0
# 3    -1.991431 -1.087365  Methane           0
# 4    -1.764751 -1.137672  Methane           0
# ...        ...       ...      ...         ...
# 8359  0.997686 -1.062292  Methane           1
# 8360  1.097278 -1.176797  Methane           1
# 8361  1.179578 -1.281382  Methane           1
# 8362  1.242424 -1.382197  Methane           1
# 8363  1.283985 -1.463480  Methane           1
#
# [8364 rows x 28 columns]

# %%
BET_df = pd.DataFrame()
cols = ["E","S","A","B","V","BET","Vt","Vmic","Vmeso","Temp(K)","Pressure","Adsorp(mmol/g)","Index"]
def bet_extraction(temp_df:pd.DataFrame):
    global BET_df
    literature = temp_df["Literature"].values[0]
    gac_name = temp_df["GAC"].values[0]
    print(literature,gac_name)
    try:
        if literature!=np.nan:
                bet_data = BET_path+'/'+str(literature)+"/"+gac_name+".csv"
                #print(bet_data)
                bet_curve = pd.read_csv(bet_data,header=None)
                x = bet_curve.iloc[:,0].values.tolist()
                y = bet_curve.iloc[:,1].values.tolist()
                _,new_y = inter_data(x,y)
                rows = len(temp_df)
                bet_matrix = [new_y for _ in range(rows)]
                bet_df = pd.DataFrame(bet_matrix,columns = ["BET_"+str(i) for i in range(len(new_y))])
                bet_df = pd.concat([bet_df,temp_df[cols].reset_index()],axis= 1,ignore_index=True)
                print(bet_df.shape)
                BET_df = pd.concat([BET_df,bet_df,],axis= 0,ignore_index=True)    

        #else:
        #    print("There is not leterature for this gac: {}".format(gac_name))         
    except:
        print("The BET curve for gac: {} from paper {} is not available.".format(gac_name,literature))
total_index = list(set(data["Index"].values.tolist()))
for index in total_index:
    temp_df =  data[data["Index"]==index]
    bet_extraction(temp_df)
# Out:
# 1 Graphene
# (8, 49)
# 1 Graphene
# (8, 49)
# nan Norit R1 Extra
# The BET curve for gac: Norit R1 Extra from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan BPL
# The BET curve for gac: BPL from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan A10
# The BET curve for gac: A10 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MaxSorb
# The BET curve for gac: MaxSorb from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Carbon A
# The BET curve for gac: Carbon A from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CAQF-30
# The BET curve for gac: CAQF-30 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Maxsorb II
# The BET curve for gac: Maxsorb II from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 7 ACB-5
# (9, 49)
# 7 ACB-2
# (11, 49)
# nan MAC
# The BET curve for gac: MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3/MAC
# The BET curve for gac: K2CO3/MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Coal tar pitch
# The BET curve for gac: Coal tar pitch from paper nan is not available.
# nan Petro pitch 1
# The BET curve for gac: Petro pitch 1 from paper nan is not available.
# nan Viscose Rayon
# The BET curve for gac: Viscose Rayon from paper nan is not available.
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# 10 KUA11701
# (9, 49)
# 10 KUA2170-200
# The BET curve for gac: KUA2170-200 from paper 10 is not available.
# 10 KUA21801
# (10, 49)
# 10 KUA21751
# (10, 49)
# 10 KUA41701
# The BET curve for gac: KUA41701 from paper 10 is not available.
# 10 KUA31752
# (10, 49)
# 10 CFC79
# (10, 49)
# 10 Com-AFC
# The BET curve for gac: Com-AFC from paper 10 is not available.
# 10 LFC61
# (9, 49)
# 10 CFC50
# The BET curve for gac: CFC50 from paper 10 is not available.
# 10 CFS54
# (9, 49)
# 10 LFC29
# (8, 49)
# 10 CFS27
# (8, 49)
# 10 CFC11
# The BET curve for gac: CFC11 from paper 10 is not available.
# 11 RP-15
# (13, 49)
# 11 RP-15
# (13, 49)
# 11 RP-15
# (12, 49)
# 11 RP-20
# (14, 49)
# 11 RP-20
# (12, 49)
# 11 RP-20
# (12, 49)
# 12 Maxsorb II
# The BET curve for gac: Maxsorb II from paper 12 is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 13 MaxSorb III
# The BET curve for gac: MaxSorb III from paper 13 is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AFC-20
# The BET curve for gac: AFC-20 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 14 ACF
# (9, 49)
# 14 ACF
# (9, 49)
# 14 ACF
# (9, 49)
# 14 ACS
# (9, 49)
# 14 ACS
# (9, 49)
# 14 ACS
# (9, 49)
# 15 C2
# The BET curve for gac: C2 from paper 15 is not available.
# nan 53-W2-N
# The BET curve for gac: 53-W2-N from paper nan is not available.
# nan 36-W2
# The BET curve for gac: 36-W2 from paper nan is not available.
# nan 53-W1
# The BET curve for gac: 53-W1 from paper nan is not available.
# nan 44-W2
# The BET curve for gac: 44-W2 from paper nan is not available.
# nan 53-W2
# The BET curve for gac: 53-W2 from paper nan is not available.
# nan 29-W1
# The BET curve for gac: 29-W1 from paper nan is not available.
# 16 C1
# The BET curve for gac: C1 from paper 16 is not available.
# nan C2
# The BET curve for gac: C2 from paper nan is not available.
# nan C3
# The BET curve for gac: C3 from paper nan is not available.
# nan C4
# The BET curve for gac: C4 from paper nan is not available.
# nan C5
# The BET curve for gac: C5 from paper nan is not available.
# nan C6
# The BET curve for gac: C6 from paper nan is not available.
# nan C7
# The BET curve for gac: C7 from paper nan is not available.
# nan C10
# The BET curve for gac: C10 from paper nan is not available.
# 17 Glc-C-4
# (13, 49)
# 17 Glc-C-4
# (13, 49)
# 17 Glc-C-4
# (13, 49)
# 18 LMA738
# (8, 49)
# 18 LMA726
# (9, 49)
# 18 LMA405
# (10, 49)
# 18 MaxSorb
# (8, 49)
# 18 RGC30
# (10, 49)
# 18 F400
# (7, 49)
# 19 S-750-30-09
# (7, 49)
# 19 S-800-30-09
# (7, 49)
# 19 S-850-30-09
# (7, 49)
# 19 S-900-30-09
# (6, 49)
# 19 S-800-90-09
# (8, 49)
# 19 S-800-150-09
# (6, 49)
# 19 S-800-90-06
# (5, 49)
# 19 S-800-90-10
# (6, 49)
# 19 S-800-90-12
# (6, 49)
# 20 ACDS2800
# (11, 49)
# 20 ACDS2700
# (12, 49)
# 20 ACDS2600
# (14, 49)
# 20 ACDS4800
# (12, 49)
# 20 ACDS4700
# (12, 49)
# 20 ACDS4600
# (12, 49)
# 21 sOMC
# (10, 49)
# 21 sOMC
# (9, 49)
# 21 sOMC
# (10, 49)
# 22 AC700
# (12, 49)
# 22 AC700
# (11, 49)
# 22 AC700
# (11, 49)
# 22 AC700
# (11, 49)
# 22 AC700
# (11, 49)
# 23 GAC-Egypt
# (17, 49)
# 23 GAC-Egypt
# (13, 49)
# 23 GAC-Egypt
# (13, 49)
# 23 GAC-Egypt
# (13, 49)
# 23 GAC-Egypt
# (13, 49)
# 23 GAC-Egypt
# (15, 49)
# nan 875-CO-8
# The BET curve for gac: 875-CO-8 from paper nan is not available.
# nan 875-CO-4
# The BET curve for gac: 875-CO-4 from paper nan is not available.
# nan 875-CO-2
# The BET curve for gac: 875-CO-2 from paper nan is not available.
# nan 990-CO-2
# The BET curve for gac: 990-CO-2 from paper nan is not available.
# nan 970-CO-2
# The BET curve for gac: 970-CO-2 from paper nan is not available.
# nan 925-CO-2
# The BET curve for gac: 925-CO-2 from paper nan is not available.
# nan 600-600-H2
# The BET curve for gac: 600-600-H2 from paper nan is not available.
# nan 500-600-H2
# The BET curve for gac: 500-600-H2 from paper nan is not available.
# nan 400-600-H2
# The BET curve for gac: 400-600-H2 from paper nan is not available.
# nan 400-600-H-KOH
# The BET curve for gac: 400-600-H-KOH from paper nan is not available.
# nan 500-600-H-KOH
# The BET curve for gac: 500-600-H-KOH from paper nan is not available.
# nan MaxSorb III
# The BET curve for gac: MaxSorb III from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan ACF-20
# The BET curve for gac: ACF-20 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 26 UK-GAC
# (9, 49)
# 26 UK-GAC
# (10, 49)
# 26 UK-GAC
# (9, 49)
# 27 AC1
# (10, 49)
# 27 AC2
# (12, 49)
# 27 AC3
# (12, 49)
# 27 AC4
# (12, 49)
# 27 AC3
# (13, 49)
# 27 AC3
# (12, 49)
# 27 AC3
# (13, 49)
# nan CAGO Com
# The BET curve for gac: CAGO Com from paper nan is not available.
# nan CAGO C
# The BET curve for gac: CAGO C from paper nan is not available.
# nan CA GO P
# The BET curve for gac: CA GO P from paper nan is not available.
# 29 MAXSorB
# (9, 49)
# 29 CMK-3
# (9, 49)
# 29 PACN-CO2-12h
# (9, 49)
# 29 PACN-CO2-9h
# (8, 49)
# 29 PACN-CO2-12h PELLET
# (12, 49)
# 29 PACN-CO2-9h PELLET
# (11, 49)
# 30 AN2.57301
# The BET curve for gac: AN2.57301 from paper 30 is not available.
# 30 AN37301
# The BET curve for gac: AN37301 from paper 30 is not available.
# 30 AN27301
# The BET curve for gac: AN27301 from paper 30 is not available.
# 30 AN26701
# (13, 49)
# 30 AN26702
# The BET curve for gac: AN26702 from paper 30 is not available.
# 30 AN27302
# The BET curve for gac: AN27302 from paper 30 is not available.
# nan Nprot-AC
# The BET curve for gac: Nprot-AC from paper nan is not available.
# 32 EC250H2
# (8, 49)
# 32 EC250H2
# (8, 49)
# 32 EC250H2
# (9, 49)
# 33 C-4
# (10, 49)
# 33 C-5
# (11, 49)
# 33 C-3
# (9, 49)
# 33 C-2
# (11, 49)
# 33 C-6
# (13, 49)
# 33 C-1
# (10, 49)
# 34 S0
# (7, 49)
# 34 S40
# (7, 49)
# 34 S50
# (7, 49)
# 34 S50
# (7, 49)
# 34 S50
# (6, 49)
# 35 CMS-1
# (10, 49)
# 35 CMS-2
# (12, 49)
# 35 CMS-3
# (12, 49)
# 35 CMS-1
# (11, 49)
# 35 CMS-2
# (12, 49)
# 35 CMS-3
# (12, 49)
# 35 CMS-1
# (12, 49)
# 35 CMS-2
# (12, 49)
# 35 CMS-3
# (12, 49)
# nan MICRO-GAC
# The BET curve for gac: MICRO-GAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 37 GS
# (12, 49)
# 37 GS
# (11, 49)
# 37 GS
# (11, 49)
# 37 AC-01
# (12, 49)
# 37 AC-01
# (11, 49)
# 37 AC-01
# (11, 49)
# 37 Carbon Black
# (13, 49)
# 37 Carbon Black
# (10, 49)
# 37 Carbon Black
# (10, 49)
# 38 KOH0.5TP50
# (11, 49)
# 38 KOH0.5TP50
# (11, 49)
# 38 KOH0.5TP50
# (12, 49)
# nan DO_800
# The BET curve for gac: DO_800 from paper nan is not available.
# nan DO_700
# The BET curve for gac: DO_700 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MSC-30
# The BET curve for gac: MSC-30 from paper nan is not available.
# 40 M1273-150
# (13, 49)
# 40 M1273-150
# (13, 49)
# 40 M1273-150
# (12, 49)
# 40 M1273-150
# (13, 49)
# 40 M1273-150
# (12, 49)
# 41 babassu-AC
# (15, 49)
# 41 babassu-AC
# (16, 49)
# 41 babassu-AC
# (14, 49)
# 42 C60-CC-PNP
# (11, 49)
# 42 C30-CC-PNP
# (11, 49)
# 42 C85-CC-PNP
# (12, 49)
# 42 P-CC-PNP
# (14, 49)
# 43 PRC-850
# (11, 49)
# 43 PRC-800
# (10, 49)
# 43 PRC-900
# (11, 49)
# 43 PRC-850
# (9, 49)
# 43 PRC-850
# (10, 49)
# 44 AC800
# (9, 49)
# 44 AC800
# (10, 49)
# 44 CMS
# (9, 49)
# 44 CMS
# (9, 49)
# 44 CMS
# (7, 49)
# 45 AC-H3PO4
# (7, 49)
# 45 AC-H3PO4
# (7, 49)
# 45 AC-H2O
# (9, 49)
# 45 AC-H2O
# (8, 49)
# 45 AC-CO2
# (7, 49)
# 45 AC-CO2
# (7, 49)
# 46 AC-1
# (8, 49)
# 46 AC-2
# (9, 49)
# 46 AC-4
# (8, 49)
# 46 NAC-1
# (7, 49)
# 46 NAC-2
# (8, 49)
# 46 NAC-4
# (8, 49)
# nan ADPC05
# The BET curve for gac: ADPC05 from paper nan is not available.
# nan ADPC1
# The BET curve for gac: ADPC1 from paper nan is not available.
# nan ADPC3
# The BET curve for gac: ADPC3 from paper nan is not available.
# nan C1050
# The BET curve for gac: C1050 from paper nan is not available.
# nan C1050P
# The BET curve for gac: C1050P from paper nan is not available.
# nan CDC
# The BET curve for gac: CDC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 50 AAC-1
# (9, 49)
# 50 CAC-2
# (13, 49)
# 50 AAC-1
# (17, 49)
# 50 AAC-1
# (15, 49)
# 50 AAC-1
# (18, 49)
# 51 PN18001
# (10, 49)
# 51 AC
# (8, 49)
# 51 IN18001
# (11, 49)
# 51 CN18001
# (11, 49)
# 52 CS-CO2
# (13, 49)
# 52 CS-H2O
# (12, 49)
# 52 CS-CO2
# (12, 49)
# 52 CS-H2O
# (13, 49)
# 52 CS-CO2
# (12, 49)
# 52 CS-H2O
# (11, 49)
# 53 SMC-1
# (11, 49)
# 53 SMC-2
# (8, 49)
# 53 SMC-3
# (9, 49)
# 53 SMC-1
# (9, 49)
# 53 SMC-2
# (9, 49)
# 53 SMC-2
# (8, 49)
# 53 SMC-1
# (8, 49)
# 53 SMC-2
# (8, 49)
# 53 SMC-3
# (8, 49)
# 54 CS0
# (5, 49)
# 54 CS3
# (6, 49)
# 54 CS6
# (6, 49)
# 55 AKFs1
# (8, 49)
# 55 AKFs2
# (8, 49)
# 55 AKFs3
# (6, 49)
# 55 AKFs4
# (10, 49)
# 55 AKFs5
# (9, 49)
# 55 AKFs6
# (7, 49)
# 55 AKFs7
# (8, 49)
# 55 AKFs1
# (8, 49)
# 55 AKFs2
# (8, 49)
# 55 AKFs3
# (6, 49)
# 55 AKFs4
# (8, 49)
# 55 AKFs5
# (9, 49)
# 55 AKFs6
# (8, 49)
# 55 AKFs7
# (8, 49)
# 55 AKFs1
# (7, 49)
# 55 AKFs3
# (6, 49)
# 55 AKFs5
# (9, 49)
# 55 AKFs7
# (6, 49)
# 56 RP-15
# (13, 49)
# 56 RP-15
# (13, 49)
# 56 RP-15
# (12, 49)
# 56 RP-20
# (14, 49)
# 56 RP-20
# (12, 49)
# 56 RP-20
# (12, 49)
# 58 I-AC
# The BET curve for gac: I-AC from paper 58 is not available.
# 58 I-AC
# The BET curve for gac: I-AC from paper 58 is not available.
# 58 I-AC
# The BET curve for gac: I-AC from paper 58 is not available.
# nan AC bead
# The BET curve for gac: AC bead from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 60 Super-AC
# (8, 49)
# 60 AC
# (7, 49)
# 60 OMC
# (8, 49)
# 60 Super-AC
# (7, 49)
# 60 AC
# (7, 49)
# 60 OMC
# (8, 49)
# 60 Super-AC
# (7, 49)
# 60 AC
# (8, 49)
# 60 OMC
# (7, 49)
# 61 C3
# (9, 49)
# 61 C7
# (10, 49)
# 61 C8
# (11, 49)
# 61 C10
# The BET curve for gac: C10 from paper 61 is not available.
# 62 AC600CTP
# (12, 49)
# 62 AC500CTP
# (11, 49)
# 62 AC700CTP
# (11, 49)
# 62 AC600CTP
# (13, 49)
# 62 AC600CTP
# (13, 49)
# 63 HS-KOH-1-4
# (7, 49)
# 63 HS-KOH-1-4
# (7, 49)
# 63 HS-KOH-1-4
# (7, 49)
# 64 TPC-1
# (12, 49)
# 65 PHA
# (10, 49)
# 65 NAHA-0.5
# (10, 49)
# 65 NAHA-1
# (11, 49)
# 65 NAHA-2
# (10, 49)
# 65 NAHA-4
# (10, 49)
# 65 NAHA-2
# (9, 49)
# 65 NAHA-2
# (9, 49)
# 65 NAHA-1
# (10, 49)
# 65 NAHA-1
# (10, 49)
# 65 PHA
# (10, 49)
# 65 PHA
# (10, 49)
# 66 AC-PKOH
# (10, 49)
# 66 AC-PKOH
# (10, 49)
# 66 AC-PKOH
# (11, 49)
# 66 AC-RH
# (8, 49)
# 66 AC-RH
# (7, 49)
# 66 AC-RH
# (9, 49)
# 66 AC-PH2O
# (10, 49)
# 66 AC-PH2O
# (10, 49)
# 66 AC-PH2O
# (9, 49)
# 67 Zn2-1 (+10)
# The BET curve for gac: Zn2-1 (+10) from paper 67 is not available.
# 67 Zn1-1 (+10)
# The BET curve for gac: Zn1-1 (+10) from paper 67 is not available.
# 67 Zn0.5-1 (+10)
# The BET curve for gac: Zn0.5-1 (+10) from paper 67 is not available.
# 67 LAAF2
# (10, 49)
# 67 LAAF1
# (11, 49)
# 67 LAFF3
# The BET curve for gac: LAFF3 from paper 67 is not available.
# 68 CZ1023
# (10, 49)
# 68 CZ1073
# (9, 49)
# 68 CZ1123
# (9, 49)
# 68 CZ1073
# (7, 49)
# 68 CZ1073
# (7, 49)
# 69 MR-1-2
# (11, 49)
# 69 MR-1-2
# (10, 49)
# 69 MR-1-2
# (11, 49)
# 69 MR-1-3
# (10, 49)
# 69 MR-1-3
# (11, 49)
# 69 MR-1-3
# (10, 49)
# 69 MR-1-4
# (10, 49)
# 69 MR-1-4
# (11, 49)
# 69 MR-1-4
# (10, 49)
# 70 ACD18-053
# (11, 49)
# 70 ACD18-053
# (9, 49)
# 70 ACD18-053
# (10, 49)
# nan AC-4
# The BET curve for gac: AC-4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan AC-6
# The BET curve for gac: AC-6 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 72 AMC-700
# (13, 49)
# 72 AMC-800
# (13, 49)
# 72 AMC-900
# (13, 49)
# nan KOH:FPV_850=4
# The BET curve for gac: KOH:FPV_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:FPV_850=1
# The BET curve for gac: K2CO3:FPV_850=1 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan KOH:WG-12_850=4
# The BET curve for gac: KOH:WG-12_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:WG-12_850=1
# The BET curve for gac: K2CO3:WG-12_850=1 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan KOH:CW-22_850=4
# The BET curve for gac: KOH:CW-22_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan K2CO3:CWZ-22_850=4
# The BET curve for gac: K2CO3:CWZ-22_850=4 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan MPU-007
# The BET curve for gac: MPU-007 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan LCN
# The BET curve for gac: LCN from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 76 C800
# (12, 49)
# 76 C1000
# (16, 49)
# 76 C1200
# (13, 49)
# 76 C1400
# (14, 49)
# 77 C800
# (10, 49)
# 78 CAC-50
# (11, 49)
# 78 CAC-50
# (12, 49)
# 78 CAC-50
# (12, 49)
# 79 C-PVDC-600
# (11, 49)
# 79 C-PVDC-700
# (11, 49)
# 79 C-PVDC-800
# (11, 49)
# 79 C-PVDC-900
# (11, 49)
# 79 C-PVDC-1000
# The BET curve for gac: C-PVDC-1000 from paper 79 is not available.
# 79 C-PVDC-600
# (13, 49)
# 79 C-PVDC-700
# (13, 49)
# 79 C-PVDC-800
# (11, 49)
# 79 C-PVDC-900
# (12, 49)
# 79 C-PVDC-1000
# The BET curve for gac: C-PVDC-1000 from paper 79 is not available.
# 80 UC600
# (9, 49)
# 80 UC700
# (10, 49)
# 80 UC800
# (11, 49)
# 80 UC900
# (11, 49)
# 81 AR-V
# (10, 49)
# 81 AR-V
# (12, 49)
# 81 AR-V
# (12, 49)
# 81 AR-V
# (12, 49)
# 81 AR-V
# (11, 49)
# 81 AR-V
# (10, 49)
# 82 R-AC
# (12, 49)
# 82 1H-AC
# (14, 49)
# 82 15H-AC
# (14, 49)
# 83 GOC-1
# (12, 49)
# 83 GOC-2
# (16, 49)
# 83 GOC-3
# (13, 49)
# 83 GOC-4
# (14, 49)
# 83 GOC-2
# (10, 49)
# 83 GOC-2
# (11, 49)
# 84 SC-1
# (9, 49)
# 84 SC-4
# (11, 49)
# 84 SC-6
# (11, 49)
# 84 SC-6
# (10, 49)
# 84 SC-6
# (10, 49)
# nan AC
# The BET curve for gac: AC from paper nan is not available.
# nan AC-APS
# The BET curve for gac: AC-APS from paper nan is not available.
# nan AC-HP
# The BET curve for gac: AC-HP from paper nan is not available.
# nan AC-SA-APS
# The BET curve for gac: AC-SA-APS from paper nan is not available.
# 86 AC
# (10, 49)
# 86 AC-U
# (9, 49)
# 86 AC-OX
# (9, 49)
# 86 AC-OX-U1
# (10, 49)
# 86 AC-OX-U2
# (9, 49)
# 87 BEA-ZTC
# (8, 49)
# 87 BEA-ZTC
# (8, 49)
# 87 BEA-ZTC
# (8, 49)
# 87 BEA-ZTC
# (8, 49)
# 87 BEA-ZTC-873K
# (8, 49)
# 87 BEA-ZTC-873K
# (8, 49)
# 87 BEA-ZTC-873K
# (8, 49)
# 87 BEA-ZTC-873K
# (8, 49)
# 87 BEA-ZTC-1073K
# (8, 49)
# 87 BEA-ZTC-1073K
# (8, 49)
# 87 BEA-ZTC-1073K
# (8, 49)
# 87 BEA-ZTC-1073K
# (8, 49)
# 87 FAU-ZTC
# (8, 49)
# 87 FAU-ZTC
# (8, 49)
# 87 FAU-ZTC
# (8, 49)
# 87 FAU-ZTC
# (8, 49)
# 87 FAU-ZTC-873K
# (8, 49)
# 87 FAU-ZTC-873K
# (8, 49)
# 87 FAU-ZTC-873K
# (8, 49)
# 87 FAU-ZTC-873K
# (8, 49)
# 87 FAU-ZTC-1073K
# (8, 49)
# 87 FAU-ZTC-1073K
# (8, 49)
# 87 FAU-ZTC-1073K
# (8, 49)
# 87 FAU-ZTC-1073K
# (8, 49)
# 88 CMS80070-10
# (12, 49)
# 88 CMS80070-20
# (12, 49)
# 88 Pre-AC
# (13, 49)
# nan MAC
# The BET curve for gac: MAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 90 CPC-550
# (12, 49)
# 90 CPC-600
# (10, 49)
# 90 CPC-650
# (12, 49)
# 90 CPC-700
# (11, 49)
# 90 CPC-800
# (15, 49)
# 91 CNS-AC
# (13, 49)
# 91 CNS-AC
# (12, 49)
# 91 CNS-AC
# (13, 49)
# 92 AC
# The BET curve for gac: AC from paper 92 is not available.
# 92 PS
# (11, 49)
# 92 ML
# (11, 49)
# 92 GL
# (11, 49)
# nan CS-CO2
# The BET curve for gac: CS-CO2 from paper nan is not available.
# nan CS-H2O
# The BET curve for gac: CS-H2O from paper nan is not available.
# nan Calgon BP
# The BET curve for gac: Calgon BP from paper nan is not available.
# 94 MA-PC3-PFA-10
# (14, 49)
# 94 MA-PC4-PFA
# (13, 49)
# 94 Norit-R2
# The BET curve for gac: Norit-R2 from paper 94 is not available.
# 94 MA-PC2-PFA
# (10, 49)
# 95 AC-1
# (8, 49)
# 95 AC-2
# (8, 49)
# 95 AC-1
# (8, 49)
# 95 AC-2
# (8, 49)
# 95 AC-1
# (8, 49)
# 95 AC-2
# (8, 49)
# 96 DO
# (11, 49)
# 96 DO-1000
# (11, 49)
# 96 DO-1350
# (12, 49)
# 96 DO-1500
# (13, 49)
# 96 PA
# (8, 49)
# 96 PA-1000
# (10, 49)
# 96 PA-1350
# (10, 49)
# 96 PA-1500
# (11, 49)
# 97 SBL-CO-PP-C-7
# (12, 49)
# 97 SBL-CO-PP-C-20
# (12, 49)
# 97 SBL-CO-PP-20
# (11, 49)
# 97 SBL-CO-PP-7
# (10, 49)
# 97 CO-PP-0
# (12, 49)
# 98 AC
# (10, 49)
# 98 Cl-AC
# (10, 49)
# 98 N-AC
# (9, 49)
# 98 K-AC
# (9, 49)
# 98 KCl-AC
# (9, 49)
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan RX 1.5
# The BET curve for gac: RX 1.5 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan CGran
# The BET curve for gac: CGran from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan Rox 0.8
# The BET curve for gac: Rox 0.8 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan GAC 1240
# The BET curve for gac: GAC 1240 from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# 100 SBL-PNP-0.5-2-800
# (12, 49)
# 100 SBL-PNP-1-4-750
# (13, 49)
# 100 SBL-PNP-0.5-4-750
# (11, 49)
# 102 MPP4
# (11, 49)
# 102 MPP3
# (11, 49)
# 102 MPZ8
# (11, 49)
# 102 MPZ7
# (8, 49)
# 102 MPC12
# (7, 49)
# 102 MPK16
# (10, 49)
# 102 MPK15
# (8, 49)
# 103 R-AC
# (8, 49)
# 103 1H-AC
# The BET curve for gac: 1H-AC from paper 103 is not available.
# 103 5H-AC
# (10, 49)
# 103 15H-AC
# (10, 49)
# 103 1H-AC
# The BET curve for gac: 1H-AC from paper 103 is not available.
# 103 1H-AC
# The BET curve for gac: 1H-AC from paper 103 is not available.
# 104 NCSs
# (7, 49)
# 104 ACSs
# (7, 49)
# 104 ACSs-N
# (6, 49)
# 104 ACSs-N
# (8, 49)
# 104 ACSs-N
# (7, 49)
# 105 AC-90S
# (8, 49)
# 105 AC-90S
# (7, 49)
# 105 AC-90S
# (6, 49)
# 105 AC-90S
# (7, 49)
# 105 AC-90L
# (6, 49)
# 105 AC-90L
# (6, 49)
# 105 AC-90L
# (6, 49)
# 105 AC-90L
# (6, 49)
# 105 AC-60L
# (8, 49)
# 105 AC-60L
# (8, 49)
# 105 AC-60L
# (8, 49)
# 105 AC-60L
# (6, 49)
# 106 CNT-AC0
# (6, 49)
# 106 CNT-AC1
# (5, 49)
# 106 CNT-AC2
# (5, 49)
# 106 CNT-AC3
# (5, 49)
# 106 CNT-AC5
# (5, 49)
#   DF-AC
# The BET curve for gac: DF-AC from paper   is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan SM-AC
# The BET curve for gac: SM-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# H46 C-CroPASP
# (8, 49)
# H46 C-PASP
# (9, 49)
# H53 HCPB
# (9, 49)
# H53 CHCPB-K-600
# (10, 49)
# H53 CHCPB-K-700
# (11, 49)
# H53 CHCPB-K-800
# (11, 49)
# CO189 CS
# (6, 49)
# CO189 CSK-1
# (8, 49)
# CO189 CSK-2
# (7, 49)
# CO189 CSK-7
# (7, 49)
# CO189 CSK-5
# (9, 49)
# CO189 CSK-5
# (8, 49)
# CO189 CSK-5
# (9, 49)
# CO189 CSK-5
# (9, 49)
# CO189 CSK-5
# (8, 49)
# nan SPC-5
# The BET curve for gac: SPC-5 from paper nan is not available.
# nan SPC-4
# The BET curve for gac: SPC-4 from paper nan is not available.
# nan SPC-3
# The BET curve for gac: SPC-3 from paper nan is not available.
# nan SPC-2
# The BET curve for gac: SPC-2 from paper nan is not available.
# nan SPC-1
# The BET curve for gac: SPC-1 from paper nan is not available.
# CO184 M-C-KOH-4-800
# (11, 49)
# CO184 M-C-4-800
# (10, 49)
# CO184 M-C-4-700
# (10, 49)
# CO184 M-C-APS-4-800
# (10, 49)
# CO177 CSCN_9_C180
# (8, 49)
# CO177 CSCN_9_C60
# (6, 49)
# CO177 CSCN_6
# (9, 49)
# CO177 CSCN_6_C150
# (8, 49)
# CO177 CSCN_6_C200
# (8, 49)
# CO177 CSCN_9
# (9, 49)
# CO175 PA-P
# (9, 49)
# CO175 PA-P
# (8, 49)
# CO175 PA-P-6C
# (8, 49)
# CO175 PA-P-6C
# (7, 49)
# CO175 PA-P-6A
# (9, 49)
# CO175 PA-P-6A
# (8, 49)
# CO175 PA-P-7C
# (9, 49)
# CO175 PA-P-7C
# (10, 49)
# CO175 PA-P-7A
# (10, 49)
# CO175 PA-P-7A
# (8, 49)
# CO173 NDC
# (7, 49)
# CO173 NDC
# (9, 49)
# CO173 NDC
# (7, 49)
# CO166 SD-600-4
# The BET curve for gac: SD-600-4 from paper CO166 is not available.
# CO166 SD-800-4
# The BET curve for gac: SD-800-4 from paper CO166 is not available.
# CO166 SD-M-800-4
# The BET curve for gac: SD-M-800-4 from paper CO166 is not available.
# CO166 PPY-700-2
# (9, 49)
# CO166 PPY-800-4
# The BET curve for gac: PPY-800-4 from paper CO166 is not available.
# CO166 PTH-600-2
# The BET curve for gac: PTH-600-2 from paper CO166 is not available.
# CO164 PCTP-3
# (8, 49)
# CO164 PCTP-3
# (9, 49)
# CO164 PCTP-3C
# (11, 49)
# CO164 PCTP-3C
# (10, 49)
# CO164 APCTP-3C
# (9, 49)
# CO164 APCTP-3C
# (9, 49)
# CO155 FCDTPA
# (10, 49)
# CO155 FCDTPA-500
# (10, 49)
# CO155 FCDTPA-700
# (9, 49)
# CO155 FCDTPA-900
# (9, 49)
# CO155 FCDTPA-K-500
# (10, 49)
# CO155 FCDTPA-K-700
# (10, 49)
# CO155 FCDTPA-K-900
# (10, 49)
# CO152 NMC
# (7, 49)
# CO152 NMC
# (7, 49)
# CO152 NMC
# (7, 49)
# CO152 MGO-NMC-20
# (7, 49)
# CO152 MGO-NMC-20
# (7, 49)
# CO152 MGO-NMC-20
# (7, 49)
# CO152 MGO-NMC-10
# (6, 49)
# CO152 MGO-NMC-10
# (7, 49)
# CO152 MGO-NMC-10
# (7, 49)
# CO149 OTS-3-750
# (8, 49)
# CO149 OTS-3-750
# (8, 49)
# CO149 OTS-2-650
# (10, 49)
# CO149 OTS-2-650
# (8, 49)
# CO149 OTS-1-550
# (9, 49)
# CO149 OTS-1-550
# (8, 49)
# CO128 OTSS-3-350
# (7, 49)
# CO128 OTSS-2-450
# (7, 49)
# CO128 OTSS-1-550
# (8, 49)
# CO128 OTSS-3-350
# (8, 49)
# CO128 OTSS-2-450
# (9, 49)
# CO128 OTSS-1-550
# (9, 49)
# CO101 SA-2-800
# (9, 49)
# CO101 SA-2-700
# (9, 49)
# CO101 SA-2-600
# (9, 49)
# CO101 SA-2-800
# (9, 49)
# CO101 SA-2-700
# (9, 49)
# CO101 SA-2-600
# (10, 49)
# CO101 SA-2-800
# (8, 49)
# CO101 SA-2-700
# (9, 49)
# CO101 SA-2-600
# (8, 49)
# CO101 SA-1-800
# (8, 49)
# CO101 SA-1-700
# (10, 49)
# CO101 SA-1-600
# (9, 49)
# CO101 SA-1-800
# (8, 49)
# CO101 SA-1-800
# (10, 49)
# CO101 SA-1-700
# (8, 49)
# CO101 SA-1-700
# (9, 49)
# CO101 SA-1-600
# (9, 49)
# CO101 SA-1-600
# (8, 49)
# EE2  PAC
# The BET curve for gac: PAC from paper EE2  is not available.
# EE2 PAC
# (13, 49)
# EE2 PAC
# (11, 49)
# nan PCB
# The BET curve for gac: PCB from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan RX1.5
# The BET curve for gac: RX1.5 from paper nan is not available.
# nan RX0.8
# The BET curve for gac: RX0.8 from paper nan is not available.
# nan CGRAN
# The BET curve for gac: CGRAN from paper nan is not available.
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan GAC-1240
# The BET curve for gac: GAC-1240 from paper nan is not available.
# nan CNR-115
# The BET curve for gac: CNR-115 from paper nan is not available.
# nan RX 1.5
# The BET curve for gac: RX 1.5 from paper nan is not available.
# nan CGRAN
# The BET curve for gac: CGRAN from paper nan is not available.
# nan Rox 0.8
# The BET curve for gac: Rox 0.8 from paper nan is not available.
# nan GAC1240
# The BET curve for gac: GAC1240 from paper nan is not available.
# nan TC
# The BET curve for gac: TC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan pit-GAC
# The BET curve for gac: pit-GAC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE10 MHZ-CR
# (8, 49)
# EE10 MHK-CR
# (8, 49)
# EE10 MDZ-CR
# (8, 49)
# EE10 MDK-CR
# (8, 49)
# EE10 AC-CR
# (7, 49)
# EE10 MHZ-CR
# (8, 49)
# EE10 MHZ-CR
# (8, 49)
# nan BDH-AC
# The BET curve for gac: BDH-AC from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE14 HPC800-0.5
# (7, 49)
# EE14 HPC800-1
# (8, 49)
# EE14 HPC800-1.5
# (7, 49)
# EE14 HPC800
# (10, 49)
# EE14 HPC800
# (7, 49)
# EE14 HPC800-0.5
# (7, 49)
# EE14 HPC800-1
# (8, 49)
# nan BDH-activatedcarbon
# The BET curve for gac: BDH-activatedcarbon from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# EE18 ANPC-1-800
# (10, 49)
# EE18 ANPC-2-700
# (10, 49)
# EE18 ANPC-2-800
# (11, 49)
# EE18 ANPC-1-600
# (11, 49)
# EE18 ANPC-1-700
# (9, 49)
# EE18 ANPC-2-600
# (10, 49)
# EE18 ANPC-1-600
# (11, 49)
# EE18 ANPC-2-600
# (10, 49)
# EE18 ANPC-1-700
# (10, 49)
# EE18 ANPC-2-700
# (8, 49)
# EE18 ANPC-1-800
# (9, 49)
# EE18 ANPC-2-800
# (9, 49)
# EE18 ANPC-1-600
# (9, 49)
# EE18 ANPC-2-600
# (8, 49)
# EE18 ANPC-1-700
# (10, 49)
# EE18 ANPC-2-700
# (8, 49)
# EE18 ANPC-1-800
# (8, 49)
# EE18 ANPC-2-800
# (8, 49)
# EE12 Co-NDPC-500
# (12, 49)
# EE12 Co-NDPC-600
# (11, 49)
# EE12 Co-NDPC-700
# (10, 49)
# EE12 Co-NDPC-800
# (10, 49)
# EE12 Co-NDPC-900
# (8, 49)
# EE12 Co-NDPC-500
# (8, 49)
# EE12 Co-NDPC-600
# (10, 49)
# EE12 Co-NDPC-700
# (10, 49)
# EE12 Co-NDPC-800
# (10, 49)
# EE12 Co-NDPC-900
# (9, 49)
# EE26 A-AC-3
# (9, 49)
# EE26 A-AC-4
# (9, 49)
# EE26 A-AC-5
# (9, 49)
# EE26 A-AC-3
# (8, 49)
# EE26 A-AC-4
# (8, 49)
# EE26 A-AC-5
# (8, 49)
# EE26 A-AC-3
# (8, 49)
# EE26 A-AC-4
# (8, 49)
# EE26 A-AC-5
# (8, 49)
# EE28 NAC-600
# (9, 49)
# EE28 NAC-600
# (11, 49)
# EE28 NAC-700
# (9, 49)
# EE28 NAC-700
# (9, 49)
# EE28 NAC-800
# (10, 49)
# EE28 NAC-800
# (8, 49)
# EE28 NAC-600
# (10, 49)
# EE28 NAC-700
# (9, 49)
# EE28 NAC-800
# (8, 49)
# nan PCB
# The BET curve for gac: PCB from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.
# nan nan
# The BET curve for gac: nan from paper nan is not available.

# %%
BET_df
# Out:
#               0           1           2           3           4           5   \
# 0     122.501902  129.103245  129.010691  130.461481  138.682310  146.725526
# 1     122.501902  129.103245  129.010691  130.461481  138.682310  146.725526
# 2     122.501902  129.103245  129.010691  130.461481  138.682310  146.725526
# 3     122.501902  129.103245  129.010691  130.461481  138.682310  146.725526
# 4     122.501902  129.103245  129.010691  130.461481  138.682310  146.725526
# ...          ...         ...         ...         ...         ...         ...
# 5390  442.457907  481.570098  515.329381  535.207199  554.050802  574.066048
# 5391  442.457907  481.570098  515.329381  535.207199  554.050802  574.066048
# 5392  442.457907  481.570098  515.329381  535.207199  554.050802  574.066048
# 5393  442.457907  481.570098  515.329381  535.207199  554.050802  574.066048
# 5394  442.457907  481.570098  515.329381  535.207199  554.050802  574.066048
#
#               6           7           8           9   ...  39      40      41  \
# 0     152.798909  158.585442  163.906937  168.487971  ...   0  0.2495   514.0
# 1     152.798909  158.585442  163.906937  168.487971  ...   0  0.2495   514.0
# 2     152.798909  158.585442  163.906937  168.487971  ...   0  0.2495   514.0
# 3     152.798909  158.585442  163.906937  168.487971  ...   0  0.2495   514.0
# 4     152.798909  158.585442  163.906937  168.487971  ...   0  0.2495   514.0
# ...          ...         ...         ...         ...  ...  ..     ...     ...
# 5390  593.345912  607.549410  621.534947  635.263581  ...   0  0.2495  1942.8
# 5391  593.345912  607.549410  621.534947  635.263581  ...   0  0.2495  1942.8
# 5392  593.345912  607.549410  621.534947  635.263581  ...   0  0.2495  1942.8
# 5393  593.345912  607.549410  621.534947  635.263581  ...   0  0.2495  1942.8
# 5394  593.345912  607.549410  621.534947  635.263581  ...   0  0.2495  1942.8
#
#         42    43    44     45        46        47    48
# 0     3.00   NaN   NaN  278.0  0.053415  0.018737  2751
# 1     3.00   NaN   NaN  278.0  0.170583  0.061587  2751
# 2     3.00   NaN   NaN  278.0  0.301536  0.104402  2751
# 3     3.00   NaN   NaN  278.0  0.404920  0.136500  2751
# 4     3.00   NaN   NaN  278.0  0.534150  0.171229  2751
# ...    ...   ...   ...    ...       ...       ...   ...
# 5390  1.14  0.73  0.41  323.0  0.469890  0.392164  3599
# 5391  1.14  0.73  0.41  323.0  0.612107  0.421251  3599
# 5392  1.14  0.73  0.41  323.0  0.766028  0.470575  3599
# 5393  1.14  0.73  0.41  323.0  0.937053  0.540081  3599
# 5394  1.14  0.73  0.41  323.0  1.070279  0.650684  3599
#
# [5395 rows x 49 columns]

# %%
BET_df.to_csv('./Methane_Adding_bet_35_unified.csv')

# %%
BET_df = pd.read_csv("Methane_Adding_bet_35_new.csv")
BET_df.dropna(axis=0,how="any",subset = ["BET","Vt","Vmic","BET_34"],inplace=True)
#BET_df.dropna(axis=0,how="any",subset = ["BET_34"],inplace=True)

# %% [markdown]
# # Using evenly selected BET cureve to find the feature importance of eachi region in the BET curve by the interval of 0.1

# %%
# data splitting
#from random import shuffle
from sklearn.model_selection import train_test_split
from numpy import random
def group_split(BET_df:pd.DataFrame,random_state = 42):
    #BET_df = BET_df[BET_df['Pressure']>3]
    indexs = list(set(BET_df["Index"].values.tolist()))
    #shuffle(indexs)
    _,test_index = train_test_split(indexs,test_size= 0.2,random_state =random_state)

    #test_index = random.choice(indexs,len(indexs)//5,replace=False).tolist()
    train_df = BET_df[~BET_df["Index"].isin(test_index)]
    test_df = BET_df[BET_df["Index"].isin(test_index)]
    return train_df,test_df

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor,GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor,RandomForestRegressor
from lightgbm import LGBMRegressor  
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
  
n_estimators = [50,100,120,150,180,200,300]

# define different models#,
models = [
    #('SVR',SVR(max_iter=100000)),
    #('DT',DecisionTreeRegressor(random_state=42)),\
    # ('ADBR',AdaBoostRegressor(random_state=42)), 
    #("GBR",GradientBoostingRegressor(random_state=42)),\
    #('BG',BaggingRegressor(random_state=42,n_jobs=-1)),
    #('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
    #('RF',RandomForestRegressor(n_jobs=-1,random_state=42)),
    ('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
    #('MLPR',MLPRegressor(random_state=42))
    #('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators = 200, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1)),\
    #('BGETR',BaggingRegressor(ExtraTreesRegressor(n_estimators = 180,random_state=42,n_jobs=6),random_state=42,n_jobs=-1))
    ]

# set search parameters grid for different models
para_grids = { 
    'SVR':{'kernel':['linear','poly','rbf','sigmoid','precomputed']},\
    'DT':{'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson']},\
    'ADBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2],'loss':['linear','square','exponential']},\
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'BG':{'n_estimators':[10,50,100]},\
    'ETR':{'n_estimators':n_estimators},\
    'RF':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,50,],'learning_rate': [0.05,0.1,0.5,1],'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,30,50]},\
    'BGETR':{'n_estimators':[10]},\
    'MLPR':{'hidden_layer_sizes':[(4,100),(5,100),(6,100)],
            "activation":["logistic","relu"],\
            "solver":['sgd', 'adam']}
    }

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,groups,model,para_grid):

    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(model,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error'))
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []
    for gas in gas_list:
        if gas =='total':
            train_df_com = train_df
            test_df_com = test_df
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index'].values
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2_total,test_mse_total = model_eval(model_refit,test_x,test_y.squeeze()) 
                for gases in gas_list[1:]:
                    test_df_com = test_df[test_df['Label']==gases]
                    test_xs = test_df_com[input_feature]
                    test_ys = test_df_com[output].values
                    test_r2,test_mse = model_eval(model_refit,test_xs,test_ys.squeeze()) 
                    result_total.append([gases,model_name+'_total',result[0],result[1],test_r2_total,test_mse_total,test_r2,test_mse,best_param])
                    print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))    
        else:
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                feature_importances = model_refit.feature_importances_.tolist()  #####new lines added to record the feature importance of each round
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param]+feature_importances) # adding feature importance valuels to the end of outputted results
                
                print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_total',test_r2,test_mse))     
    return result_total

# %%
BET_df = pd.read_csv("Methane_Adding_bet_35.csv")
BET_df.dropna(axis=0,how="any",subset = ["BET","Vt","Vmic","BET_34"],inplace=True)

# %%
BET_df = pd.read_csv("CO2_Adding_bet_35.csv")
BET_df.dropna(axis=0,how="any",subset = ["BET","Vt","Vmic","BET_34"],inplace=True)

# %%
import os
conditions = ['S','V','Temp(K)','Pressure']
base_feature = ["BET_"+str(i) for i in range(10,25)]+conditions
#base_feature = ["BET_"+str(i) for i in list(range(10))+list(range(25,35))]+conditions
#feature_list = [base_feature,base_feature+["BET"],base_feature+['Vt'],base_feature+["BET",'Vt'],\
#    base_feature+["BET","Vt","Vmic","Vmeso"],["BET","Vt"]+conditions,["BET","Vt","Vmic","Vmeso"]+conditions]
feature_list = [base_feature+["BET","Vt","Vmic","Vmeso"]]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ["BET_Vt_Vmic_Vmeso"]#['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] #['BET_Curve','BET_Plus_Vt',"Vmic_Vmeso"]
gas_list = ['Methane']#,'CFCs','Methane','E&E'b

for i in range(50):
    train_df,test_df = group_split(BET_df,random_state=i)
    
    for j in range(len(feature_list)):
        
        results = model_comparison(models,para_grids, feature_list[j],gas_list)
        files_name = '50_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'
        pd.DataFrame(results,columns = columns+feature_list[j]).to_csv(os.path.join('./8_using_BET_curve',files_name)) 
    print("The finish of {} th trial".format(i))
# Out:
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9329111111256516, Test_error 0.6923842527955838
# The finish of 0 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9387443098888822, Test_error 0.5704294649323168
# The finish of 1 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9086688888371653, Test_error 0.8618585266436465
# The finish of 2 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9217773302122402, Test_error 0.7715001447713702
# The finish of 3 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9263719312167281, Test_error 0.6817935787420472
# The finish of 4 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.942673192313338, Test_error 0.5364587716707733
# The finish of 5 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9228052460575898, Test_error 0.7006704557922283
# The finish of 6 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9440361868300836, Test_error 0.4618443141737819
# The finish of 7 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9143750527707916, Test_error 0.7720239321527878
# The finish of 8 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9360753231240702, Test_error 0.6319938676036156
# The finish of 9 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9449951792475123, Test_error 0.4514936105303849
# The finish of 10 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8940609455577297, Test_error 0.9230974885778497
# The finish of 11 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9328876730993573, Test_error 0.7602080224109385
# The finish of 12 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9524421436829477, Test_error 0.45060676145116396
# The finish of 13 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9470510245693398, Test_error 0.4381680959916101
# The finish of 14 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9043593128501449, Test_error 0.8963125030612112
# The finish of 15 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9495125056042961, Test_error 0.4830029748500867
# The finish of 16 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8724423821949597, Test_error 1.0325650551372227
# The finish of 17 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9533405171763435, Test_error 0.4350765402260704
# The finish of 18 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9347722603312003, Test_error 0.6214388982984371
# The finish of 19 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9371910306023126, Test_error 0.6222183781955546
# The finish of 20 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8984421873944431, Test_error 0.9075680108326083
# The finish of 21 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8960461968828042, Test_error 1.0331628331595553
# The finish of 22 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9202238854985904, Test_error 0.7519152575011634
# The finish of 23 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9425025185287069, Test_error 0.5087258340743575
# The finish of 24 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9314003145382213, Test_error 0.6428335828965095
# The finish of 25 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9303175812525711, Test_error 0.5836759737070432
# The finish of 26 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9240528139553233, Test_error 0.670483888380225
# The finish of 27 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9289076851928867, Test_error 0.8226987421194386
# The finish of 28 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.938908677246241, Test_error 0.6067039032226623
# The finish of 29 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9204132042899108, Test_error 0.7703423858315002
# The finish of 30 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9248190415952261, Test_error 0.7135886101316984
# The finish of 31 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9635074888707903, Test_error 0.3944310018483931
# The finish of 32 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8712396375498701, Test_error 0.962369967328807
# The finish of 33 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9125475016552642, Test_error 0.8171289481470846
# The finish of 34 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9399663850210744, Test_error 0.5641205196724004
# The finish of 35 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9529592342063621, Test_error 0.5101303359128032
# The finish of 36 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.928614326934842, Test_error 0.6416045337868757
# The finish of 37 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9213220568733697, Test_error 0.6582653730300678
# The finish of 38 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9399306536703778, Test_error 0.6471453144158604
# The finish of 39 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.8986848206285097, Test_error 0.8649593365149143
# The finish of 40 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9199824254206657, Test_error 0.7600223869618634
# The finish of 41 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9190152023552716, Test_error 0.648600809692074
# The finish of 42 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9354796846083486, Test_error 0.7159098749968362
# The finish of 43 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9464057284021912, Test_error 0.5068891318344892
# The finish of 44 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9502508901672522, Test_error 0.4667642012768822
# The finish of 45 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9437148015374575, Test_error 0.4826078232880111
# The finish of 46 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9249862989753691, Test_error 0.7305864388668644
# The finish of 47 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.927374499083655, Test_error 0.7149003640600291
# The finish of 48 th trial
# Dataset Methane, Algorithm LGBM_total, Test_r2 0.9337020364796889, Test_error 0.7681382632222109
# The finish of 49 th trial

# %% [markdown]
# # Post result treatments

# %%
import pandas as pd
"""
file_name = ['BET_Curve',"BET_Curve_BET","BET_Cureve_Vt","BET_Curve_BET_Vt","BET_Curve_BET_Vt_Vmic_Vmeso","BET_Vt","BET_Vt_Vmic_Vmeso"] 
feature_list = [base_feature,base_feature+["BET"],base_feature+['Vt'],base_feature+["BET",'Vt'],\
    base_feature+["BET","Vt","Vmic","Vmeso"],["BET","Vt"]+conditions,["BET","Vt","Vmic","Vmeso"]+conditions]
"""
feature_list = [base_feature+["BET","Vt","Vmic","Vmeso"]]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param']
file_name = ["BET_Vt_Vmic_Vmeso"]
cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model"]
for j in range(len(file_name)):
    df_list = []
    for i in range(50):
        files_name = '50_point_curve_feature_'+file_name[j]+'_result_'+str(i)+'.csv'


        temp_pd = pd.read_csv(os.path.join('./8_using_BET_curve',files_name))[cal_columns+feature_list[j]]
        temp_pd['feature_sum'] = temp_pd[feature_list[j]].sum(axis=1)
       

        for feature in feature_list[j]:
            temp_pd[feature]=temp_pd[feature]/temp_pd["feature_sum"]
        
        df_list.append(temp_pd)
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_mean.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./8_using_BET_curve',file_name[j]+'_std.csv'))
