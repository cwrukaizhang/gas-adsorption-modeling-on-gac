# %%
import pandas as pd
import numpy as np
from sklearn.utils import shuffle

def pred_dataset(file_names, feature_set ,i):
    source_path = 'C:/Kai_Zhang/MachineLearning/Unified gas Adsorption/CO2_adsorption/new_data'
    train_df = pd.DataFrame()
    test_df = pd.DataFrame()
    for file_name in file_names:
        temp_data = pd.read_excel(os.path.join(source_path,file_name+'-02-02-2022.xlsx'),skiprows= 1 )
        temp_data = temp_data.dropna(axis=0,how = 'any',subset = feature_set)
        temp_data = temp_data[temp_data['Pressure']>0.01]
        index = list(set(temp_data['Index'].values))
        
        test_index = shuffle(sorted(index),random_state=i)[:55]
        #test_index= np.random.choice(index,55,replace=False)
        train_x = temp_data.loc[~temp_data['Index'].isin(test_index)]#[1,2,3]
        test_x = temp_data.loc[temp_data['Index'].isin(test_index)]
        
        train_df = pd.concat([train_df,train_x],axis=0)
        test_df = pd.concat([test_df,test_x],axis =0)
    return train_df,test_df

# %%
from sklearn.ensemble import GradientBoostingRegressor,\
    BaggingRegressor,ExtraTreesRegressor
from lightgbm import LGBMRegressor  

n_estimators = [50,100,120,150,180,200]
# define different models#,
models = [
    #("GBR",GradientBoostingRegressor(random_state=42)),\
   # ('ETR',ExtraTreesRegressor(random_state=42,n_jobs=-1)),\
    #('LGBM',LGBMRegressor(n_jobs = -1,random_state = 42)),\
    ('BGLGBM',BaggingRegressor(LGBMRegressor(n_estimators = 200, n_jobs = -1,random_state = 42), random_state=42,n_jobs=-1)),\
    ]

# set search parameters grid for different models
para_grids = { 
    'GBR':{'n_estimators':n_estimators,'learning_rate':[0.1,0.5,1,2]},\
    'ETR':{'n_estimators':n_estimators},\
    'LGBM':{'num_leaves':[10,20,30,50],'learning_rate': [0.05,0.1,0.5,1],'n_estimators':n_estimators},\
    'BGLGBM':{'n_estimators':[10,30,50]},\
    }

# %%
from sklearn.model_selection import GridSearchCV,cross_validate,GroupKFold
from sklearn.ensemble import ExtraTreesRegressor
from  sklearn.metrics import mean_squared_error,r2_score
from sklearn.utils import shuffle

def model_CV(train_x,train_y,groups,model,para_grid):

    out_cv = GroupKFold(n_splits = 5)
    result = GridSearchCV(model,para_grid,cv= out_cv.get_n_splits(groups =groups),
    scoring='neg_mean_squared_error', return_train_score=True,n_jobs=-1)
    result.fit(train_x,train_y)
    
    model_refit =model.set_params(**result.best_params_)
    train_cv = cross_validate(model_refit,train_x,train_y,groups = groups,cv =out_cv,scoring = ('r2', 'neg_mean_squared_error')) 
    train_mse_cv = -train_cv['test_neg_mean_squared_error'].mean()
    train_r2_cv = train_cv['test_r2'].mean()
    
    return [train_r2_cv,train_mse_cv],result.best_params_

# model evaluation
def model_eval(model,test_x,test_y):
      
    test_pre = model.predict(test_x)
    test_r2 = r2_score(test_pre,test_y)
    test_mse = mean_squared_error(test_y,test_pre)
    return test_r2,test_mse

# comparing different models
def model_comparison(model_list,para_grids,feature_list,gas_list):
    gas_list = gas_list 
    input_feature = feature_list
    output = ['Adsorp(mmol/g)']
    result_total = []

    for gas in gas_list:
        
            train_df_com = train_df[train_df['Label']==gas]
            test_df_com = test_df[test_df['Label']==gas]
            train_x = train_df_com[input_feature]
            test_x = test_df_com[input_feature]
            train_y = train_df_com[output].values
            test_y = test_df_com[output].values
            groups = train_df_com['Index']
            train_x, train_y, groups = shuffle(train_x, train_y, groups, random_state=42)
           
            for model_name, model in model_list:
                result, best_param = model_CV(train_x,train_y.squeeze(),groups,model,para_grids[model_name])
                model_refit = model.set_params(**best_param)
                model_refit.fit(train_x,train_y.squeeze())
                test_r2,test_mse = model_eval(model_refit,test_x,test_y.squeeze()) 
                result_total.append([gas,model_name+'_separate',result[0],result[1],-1,-1, test_r2,test_mse,best_param])
                
                print('Dataset {}, Algorithm {}, Test_r2 {}, Test_error {}'.format(gas,model_name+'_separate',test_r2,test_mse))           
    return result_total

# %%
import numpy.random as nrd
from sklearn.decomposition import KernelPCA,SparsePCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from  collections import Counter

def bgk_pca(train_df,test_df): 
    #np.random.RandomState(42)# using major voting approach to find the outliers in the test dataset
    test_index = list(set(test_df["Index"].values))
    len_test = len(test_index)
    train_index = list(set(train_df["Index"].values))
    #total_feature = ["Index",'V','L','BET','Vt','Temp(K)']
    total_feature = ["Index",'BET','Vt','Temp(K)']
    #pca_feature =  ['V','L','BET','Vt','Temp(K)']
    pca_feature =  ['BET','Vt','Temp(K)']
    num_feature = len(pca_feature)
    removed_index = []
    res = []
    iters = 10
    multi_mse = []
    for i in range(iters):
        mses = []
        train_selected = train_df[train_df["Index"].isin(nrd.choice(train_index,int(len(train_index)*0.75),replace=False))] # modified here change fixed len to a the fraction of the len of the training dataset.
        data = pd.concat([test_df,train_selected])
        sub_data = data[total_feature].drop_duplicates()
        sub_data_scalered = MinMaxScaler().fit_transform(sub_data[pca_feature].values)
        
        """adding lines to determine the number of components to achieve 0.99 threshold"""
        kernel_pca = KernelPCA(kernel='poly',max_iter =100000,n_jobs =-1,gamma=1e-2,fit_inverse_transform=True,random_state=42)
        kpca_transform = kernel_pca.fit_transform(sub_data_scalered.reshape(num_feature,-1))
        explained_variance = np.var(kpca_transform, axis=0)
        explained_variance_ratio = explained_variance / np.sum(explained_variance)
        cumu_variance = np.cumsum(explained_variance_ratio)
        n_components = np.where(cumu_variance>0.99)[0][0]+1
        kernel_pca = KernelPCA(n_components=n_components,kernel='poly',max_iter =100000,n_jobs =-1,gamma=1e-2,fit_inverse_transform=True,random_state=42)
        """ The end of adding new lines"""

        sub_data_transformed = kernel_pca.fit_transform(sub_data_scalered.reshape(num_feature,-1))
        reconstructed = kernel_pca.inverse_transform(sub_data_transformed.reshape(num_feature,-1))
        for i in range(len(sub_data_scalered)):
            mses.append(mean_squared_error(sub_data_scalered[i],reconstructed.reshape(-1,num_feature)[i]))
            df_mse = pd.DataFrame(mses,columns = ['MSE'])
        df_mse['Indexs'] = sub_data["Index"].drop_duplicates().values
        mean_mse = df_mse["MSE"].mean()
        test_mse_df = df_mse[df_mse["Indexs"].isin(test_index)]
        outlier_index = test_mse_df[test_mse_df["MSE"]>3*mean_mse]["Indexs"].values.tolist()
        removed_index.extend(outlier_index)
        multi_mse.append(mean_mse)

    counter = Counter(removed_index)
    thresh = int(0.7*iters)
    for key,values in counter.most_common():
        if values>=thresh:
            res.append(key)
            
        if values<thresh: break

    return np.mean(multi_mse)#res

# %%
import os
from sklearn.utils import shuffle
base_feature = ['V','S','L','BET',]
condition_feature = ['Temp(K)','Pressure']
combin_1 = ['Vt']
combin_2 = ["Vmeso"]
combin_3 = ['Vmic']
combin_4 = ['Vt',"Vmeso",]
combin_3 = ['Vt',"Vmic",] 
combin_5 = ['Vt',"Vmic",'Vmeso',]
combin_6 = ["Vmic",'Vmeso',]
feature_list = [base_feature+combin_1+condition_feature]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param','kpg_pca_mse']
#file_name = ['Total',"Meso","Micro",'All','Vmic_meso']
file_name = ['BET_plus_Vt']
feature_set = ["Vt",]
gas_list = ['CO2']
'''
for i in range(15):
    train_dfs,test_df = pred_dataset(gas_list,feature_set)#
    fraction = range(100,len(list(set(train_dfs["Index"].values))),50)
    for k in fraction:
        print(k)
        temp_df = train_dfs
        nums_test = len(list(set(test_df["Index"].values)))
        index = list(set(temp_df['Index'].values))
        #print(len(index))
        train_index= np.random.choice(index,k,replace=False)
        train_df = temp_df.loc[temp_df['Index'].isin(train_index)]
        k_recon_mse = bgk_pca(train_df,test_df)
        
        results = model_comparison(models,para_grids, feature_list[0],gas_list)
        temp_results  = []
        for ele in results:
            temp_results.append(ele+[k_recon_mse])
        print("recons_mse: {:.4f}".format(k_recon_mse))
        files_name = 'Res_pca_The_impact_of_different_training_sample_size_of_'+str(k)+"_"+file_name[0]+'_result_'+str(i)+'.csv'
        pd.DataFrame(temp_results,columns = columns).to_csv(os.path.join('./3_The_impact_of_different_training_sample_size',files_name)) 
'''

for i in range(50):
    recons_error = []
    train_index = []
    train_dfs,test_df = pred_dataset(gas_list,feature_set,i)#
    nums_test = len(list(set(test_df["Index"].values)))
    index = list(set(train_dfs['Index'].values))
    interval = 50

    fraction = range(100,len(list(set(train_dfs["Index"].values))),interval)
    for k in range(len(fraction)):
        if k==0:
            selected_index = np.random.choice(index,100,replace=False)
        else:
            selected_index = np.random.choice(index,interval,replace=False)

        for ele in selected_index:
            index.remove(ele)
        #print(len(index),print(train_index))
        train_index.extend(selected_index) 
        print(k, nums_test,len(train_index))
        train_df = train_dfs.loc[train_dfs['Index'].isin(train_index)]
        k_recon_mse = bgk_pca(train_df,test_df)
        results = model_comparison(models,para_grids, feature_list[0],gas_list)
        temp_results  = []
        for ele in results:
            temp_results.append(ele+[k_recon_mse])
        print("recons_mse: {:.4f}".format(k_recon_mse))
        files_name = 'Res_pca_The_impact_of_different_training_sample_size_of_'+str((k+1)*interval)+"_"+file_name[0]+'_result_'+str(i)+'.csv'
        pd.DataFrame(temp_results,columns = columns).to_csv(os.path.join('./3_The_impact_of_different_training_sample_size',files_name))
# Out:
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8739030461021208, Test_error 1.4685914845862456
# recons_mse: 0.0300
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9160779902670984, Test_error 1.0287185343629535
# recons_mse: 0.0307
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9202424787076249, Test_error 0.9572893757108799
# recons_mse: 0.0299
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9301928433554695, Test_error 0.8606365523222863
# recons_mse: 0.0258
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9308694083623454, Test_error 0.8260247778516332
# recons_mse: 0.0250
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9312481270895773, Test_error 0.7788349902159744
# recons_mse: 0.0249
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9383307746198016, Test_error 0.7092869354987921
# recons_mse: 0.0243
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.939685928330698, Test_error 0.703968030513986
# recons_mse: 0.0244
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9295687997651598, Test_error 0.8201666584609038
# recons_mse: 0.0235
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9416419572374103, Test_error 0.6534358419632476
# recons_mse: 0.0236
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9355806380260491, Test_error 0.6966127157215657
# recons_mse: 0.0241
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9374935303871815, Test_error 0.6976779370239358
# recons_mse: 0.0245
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9421253938634051, Test_error 0.6414055660391181
# recons_mse: 0.0242
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9386194968612788, Test_error 0.6659660787162784
# recons_mse: 0.0235
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9493339626625932, Test_error 0.5323961684145156
# recons_mse: 0.0237
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9520539943825932, Test_error 0.5042185036269115
# recons_mse: 0.0231
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9512571525557372, Test_error 0.5172518405276284
# recons_mse: 0.0228
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9485739219847482, Test_error 0.5537781177721673
# recons_mse: 0.0230
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9450360718750129, Test_error 0.5725686516305475
# recons_mse: 0.0226
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9508942130049343, Test_error 0.5270117860648819
# recons_mse: 0.0225
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.945990630674101, Test_error 0.565826554698652
# recons_mse: 0.0218
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9405583878156158, Test_error 0.6247820248602561
# recons_mse: 0.0219
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9364644521800956, Test_error 0.6618194288581676
# recons_mse: 0.0221
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9448282734960045, Test_error 0.5911172628507898
# recons_mse: 0.0214
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9337811527050804, Test_error 0.6855321719215542
# recons_mse: 0.0213
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9387421631428629, Test_error 0.644139237574199
# recons_mse: 0.0213
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9421351417771315, Test_error 0.6080941905313112
# recons_mse: 0.0210
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9422508188252301, Test_error 0.6123918192166854
# recons_mse: 0.0213
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9432212541008355, Test_error 0.6073554520322522
# recons_mse: 0.0203
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9443995707656252, Test_error 0.5881249754359353
# recons_mse: 0.0202
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9452142647437416, Test_error 0.5860949738660992
# recons_mse: 0.0200
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9469288488142588, Test_error 0.5718440424749794
# recons_mse: 0.0199
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9457385207956241, Test_error 0.5881801879770103
# recons_mse: 0.0197
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.945041454221369, Test_error 0.6041024494945739
# recons_mse: 0.0192
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9446802685409241, Test_error 0.6003560600664202
# recons_mse: 0.0194
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9450855335796633, Test_error 0.6079981073546697
# recons_mse: 0.0188
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9536464215889516, Test_error 0.5287712368422588
# recons_mse: 0.0192
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9533582056028929, Test_error 0.5295682385010909
# recons_mse: 0.0186
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9527973691986642, Test_error 0.5284775700620042
# recons_mse: 0.0185
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9505560737282848, Test_error 0.5424646151760233
# recons_mse: 0.0184
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8315096055015369, Test_error 2.0969874099664767
# recons_mse: 0.0371
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8274399336326248, Test_error 2.0251714775649114
# recons_mse: 0.0345
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8365312808973442, Test_error 2.033519237687384
# recons_mse: 0.0341
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8685279136442547, Test_error 1.7453128261059558
# recons_mse: 0.0316
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9434920937421145, Test_error 0.8997319428256612
# recons_mse: 0.0298
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9396395767766831, Test_error 1.0401373614394254
# recons_mse: 0.0301
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9421471694021251, Test_error 1.019781474038047
# recons_mse: 0.0287
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9378841615771358, Test_error 1.1257094266514474
# recons_mse: 0.0285
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.939012529476521, Test_error 1.0394133882865977
# recons_mse: 0.0284
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9414960905165881, Test_error 1.0203129083810767
# recons_mse: 0.0303
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9367176248306324, Test_error 1.0794352481359502
# recons_mse: 0.0293
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9390058549930435, Test_error 1.0529050161469184
# recons_mse: 0.0296
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9394986665030257, Test_error 1.0661023829364396
# recons_mse: 0.0295
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9411747120652322, Test_error 1.0395249941655245
# recons_mse: 0.0281
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.941943507783482, Test_error 1.0210250654664679
# recons_mse: 0.0283
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9421468508724409, Test_error 1.062068774383999
# recons_mse: 0.0277
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9413065318482754, Test_error 1.0362816024946897
# recons_mse: 0.0269
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9442526313996109, Test_error 0.9856145887505765
# recons_mse: 0.0270
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9448312940828475, Test_error 0.9670897840375992
# recons_mse: 0.0257
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9420878264641128, Test_error 1.0462031407448706
# recons_mse: 0.0248
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9437427582482598, Test_error 1.009601640390774
# recons_mse: 0.0247
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9429516536363766, Test_error 1.025554223159589
# recons_mse: 0.0245
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9419004834060457, Test_error 1.042943833461915
# recons_mse: 0.0244
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9438872838848686, Test_error 1.0139364022675963
# recons_mse: 0.0244
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9434569995935771, Test_error 1.0073160461888213
# recons_mse: 0.0237
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9445042672677911, Test_error 0.9894524407682407
# recons_mse: 0.0236
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9438104985794872, Test_error 0.9899957951755385
# recons_mse: 0.0235
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9459931284266949, Test_error 0.9609457137609
# recons_mse: 0.0227
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9482684183584704, Test_error 0.9194571476602227
# recons_mse: 0.0223
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9548499743121, Test_error 0.8144234601750842
# recons_mse: 0.0218
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9518683189752608, Test_error 0.8540672412717485
# recons_mse: 0.0204
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9548927592289348, Test_error 0.8096841500795217
# recons_mse: 0.0203
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9524750949070828, Test_error 0.8476775992307143
# recons_mse: 0.0200
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9537619626641609, Test_error 0.8261238470837144
# recons_mse: 0.0197
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9611932409124647, Test_error 0.6671397304788645
# recons_mse: 0.0198
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9615104109419417, Test_error 0.6656005107335157
# recons_mse: 0.0192
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9593688979167836, Test_error 0.6940905321828456
# recons_mse: 0.0191
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9609350308389683, Test_error 0.6663660980913491
# recons_mse: 0.0187
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.96114454812784, Test_error 0.6705265025771516
# recons_mse: 0.0184
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9598581956683953, Test_error 0.6850223309924749
# recons_mse: 0.0183
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8647242593796022, Test_error 1.2707428359626745
# recons_mse: 0.0397
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.878885951900485, Test_error 1.0787430119220387
# recons_mse: 0.0349
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9042666599657125, Test_error 0.8927979171010537
# recons_mse: 0.0349
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8992436891520376, Test_error 0.8996709376315642
# recons_mse: 0.0322
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9006757717559805, Test_error 0.9829929078647451
# recons_mse: 0.0323
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9107451993073141, Test_error 0.9055680367265107
# recons_mse: 0.0308
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9189226079888886, Test_error 0.8232071092909385
# recons_mse: 0.0302
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9166312071957867, Test_error 0.8301024574633951
# recons_mse: 0.0304
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9175458212796606, Test_error 0.7833405241512179
# recons_mse: 0.0319
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9131558326861593, Test_error 0.9054854830708948
# recons_mse: 0.0310
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9143750411572746, Test_error 0.8994028357273317
# recons_mse: 0.0305
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9133466059485362, Test_error 0.932824263930173
# recons_mse: 0.0302
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9142252119878721, Test_error 0.9212563127160317
# recons_mse: 0.0293
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9188717322252581, Test_error 0.8418322098363181
# recons_mse: 0.0296
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9124475424007151, Test_error 0.9440583754212609
# recons_mse: 0.0295
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9124254301517011, Test_error 0.9883458299250735
# recons_mse: 0.0295
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9243718578058415, Test_error 0.7898417146889056
# recons_mse: 0.0280
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9209901004190663, Test_error 0.8534251942777442
# recons_mse: 0.0273
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9216975920487213, Test_error 0.8501664628169207
# recons_mse: 0.0265
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9182983150964551, Test_error 0.890392207827278
# recons_mse: 0.0254
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9208632049830533, Test_error 0.8530106649683307
# recons_mse: 0.0250
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.916242404631329, Test_error 0.9167486312694605
# recons_mse: 0.0238
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9156376812886393, Test_error 0.9197262414832368
# recons_mse: 0.0239
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9185448693159598, Test_error 0.8725761697267334
# recons_mse: 0.0222
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9260072470195466, Test_error 0.7710797495039088
# recons_mse: 0.0227
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9206674302818095, Test_error 0.834045142677093
# recons_mse: 0.0224
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9111773999070814, Test_error 0.988603563852867
# recons_mse: 0.0217
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9053378351331607, Test_error 1.0810668932765006
# recons_mse: 0.0213
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9060207056040086, Test_error 1.0801473767874201
# recons_mse: 0.0214
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9022663801487911, Test_error 1.136024086985824
# recons_mse: 0.0207
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9047833245979285, Test_error 1.0945966984870579
# recons_mse: 0.0203
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9055481083426058, Test_error 1.0831083909273895
# recons_mse: 0.0199
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9053787134789177, Test_error 1.076004191196803
# recons_mse: 0.0200
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9013734490937934, Test_error 1.1409502669077636
# recons_mse: 0.0200
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8991630324226896, Test_error 1.1745305654921592
# recons_mse: 0.0197
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8964494845999466, Test_error 1.2257196555356067
# recons_mse: 0.0192
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8987022838781734, Test_error 1.190509625587938
# recons_mse: 0.0191
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9014603255329864, Test_error 1.153982514177141
# recons_mse: 0.0184
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9026983107546308, Test_error 1.133125888466081
# recons_mse: 0.0183
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9037589167954524, Test_error 1.1009237919609278
# recons_mse: 0.0180
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6550704615956913, Test_error 1.5848275989483163
# recons_mse: 0.0422
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7169483893060589, Test_error 1.3514178516768047
# recons_mse: 0.0395
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7978938629006231, Test_error 1.0164709403199783
# recons_mse: 0.0377
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7675785235620426, Test_error 1.00863883802119
# recons_mse: 0.0335
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7816299921142134, Test_error 0.9794877691083809
# recons_mse: 0.0335
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7685390824857974, Test_error 1.0344096988144524
# recons_mse: 0.0304
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7894492360795018, Test_error 1.0238895368253984
# recons_mse: 0.0290
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7677498139706024, Test_error 1.1130246403775068
# recons_mse: 0.0297
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7730210338931227, Test_error 1.0337297483386483
# recons_mse: 0.0284
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7900844223544483, Test_error 0.966160039625434
# recons_mse: 0.0269
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7823607341136033, Test_error 0.9876554606918134
# recons_mse: 0.0255
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7929643058338942, Test_error 0.9298786476619638
# recons_mse: 0.0254
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7903111361845789, Test_error 0.9503035600816447
# recons_mse: 0.0256
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7933184772369852, Test_error 0.9284887994290311
# recons_mse: 0.0247
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7890460338396196, Test_error 0.9454866695460021
# recons_mse: 0.0246
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.798608507359367, Test_error 0.9096618868876363
# recons_mse: 0.0245
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.796324162215728, Test_error 0.921922474820039
# recons_mse: 0.0247
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8177828722299796, Test_error 0.8588553990308132
# recons_mse: 0.0250
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8097947953653849, Test_error 1.065107077843402
# recons_mse: 0.0247
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8191704626617808, Test_error 1.0222309539277705
# recons_mse: 0.0248
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8225657060851718, Test_error 1.0023470145775517
# recons_mse: 0.0242
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8193831397730352, Test_error 1.0236912926987385
# recons_mse: 0.0231
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.808894114530431, Test_error 1.0264546658936446
# recons_mse: 0.0233
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8042642356994291, Test_error 1.0541568884832182
# recons_mse: 0.0240
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8126233992953121, Test_error 1.0161780092171266
# recons_mse: 0.0232
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8157292770859257, Test_error 0.9961945509809309
# recons_mse: 0.0227
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8142812321090058, Test_error 0.988953041491375
# recons_mse: 0.0223
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8139606766621349, Test_error 0.9905129639940464
# recons_mse: 0.0222
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8200360213516413, Test_error 1.0126209797283938
# recons_mse: 0.0216
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.81271043517734, Test_error 1.0043540912464242
# recons_mse: 0.0215
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8071277035692577, Test_error 1.0210490123650147
# recons_mse: 0.0209
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8080881470489009, Test_error 1.016924477420166
# recons_mse: 0.0213
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.819286402069481, Test_error 0.9938846924113564
# recons_mse: 0.0208
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8621377456933518, Test_error 0.7818517404811675
# recons_mse: 0.0203
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.86911156252848, Test_error 0.7488642380455343
# recons_mse: 0.0198
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8651017948149549, Test_error 0.748304297640191
# recons_mse: 0.0194
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8695684671362606, Test_error 0.7210276974500944
# recons_mse: 0.0187
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8729097965741484, Test_error 0.7037929010761275
# recons_mse: 0.0185
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8659249534845361, Test_error 0.7498988434613778
# recons_mse: 0.0185
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.874987502419966, Test_error 0.7298188145898775
# recons_mse: 0.0181
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7376078977956925, Test_error 1.7965835269385042
# recons_mse: 0.0321
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.820329796155307, Test_error 1.4607897237797909
# recons_mse: 0.0307
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8507249573366226, Test_error 1.2670174968621253
# recons_mse: 0.0297
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8650231679370921, Test_error 1.1286103226863917
# recons_mse: 0.0293
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8915358856648885, Test_error 0.8222287637549607
# recons_mse: 0.0306
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8842457423824466, Test_error 0.8809153916647757
# recons_mse: 0.0299
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8908575191932386, Test_error 0.9702991842895009
# recons_mse: 0.0284
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8824934548798727, Test_error 1.1805825661960234
# recons_mse: 0.0299
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8885693638701911, Test_error 1.09949979195203
# recons_mse: 0.0282
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8898578556889789, Test_error 1.0108895791529824
# recons_mse: 0.0281
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8879537686155448, Test_error 1.020168839886002
# recons_mse: 0.0281
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8917113054643941, Test_error 1.0196393679686544
# recons_mse: 0.0285
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8720719242980175, Test_error 1.2438629164125936
# recons_mse: 0.0279
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.868699560825508, Test_error 1.2498655780354087
# recons_mse: 0.0274
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8800780642396662, Test_error 1.1080140765555104
# recons_mse: 0.0268
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.869614423954554, Test_error 1.1643129371961134
# recons_mse: 0.0268
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8806428454244731, Test_error 1.0386938543284001
# recons_mse: 0.0271
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8706153755506129, Test_error 1.1272694220228623
# recons_mse: 0.0262
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8504059332720897, Test_error 1.361399472620881
# recons_mse: 0.0266
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8473914047264398, Test_error 1.3665665652720211
# recons_mse: 0.0257
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8593929432207315, Test_error 1.1736211934630965
# recons_mse: 0.0245
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8724113768372224, Test_error 1.0637300853212825
# recons_mse: 0.0237
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8680331127276281, Test_error 1.1117550367450133
# recons_mse: 0.0231
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8765609889901398, Test_error 1.0500926194033189
# recons_mse: 0.0235
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8683726129724532, Test_error 1.0855388562209567
# recons_mse: 0.0217
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8719897175334339, Test_error 1.0498320233026195
# recons_mse: 0.0216
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9125465178606198, Test_error 0.6527911205014644
# recons_mse: 0.0214
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9189241788063777, Test_error 0.6069530037452385
# recons_mse: 0.0217
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9206589189019968, Test_error 0.5986103749219236
# recons_mse: 0.0214
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9217671519095935, Test_error 0.5808140572731266
# recons_mse: 0.0203
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.919014281676534, Test_error 0.5977983089987948
# recons_mse: 0.0205
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9261148865894049, Test_error 0.5515478333725184
# recons_mse: 0.0199
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9276057555802206, Test_error 0.5412956331498072
# recons_mse: 0.0197
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9279757194880747, Test_error 0.5357513695096073
# recons_mse: 0.0200
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9229478341336291, Test_error 0.5747963510458878
# recons_mse: 0.0199
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9348951313570775, Test_error 0.49380270699194057
# recons_mse: 0.0191
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.932008862655642, Test_error 0.5235526545537864
# recons_mse: 0.0189
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9326124861317483, Test_error 0.5182253817921465
# recons_mse: 0.0181
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.934163922315103, Test_error 0.5050793641331819
# recons_mse: 0.0185
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9315228099007887, Test_error 0.49831024341924224
# recons_mse: 0.0182
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.5586136066115746, Test_error 6.361809987581235
# recons_mse: 0.0404
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7241314284079063, Test_error 4.694649761515526
# recons_mse: 0.0378
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7369997302911808, Test_error 4.17371273758898
# recons_mse: 0.0357
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7200985718993822, Test_error 3.957927827087169
# recons_mse: 0.0350
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.726373937225969, Test_error 3.9483775172396727
# recons_mse: 0.0341
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7290402133587587, Test_error 3.9627735635774775
# recons_mse: 0.0303
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7342415487113758, Test_error 3.87475637381083
# recons_mse: 0.0312
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7304936025107699, Test_error 3.8806619433692475
# recons_mse: 0.0311
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7483966274970986, Test_error 3.6823892591456744
# recons_mse: 0.0301
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8219627025264535, Test_error 2.8846892642018878
# recons_mse: 0.0302
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8345424033858262, Test_error 2.742497063830748
# recons_mse: 0.0299
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8305915620574127, Test_error 2.8737869712676076
# recons_mse: 0.0292
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8252252690372321, Test_error 2.925552059604596
# recons_mse: 0.0287
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8330193233125801, Test_error 2.8397293105400423
# recons_mse: 0.0292
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8359050015484135, Test_error 2.8098616794417355
# recons_mse: 0.0289
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8491722352230117, Test_error 2.5336330698063727
# recons_mse: 0.0282
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8574166858057023, Test_error 2.457412552614875
# recons_mse: 0.0274
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8588126303752619, Test_error 2.454257514511082
# recons_mse: 0.0272
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8634768043588118, Test_error 2.3858340513267193
# recons_mse: 0.0268
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8621723414402379, Test_error 2.375913142298088
# recons_mse: 0.0252
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8646828955464888, Test_error 2.3504731271933026
# recons_mse: 0.0248
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.862790196232473, Test_error 2.398636526617178
# recons_mse: 0.0231
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8615043713807634, Test_error 2.407940098725417
# recons_mse: 0.0223
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8666248903743737, Test_error 2.332396271944125
# recons_mse: 0.0222
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8660814895655964, Test_error 2.3309310084150505
# recons_mse: 0.0217
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8604132728620892, Test_error 2.382554529762314
# recons_mse: 0.0218
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8645449495231895, Test_error 2.3141483175918114
# recons_mse: 0.0211
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8633054185194105, Test_error 2.351756730400847
# recons_mse: 0.0220
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.856323619023444, Test_error 2.4233861283946663
# recons_mse: 0.0208
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8564731001260778, Test_error 2.427453567217476
# recons_mse: 0.0208
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8512088541459395, Test_error 2.4689794069841193
# recons_mse: 0.0212
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8484818382207575, Test_error 2.4966061773588906
# recons_mse: 0.0203
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8589481563008696, Test_error 2.297536216391625
# recons_mse: 0.0200
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8947059970120553, Test_error 1.8692391174601308
# recons_mse: 0.0199
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8955208319410304, Test_error 1.8668580473998322
# recons_mse: 0.0198
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9057260465109583, Test_error 1.7394158374899984
# recons_mse: 0.0192
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9071968243963849, Test_error 1.7262508716278036
# recons_mse: 0.0190
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9008881857972413, Test_error 1.7797370258003353
# recons_mse: 0.0187
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8974387631324016, Test_error 1.818823429894531
# recons_mse: 0.0186
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.886512502176721, Test_error 1.942919329359615
# recons_mse: 0.0182
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8152820066691127, Test_error 1.5656752089207489
# recons_mse: 0.0369
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8512822500880919, Test_error 1.3302026897428305
# recons_mse: 0.0309
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9145643257774507, Test_error 1.0162126283714605
# recons_mse: 0.0305
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9182422434545433, Test_error 0.9706785058862053
# recons_mse: 0.0294
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9178427858274572, Test_error 0.950455542882296
# recons_mse: 0.0281
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9158046479575387, Test_error 0.9737796634511277
# recons_mse: 0.0279
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9160372999769661, Test_error 0.9641100096545147
# recons_mse: 0.0256
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9202724769376962, Test_error 0.9174611364412549
# recons_mse: 0.0248
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9204591284643528, Test_error 0.9080319334212397
# recons_mse: 0.0238
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9207144298241456, Test_error 0.9292400761600049
# recons_mse: 0.0243
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9248157228110008, Test_error 0.8818167103491285
# recons_mse: 0.0238
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9280232830762648, Test_error 0.8617679066537608
# recons_mse: 0.0241
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9259928585583694, Test_error 0.9080662606315937
# recons_mse: 0.0239
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.924687813806419, Test_error 0.8999712695038771
# recons_mse: 0.0228
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.903239022347018, Test_error 1.0480706714639685
# recons_mse: 0.0244
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9249332105096287, Test_error 0.8492435061482917
# recons_mse: 0.0251
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9326357362065454, Test_error 0.7817667905357183
# recons_mse: 0.0227
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9294256712117933, Test_error 0.8037875887553794
# recons_mse: 0.0242
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9289234788791161, Test_error 0.812434318449518
# recons_mse: 0.0238
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9269803962567569, Test_error 0.8584637033086602
# recons_mse: 0.0235
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9274194340396333, Test_error 0.8341640802528316
# recons_mse: 0.0229
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9324650766490588, Test_error 0.7862962833923831
# recons_mse: 0.0226
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.939409703761022, Test_error 0.7126679248363341
# recons_mse: 0.0227
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9352718397066502, Test_error 0.739632388266218
# recons_mse: 0.0220
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9324940860267095, Test_error 0.7711147486246808
# recons_mse: 0.0220
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9426025384191471, Test_error 0.6933568857497491
# recons_mse: 0.0215
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9470711806690947, Test_error 0.644960651381243
# recons_mse: 0.0209
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9458487076339323, Test_error 0.6383774719770255
# recons_mse: 0.0211
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.945619371791146, Test_error 0.6398494041568823
# recons_mse: 0.0209
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9519768933289554, Test_error 0.5894039610494284
# recons_mse: 0.0204
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.949314087771201, Test_error 0.600220739315298
# recons_mse: 0.0203
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9478823619592359, Test_error 0.614716262949738
# recons_mse: 0.0201
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9518937235657019, Test_error 0.5820062022893671
# recons_mse: 0.0198
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9528064675904493, Test_error 0.5709163700608524
# recons_mse: 0.0200
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9520084493896206, Test_error 0.5849298901795096
# recons_mse: 0.0195
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9490542685283392, Test_error 0.6098268520812496
# recons_mse: 0.0192
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9493886907318211, Test_error 0.5996428780478193
# recons_mse: 0.0188
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9479059225647488, Test_error 0.6073858735981215
# recons_mse: 0.0188
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9527106939776284, Test_error 0.5696388107300385
# recons_mse: 0.0184
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.95323018203911, Test_error 0.5661124067912828
# recons_mse: 0.0182
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7982693071693275, Test_error 1.7572067225455308
# recons_mse: 0.0353
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7831499232047192, Test_error 1.8604039001088049
# recons_mse: 0.0344
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8330234676542657, Test_error 1.534040376301982
# recons_mse: 0.0342
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9011819747797017, Test_error 0.9799980888797037
# recons_mse: 0.0324
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9174807327539873, Test_error 0.8502101874758287
# recons_mse: 0.0280
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9560049389389554, Test_error 0.526403888500131
# recons_mse: 0.0294
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9459066134452268, Test_error 0.6618218885334299
# recons_mse: 0.0269
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9452187284376955, Test_error 0.685014525562482
# recons_mse: 0.0274
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9566877301194662, Test_error 0.5835763087639632
# recons_mse: 0.0252
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9642134305800387, Test_error 0.4728500108228425
# recons_mse: 0.0255
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9664048961205356, Test_error 0.4340544108930546
# recons_mse: 0.0251
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9671105004681667, Test_error 0.42762519324097015
# recons_mse: 0.0263
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9657433513644716, Test_error 0.4397352683597041
# recons_mse: 0.0255
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9644221736319923, Test_error 0.4420502306122304
# recons_mse: 0.0252
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9668353884433462, Test_error 0.4424562826619698
# recons_mse: 0.0247
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9642491775316999, Test_error 0.4596840437281872
# recons_mse: 0.0243
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9644753866070584, Test_error 0.4613100939637466
# recons_mse: 0.0242
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9619524695416187, Test_error 0.4825121790972441
# recons_mse: 0.0236
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9636243567010768, Test_error 0.45688216873813775
# recons_mse: 0.0235
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9625967683966019, Test_error 0.482271793120088
# recons_mse: 0.0228
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9653804596441101, Test_error 0.43523953331044735
# recons_mse: 0.0223
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9624452922553672, Test_error 0.46353764303852496
# recons_mse: 0.0220
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9662904896946203, Test_error 0.42357572311456526
# recons_mse: 0.0216
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9669486809277578, Test_error 0.4114558384577025
# recons_mse: 0.0217
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9653951921552553, Test_error 0.43830848004033135
# recons_mse: 0.0213
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9651150575454263, Test_error 0.43552036596791305
# recons_mse: 0.0212
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.964037326504698, Test_error 0.45118053650970336
# recons_mse: 0.0210
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9673469150797103, Test_error 0.4201753020911839
# recons_mse: 0.0211
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.970660891857452, Test_error 0.37645867711836933
# recons_mse: 0.0208
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9684950416329127, Test_error 0.39318932877136425
# recons_mse: 0.0205
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9686714114481211, Test_error 0.39134133072763677
# recons_mse: 0.0212
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9691656046244819, Test_error 0.3859282353654773
# recons_mse: 0.0209
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9706660972064838, Test_error 0.36997643312602174
# recons_mse: 0.0204
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.96999529074531, Test_error 0.3764401631671319
# recons_mse: 0.0192
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9701101170437663, Test_error 0.37710125882673945
# recons_mse: 0.0191
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9710151322546435, Test_error 0.3677732956225694
# recons_mse: 0.0193
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9704193135356469, Test_error 0.3818757259905869
# recons_mse: 0.0192
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9714421051219876, Test_error 0.3646761878517801
# recons_mse: 0.0187
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9721269736134442, Test_error 0.36084995817336196
# recons_mse: 0.0185
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.972744259088662, Test_error 0.3552383348649175
# recons_mse: 0.0181
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.5575808703156453, Test_error 2.709771272581332
# recons_mse: 0.0346
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6317761632031389, Test_error 2.2800947789461357
# recons_mse: 0.0351
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.5138014877364712, Test_error 2.6716115422944227
# recons_mse: 0.0343
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.543727658396881, Test_error 2.519506896297397
# recons_mse: 0.0344
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.5712107966060762, Test_error 2.535994802004383
# recons_mse: 0.0315
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6100070536898257, Test_error 2.346878524281433
# recons_mse: 0.0315
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6236767478733753, Test_error 2.2864175630271633
# recons_mse: 0.0316
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.625869022377741, Test_error 2.2267478660578925
# recons_mse: 0.0297
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6716564411020924, Test_error 2.076632885874752
# recons_mse: 0.0304
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.690140535574916, Test_error 2.0090899425441444
# recons_mse: 0.0301
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.710014444889131, Test_error 1.8510781514156518
# recons_mse: 0.0299
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7591737248766279, Test_error 1.6205418401753686
# recons_mse: 0.0291
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7465010402241408, Test_error 1.6880907753248064
# recons_mse: 0.0291
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7506207168223566, Test_error 1.6812311532180846
# recons_mse: 0.0291
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7503253549267148, Test_error 1.6725431606716454
# recons_mse: 0.0284
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7570390873789861, Test_error 1.6201677824725913
# recons_mse: 0.0285
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7766754781523137, Test_error 1.5296919862007377
# recons_mse: 0.0280
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7630387547038692, Test_error 1.5965454719142342
# recons_mse: 0.0278
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7771993307967484, Test_error 1.521414391083477
# recons_mse: 0.0264
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7705455189407706, Test_error 1.5457504186379258
# recons_mse: 0.0257
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.771635061764937, Test_error 1.5410833754722937
# recons_mse: 0.0243
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7761163307559145, Test_error 1.5304394719768781
# recons_mse: 0.0240
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7621658434460896, Test_error 1.5807721969716282
# recons_mse: 0.0238
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7743493924983438, Test_error 1.5209121075263736
# recons_mse: 0.0227
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7585933384719077, Test_error 1.5933838645057323
# recons_mse: 0.0234
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7823219557364451, Test_error 1.4689136717707036
# recons_mse: 0.0230
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7901392474903577, Test_error 1.4415178269909419
# recons_mse: 0.0218
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7800680153473827, Test_error 1.4779246181554937
# recons_mse: 0.0217
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8269560987550011, Test_error 1.2154314156837887
# recons_mse: 0.0214
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8304873173746449, Test_error 1.1942540874862249
# recons_mse: 0.0208
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8176420794417308, Test_error 1.246466351691592
# recons_mse: 0.0207
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8183015724029734, Test_error 1.2619762622981305
# recons_mse: 0.0204
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8084090760234688, Test_error 1.3234288069732134
# recons_mse: 0.0207
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.813240109604189, Test_error 1.2820277427472087
# recons_mse: 0.0198
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8194260763450089, Test_error 1.2480339193766916
# recons_mse: 0.0203
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8122324960513098, Test_error 1.285627939657794
# recons_mse: 0.0198
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8145909805482395, Test_error 1.270053699099676
# recons_mse: 0.0191
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8208834304721894, Test_error 1.2468387260143465
# recons_mse: 0.0185
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8266757165857521, Test_error 1.2098971681029107
# recons_mse: 0.0189
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8200211558875093, Test_error 1.2432190423644782
# recons_mse: 0.0181
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9232937912748799, Test_error 0.47817056759400595
# recons_mse: 0.0364
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8989745550402316, Test_error 0.6533550246191544
# recons_mse: 0.0342
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9045955918958124, Test_error 0.6147949332918012
# recons_mse: 0.0338
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9021259260853275, Test_error 0.614500950613328
# recons_mse: 0.0329
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8979343095020262, Test_error 0.6596164625078431
# recons_mse: 0.0324
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9063979395873022, Test_error 0.600077273668831
# recons_mse: 0.0317
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9017928822009406, Test_error 0.6239354863211686
# recons_mse: 0.0316
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8916591439013548, Test_error 0.7580100688503355
# recons_mse: 0.0290
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8886961170423111, Test_error 0.756909715271683
# recons_mse: 0.0259
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8897284946195783, Test_error 0.7297668870033595
# recons_mse: 0.0270
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8954524696518785, Test_error 0.6907090403086126
# recons_mse: 0.0262
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.903823502895382, Test_error 0.6198928535172392
# recons_mse: 0.0256
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9071825779464326, Test_error 0.5860421434918449
# recons_mse: 0.0266
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.909421783440643, Test_error 0.5618369454942496
# recons_mse: 0.0264
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9111289611330899, Test_error 0.5394599644117938
# recons_mse: 0.0255
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.914573950203665, Test_error 0.5122631297659549
# recons_mse: 0.0253
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9107972875330524, Test_error 0.5335430975092051
# recons_mse: 0.0255
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9136893528587327, Test_error 0.5068882298469769
# recons_mse: 0.0249
# ...
# recons_mse: 0.0197
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8892654187815833, Test_error 1.0815024428460998
# recons_mse: 0.0195
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8916774387732878, Test_error 1.0420275047408325
# recons_mse: 0.0189
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9011370400562326, Test_error 0.9902170006329772
# recons_mse: 0.0186
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8985672693427441, Test_error 0.9914402405957246
# recons_mse: 0.0186
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8997358660082815, Test_error 1.0040405891771285
# recons_mse: 0.0185
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8296464856600368, Test_error 1.7260702357553144
# recons_mse: 0.0385
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8203119763957373, Test_error 1.5231722650681037
# recons_mse: 0.0355
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8298521754376186, Test_error 1.4763259166720313
# recons_mse: 0.0336
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8520975448457272, Test_error 1.3800489577198858
# recons_mse: 0.0325
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.860398929014289, Test_error 1.2895966653725652
# recons_mse: 0.0320
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8500837746397034, Test_error 1.3820917369837695
# recons_mse: 0.0309
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8799608555419849, Test_error 1.1798297667734943
# recons_mse: 0.0289
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8726396887850317, Test_error 1.2712784308268663
# recons_mse: 0.0293
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8638431733199281, Test_error 1.3018892139040323
# recons_mse: 0.0276
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8748599163732306, Test_error 1.2117623778085649
# recons_mse: 0.0273
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8912898090868049, Test_error 1.0851383046854586
# recons_mse: 0.0272
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8904206583213852, Test_error 1.0760699085991228
# recons_mse: 0.0268
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9172497196469188, Test_error 0.861030604978048
# recons_mse: 0.0260
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9280459963160116, Test_error 0.7770611712752251
# recons_mse: 0.0257
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9421735553194098, Test_error 0.6639325959274411
# recons_mse: 0.0259
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9422967281527443, Test_error 0.6541412115995868
# recons_mse: 0.0246
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9471402535533467, Test_error 0.6177948625819716
# recons_mse: 0.0247
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9440714905012171, Test_error 0.65374763654757
# recons_mse: 0.0247
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9436867883490951, Test_error 0.6550225665083476
# recons_mse: 0.0237
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.945376046187844, Test_error 0.6391691779481606
# recons_mse: 0.0224
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9486133334227955, Test_error 0.6065085207986387
# recons_mse: 0.0225
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9490281293904883, Test_error 0.6017720360161989
# recons_mse: 0.0222
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9511676356603354, Test_error 0.5807475258600906
# recons_mse: 0.0220
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9528813249758247, Test_error 0.5794008562029851
# recons_mse: 0.0217
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9519721447988568, Test_error 0.5784609372295412
# recons_mse: 0.0214
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9496507687378399, Test_error 0.6030416524461825
# recons_mse: 0.0212
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9572395504749738, Test_error 0.525985736950676
# recons_mse: 0.0213
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.958547790572127, Test_error 0.5146141685279264
# recons_mse: 0.0206
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9576101247073892, Test_error 0.520746755195172
# recons_mse: 0.0202
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9617915352385854, Test_error 0.4723362166264563
# recons_mse: 0.0201
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9634352799474751, Test_error 0.4751289722897117
# recons_mse: 0.0205
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.965876652979782, Test_error 0.4612719868319783
# recons_mse: 0.0204
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9639847000900958, Test_error 0.49050270195014994
# recons_mse: 0.0198
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9652839101345931, Test_error 0.475209257481314
# recons_mse: 0.0195
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9620645308284813, Test_error 0.5082094055614205
# recons_mse: 0.0195
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9659311990920949, Test_error 0.4591049149052513
# recons_mse: 0.0193
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9640408707427068, Test_error 0.47649856594618145
# recons_mse: 0.0192
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9664533256098699, Test_error 0.4524418595595966
# recons_mse: 0.0186
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9664329264566427, Test_error 0.45579872834533475
# recons_mse: 0.0184
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9681153552039687, Test_error 0.4399510133280169
# recons_mse: 0.0179
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.6230734378748537, Test_error 2.947411988385686
# recons_mse: 0.0361
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8239586205427941, Test_error 1.6465854870719527
# recons_mse: 0.0346
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8211120425410443, Test_error 1.5874372557410472
# recons_mse: 0.0326
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8069427066745265, Test_error 1.6866300895780144
# recons_mse: 0.0309
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8394454377895523, Test_error 1.4538826907068823
# recons_mse: 0.0307
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8481346042769777, Test_error 1.3637955581535937
# recons_mse: 0.0307
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9232915341100896, Test_error 0.8474582975996934
# recons_mse: 0.0308
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9407465275618512, Test_error 0.6753217360316628
# recons_mse: 0.0280
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9453361665019575, Test_error 0.6619856389614163
# recons_mse: 0.0278
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9394368879251201, Test_error 0.7117432610245454
# recons_mse: 0.0272
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9406424534672195, Test_error 0.7085828784006399
# recons_mse: 0.0273
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9428003118180568, Test_error 0.6927755600320845
# recons_mse: 0.0286
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.945370787490291, Test_error 0.6760017070871435
# recons_mse: 0.0276
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9479035383426223, Test_error 0.6553278636251771
# recons_mse: 0.0273
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9476267428162194, Test_error 0.6573701291601395
# recons_mse: 0.0251
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9483506166681732, Test_error 0.6508086380167283
# recons_mse: 0.0254
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9515364830792151, Test_error 0.5982612282354791
# recons_mse: 0.0245
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9528577420735206, Test_error 0.5753646283302196
# recons_mse: 0.0243
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9546203147301082, Test_error 0.5617409909362228
# recons_mse: 0.0242
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.954241726767358, Test_error 0.5607609313497367
# recons_mse: 0.0251
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9523065371126592, Test_error 0.5898124721664908
# recons_mse: 0.0241
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.952612885542723, Test_error 0.5871226841617861
# recons_mse: 0.0245
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9512457094229695, Test_error 0.5917908371593733
# recons_mse: 0.0242
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9503331204389467, Test_error 0.5997431119302892
# recons_mse: 0.0238
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9514102962526036, Test_error 0.5896196177974926
# recons_mse: 0.0239
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9535334470986635, Test_error 0.5762871746134487
# recons_mse: 0.0229
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9522856990918471, Test_error 0.5930904846554883
# recons_mse: 0.0228
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9532720358951834, Test_error 0.577090646558426
# recons_mse: 0.0226
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9512338422128199, Test_error 0.5971563584421183
# recons_mse: 0.0224
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9511547506252831, Test_error 0.5976664585745003
# recons_mse: 0.0221
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9496993846739413, Test_error 0.6165823548329639
# recons_mse: 0.0216
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.949409137010919, Test_error 0.6188762225710215
# recons_mse: 0.0215
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9531693220253991, Test_error 0.5716469197092516
# recons_mse: 0.0211
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9519682008293858, Test_error 0.5818740533267099
# recons_mse: 0.0207
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9520179160369974, Test_error 0.5838771936363666
# recons_mse: 0.0198
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.953405875044054, Test_error 0.5729832300124327
# recons_mse: 0.0191
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9525641355752231, Test_error 0.5833113623303742
# recons_mse: 0.0189
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9556610010306111, Test_error 0.5476408181343206
# recons_mse: 0.0191
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9591383058820498, Test_error 0.502346839377825
# recons_mse: 0.0184
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9620749162318898, Test_error 0.4810894015376433
# recons_mse: 0.0182
# 0 55 100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.7376527638600645, Test_error 1.0681174237595819
# recons_mse: 0.0307
# 1 55 150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8601520380173099, Test_error 0.7516739243969363
# recons_mse: 0.0287
# 2 55 200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.8939435888460278, Test_error 0.6061036709810028
# recons_mse: 0.0288
# 3 55 250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.894094994426809, Test_error 0.6531235148660258
# recons_mse: 0.0292
# 4 55 300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9040366002740856, Test_error 0.637897141697165
# recons_mse: 0.0292
# 5 55 350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9024397861517104, Test_error 0.6254251785282845
# recons_mse: 0.0284
# 6 55 400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9099941841804136, Test_error 0.5628124684599677
# recons_mse: 0.0286
# 7 55 450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9130874507128761, Test_error 0.510452087350204
# recons_mse: 0.0282
# 8 55 500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9059609175562077, Test_error 0.5464353509632719
# recons_mse: 0.0285
# 9 55 550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.914077841735513, Test_error 0.49763902025992085
# recons_mse: 0.0285
# 10 55 600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9054049436741883, Test_error 0.6003260087933885
# recons_mse: 0.0278
# 11 55 650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9106062112862603, Test_error 0.5443918284702141
# recons_mse: 0.0290
# 12 55 700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9202027929045484, Test_error 0.49901402468837497
# recons_mse: 0.0284
# 13 55 750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9239406154642977, Test_error 0.49168059922382024
# recons_mse: 0.0275
# 14 55 800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9253399557666273, Test_error 0.48163994112673597
# recons_mse: 0.0262
# 15 55 850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9224049337331426, Test_error 0.4911210930439625
# recons_mse: 0.0252
# 16 55 900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9140444165692149, Test_error 0.583529062765925
# recons_mse: 0.0254
# 17 55 950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9266977591782588, Test_error 0.46777371928517236
# recons_mse: 0.0248
# 18 55 1000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9079371377698837, Test_error 0.6487927915188337
# recons_mse: 0.0245
# 19 55 1050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9310833476454133, Test_error 0.43568404821031637
# recons_mse: 0.0236
# 20 55 1100
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9302798794140248, Test_error 0.4351403374623394
# recons_mse: 0.0238
# 21 55 1150
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9303833215621169, Test_error 0.43178927145788987
# recons_mse: 0.0240
# 22 55 1200
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9289850937662645, Test_error 0.4166032165902249
# recons_mse: 0.0239
# 23 55 1250
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.932510601722246, Test_error 0.4125332419909177
# recons_mse: 0.0234
# 24 55 1300
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9245338049362255, Test_error 0.4798169756595741
# recons_mse: 0.0228
# 25 55 1350
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.930839329527892, Test_error 0.4255050692213428
# recons_mse: 0.0230
# 26 55 1400
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.931946963119228, Test_error 0.40376451610611014
# recons_mse: 0.0222
# 27 55 1450
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9302172736616313, Test_error 0.4108743788252771
# recons_mse: 0.0222
# 28 55 1500
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.939645444912518, Test_error 0.3461230273597431
# recons_mse: 0.0224
# 29 55 1550
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9321708111721037, Test_error 0.3978303378983701
# recons_mse: 0.0203
# 30 55 1600
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9396784344737608, Test_error 0.3525134538145466
# recons_mse: 0.0205
# 31 55 1650
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9390870353710917, Test_error 0.3399866133713964
# recons_mse: 0.0200
# 32 55 1700
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9391077424004098, Test_error 0.33998992070305306
# recons_mse: 0.0193
# 33 55 1750
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9401741084028559, Test_error 0.3387428214693764
# recons_mse: 0.0196
# 34 55 1800
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9420848265452272, Test_error 0.3297323609116236
# recons_mse: 0.0190
# 35 55 1850
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.941705366614848, Test_error 0.32838994308869934
# recons_mse: 0.0190
# 36 55 1900
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.941948561413786, Test_error 0.32549419328214146
# recons_mse: 0.0190
# 37 55 1950
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9408714454319242, Test_error 0.3348530441209938
# recons_mse: 0.0185
# 38 55 2000
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9399952900212835, Test_error 0.33568341616438824
# recons_mse: 0.0184
# 39 55 2050
# Dataset CO2, Algorithm BGLGBM_separate, Test_r2 0.9420592486932493, Test_error 0.3204414780100388
# recons_mse: 0.0179

# %%
import pandas as pd
#file_name = ['BET_only','BET_plut_Vt',"BET_Vmic","BET_Vmeso",'BET_Vt_Vmeso','BET_Vt_Vmic',"BET_Vt_Vmic_meso","BET_Vmic_meso"]
file_name = ['BET_plus_Vt']
cal_columns= ["CV_r2","CV_mse","test_r2_separa_model","test_mse_separa_model",'kpg_pca_mse']
tpd = []
for gas in gas_list:
    
    fraction = range(100,len(list(set(train_dfs["Index"].values)))-50,interval)
    #fraction = range(50,2125,interval)
    for k in fraction: 
        df_list = []
        for i in range(50):
            for j in range(len(feature_list)):
                files_name = 'Res_pca_The_impact_of_different_training_sample_size_of_'+str(k)+"_"+file_name[0]+'_result_'+str(i)+'.csv'
                df_list.append(pd.read_csv(os.path.join('./3_The_impact_of_different_training_sample_size',files_name))[cal_columns] )
        pd.concat(df_list).groupby(level=0).mean().to_csv(os.path.join('./3_The_impact_of_different_training_sample_size',   str(k)+'-mean.csv'))
        pd.concat(df_list).groupby(level=0).std().to_csv(os.path.join('./3_The_impact_of_different_training_sample_size',str(k)+'-std.csv'))
        tpd = df_list

# %%
tpd[0]
# Out:
#       CV_r2    CV_mse  test_r2_separa_model  test_mse_separa_model  \
# 0  0.939815  0.792283              0.951128               0.576892
# 1  0.944506  0.732007              0.938620               0.740196
#
#    kpg_pca_mse
# 0     0.018231
# 1     0.018231

# %% [markdown]
# Post-post treatment

# %%
file_path = "./3_The_impact_of_different_training_sample_size" #/Methane-25(test)-775(max training)-with-reconstruction-mse
mean_df = pd.DataFrame()
std_df = pd.DataFrame()
for i in  range(100,len(list(set(train_dfs["Index"].values)))-50,interval):
    mean_temp = pd.read_csv(os.path.join(file_path,str(i)+'-mean.csv'))
    std_temp = pd.read_csv(os.path.join(file_path,str(i)+'-std.csv'))
    mean_df = pd.concat([mean_df,mean_temp],axis = 0)
    std_df = pd.concat([std_df,std_temp],axis = 0)
mean_df.to_csv(os.path.join(file_path,"Total_mean.csv"))
std_df.to_csv(os.path.join(file_path,"Total_std.csv"))

# %% [markdown]
# Only calculating the reconstruction error

# %%
import os
base_feature = ['V','S','L','BET',]
condition_feature = ['Temp(K)','Pressure']
combin_1 = ['Vt']
combin_2 = ["Vmeso"]
combin_3 = ['Vmic']
combin_4 = ['Vt',"Vmeso",]
combin_3 = ['Vt',"Vmic",] 
combin_5 = ['Vt',"Vmic",'Vmeso',]
combin_6 = ["Vmic",'Vmeso',]
feature_list = [base_feature+combin_1+condition_feature]
columns = ['Gas','Model_name','CV_r2','CV_mse','test_r2_total_model','test_mse_by_total_model','test_r2_separa_model','test_mse_separa_model','best_param','kpg_pca_mse']
#file_name = ['Total',"Meso","Micro",'All','Vmic_meso']
file_name = ['BET_plus_Vt']
feature_set = ["Vt",]
gas_list = ['CO2']

for i in range(15):
    recons_error = []
    train_index = []
    train_dfs,test_df = pred_dataset(gas_list,feature_set)#
    nums_test = len(list(set(test_df["Index"].values)))
    
    index = list(set(train_dfs['Index'].values))
    fraction = range(100,len(list(set(train_dfs["Index"].values))),50)
    for k in range(len(fraction)):
        print(k)
        
        #k = 50
        selected_index = np.random.choice(index,50,replace=False)
        
        for ele in selected_index:
            index.remove(ele)
        train_index.extend(selected_index) 
        print(k, len(train_index))
        train_df = temp_df.loc[temp_df['Index'].isin(train_index)]
        k_recon_mse = bgk_pca(train_df,test_df)
        recons_error.append(k_recon_mse)
        files_name = 'Res_pca_The_impact_of_different_training_sample_size_of_'+str(50*k)+"_"+file_name[0]+'_result_'+str(i)+'.csv'
        pd.DataFrame(recons_error).to_csv(os.path.join('./3_The_impact_of_different_training_sample_size',files_name))
# Out:
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000
# 2145
# 0
# 0 50
# 1
# 1 100
# 2
# 2 150
# 3
# 3 200
# 4
# 4 250
# 5
# 5 300
# 6
# 6 350
# 7
# 7 400
# 8
# 8 450
# 9
# 9 500
# 10
# 10 550
# 11
# 11 600
# 12
# 12 650
# 13
# 13 700
# 14
# 14 750
# 15
# 15 800
# 16
# 16 850
# 17
# 17 900
# 18
# 18 950
# 19
# 19 1000
# 20
# 20 1050
# 21
# 21 1100
# 22
# 22 1150
# 23
# 23 1200
# 24
# 24 1250
# 25
# 25 1300
# 26
# 26 1350
# 27
# 27 1400
# 28
# 28 1450
# 29
# 29 1500
# 30
# 30 1550
# 31
# 31 1600
# 32
# 32 1650
# 33
# 33 1700
# 34
# 34 1750
# 35
# 35 1800
# 36
# 36 1850
# 37
# 37 1900
# 38
# 38 1950
# 39
# 39 2000

# %%
len(range(2))
# Out:
# 2
